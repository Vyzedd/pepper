# %%
import os # Handle OS file systems and directory paths
import random # Random number
import numpy as np # Import NumPy for arrays and such
import matplotlib.pyplot as plt # Plotting Tools
import numpy.linalg as npl # Linear Algebra Library
import time # Time
# from google.colab import drive # Read files in from Google Drive
import pandas as pd # Import Pandas for data processing
import datetime as dt
import scipy.io as sio
import io
from decimal import Decimal # String to double conversion
from glob import glob  # 从 glob 模块中导入 glob 函数

# %%
import boto3
from botocore.exceptions import NoCredentialsError

# %%
# Optionally, you can specify the AWS region
s3 = boto3.client('s3', region_name='us-east-1')  # Replace 'us-west-2' with your AWS region

# %%
import pandas as pd
# s3_uri = 's3://pepper-dataset/crop_data/crop_IOWA/Iowa_corn_2019.csv'
# df = pd.read_csv(s3_uri)

#Read files from s3
bucket_name = 'pepper-dataset'
prefix = 'county-env-data/county_env_NetCDF4/'

# %%
# Helper Functions
def get_time_now_ms():
    """Returns the current time in milliseconds"""
    ts = time.time()
    ts = round(ts) * 1000
    return int(ts)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (3.9.2)
# Requirement already satisfied: absl-py in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras) (2.2.2)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras) (0.15.0)
# Requirement already satisfied: ml-dtypes in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras) (0.3.2)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from keras) (24.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from optree->keras) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import tensorflow as tf
from keras.layers import Input, Dense, LSTM, MaxPooling1D, Conv1D
from keras.models import Model
import keras
from keras.layers import Dense, TimeDistributed
from keras.models import Sequential
# from keras.utils import to_categorical
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping
# from keras.utils import np_utils
import itertools

from keras.layers import LSTM, RepeatVector
# from keras.layers.convolutional import Conv1D,Conv2D
# from keras.layers.convolutional import MaxPooling1D,MaxPooling2D
from keras.layers import Dropout, Flatten
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from numpy import dstack,  hstack
import scipy.io as sio
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from sklearn.model_selection import train_test_split


# data_mat = "/content/drive/MyDrive/ai/era5/yield_Iowa_corn_noIrr.mat" #Name of File, may need to specify path
# data_dict = sio.loadmat(data_mat) #Load MAT as a python dictionary
# print(data_dict)
# Out:
# 2025-05-18 18:30:58.188821: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-18 18:30:58.214006: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-18 18:30:58.214048: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-18 18:30:58.229739: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-18 18:30:59.208923: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# data_feature = data_dict['feature'] #Extract Features
# data_feature = feat_arr
data_feature = pd.read_csv('s3://'+bucket_name+ '/new_ARKANSAS_data_feature_expanded_SOYBEAN.csv')

# print('Data Feature Shape:',data_feature.shape) # Verify Shape
# print("feature len: ", len(data_feature[0][0]))
# data_label = data_dict['label'] #Extract Labels
# data_label = label
data_label = pd.read_csv('s3://'+bucket_name+ '/new_ARKANSAS_data_label_expanded_SOYBEAN.csv')
# print('Data Label Shape:',data_label.shape) # Verify Shape

# print(data_label)
# c1 = ["dewpoint_temperature_2m", "temperature_2m", "soil_temperature_level_1","soil_temperature_level_2"
#       ,"soil_temperature_level_3","soil_temperature_level_4","snowfall","volumetric_soil_water_layer_1",
#       "volumetric_soil_water_layer_2","volumetric_soil_water_layer_3","volumetric_soil_water_layer_4",
#       "surface_net_solar_radiation","surface_net_solar_radiation1",
#       "total_evaporation","surface_pressure","total_precipitation"]

# c = ["dewpoint_temperature_2m", "temperature_2m", "soil_temperature_level_1","soil_temperature_level_2"
#                              ,"soil_temperature_level_3","soil_temperature_level_4","snowfall","volumetric_soil_water_layer_1",
#                               "volumetric_soil_water_layer_2","volumetric_soil_water_layer_3","volumetric_soil_water_layer_4",
#                               "surface_net_solar_radiation","surface_net_solar_radiation1",
#                               "total_evaporation","surface_pressure","total_precipitation"]*288



# 假设 data_feature 是一个 1*467 的 DataFrame，每个单元格是一个长度为 175200 的序列
# 构造一个示例 DataFrame（实际使用中应替换为你的 data_feature）
# data_feature = pd.DataFrame([[np.random.rand(175200) for _ in range(467)]])

# 将 DataFrame 转置
# data_feature_transposed = data_feature.T

# print("data_feature_transposed[0].tolist(): ", len(data_feature_transposed[0][0]))
# 展开每个单元格中的序列
# data_feature_expanded = pd.DataFrame(data_feature_transposed[0][0].tolist())

# 检查转换后的 DataFrame 形状
# print("Original shape:", data_feature.shape)
# print("Transformed shape:", data_feature_expanded.shape)


train_X = data_feature
train_y = data_label.T

train_X = np.nan_to_num(train_X)
train_y = np.nan_to_num(train_y)

print(train_X.shape)
print(train_y.shape)

x = np.asarray(train_X, dtype=np.float32)
y = np.asarray(train_y).flatten()

# Training/Validation split 67%, 33% split
data_feature, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
print(X_test.shape)
print(data_feature.shape)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/fsspec/registry.py:286: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# (83, 87312)
# (1, 83)
# (28, 87312)
# (55, 87312)

# %%
print(data_feature.shape)
print(data_label.shape)
# Out:
# (55, 87312)
# (83, 1)

# %%
def dataReshape(dataIn,debug=True,runOnce=False):
  """Takes the 1D feature array and reshapes to 270x16"""
  print(dataIn.shape)

  dataOut = []
  for idx in range(len(dataIn)):
    dataTemp = dataIn[idx].reshape(5457, 16) #(216,15) 3240
    if debug: print(dataTemp.shape)
    dataOut.append(dataTemp)

    if runOnce: return -1

  return np.array(dataOut)

data_feature_rs = dataReshape(data_feature,debug=False,runOnce=False)
print(data_feature_rs.shape)

#Reshape test
X_test = dataReshape(X_test,debug=False,runOnce=False)
print(X_test.shape)
# Out:
# (55, 87312)
# (55, 5457, 16)
# (28, 87312)
# (28, 5457, 16)

# %%
# Network Parameters
BATCH_SIZE = 32
NUM_EPOCHS = 200
SHUFFLE_BUFFER_SIZE = 64

# Normalize Data
normalizer = Normalization(axis=-1)
normalizer.adapt(data_feature_rs)
data_feature_norm = normalizer(data_feature_rs)

# Normalize Test
normalizer = Normalization(axis=-1)
normalizer.adapt(X_test)
X_test_norm = normalizer(X_test)


# Split into train and test datasets
# Load the Data into a data loader
train_dataset = tf.data.Dataset.from_tensor_slices((data_feature_norm,y_train.T))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test_norm,y_test.T)) #TODO: REPLACE WITH TEST DATASET
DATASET_SIZE = len(data_feature_norm)

# Shuffle & Batch the Datasets
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
# Out:
# 2025-05-18 18:31:37.287147: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
def step_decay(epoch):
   initial_lrate = 0.1
   drop = 0.5
   epochs_drop = 10.0
   lrate = initial_lrate * math.pow(drop,
           math.floor((1+epoch)/epochs_drop))
   return lrate

# %%
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, Add

def residual_block(input_tensor, filters, kernel_size=2):
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    
    # Add the input tensor back to the output
    x = Add()([x, input_tensor])
    x = Activation('relu')(x)
    return x

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, MaxPooling1D, concatenate
from tensorflow.keras.models import Model

# Input layer
visible = Input(shape=(5457, 16))

# First ResNet Pathway
cnn1 = Conv1D(filters=80, kernel_size=2, padding='same', activation='relu')(visible)
cnn1 = residual_block(cnn1, 80)
cnn1 = MaxPooling1D(pool_size=128)(cnn1)

# Second ResNet Pathway
cnn2 = Conv1D(filters=64, kernel_size=2, padding='same', activation='relu')(visible)
cnn2 = residual_block(cnn2, 64)
cnn2 = MaxPooling1D(pool_size=128)(cnn2)

# Third ResNet Pathway
cnn3 = Conv1D(filters=32, kernel_size=2, padding='same', activation='relu')(visible)
cnn3 = residual_block(cnn3, 32)
cnn3 = MaxPooling1D(pool_size=128)(cnn3)

# Fourth ResNet Pathway
cnn4 = Conv1D(filters=16, kernel_size=2, padding='same', activation='relu')(visible)
cnn4 = residual_block(cnn4, 16)
cnn4 = MaxPooling1D(pool_size=128)(cnn4)

# Concatenate the outputs from all paths
merged = concatenate([cnn1, cnn2, cnn3, cnn4], axis=2)

# Fully connected layer after concatenation
cnn = Dense(16)(merged)

# Flatten the output
cnn = Flatten()(cnn)

# Output layer
output1 = Dense(1, activation='linear')(cnn)

# Define the model
model = Model(inputs=visible, outputs=output1)

model.compile(optimizer='adam', loss='mse', metrics =['accuracy','mean_squared_error','mean_absolute_percentage_error',tf.keras.metrics.RootMeanSquaredError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5457, 16)]           0         []
#
#  conv1d (Conv1D)             (None, 5457, 80)             2640      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 5457, 64)             2112      ['input_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 5457, 32)             1056      ['input_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 5457, 16)             528       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 5457, 80)             12880     ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 5457, 64)             8256      ['conv1d_3[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5457, 32)             2080      ['conv1d_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 5457, 16)             528       ['conv1d_9[0][0]']
#
#  batch_normalization (Batch  (None, 5457, 80)             320       ['conv1d_1[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 5457, 64)             256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 5457, 32)             128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 5457, 16)             64        ['conv1d_10[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 5457, 80)             0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 5457, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 5457, 32)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 5457, 16)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 5457, 80)             12880     ['activation[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5457, 64)             8256      ['activation_2[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 5457, 32)             2080      ['activation_4[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 5457, 16)             528       ['activation_6[0][0]']
#
#  batch_normalization_1 (Bat  (None, 5457, 80)             320       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 5457, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 5457, 32)             128       ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 5457, 16)             64        ['conv1d_11[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 5457, 80)             0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv1d[0][0]']
#
#  add_1 (Add)                 (None, 5457, 64)             0         ['batch_normalization_3[0][0]'
#                                                                     , 'conv1d_3[0][0]']
#
#  add_2 (Add)                 (None, 5457, 32)             0         ['batch_normalization_5[0][0]'
#                                                                     , 'conv1d_6[0][0]']
#
#  add_3 (Add)                 (None, 5457, 16)             0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv1d_9[0][0]']
#
#  activation_1 (Activation)   (None, 5457, 80)             0         ['add[0][0]']
#
#  activation_3 (Activation)   (None, 5457, 64)             0         ['add_1[0][0]']
#
#  activation_5 (Activation)   (None, 5457, 32)             0         ['add_2[0][0]']
#
#  activation_7 (Activation)   (None, 5457, 16)             0         ['add_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 42, 80)               0         ['activation_1[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 42, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 42, 32)               0         ['activation_5[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 42, 16)               0         ['activation_7[0][0]']
#  g1D)
#
#  concatenate (Concatenate)   (None, 42, 192)              0         ['max_pooling1d[0][0]',
#                                                                      'max_pooling1d_1[0][0]',
#                                                                      'max_pooling1d_2[0][0]',
#                                                                      'max_pooling1d_3[0][0]']
#
#  dense (Dense)               (None, 42, 16)               3088      ['concatenate[0][0]']
#
#  flatten (Flatten)           (None, 672)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    673       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 59121 (230.94 KB)
# Trainable params: 58353 (227.94 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________

# %%
# FIT model with TRAINING DATA
history = model.fit(train_dataset, validation_data=test_dataset,epochs=NUM_EPOCHS,verbose=2)
model.summary()

# EVALUATE model with TESTING DATA
model.evaluate(test_dataset, verbose=0)

ynew = model.predict(test_dataset)
print(f'Test Loss: {ynew[0]}')
print(f'Test Mean Squared Error: {ynew[1]}')
print(f'Test Mean Absolute Percentage Error: {ynew[2]}')
print(f'Test Root Mean Squared Error: {ynew[3]}')

fig, ax = plt.subplots()
ax.set_title('Training and Validation \n Mean Absolute Percentage Error') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['mean_absolute_percentage_error'], color = 'blue', label = 'train')

# plt.title('Validation Mean Absolute Percentage Error (MAPE)') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['val_mean_absolute_percentage_error'], color = 'orange', label = 'val')
ax.legend()
# Out:
# Epoch 1/200
# 2/2 - 26s - loss: 1781.5276 - accuracy: 0.0000e+00 - mean_squared_error: 1781.5276 - mean_absolute_percentage_error: 103.3236 - root_mean_squared_error: 42.2081 - val_loss: 1359.1453 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1359.1453 - val_mean_absolute_percentage_error: 93.7697 - val_root_mean_squared_error: 36.8666 - 26s/epoch - 13s/step
# Epoch 2/200
# 2/2 - 2s - loss: 744.8967 - accuracy: 0.0000e+00 - mean_squared_error: 744.8967 - mean_absolute_percentage_error: 63.5026 - root_mean_squared_error: 27.2928 - val_loss: 1110.6720 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1110.6720 - val_mean_absolute_percentage_error: 83.9954 - val_root_mean_squared_error: 33.3267 - 2s/epoch - 841ms/step
# Epoch 3/200
# 2/2 - 2s - loss: 235.3863 - accuracy: 0.0000e+00 - mean_squared_error: 235.3863 - mean_absolute_percentage_error: 30.5181 - root_mean_squared_error: 15.3423 - val_loss: 907.3488 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 907.3488 - val_mean_absolute_percentage_error: 75.1026 - val_root_mean_squared_error: 30.1222 - 2s/epoch - 960ms/step
# Epoch 4/200
# 2/2 - 2s - loss: 67.3430 - accuracy: 0.0000e+00 - mean_squared_error: 67.3430 - mean_absolute_percentage_error: 15.9017 - root_mean_squared_error: 8.2063 - val_loss: 750.3241 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 750.3241 - val_mean_absolute_percentage_error: 67.4789 - val_root_mean_squared_error: 27.3920 - 2s/epoch - 951ms/step
# Epoch 5/200
# 2/2 - 2s - loss: 90.0341 - accuracy: 0.0000e+00 - mean_squared_error: 90.0341 - mean_absolute_percentage_error: 22.8746 - root_mean_squared_error: 9.4886 - val_loss: 656.8146 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 656.8146 - val_mean_absolute_percentage_error: 62.5290 - val_root_mean_squared_error: 25.6284 - 2s/epoch - 754ms/step
# Epoch 6/200
# 2/2 - 2s - loss: 86.4196 - accuracy: 0.0000e+00 - mean_squared_error: 86.4196 - mean_absolute_percentage_error: 22.1996 - root_mean_squared_error: 9.2962 - val_loss: 619.9238 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 619.9238 - val_mean_absolute_percentage_error: 60.4744 - val_root_mean_squared_error: 24.8983 - 2s/epoch - 922ms/step
# Epoch 7/200
# 2/2 - 2s - loss: 60.0776 - accuracy: 0.0000e+00 - mean_squared_error: 60.0776 - mean_absolute_percentage_error: 16.9097 - root_mean_squared_error: 7.7510 - val_loss: 604.4629 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 604.4629 - val_mean_absolute_percentage_error: 59.5881 - val_root_mean_squared_error: 24.5858 - 2s/epoch - 877ms/step
# Epoch 8/200
# 2/2 - 2s - loss: 59.4421 - accuracy: 0.0000e+00 - mean_squared_error: 59.4421 - mean_absolute_percentage_error: 14.9686 - root_mean_squared_error: 7.7099 - val_loss: 586.4078 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 586.4078 - val_mean_absolute_percentage_error: 58.5401 - val_root_mean_squared_error: 24.2159 - 2s/epoch - 883ms/step
# Epoch 9/200
# 2/2 - 2s - loss: 64.6705 - accuracy: 0.0000e+00 - mean_squared_error: 64.6705 - mean_absolute_percentage_error: 14.8917 - root_mean_squared_error: 8.0418 - val_loss: 555.7631 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 555.7631 - val_mean_absolute_percentage_error: 56.7259 - val_root_mean_squared_error: 23.5746 - 2s/epoch - 1s/step
# Epoch 10/200
# 2/2 - 2s - loss: 59.6369 - accuracy: 0.0000e+00 - mean_squared_error: 59.6369 - mean_absolute_percentage_error: 14.9356 - root_mean_squared_error: 7.7225 - val_loss: 517.4294 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 517.4294 - val_mean_absolute_percentage_error: 54.3748 - val_root_mean_squared_error: 22.7471 - 2s/epoch - 888ms/step
# Epoch 11/200
# 2/2 - 2s - loss: 53.5665 - accuracy: 0.0000e+00 - mean_squared_error: 53.5665 - mean_absolute_percentage_error: 15.0785 - root_mean_squared_error: 7.3189 - val_loss: 483.7206 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 483.7206 - val_mean_absolute_percentage_error: 52.2264 - val_root_mean_squared_error: 21.9937 - 2s/epoch - 907ms/step
# Epoch 12/200
# 2/2 - 2s - loss: 57.6775 - accuracy: 0.0000e+00 - mean_squared_error: 57.6775 - mean_absolute_percentage_error: 16.8814 - root_mean_squared_error: 7.5946 - val_loss: 458.3171 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 458.3171 - val_mean_absolute_percentage_error: 50.5510 - val_root_mean_squared_error: 21.4083 - 2s/epoch - 821ms/step
# Epoch 13/200
# 2/2 - 2s - loss: 58.9825 - accuracy: 0.0000e+00 - mean_squared_error: 58.9825 - mean_absolute_percentage_error: 17.2367 - root_mean_squared_error: 7.6800 - val_loss: 453.9221 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 453.9221 - val_mean_absolute_percentage_error: 50.2568 - val_root_mean_squared_error: 21.3054 - 2s/epoch - 903ms/step
# Epoch 14/200
# 2/2 - 1s - loss: 56.0818 - accuracy: 0.0000e+00 - mean_squared_error: 56.0818 - mean_absolute_percentage_error: 16.1123 - root_mean_squared_error: 7.4888 - val_loss: 456.6637 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 456.6637 - val_mean_absolute_percentage_error: 50.4414 - val_root_mean_squared_error: 21.3697 - 1s/epoch - 744ms/step
# Epoch 15/200
# 2/2 - 2s - loss: 53.2838 - accuracy: 0.0000e+00 - mean_squared_error: 53.2838 - mean_absolute_percentage_error: 14.9717 - root_mean_squared_error: 7.2996 - val_loss: 456.7417 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 456.7417 - val_mean_absolute_percentage_error: 50.4467 - val_root_mean_squared_error: 21.3715 - 2s/epoch - 985ms/step
# Epoch 16/200
# 2/2 - 2s - loss: 52.9554 - accuracy: 0.0000e+00 - mean_squared_error: 52.9554 - mean_absolute_percentage_error: 14.6070 - root_mean_squared_error: 7.2770 - val_loss: 450.2091 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 450.2091 - val_mean_absolute_percentage_error: 50.0080 - val_root_mean_squared_error: 21.2181 - 2s/epoch - 941ms/step
# Epoch 17/200
# 2/2 - 2s - loss: 52.1831 - accuracy: 0.0000e+00 - mean_squared_error: 52.1831 - mean_absolute_percentage_error: 14.5620 - root_mean_squared_error: 7.2238 - val_loss: 437.8633 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 437.8633 - val_mean_absolute_percentage_error: 49.1692 - val_root_mean_squared_error: 20.9252 - 2s/epoch - 1s/step
# Epoch 18/200
# 2/2 - 2s - loss: 51.4309 - accuracy: 0.0000e+00 - mean_squared_error: 51.4309 - mean_absolute_percentage_error: 14.8752 - root_mean_squared_error: 7.1715 - val_loss: 424.3883 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 424.3883 - val_mean_absolute_percentage_error: 48.2381 - val_root_mean_squared_error: 20.6007 - 2s/epoch - 956ms/step
# Epoch 19/200
# 2/2 - 2s - loss: 50.8423 - accuracy: 0.0000e+00 - mean_squared_error: 50.8423 - mean_absolute_percentage_error: 14.9939 - root_mean_squared_error: 7.1304 - val_loss: 417.5812 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 417.5812 - val_mean_absolute_percentage_error: 47.7622 - val_root_mean_squared_error: 20.4348 - 2s/epoch - 1s/step
# Epoch 20/200
# 2/2 - 2s - loss: 50.0450 - accuracy: 0.0000e+00 - mean_squared_error: 50.0450 - mean_absolute_percentage_error: 14.8798 - root_mean_squared_error: 7.0743 - val_loss: 417.3543 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 417.3543 - val_mean_absolute_percentage_error: 47.7488 - val_root_mean_squared_error: 20.4293 - 2s/epoch - 993ms/step
# Epoch 21/200
# 2/2 - 2s - loss: 49.3995 - accuracy: 0.0000e+00 - mean_squared_error: 49.3995 - mean_absolute_percentage_error: 14.5854 - root_mean_squared_error: 7.0285 - val_loss: 417.0562 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 417.0562 - val_mean_absolute_percentage_error: 47.7313 - val_root_mean_squared_error: 20.4220 - 2s/epoch - 1s/step
# Epoch 22/200
# 2/2 - 2s - loss: 48.7939 - accuracy: 0.0000e+00 - mean_squared_error: 48.7939 - mean_absolute_percentage_error: 14.2333 - root_mean_squared_error: 6.9853 - val_loss: 419.5794 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 419.5794 - val_mean_absolute_percentage_error: 47.9143 - val_root_mean_squared_error: 20.4836 - 2s/epoch - 983ms/step
# Epoch 23/200
# 2/2 - 2s - loss: 48.6138 - accuracy: 0.0000e+00 - mean_squared_error: 48.6138 - mean_absolute_percentage_error: 13.9821 - root_mean_squared_error: 6.9724 - val_loss: 414.1693 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 414.1693 - val_mean_absolute_percentage_error: 47.5366 - val_root_mean_squared_error: 20.3511 - 2s/epoch - 894ms/step
# Epoch 24/200
# 2/2 - 2s - loss: 47.0974 - accuracy: 0.0000e+00 - mean_squared_error: 47.0974 - mean_absolute_percentage_error: 13.9530 - root_mean_squared_error: 6.8628 - val_loss: 401.7283 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 401.7283 - val_mean_absolute_percentage_error: 46.6496 - val_root_mean_squared_error: 20.0432 - 2s/epoch - 899ms/step
# Epoch 25/200
# 2/2 - 2s - loss: 46.6073 - accuracy: 0.0000e+00 - mean_squared_error: 46.6073 - mean_absolute_percentage_error: 14.2719 - root_mean_squared_error: 6.8270 - val_loss: 393.6219 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 393.6219 - val_mean_absolute_percentage_error: 46.0638 - val_root_mean_squared_error: 19.8399 - 2s/epoch - 768ms/step
# Epoch 26/200
# 2/2 - 2s - loss: 46.7443 - accuracy: 0.0000e+00 - mean_squared_error: 46.7443 - mean_absolute_percentage_error: 14.5585 - root_mean_squared_error: 6.8370 - val_loss: 394.7596 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 394.7596 - val_mean_absolute_percentage_error: 46.1508 - val_root_mean_squared_error: 19.8686 - 2s/epoch - 870ms/step
# Epoch 27/200
# 2/2 - 2s - loss: 45.3263 - accuracy: 0.0000e+00 - mean_squared_error: 45.3263 - mean_absolute_percentage_error: 14.0833 - root_mean_squared_error: 6.7325 - val_loss: 397.7754 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 397.7754 - val_mean_absolute_percentage_error: 46.3753 - val_root_mean_squared_error: 19.9443 - 2s/epoch - 965ms/step
# Epoch 28/200
# 2/2 - 2s - loss: 44.3429 - accuracy: 0.0000e+00 - mean_squared_error: 44.3429 - mean_absolute_percentage_error: 13.6934 - root_mean_squared_error: 6.6590 - val_loss: 398.1658 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 398.1658 - val_mean_absolute_percentage_error: 46.4091 - val_root_mean_squared_error: 19.9541 - 2s/epoch - 1s/step
# Epoch 29/200
# 2/2 - 2s - loss: 43.7640 - accuracy: 0.0000e+00 - mean_squared_error: 43.7640 - mean_absolute_percentage_error: 13.5900 - root_mean_squared_error: 6.6154 - val_loss: 396.2014 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 396.2014 - val_mean_absolute_percentage_error: 46.2724 - val_root_mean_squared_error: 19.9048 - 2s/epoch - 866ms/step
# Epoch 30/200
# 2/2 - 2s - loss: 43.1844 - accuracy: 0.0000e+00 - mean_squared_error: 43.1844 - mean_absolute_percentage_error: 13.5595 - root_mean_squared_error: 6.5715 - val_loss: 395.9348 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 395.9348 - val_mean_absolute_percentage_error: 46.2579 - val_root_mean_squared_error: 19.8981 - 2s/epoch - 846ms/step
# Epoch 31/200
# 2/2 - 2s - loss: 41.7269 - accuracy: 0.0000e+00 - mean_squared_error: 41.7269 - mean_absolute_percentage_error: 13.1830 - root_mean_squared_error: 6.4596 - val_loss: 398.5302 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 398.5302 - val_mean_absolute_percentage_error: 46.4510 - val_root_mean_squared_error: 19.9632 - 2s/epoch - 776ms/step
# Epoch 32/200
# 2/2 - 2s - loss: 41.2762 - accuracy: 0.0000e+00 - mean_squared_error: 41.2762 - mean_absolute_percentage_error: 12.9706 - root_mean_squared_error: 6.4247 - val_loss: 395.9453 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 395.9453 - val_mean_absolute_percentage_error: 46.2683 - val_root_mean_squared_error: 19.8984 - 2s/epoch - 757ms/step
# Epoch 33/200
# 2/2 - 2s - loss: 40.2397 - accuracy: 0.0000e+00 - mean_squared_error: 40.2397 - mean_absolute_percentage_error: 12.9399 - root_mean_squared_error: 6.3435 - val_loss: 390.0931 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 390.0931 - val_mean_absolute_percentage_error: 45.8466 - val_root_mean_squared_error: 19.7508 - 2s/epoch - 793ms/step
# Epoch 34/200
# 2/2 - 2s - loss: 39.9406 - accuracy: 0.0000e+00 - mean_squared_error: 39.9406 - mean_absolute_percentage_error: 13.1296 - root_mean_squared_error: 6.3199 - val_loss: 386.0922 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 386.0922 - val_mean_absolute_percentage_error: 45.5581 - val_root_mean_squared_error: 19.6492 - 2s/epoch - 907ms/step
# Epoch 35/200
# 2/2 - 2s - loss: 38.6458 - accuracy: 0.0000e+00 - mean_squared_error: 38.6458 - mean_absolute_percentage_error: 12.9001 - root_mean_squared_error: 6.2166 - val_loss: 389.8062 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 389.8062 - val_mean_absolute_percentage_error: 45.8397 - val_root_mean_squared_error: 19.7435 - 2s/epoch - 930ms/step
# Epoch 36/200
# 2/2 - 2s - loss: 38.1803 - accuracy: 0.0000e+00 - mean_squared_error: 38.1803 - mean_absolute_percentage_error: 12.6471 - root_mean_squared_error: 6.1790 - val_loss: 389.2882 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 389.2882 - val_mean_absolute_percentage_error: 45.8093 - val_root_mean_squared_error: 19.7304 - 2s/epoch - 1s/step
# Epoch 37/200
# 2/2 - 2s - loss: 36.9075 - accuracy: 0.0000e+00 - mean_squared_error: 36.9075 - mean_absolute_percentage_error: 12.3076 - root_mean_squared_error: 6.0752 - val_loss: 389.6651 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 389.6651 - val_mean_absolute_percentage_error: 45.8448 - val_root_mean_squared_error: 19.7399 - 2s/epoch - 880ms/step
# Epoch 38/200
# 2/2 - 3s - loss: 36.1211 - accuracy: 0.0000e+00 - mean_squared_error: 36.1211 - mean_absolute_percentage_error: 12.2242 - root_mean_squared_error: 6.0101 - val_loss: 383.8911 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 383.8911 - val_mean_absolute_percentage_error: 45.4266 - val_root_mean_squared_error: 19.5931 - 3s/epoch - 1s/step
# Epoch 39/200
# 2/2 - 3s - loss: 34.9239 - accuracy: 0.0000e+00 - mean_squared_error: 34.9239 - mean_absolute_percentage_error: 12.1679 - root_mean_squared_error: 5.9096 - val_loss: 379.9907 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 379.9907 - val_mean_absolute_percentage_error: 45.1450 - val_root_mean_squared_error: 19.4933 - 3s/epoch - 1s/step
# Epoch 40/200
# 2/2 - 2s - loss: 34.2923 - accuracy: 0.0000e+00 - mean_squared_error: 34.2923 - mean_absolute_percentage_error: 12.1922 - root_mean_squared_error: 5.8560 - val_loss: 377.1516 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 377.1516 - val_mean_absolute_percentage_error: 44.9394 - val_root_mean_squared_error: 19.4204 - 2s/epoch - 1s/step
# Epoch 41/200
# 2/2 - 2s - loss: 33.3643 - accuracy: 0.0000e+00 - mean_squared_error: 33.3643 - mean_absolute_percentage_error: 11.9413 - root_mean_squared_error: 5.7762 - val_loss: 377.3146 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 377.3146 - val_mean_absolute_percentage_error: 44.9589 - val_root_mean_squared_error: 19.4246 - 2s/epoch - 997ms/step
# Epoch 42/200
# 2/2 - 2s - loss: 32.7778 - accuracy: 0.0000e+00 - mean_squared_error: 32.7778 - mean_absolute_percentage_error: 11.5308 - root_mean_squared_error: 5.7252 - val_loss: 375.9489 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 375.9489 - val_mean_absolute_percentage_error: 44.8646 - val_root_mean_squared_error: 19.3894 - 2s/epoch - 825ms/step
# Epoch 43/200
# 2/2 - 2s - loss: 31.8477 - accuracy: 0.0000e+00 - mean_squared_error: 31.8477 - mean_absolute_percentage_error: 11.4014 - root_mean_squared_error: 5.6434 - val_loss: 369.1161 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 369.1161 - val_mean_absolute_percentage_error: 44.3587 - val_root_mean_squared_error: 19.2124 - 2s/epoch - 892ms/step
# Epoch 44/200
# 2/2 - 2s - loss: 31.4323 - accuracy: 0.0000e+00 - mean_squared_error: 31.4323 - mean_absolute_percentage_error: 11.6561 - root_mean_squared_error: 5.6065 - val_loss: 364.5786 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 364.5786 - val_mean_absolute_percentage_error: 44.0233 - val_root_mean_squared_error: 19.0939 - 2s/epoch - 795ms/step
# Epoch 45/200
# 2/2 - 2s - loss: 30.6169 - accuracy: 0.0000e+00 - mean_squared_error: 30.6169 - mean_absolute_percentage_error: 11.6243 - root_mean_squared_error: 5.5333 - val_loss: 362.1186 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 362.1186 - val_mean_absolute_percentage_error: 43.8443 - val_root_mean_squared_error: 19.0294 - 2s/epoch - 836ms/step
# Epoch 46/200
# 2/2 - 1s - loss: 29.5989 - accuracy: 0.0000e+00 - mean_squared_error: 29.5989 - mean_absolute_percentage_error: 11.3212 - root_mean_squared_error: 5.4405 - val_loss: 364.1098 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 364.1098 - val_mean_absolute_percentage_error: 44.0035 - val_root_mean_squared_error: 19.0817 - 1s/epoch - 692ms/step
# Epoch 47/200
# 2/2 - 2s - loss: 29.2017 - accuracy: 0.0000e+00 - mean_squared_error: 29.2017 - mean_absolute_percentage_error: 10.8439 - root_mean_squared_error: 5.4039 - val_loss: 364.3740 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 364.3740 - val_mean_absolute_percentage_error: 44.0318 - val_root_mean_squared_error: 19.0886 - 2s/epoch - 967ms/step
# Epoch 48/200
# 2/2 - 2s - loss: 28.4883 - accuracy: 0.0000e+00 - mean_squared_error: 28.4883 - mean_absolute_percentage_error: 10.7013 - root_mean_squared_error: 5.3374 - val_loss: 358.2148 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 358.2148 - val_mean_absolute_percentage_error: 43.5679 - val_root_mean_squared_error: 18.9266 - 2s/epoch - 835ms/step
# Epoch 49/200
# 2/2 - 2s - loss: 27.7916 - accuracy: 0.0000e+00 - mean_squared_error: 27.7916 - mean_absolute_percentage_error: 10.9077 - root_mean_squared_error: 5.2718 - val_loss: 353.8983 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 353.8983 - val_mean_absolute_percentage_error: 43.2432 - val_root_mean_squared_error: 18.8122 - 2s/epoch - 913ms/step
# Epoch 50/200
# 2/2 - 2s - loss: 27.2311 - accuracy: 0.0000e+00 - mean_squared_error: 27.2311 - mean_absolute_percentage_error: 10.9232 - root_mean_squared_error: 5.2183 - val_loss: 355.3518 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 355.3518 - val_mean_absolute_percentage_error: 43.3645 - val_root_mean_squared_error: 18.8508 - 2s/epoch - 1s/step
# Epoch 51/200
# 2/2 - 2s - loss: 26.3310 - accuracy: 0.0000e+00 - mean_squared_error: 26.3310 - mean_absolute_percentage_error: 10.3405 - root_mean_squared_error: 5.1314 - val_loss: 357.2385 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 357.2385 - val_mean_absolute_percentage_error: 43.5192 - val_root_mean_squared_error: 18.9008 - 2s/epoch - 777ms/step
# Epoch 52/200
# 2/2 - 2s - loss: 25.7493 - accuracy: 0.0000e+00 - mean_squared_error: 25.7493 - mean_absolute_percentage_error: 10.0374 - root_mean_squared_error: 5.0744 - val_loss: 350.8045 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 350.8045 - val_mean_absolute_percentage_error: 43.0288 - val_root_mean_squared_error: 18.7298 - 2s/epoch - 753ms/step
# Epoch 53/200
# 2/2 - 2s - loss: 25.1860 - accuracy: 0.0000e+00 - mean_squared_error: 25.1860 - mean_absolute_percentage_error: 10.2554 - root_mean_squared_error: 5.0186 - val_loss: 344.8965 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 344.8965 - val_mean_absolute_percentage_error: 42.5740 - val_root_mean_squared_error: 18.5714 - 2s/epoch - 1s/step
# Epoch 54/200
# 2/2 - 2s - loss: 24.3336 - accuracy: 0.0000e+00 - mean_squared_error: 24.3336 - mean_absolute_percentage_error: 10.2043 - root_mean_squared_error: 4.9329 - val_loss: 347.3202 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 347.3202 - val_mean_absolute_percentage_error: 42.7723 - val_root_mean_squared_error: 18.6365 - 2s/epoch - 792ms/step
# Epoch 55/200
# 2/2 - 2s - loss: 24.3843 - accuracy: 0.0000e+00 - mean_squared_error: 24.3843 - mean_absolute_percentage_error: 9.7004 - root_mean_squared_error: 4.9380 - val_loss: 346.4641 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 346.4641 - val_mean_absolute_percentage_error: 42.7134 - val_root_mean_squared_error: 18.6135 - 2s/epoch - 757ms/step
# Epoch 56/200
# 2/2 - 1s - loss: 22.6903 - accuracy: 0.0000e+00 - mean_squared_error: 22.6903 - mean_absolute_percentage_error: 9.3797 - root_mean_squared_error: 4.7634 - val_loss: 336.3846 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 336.3846 - val_mean_absolute_percentage_error: 41.9230 - val_root_mean_squared_error: 18.3408 - 1s/epoch - 707ms/step
# Epoch 57/200
# 2/2 - 1s - loss: 23.3032 - accuracy: 0.0000e+00 - mean_squared_error: 23.3032 - mean_absolute_percentage_error: 10.2448 - root_mean_squared_error: 4.8273 - val_loss: 335.5891 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 335.5891 - val_mean_absolute_percentage_error: 41.8679 - val_root_mean_squared_error: 18.3191 - 1s/epoch - 655ms/step
# Epoch 58/200
# 2/2 - 2s - loss: 21.8333 - accuracy: 0.0000e+00 - mean_squared_error: 21.8333 - mean_absolute_percentage_error: 9.4380 - root_mean_squared_error: 4.6726 - val_loss: 343.4290 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 343.4290 - val_mean_absolute_percentage_error: 42.4994 - val_root_mean_squared_error: 18.5318 - 2s/epoch - 865ms/step
# Epoch 59/200
# 2/2 - 2s - loss: 22.1093 - accuracy: 0.0000e+00 - mean_squared_error: 22.1093 - mean_absolute_percentage_error: 8.8888 - root_mean_squared_error: 4.7021 - val_loss: 336.4297 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 336.4297 - val_mean_absolute_percentage_error: 41.9562 - val_root_mean_squared_error: 18.3420 - 2s/epoch - 898ms/step
# Epoch 60/200
# 2/2 - 2s - loss: 20.1142 - accuracy: 0.0000e+00 - mean_squared_error: 20.1142 - mean_absolute_percentage_error: 9.0202 - root_mean_squared_error: 4.4849 - val_loss: 324.8278 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 324.8278 - val_mean_absolute_percentage_error: 41.0340 - val_root_mean_squared_error: 18.0230 - 2s/epoch - 799ms/step
# Epoch 61/200
# 2/2 - 2s - loss: 21.6326 - accuracy: 0.0000e+00 - mean_squared_error: 21.6326 - mean_absolute_percentage_error: 10.0431 - root_mean_squared_error: 4.6511 - val_loss: 326.0661 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 326.0661 - val_mean_absolute_percentage_error: 41.1439 - val_root_mean_squared_error: 18.0573 - 2s/epoch - 907ms/step
# Epoch 62/200
# 2/2 - 2s - loss: 20.2146 - accuracy: 0.0000e+00 - mean_squared_error: 20.2146 - mean_absolute_percentage_error: 9.2085 - root_mean_squared_error: 4.4961 - val_loss: 331.8015 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 331.8015 - val_mean_absolute_percentage_error: 41.6144 - val_root_mean_squared_error: 18.2154 - 2s/epoch - 874ms/step
# Epoch 63/200
# 2/2 - 1s - loss: 18.8391 - accuracy: 0.0000e+00 - mean_squared_error: 18.8391 - mean_absolute_percentage_error: 8.4497 - root_mean_squared_error: 4.3404 - val_loss: 326.0299 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 326.0299 - val_mean_absolute_percentage_error: 41.1581 - val_root_mean_squared_error: 18.0563 - 1s/epoch - 749ms/step
# Epoch 64/200
# 2/2 - 2s - loss: 18.5578 - accuracy: 0.0000e+00 - mean_squared_error: 18.5578 - mean_absolute_percentage_error: 8.7161 - root_mean_squared_error: 4.3079 - val_loss: 322.7563 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 322.7563 - val_mean_absolute_percentage_error: 40.9041 - val_root_mean_squared_error: 17.9654 - 2s/epoch - 931ms/step
# Epoch 65/200
# 2/2 - 1s - loss: 18.1671 - accuracy: 0.0000e+00 - mean_squared_error: 18.1671 - mean_absolute_percentage_error: 8.4656 - root_mean_squared_error: 4.2623 - val_loss: 323.9927 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 323.9927 - val_mean_absolute_percentage_error: 41.0200 - val_root_mean_squared_error: 17.9998 - 1s/epoch - 689ms/step
# Epoch 66/200
# 2/2 - 1s - loss: 17.7934 - accuracy: 0.0000e+00 - mean_squared_error: 17.7934 - mean_absolute_percentage_error: 8.2196 - root_mean_squared_error: 4.2182 - val_loss: 319.6545 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 319.6545 - val_mean_absolute_percentage_error: 40.6774 - val_root_mean_squared_error: 17.8789 - 1s/epoch - 702ms/step
# Epoch 67/200
# 2/2 - 2s - loss: 17.0095 - accuracy: 0.0000e+00 - mean_squared_error: 17.0095 - mean_absolute_percentage_error: 8.4185 - root_mean_squared_error: 4.1243 - val_loss: 315.3640 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 315.3640 - val_mean_absolute_percentage_error: 40.3330 - val_root_mean_squared_error: 17.7585 - 2s/epoch - 764ms/step
# Epoch 68/200
# 2/2 - 2s - loss: 17.7363 - accuracy: 0.0000e+00 - mean_squared_error: 17.7363 - mean_absolute_percentage_error: 8.4082 - root_mean_squared_error: 4.2114 - val_loss: 315.7521 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 315.7521 - val_mean_absolute_percentage_error: 40.3736 - val_root_mean_squared_error: 17.7694 - 2s/epoch - 974ms/step
# Epoch 69/200
# 2/2 - 1s - loss: 16.5623 - accuracy: 0.0000e+00 - mean_squared_error: 16.5623 - mean_absolute_percentage_error: 8.0497 - root_mean_squared_error: 4.0697 - val_loss: 311.4076 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 311.4076 - val_mean_absolute_percentage_error: 40.0252 - val_root_mean_squared_error: 17.6467 - 1s/epoch - 735ms/step
# Epoch 70/200
# 2/2 - 2s - loss: 15.7343 - accuracy: 0.0000e+00 - mean_squared_error: 15.7343 - mean_absolute_percentage_error: 8.1954 - root_mean_squared_error: 3.9666 - val_loss: 310.7917 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 310.7917 - val_mean_absolute_percentage_error: 39.9882 - val_root_mean_squared_error: 17.6293 - 2s/epoch - 828ms/step
# Epoch 71/200
# 2/2 - 2s - loss: 15.2379 - accuracy: 0.0000e+00 - mean_squared_error: 15.2379 - mean_absolute_percentage_error: 7.6584 - root_mean_squared_error: 3.9036 - val_loss: 313.2697 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 313.2697 - val_mean_absolute_percentage_error: 40.2065 - val_root_mean_squared_error: 17.6994 - 2s/epoch - 945ms/step
# Epoch 72/200
# 2/2 - 2s - loss: 15.0025 - accuracy: 0.0000e+00 - mean_squared_error: 15.0025 - mean_absolute_percentage_error: 7.4164 - root_mean_squared_error: 3.8733 - val_loss: 307.8850 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 307.8850 - val_mean_absolute_percentage_error: 39.7704 - val_root_mean_squared_error: 17.5467 - 2s/epoch - 894ms/step
# Epoch 73/200
# 2/2 - 2s - loss: 15.0514 - accuracy: 0.0000e+00 - mean_squared_error: 15.0514 - mean_absolute_percentage_error: 7.6857 - root_mean_squared_error: 3.8796 - val_loss: 304.9044 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 304.9044 - val_mean_absolute_percentage_error: 39.5346 - val_root_mean_squared_error: 17.4615 - 2s/epoch - 899ms/step
# Epoch 74/200
# 2/2 - 2s - loss: 14.2630 - accuracy: 0.0000e+00 - mean_squared_error: 14.2630 - mean_absolute_percentage_error: 7.5076 - root_mean_squared_error: 3.7766 - val_loss: 300.9542 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 300.9542 - val_mean_absolute_percentage_error: 39.2157 - val_root_mean_squared_error: 17.3480 - 2s/epoch - 881ms/step
# Epoch 75/200
# 2/2 - 2s - loss: 15.2078 - accuracy: 0.0000e+00 - mean_squared_error: 15.2078 - mean_absolute_percentage_error: 7.6597 - root_mean_squared_error: 3.8997 - val_loss: 299.7733 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 299.7733 - val_mean_absolute_percentage_error: 39.1290 - val_root_mean_squared_error: 17.3140 - 2s/epoch - 916ms/step
# Epoch 76/200
# 2/2 - 1s - loss: 13.3586 - accuracy: 0.0000e+00 - mean_squared_error: 13.3586 - mean_absolute_percentage_error: 7.3398 - root_mean_squared_error: 3.6549 - val_loss: 295.9993 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 295.9993 - val_mean_absolute_percentage_error: 38.8185 - val_root_mean_squared_error: 17.2046 - 1s/epoch - 707ms/step
# Epoch 77/200
# 2/2 - 2s - loss: 16.0288 - accuracy: 0.0000e+00 - mean_squared_error: 16.0288 - mean_absolute_percentage_error: 7.2696 - root_mean_squared_error: 4.0036 - val_loss: 293.7587 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 293.7587 - val_mean_absolute_percentage_error: 38.6346 - val_root_mean_squared_error: 17.1394 - 2s/epoch - 805ms/step
# Epoch 78/200
# 2/2 - 2s - loss: 12.9366 - accuracy: 0.0000e+00 - mean_squared_error: 12.9366 - mean_absolute_percentage_error: 7.3692 - root_mean_squared_error: 3.5968 - val_loss: 287.1634 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 287.1634 - val_mean_absolute_percentage_error: 38.0758 - val_root_mean_squared_error: 16.9459 - 2s/epoch - 900ms/step
# Epoch 79/200
# 2/2 - 1s - loss: 15.8217 - accuracy: 0.0000e+00 - mean_squared_error: 15.8217 - mean_absolute_percentage_error: 8.1527 - root_mean_squared_error: 3.9776 - val_loss: 288.7469 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 288.7469 - val_mean_absolute_percentage_error: 38.2269 - val_root_mean_squared_error: 16.9926 - 1s/epoch - 714ms/step
# Epoch 80/200
# 2/2 - 1s - loss: 13.8059 - accuracy: 0.0000e+00 - mean_squared_error: 13.8059 - mean_absolute_percentage_error: 7.5130 - root_mean_squared_error: 3.7156 - val_loss: 282.9606 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 282.9606 - val_mean_absolute_percentage_error: 37.7391 - val_root_mean_squared_error: 16.8214 - 1s/epoch - 687ms/step
# Epoch 81/200
# 2/2 - 2s - loss: 12.0487 - accuracy: 0.0000e+00 - mean_squared_error: 12.0487 - mean_absolute_percentage_error: 6.7919 - root_mean_squared_error: 3.4711 - val_loss: 289.0556 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 289.0556 - val_mean_absolute_percentage_error: 38.2844 - val_root_mean_squared_error: 17.0016 - 2s/epoch - 846ms/step
# Epoch 82/200
# 2/2 - 2s - loss: 14.1185 - accuracy: 0.0000e+00 - mean_squared_error: 14.1185 - mean_absolute_percentage_error: 7.1852 - root_mean_squared_error: 3.7575 - val_loss: 283.3208 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 283.3208 - val_mean_absolute_percentage_error: 37.7986 - val_root_mean_squared_error: 16.8321 - 2s/epoch - 883ms/step
# Epoch 83/200
# 2/2 - 2s - loss: 12.1824 - accuracy: 0.0000e+00 - mean_squared_error: 12.1824 - mean_absolute_percentage_error: 6.5774 - root_mean_squared_error: 3.4903 - val_loss: 279.2113 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 279.2113 - val_mean_absolute_percentage_error: 37.4486 - val_root_mean_squared_error: 16.7096 - 2s/epoch - 786ms/step
# Epoch 84/200
# 2/2 - 2s - loss: 11.2702 - accuracy: 0.0000e+00 - mean_squared_error: 11.2702 - mean_absolute_percentage_error: 6.4931 - root_mean_squared_error: 3.3571 - val_loss: 268.5882 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 268.5882 - val_mean_absolute_percentage_error: 36.5072 - val_root_mean_squared_error: 16.3887 - 2s/epoch - 834ms/step
# Epoch 85/200
# 2/2 - 2s - loss: 11.9716 - accuracy: 0.0000e+00 - mean_squared_error: 11.9716 - mean_absolute_percentage_error: 7.1627 - root_mean_squared_error: 3.4600 - val_loss: 272.0892 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 272.0892 - val_mean_absolute_percentage_error: 36.8340 - val_root_mean_squared_error: 16.4951 - 2s/epoch - 948ms/step
# Epoch 86/200
# 2/2 - 2s - loss: 11.3155 - accuracy: 0.0000e+00 - mean_squared_error: 11.3155 - mean_absolute_percentage_error: 6.2050 - root_mean_squared_error: 3.3639 - val_loss: 272.5385 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 272.5385 - val_mean_absolute_percentage_error: 36.8859 - val_root_mean_squared_error: 16.5087 - 2s/epoch - 842ms/step
# Epoch 87/200
# 2/2 - 2s - loss: 11.1723 - accuracy: 0.0000e+00 - mean_squared_error: 11.1723 - mean_absolute_percentage_error: 6.2921 - root_mean_squared_error: 3.3425 - val_loss: 266.2723 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 266.2723 - val_mean_absolute_percentage_error: 36.3372 - val_root_mean_squared_error: 16.3179 - 2s/epoch - 851ms/step
# Epoch 88/200
# 2/2 - 2s - loss: 10.6347 - accuracy: 0.0000e+00 - mean_squared_error: 10.6347 - mean_absolute_percentage_error: 6.1967 - root_mean_squared_error: 3.2611 - val_loss: 262.5844 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 262.5844 - val_mean_absolute_percentage_error: 36.0218 - val_root_mean_squared_error: 16.2045 - 2s/epoch - 971ms/step
# Epoch 89/200
# 2/2 - 2s - loss: 10.6737 - accuracy: 0.0000e+00 - mean_squared_error: 10.6737 - mean_absolute_percentage_error: 6.0240 - root_mean_squared_error: 3.2671 - val_loss: 254.2998 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 254.2998 - val_mean_absolute_percentage_error: 35.2701 - val_root_mean_squared_error: 15.9468 - 2s/epoch - 759ms/step
# Epoch 90/200
# 2/2 - 2s - loss: 10.8295 - accuracy: 0.0000e+00 - mean_squared_error: 10.8295 - mean_absolute_percentage_error: 6.6968 - root_mean_squared_error: 3.2908 - val_loss: 256.8047 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 256.8047 - val_mean_absolute_percentage_error: 35.5226 - val_root_mean_squared_error: 16.0251 - 2s/epoch - 763ms/step
# Epoch 91/200
# 2/2 - 1s - loss: 9.8291 - accuracy: 0.0000e+00 - mean_squared_error: 9.8291 - mean_absolute_percentage_error: 5.8716 - root_mean_squared_error: 3.1351 - val_loss: 262.1777 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 262.1777 - val_mean_absolute_percentage_error: 36.0311 - val_root_mean_squared_error: 16.1919 - 1s/epoch - 718ms/step
# Epoch 92/200
# 2/2 - 2s - loss: 10.2006 - accuracy: 0.0000e+00 - mean_squared_error: 10.2006 - mean_absolute_percentage_error: 5.7553 - root_mean_squared_error: 3.1938 - val_loss: 257.5781 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 257.5781 - val_mean_absolute_percentage_error: 35.6101 - val_root_mean_squared_error: 16.0492 - 2s/epoch - 792ms/step
# Epoch 93/200
# 2/2 - 1s - loss: 11.0621 - accuracy: 0.0000e+00 - mean_squared_error: 11.0621 - mean_absolute_percentage_error: 6.7359 - root_mean_squared_error: 3.3260 - val_loss: 257.7790 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 257.7790 - val_mean_absolute_percentage_error: 35.6437 - val_root_mean_squared_error: 16.0555 - 1s/epoch - 675ms/step
# Epoch 94/200
# 2/2 - 2s - loss: 9.9350 - accuracy: 0.0000e+00 - mean_squared_error: 9.9350 - mean_absolute_percentage_error: 5.6501 - root_mean_squared_error: 3.1520 - val_loss: 253.8503 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 253.8503 - val_mean_absolute_percentage_error: 35.2958 - val_root_mean_squared_error: 15.9327 - 2s/epoch - 805ms/step
# Epoch 95/200
# 2/2 - 2s - loss: 9.0159 - accuracy: 0.0000e+00 - mean_squared_error: 9.0159 - mean_absolute_percentage_error: 5.5516 - root_mean_squared_error: 3.0026 - val_loss: 241.0053 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 241.0053 - val_mean_absolute_percentage_error: 34.0939 - val_root_mean_squared_error: 15.5243 - 2s/epoch - 865ms/step
# Epoch 96/200
# 2/2 - 2s - loss: 9.6217 - accuracy: 0.0000e+00 - mean_squared_error: 9.6217 - mean_absolute_percentage_error: 6.2752 - root_mean_squared_error: 3.1019 - val_loss: 246.2683 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 246.2683 - val_mean_absolute_percentage_error: 34.6211 - val_root_mean_squared_error: 15.6929 - 2s/epoch - 834ms/step
# Epoch 97/200
# 2/2 - 2s - loss: 8.7991 - accuracy: 0.0000e+00 - mean_squared_error: 8.7991 - mean_absolute_percentage_error: 5.5194 - root_mean_squared_error: 2.9663 - val_loss: 242.4272 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 242.4272 - val_mean_absolute_percentage_error: 34.2702 - val_root_mean_squared_error: 15.5701 - 2s/epoch - 934ms/step
# Epoch 98/200
# 2/2 - 2s - loss: 9.0876 - accuracy: 0.0000e+00 - mean_squared_error: 9.0876 - mean_absolute_percentage_error: 5.8705 - root_mean_squared_error: 3.0146 - val_loss: 239.0050 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 239.0050 - val_mean_absolute_percentage_error: 33.9547 - val_root_mean_squared_error: 15.4598 - 2s/epoch - 931ms/step
# Epoch 99/200
# 2/2 - 2s - loss: 8.6529 - accuracy: 0.0000e+00 - mean_squared_error: 8.6529 - mean_absolute_percentage_error: 5.5550 - root_mean_squared_error: 2.9416 - val_loss: 237.8454 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 237.8454 - val_mean_absolute_percentage_error: 33.8531 - val_root_mean_squared_error: 15.4222 - 2s/epoch - 868ms/step
# Epoch 100/200
# 2/2 - 2s - loss: 8.2364 - accuracy: 0.0000e+00 - mean_squared_error: 8.2364 - mean_absolute_percentage_error: 5.4215 - root_mean_squared_error: 2.8699 - val_loss: 230.1024 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 230.1024 - val_mean_absolute_percentage_error: 33.1052 - val_root_mean_squared_error: 15.1691 - 2s/epoch - 789ms/step
# Epoch 101/200
# 2/2 - 2s - loss: 8.0373 - accuracy: 0.0000e+00 - mean_squared_error: 8.0373 - mean_absolute_percentage_error: 5.5758 - root_mean_squared_error: 2.8350 - val_loss: 232.4696 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 232.4696 - val_mean_absolute_percentage_error: 33.3531 - val_root_mean_squared_error: 15.2470 - 2s/epoch - 802ms/step
# Epoch 102/200
# 2/2 - 2s - loss: 8.3846 - accuracy: 0.0000e+00 - mean_squared_error: 8.3846 - mean_absolute_percentage_error: 5.7282 - root_mean_squared_error: 2.8956 - val_loss: 228.9478 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 228.9478 - val_mean_absolute_percentage_error: 33.0136 - val_root_mean_squared_error: 15.1310 - 2s/epoch - 858ms/step
# Epoch 103/200
# 2/2 - 2s - loss: 7.8974 - accuracy: 0.0000e+00 - mean_squared_error: 7.8974 - mean_absolute_percentage_error: 5.2926 - root_mean_squared_error: 2.8102 - val_loss: 227.2842 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 227.2842 - val_mean_absolute_percentage_error: 32.8493 - val_root_mean_squared_error: 15.0759 - 2s/epoch - 867ms/step
# Epoch 104/200
# 2/2 - 2s - loss: 7.9085 - accuracy: 0.0000e+00 - mean_squared_error: 7.9085 - mean_absolute_percentage_error: 5.4550 - root_mean_squared_error: 2.8122 - val_loss: 224.5598 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 224.5598 - val_mean_absolute_percentage_error: 32.5826 - val_root_mean_squared_error: 14.9853 - 2s/epoch - 986ms/step
# Epoch 105/200
# 2/2 - 1s - loss: 8.3889 - accuracy: 0.0000e+00 - mean_squared_error: 8.3889 - mean_absolute_percentage_error: 5.1732 - root_mean_squared_error: 2.8964 - val_loss: 221.5722 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 221.5722 - val_mean_absolute_percentage_error: 32.2953 - val_root_mean_squared_error: 14.8853 - 1s/epoch - 740ms/step
# Epoch 106/200
# 2/2 - 1s - loss: 7.7424 - accuracy: 0.0000e+00 - mean_squared_error: 7.7424 - mean_absolute_percentage_error: 5.4893 - root_mean_squared_error: 2.7825 - val_loss: 212.7737 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 212.7737 - val_mean_absolute_percentage_error: 31.4068 - val_root_mean_squared_error: 14.5868 - 1s/epoch - 719ms/step
# Epoch 107/200
# 2/2 - 2s - loss: 7.1251 - accuracy: 0.0000e+00 - mean_squared_error: 7.1251 - mean_absolute_percentage_error: 5.2845 - root_mean_squared_error: 2.6693 - val_loss: 221.3023 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 221.3023 - val_mean_absolute_percentage_error: 32.2899 - val_root_mean_squared_error: 14.8762 - 2s/epoch - 798ms/step
# Epoch 108/200
# 2/2 - 2s - loss: 8.7355 - accuracy: 0.0000e+00 - mean_squared_error: 8.7355 - mean_absolute_percentage_error: 5.4912 - root_mean_squared_error: 2.9556 - val_loss: 210.6217 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 210.6217 - val_mean_absolute_percentage_error: 31.2001 - val_root_mean_squared_error: 14.5128 - 2s/epoch - 984ms/step
# Epoch 109/200
# 2/2 - 2s - loss: 7.0652 - accuracy: 0.0000e+00 - mean_squared_error: 7.0652 - mean_absolute_percentage_error: 5.1481 - root_mean_squared_error: 2.6580 - val_loss: 209.1869 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 209.1869 - val_mean_absolute_percentage_error: 31.0685 - val_root_mean_squared_error: 14.4633 - 2s/epoch - 961ms/step
# Epoch 110/200
# 2/2 - 2s - loss: 7.0096 - accuracy: 0.0000e+00 - mean_squared_error: 7.0096 - mean_absolute_percentage_error: 5.0582 - root_mean_squared_error: 2.6476 - val_loss: 207.0075 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 207.0075 - val_mean_absolute_percentage_error: 30.8549 - val_root_mean_squared_error: 14.3878 - 2s/epoch - 979ms/step
# Epoch 111/200
# 2/2 - 2s - loss: 6.8018 - accuracy: 0.0000e+00 - mean_squared_error: 6.8018 - mean_absolute_percentage_error: 4.8729 - root_mean_squared_error: 2.6080 - val_loss: 202.2357 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 202.2357 - val_mean_absolute_percentage_error: 30.3593 - val_root_mean_squared_error: 14.2210 - 2s/epoch - 774ms/step
# Epoch 112/200
# 2/2 - 2s - loss: 6.3897 - accuracy: 0.0000e+00 - mean_squared_error: 6.3897 - mean_absolute_percentage_error: 4.8661 - root_mean_squared_error: 2.5278 - val_loss: 199.6683 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 199.6683 - val_mean_absolute_percentage_error: 30.1001 - val_root_mean_squared_error: 14.1304 - 2s/epoch - 815ms/step
# Epoch 113/200
# 2/2 - 2s - loss: 6.6164 - accuracy: 0.0000e+00 - mean_squared_error: 6.6164 - mean_absolute_percentage_error: 5.1017 - root_mean_squared_error: 2.5722 - val_loss: 199.2019 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 199.2019 - val_mean_absolute_percentage_error: 30.0624 - val_root_mean_squared_error: 14.1139 - 2s/epoch - 776ms/step
# Epoch 114/200
# 2/2 - 2s - loss: 6.9465 - accuracy: 0.0000e+00 - mean_squared_error: 6.9465 - mean_absolute_percentage_error: 5.0090 - root_mean_squared_error: 2.6356 - val_loss: 195.7985 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 195.7985 - val_mean_absolute_percentage_error: 29.7032 - val_root_mean_squared_error: 13.9928 - 2s/epoch - 916ms/step
# Epoch 115/200
# 2/2 - 2s - loss: 6.4809 - accuracy: 0.0000e+00 - mean_squared_error: 6.4809 - mean_absolute_percentage_error: 4.7531 - root_mean_squared_error: 2.5458 - val_loss: 192.0266 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 192.0266 - val_mean_absolute_percentage_error: 29.3001 - val_root_mean_squared_error: 13.8574 - 2s/epoch - 804ms/step
# Epoch 116/200
# 2/2 - 2s - loss: 7.1381 - accuracy: 0.0000e+00 - mean_squared_error: 7.1381 - mean_absolute_percentage_error: 5.3170 - root_mean_squared_error: 2.6717 - val_loss: 188.0887 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 188.0887 - val_mean_absolute_percentage_error: 28.8852 - val_root_mean_squared_error: 13.7145 - 2s/epoch - 850ms/step
# Epoch 117/200
# 2/2 - 2s - loss: 6.8318 - accuracy: 0.0000e+00 - mean_squared_error: 6.8318 - mean_absolute_percentage_error: 4.8435 - root_mean_squared_error: 2.6138 - val_loss: 185.9581 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 185.9581 - val_mean_absolute_percentage_error: 28.6685 - val_root_mean_squared_error: 13.6366 - 2s/epoch - 773ms/step
# Epoch 118/200
# 2/2 - 2s - loss: 5.8533 - accuracy: 0.0000e+00 - mean_squared_error: 5.8533 - mean_absolute_percentage_error: 4.6250 - root_mean_squared_error: 2.4194 - val_loss: 177.6949 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 177.6949 - val_mean_absolute_percentage_error: 27.7328 - val_root_mean_squared_error: 13.3302 - 2s/epoch - 914ms/step
# Epoch 119/200
# 2/2 - 2s - loss: 6.0366 - accuracy: 0.0000e+00 - mean_squared_error: 6.0366 - mean_absolute_percentage_error: 4.8038 - root_mean_squared_error: 2.4569 - val_loss: 185.0007 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 185.0007 - val_mean_absolute_percentage_error: 28.5759 - val_root_mean_squared_error: 13.6015 - 2s/epoch - 793ms/step
# Epoch 120/200
# 2/2 - 2s - loss: 5.9789 - accuracy: 0.0000e+00 - mean_squared_error: 5.9789 - mean_absolute_percentage_error: 4.7256 - root_mean_squared_error: 2.4452 - val_loss: 173.9319 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 173.9319 - val_mean_absolute_percentage_error: 27.3080 - val_root_mean_squared_error: 13.1883 - 2s/epoch - 924ms/step
# Epoch 121/200
# 2/2 - 2s - loss: 5.9044 - accuracy: 0.0000e+00 - mean_squared_error: 5.9044 - mean_absolute_percentage_error: 4.7473 - root_mean_squared_error: 2.4299 - val_loss: 174.5175 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 174.5175 - val_mean_absolute_percentage_error: 27.3957 - val_root_mean_squared_error: 13.2105 - 2s/epoch - 898ms/step
# Epoch 122/200
# 2/2 - 2s - loss: 6.0187 - accuracy: 0.0000e+00 - mean_squared_error: 6.0187 - mean_absolute_percentage_error: 4.8774 - root_mean_squared_error: 2.4533 - val_loss: 173.7773 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 173.7773 - val_mean_absolute_percentage_error: 27.3270 - val_root_mean_squared_error: 13.1825 - 2s/epoch - 794ms/step
# Epoch 123/200
# 2/2 - 1s - loss: 5.6246 - accuracy: 0.0000e+00 - mean_squared_error: 5.6246 - mean_absolute_percentage_error: 4.4693 - root_mean_squared_error: 2.3716 - val_loss: 167.5388 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 167.5388 - val_mean_absolute_percentage_error: 26.5955 - val_root_mean_squared_error: 12.9437 - 1s/epoch - 706ms/step
# Epoch 124/200
# 2/2 - 1s - loss: 6.1677 - accuracy: 0.0000e+00 - mean_squared_error: 6.1677 - mean_absolute_percentage_error: 4.8117 - root_mean_squared_error: 2.4835 - val_loss: 165.0742 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 165.0742 - val_mean_absolute_percentage_error: 26.3157 - val_root_mean_squared_error: 12.8481 - 1s/epoch - 711ms/step
# Epoch 125/200
# 2/2 - 2s - loss: 5.0268 - accuracy: 0.0000e+00 - mean_squared_error: 5.0268 - mean_absolute_percentage_error: 4.3236 - root_mean_squared_error: 2.2420 - val_loss: 167.9231 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 167.9231 - val_mean_absolute_percentage_error: 26.6683 - val_root_mean_squared_error: 12.9585 - 2s/epoch - 752ms/step
# Epoch 126/200
# 2/2 - 2s - loss: 5.1989 - accuracy: 0.0000e+00 - mean_squared_error: 5.1989 - mean_absolute_percentage_error: 4.2717 - root_mean_squared_error: 2.2801 - val_loss: 157.2645 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 157.2645 - val_mean_absolute_percentage_error: 25.3751 - val_root_mean_squared_error: 12.5405 - 2s/epoch - 755ms/step
# Epoch 127/200
# 2/2 - 2s - loss: 5.3783 - accuracy: 0.0000e+00 - mean_squared_error: 5.3783 - mean_absolute_percentage_error: 4.7143 - root_mean_squared_error: 2.3191 - val_loss: 162.8004 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 162.8004 - val_mean_absolute_percentage_error: 26.0632 - val_root_mean_squared_error: 12.7593 - 2s/epoch - 823ms/step
# Epoch 128/200
# 2/2 - 1s - loss: 5.2673 - accuracy: 0.0000e+00 - mean_squared_error: 5.2673 - mean_absolute_percentage_error: 4.4270 - root_mean_squared_error: 2.2951 - val_loss: 153.9977 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 153.9977 - val_mean_absolute_percentage_error: 25.0079 - val_root_mean_squared_error: 12.4096 - 1s/epoch - 707ms/step
# Epoch 129/200
# 2/2 - 1s - loss: 4.7515 - accuracy: 0.0000e+00 - mean_squared_error: 4.7515 - mean_absolute_percentage_error: 4.4376 - root_mean_squared_error: 2.1798 - val_loss: 151.8564 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 151.8564 - val_mean_absolute_percentage_error: 24.7704 - val_root_mean_squared_error: 12.3230 - 1s/epoch - 721ms/step
# Epoch 130/200
# 2/2 - 2s - loss: 4.3089 - accuracy: 0.0000e+00 - mean_squared_error: 4.3089 - mean_absolute_percentage_error: 4.0535 - root_mean_squared_error: 2.0758 - val_loss: 153.4328 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 153.4328 - val_mean_absolute_percentage_error: 24.9530 - val_root_mean_squared_error: 12.3868 - 2s/epoch - 787ms/step
# Epoch 131/200
# 2/2 - 2s - loss: 4.5646 - accuracy: 0.0000e+00 - mean_squared_error: 4.5646 - mean_absolute_percentage_error: 4.2407 - root_mean_squared_error: 2.1365 - val_loss: 145.1906 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 145.1906 - val_mean_absolute_percentage_error: 23.9808 - val_root_mean_squared_error: 12.0495 - 2s/epoch - 829ms/step
# Epoch 132/200
# 2/2 - 2s - loss: 4.3527 - accuracy: 0.0000e+00 - mean_squared_error: 4.3527 - mean_absolute_percentage_error: 4.2071 - root_mean_squared_error: 2.0863 - val_loss: 146.7842 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 146.7842 - val_mean_absolute_percentage_error: 24.1599 - val_root_mean_squared_error: 12.1155 - 2s/epoch - 940ms/step
# Epoch 133/200
# 2/2 - 2s - loss: 4.2023 - accuracy: 0.0000e+00 - mean_squared_error: 4.2023 - mean_absolute_percentage_error: 4.0408 - root_mean_squared_error: 2.0499 - val_loss: 142.8064 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 142.8064 - val_mean_absolute_percentage_error: 23.6926 - val_root_mean_squared_error: 11.9502 - 2s/epoch - 899ms/step
# Epoch 134/200
# 2/2 - 2s - loss: 4.9151 - accuracy: 0.0000e+00 - mean_squared_error: 4.9151 - mean_absolute_percentage_error: 4.5289 - root_mean_squared_error: 2.2170 - val_loss: 144.5412 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 144.5412 - val_mean_absolute_percentage_error: 23.9220 - val_root_mean_squared_error: 12.0225 - 2s/epoch - 785ms/step
# Epoch 135/200
# ...
# Epoch 188/200
# 2/2 - 2s - loss: 1.5588 - accuracy: 0.0000e+00 - mean_squared_error: 1.5588 - mean_absolute_percentage_error: 2.6401 - root_mean_squared_error: 1.2485 - val_loss: 79.9436 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 79.9436 - val_mean_absolute_percentage_error: 16.9820 - val_root_mean_squared_error: 8.9411 - 2s/epoch - 918ms/step
# Epoch 189/200
# 2/2 - 2s - loss: 1.6288 - accuracy: 0.0000e+00 - mean_squared_error: 1.6288 - mean_absolute_percentage_error: 2.5824 - root_mean_squared_error: 1.2762 - val_loss: 80.7333 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 80.7333 - val_mean_absolute_percentage_error: 17.0030 - val_root_mean_squared_error: 8.9852 - 2s/epoch - 987ms/step
# Epoch 190/200
# 2/2 - 2s - loss: 1.6238 - accuracy: 0.0000e+00 - mean_squared_error: 1.6238 - mean_absolute_percentage_error: 2.6920 - root_mean_squared_error: 1.2743 - val_loss: 76.7138 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 76.7138 - val_mean_absolute_percentage_error: 16.6024 - val_root_mean_squared_error: 8.7586 - 2s/epoch - 946ms/step
# Epoch 191/200
# 2/2 - 2s - loss: 1.3714 - accuracy: 0.0000e+00 - mean_squared_error: 1.3714 - mean_absolute_percentage_error: 2.4577 - root_mean_squared_error: 1.1711 - val_loss: 73.8852 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 73.8852 - val_mean_absolute_percentage_error: 16.3439 - val_root_mean_squared_error: 8.5957 - 2s/epoch - 929ms/step
# Epoch 192/200
# 2/2 - 2s - loss: 1.6509 - accuracy: 0.0000e+00 - mean_squared_error: 1.6509 - mean_absolute_percentage_error: 2.6870 - root_mean_squared_error: 1.2849 - val_loss: 73.6081 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 73.6081 - val_mean_absolute_percentage_error: 16.3105 - val_root_mean_squared_error: 8.5795 - 2s/epoch - 793ms/step
# Epoch 193/200
# 2/2 - 2s - loss: 1.3431 - accuracy: 0.0000e+00 - mean_squared_error: 1.3431 - mean_absolute_percentage_error: 2.4002 - root_mean_squared_error: 1.1589 - val_loss: 75.3297 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 75.3297 - val_mean_absolute_percentage_error: 16.4382 - val_root_mean_squared_error: 8.6793 - 2s/epoch - 829ms/step
# Epoch 194/200
# 2/2 - 2s - loss: 1.2570 - accuracy: 0.0000e+00 - mean_squared_error: 1.2570 - mean_absolute_percentage_error: 2.4096 - root_mean_squared_error: 1.1211 - val_loss: 74.0402 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 74.0402 - val_mean_absolute_percentage_error: 16.2641 - val_root_mean_squared_error: 8.6047 - 2s/epoch - 936ms/step
# Epoch 195/200
# 2/2 - 2s - loss: 1.2161 - accuracy: 0.0000e+00 - mean_squared_error: 1.2161 - mean_absolute_percentage_error: 2.2703 - root_mean_squared_error: 1.1028 - val_loss: 72.1033 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 72.1033 - val_mean_absolute_percentage_error: 16.0764 - val_root_mean_squared_error: 8.4914 - 2s/epoch - 830ms/step
# Epoch 196/200
# 2/2 - 2s - loss: 1.1812 - accuracy: 0.0000e+00 - mean_squared_error: 1.1812 - mean_absolute_percentage_error: 2.2304 - root_mean_squared_error: 1.0868 - val_loss: 76.7439 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 76.7439 - val_mean_absolute_percentage_error: 16.5150 - val_root_mean_squared_error: 8.7604 - 2s/epoch - 902ms/step
# Epoch 197/200
# 2/2 - 2s - loss: 1.1682 - accuracy: 0.0000e+00 - mean_squared_error: 1.1682 - mean_absolute_percentage_error: 2.2314 - root_mean_squared_error: 1.0809 - val_loss: 72.5855 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 72.5855 - val_mean_absolute_percentage_error: 16.1001 - val_root_mean_squared_error: 8.5197 - 2s/epoch - 956ms/step
# Epoch 198/200
# 2/2 - 2s - loss: 1.1407 - accuracy: 0.0000e+00 - mean_squared_error: 1.1407 - mean_absolute_percentage_error: 2.2355 - root_mean_squared_error: 1.0680 - val_loss: 74.8382 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 74.8382 - val_mean_absolute_percentage_error: 16.2840 - val_root_mean_squared_error: 8.6509 - 2s/epoch - 766ms/step
# Epoch 199/200
# 2/2 - 2s - loss: 1.4386 - accuracy: 0.0000e+00 - mean_squared_error: 1.4386 - mean_absolute_percentage_error: 2.4240 - root_mean_squared_error: 1.1994 - val_loss: 71.4812 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 71.4812 - val_mean_absolute_percentage_error: 15.9441 - val_root_mean_squared_error: 8.4547 - 2s/epoch - 869ms/step
# Epoch 200/200
# 2/2 - 2s - loss: 1.2241 - accuracy: 0.0000e+00 - mean_squared_error: 1.2241 - mean_absolute_percentage_error: 2.3447 - root_mean_squared_error: 1.1064 - val_loss: 72.1219 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 72.1219 - val_mean_absolute_percentage_error: 16.0161 - val_root_mean_squared_error: 8.4925 - 2s/epoch - 877ms/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5457, 16)]           0         []
#
#  conv1d (Conv1D)             (None, 5457, 80)             2640      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 5457, 64)             2112      ['input_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 5457, 32)             1056      ['input_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 5457, 16)             528       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 5457, 80)             12880     ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 5457, 64)             8256      ['conv1d_3[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5457, 32)             2080      ['conv1d_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 5457, 16)             528       ['conv1d_9[0][0]']
#
#  batch_normalization (Batch  (None, 5457, 80)             320       ['conv1d_1[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 5457, 64)             256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 5457, 32)             128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 5457, 16)             64        ['conv1d_10[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 5457, 80)             0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 5457, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 5457, 32)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 5457, 16)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 5457, 80)             12880     ['activation[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5457, 64)             8256      ['activation_2[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 5457, 32)             2080      ['activation_4[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 5457, 16)             528       ['activation_6[0][0]']
#
#  batch_normalization_1 (Bat  (None, 5457, 80)             320       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 5457, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 5457, 32)             128       ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 5457, 16)             64        ['conv1d_11[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 5457, 80)             0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv1d[0][0]']
#
#  add_1 (Add)                 (None, 5457, 64)             0         ['batch_normalization_3[0][0]'
#                                                                     , 'conv1d_3[0][0]']
#
#  add_2 (Add)                 (None, 5457, 32)             0         ['batch_normalization_5[0][0]'
#                                                                     , 'conv1d_6[0][0]']
#
#  add_3 (Add)                 (None, 5457, 16)             0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv1d_9[0][0]']
#
#  activation_1 (Activation)   (None, 5457, 80)             0         ['add[0][0]']
#
#  activation_3 (Activation)   (None, 5457, 64)             0         ['add_1[0][0]']
#
#  activation_5 (Activation)   (None, 5457, 32)             0         ['add_2[0][0]']
#
#  activation_7 (Activation)   (None, 5457, 16)             0         ['add_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 42, 80)               0         ['activation_1[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 42, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 42, 32)               0         ['activation_5[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 42, 16)               0         ['activation_7[0][0]']
#  g1D)
#
#  concatenate (Concatenate)   (None, 42, 192)              0         ['max_pooling1d[0][0]',
#                                                                      'max_pooling1d_1[0][0]',
#                                                                      'max_pooling1d_2[0][0]',
#                                                                      'max_pooling1d_3[0][0]']
#
#  dense (Dense)               (None, 42, 16)               3088      ['concatenate[0][0]']
#
#  flatten (Flatten)           (None, 672)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    673       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 59121 (230.94 KB)
# Trainable params: 58353 (227.94 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________
# 1/1 [==============================] - 1s 1s/step
# Test Loss: [31.84762]
# Test Mean Squared Error: [29.748844]
# Test Mean Absolute Percentage Error: [32.545444]
# Test Root Mean Squared Error: [35.341984]

# %%
results = model.evaluate(test_dataset, batch_size=64)
# Out:
# 1/1 [==============================] - 0s 156ms/step - loss: 72.1219 - accuracy: 0.0000e+00 - mean_squared_error: 72.1219 - mean_absolute_percentage_error: 16.0161 - root_mean_squared_error: 8.4925

# %%
import tensorflow as tf
import numpy as np

# 重置数据集
def create_test_dataset(X_test_norm, y_test):
    return tf.data.Dataset.from_tensor_slices((X_test_norm, y_test.T)).batch(64)

# 创建测试数据集
test_dataset = create_test_dataset(X_test_norm, y_test)

# EVALUATE model with TESTING DATA
results = model.evaluate(test_dataset, verbose=0)
print(f'Test Loss: {results[0]}')
print(f'Test Mean Squared Error: {results[1]}')
print(f'Test Mean Absolute Percentage Error: {results[2]}')
print(f'Test Root Mean Squared Error: {results[3]}')

# PREDICT with TESTING DATA
ynew = model.predict(test_dataset)

# 重置测试数据集
test_dataset = create_test_dataset(X_test_norm, y_test)

# EVALUATE model again with TESTING DATA
results = model.evaluate(test_dataset, batch_size=64)
print(f'loss: {results[0]} - accuracy: {results[1]} - mean_squared_error: {results[2]} - mean_absolute_percentage_error: {results[3]} - root_mean_squared_error: {results[4]}')
# Out:
# Test Loss: 72.12194061279297
# Test Mean Squared Error: 0.0
# Test Mean Absolute Percentage Error: 72.12194061279297
# Test Root Mean Squared Error: 16.016117095947266
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 146ms/step - loss: 72.1219 - accuracy: 0.0000e+00 - mean_squared_error: 72.1219 - mean_absolute_percentage_error: 16.0161 - root_mean_squared_error: 8.4925
# loss: 72.12194061279297 - accuracy: 0.0 - mean_squared_error: 72.12194061279297 - mean_absolute_percentage_error: 16.016117095947266 - root_mean_squared_error: 8.492464065551758

# %%
# plt.figure()
# plt.title('Loss (Mean Squared Error)')
# plt.plot(history.history['loss'])
# plt.figure()
# plt.title('Accuracy')
# plt.plot(history.history['accuracy'])
# plt.figure()
# plt.title('Mean Squared Error')
# plt.plot(history.history['mean_squared_error'])
# plt.figure()
fig, ax = plt.subplots()
ax.set_title('Training and Validation \n Mean Squared Error') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['loss'], color = 'blue', label = 'train')
# plt.figure()
## Validation Plots
# plt.title('Validation Loss (MSE)') # loss = 100 * abs(y_true - y_pred) / y_true
# plt.plot(history.history['val_loss'])
# plt.figure()

# plt.title('Validation Mean Absolute Percentage Error (MAPE)') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['val_loss'], color = 'orange', label = 'val')
ax.semilogy((0,50))
ax.legend()
# plt.figure()
