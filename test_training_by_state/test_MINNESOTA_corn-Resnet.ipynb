# %%
import os # Handle OS file systems and directory paths
import random # Random number
import numpy as np # Import NumPy for arrays and such
import matplotlib.pyplot as plt # Plotting Tools
import numpy.linalg as npl # Linear Algebra Library
import time # Time
# from google.colab import drive # Read files in from Google Drive
import pandas as pd # Import Pandas for data processing
import datetime as dt
import scipy.io as sio
import io
from decimal import Decimal # String to double conversion
from glob import glob  # 从 glob 模块中导入 glob 函数
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import boto3
from botocore.exceptions import NoCredentialsError

# %%
# Optionally, you can specify the AWS region
s3 = boto3.client('s3', region_name='us-east-1')  # Replace 'us-west-2' with your AWS region

# %%
import pandas as pd
# s3_uri = 's3://pepper-dataset/crop_data/crop_IOWA/Iowa_corn_2019.csv'
# df = pd.read_csv(s3_uri)

# %%
# get county list
# county_path_list = glob('/content/drive/MyDrive/ai/era5/county_env/*')
# county_list = [os.path.basename(x) for x in county_path_list]
# print(county_list)

#Read files from s3
bucket_name = 'pepper-dataset'
prefix = 'county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/'

# List to store all object keys
county_files = []

# Initial call to list_objects_v2
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

# Process the initial response
while True:
    # Collect keys from current response
    current_keys = [obj['Key'] for obj in response.get('Contents', [])]
    county_files.extend(current_keys)

    # Check if there are more objects to retrieve
    if not response['IsTruncated']:
        break  # No more objects to retrieve

    # Get ContinuationToken for next paginated call
    continuation_token = response['NextContinuationToken']

    # Make subsequent call with ContinuationToken
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, ContinuationToken=continuation_token)
    
    
county_files = ["/" + path if not path.startswith("/") else path for path in county_files]

# %%
len(county_files)
# Out:
# 81217

# %%
county_files[:10]
# Out:
# ['/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2000-01_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2000-01_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2000-02_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2000-02_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2000-03_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2000-03_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2000-04_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2000-04_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2000-05_part1.csv']

# %%
# try 1 county
year_range = [2015, 2020]
years = [x for x in range(year_range[0], year_range[-1]+1)]

filtered_files = [file_path for file_path in county_files
                  if any(str(year) in file_path for year in years)]

# basedir = '/content/drive/MyDrive/ai/era5/county_env/'
# county_files = []

# for c in county_list:
#   county = os.path.join(basedir, c)
#   print(county)

#   county_f = glob(os.path.join(county, '*'))

#   for f in county_f:
#     ym_str = f.split('_')[-2]
#     ym_obj = dt.datetime.strptime(ym_str, '%Y-%m')
#     if ym_obj.year not in years:
#         continue
#     county_files.append(f)

print(len(filtered_files))

  # print(len(county_files))
  # print(county_files[:3])

# get year-month info for the county
# ym_list = [x.split('_')[-2] for x in county_files]
# ym_list = list(set(ym_list))
# ym_list.sort()
# print(ym_list)

filtered_files[:50]
# Out:
# 20304
# ['/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-01_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-01_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-02_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-02_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-03_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-03_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-04_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-04_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-05_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-05_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-06_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-06_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-07_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-07_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-08_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-08_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-09_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-09_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-10_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-10_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-11_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-11_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-12_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2015-12_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-01_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-01_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-02_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-02_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-03_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-03_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-04_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-04_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-05_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-05_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-06_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-06_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-07_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-07_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-08_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-08_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-09_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-09_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-10_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-10_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-11_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-11_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-12_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2016-12_part2.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2017-01_part1.csv',
#  '/county-env-data/county_env_2_IL_AK_MN/processed_with_all_features/Arkansas_Jackson/Arkansas_Jackson_2017-01_part2.csv']

# %%
pd.read_csv('s3://'+bucket_name+filtered_files[0])
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/fsspec/registry.py:279: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
#              t2m           rsn      sde         stl1         stl2  \
# 0    1010.666667 -25195.800000 -32766.0 -7531.800000 -1533.400000
# 1     455.466667 -25021.000000 -32766.0 -8140.733333 -1605.466667
# 2     388.666667 -24844.133333 -32766.0 -8397.533333 -1692.266667
# 3     471.066667 -24659.066667 -32766.0 -8472.133333 -1779.266667
# 4     506.000000 -24463.666667 -32766.0 -8487.200000 -1861.266667
# ..           ...           ...      ...          ...          ...
# 739  7277.000000 -19673.133333 -32766.0 -2578.333333  1113.266667
# 740  7357.933333 -19870.266667 -32766.0 -2443.533333  1259.066667
# 741  7219.533333 -19863.000000 -32766.0 -2649.800000  1378.800000
# 742  7216.266667 -20187.466667 -32766.0 -2680.533333  1487.400000
# 743  6944.866667 -20175.666667 -32766.0 -2935.666667  1569.266667
#
#             stl3         stl4           tsn        swvl1        swvl2  \
# 0     400.333333  1179.266667  25135.733333  5722.333333  6580.800000
# 1     371.333333  1169.466667  23691.400000  5717.800000  6567.200000
# 2     342.333333  1161.333333  24787.133333  5715.333333  6553.533333
# 3     312.866667  1153.800000  26445.200000  5710.933333  6540.066667
# 4     282.333333  1144.266667  27897.533333  5705.333333  6526.333333
# ..           ...          ...           ...          ...          ...
# 739 -1741.266667 -5683.200000  32766.000000  2941.600000  4195.666667
# 740 -1748.533333 -5688.600000  32766.000000  2917.600000  4183.666667
# 741 -1754.866667 -5695.133333  32767.000000  2902.666667  4174.466667
# 742 -1758.933333 -5699.533333  32766.000000  2888.133333  4165.733333
# 743 -1764.533333 -5705.866667  32765.000000  2876.200000  4158.466667
#
#            swvl3        swvl4             datetime
# 0    2787.333333  6270.933333  2015-01-01 00:00:00
# 1    2790.933333  6270.866667  2015-01-01 01:00:00
# 2    2794.666667  6270.866667  2015-01-01 02:00:00
# 3    2798.600000  6270.733333  2015-01-01 03:00:00
# 4    2802.133333  6270.733333  2015-01-01 04:00:00
# ..           ...          ...                  ...
# 739  6174.266667  6473.133333  2015-01-31 19:00:00
# 740  6170.533333  6473.333333  2015-01-31 20:00:00
# 741  6167.866667  6473.533333  2015-01-31 21:00:00
# 742  6165.333333  6473.533333  2015-01-31 22:00:00
# 743  6163.200000  6473.866667  2015-01-31 23:00:00
#
# [744 rows x 13 columns]

# %%
df_list = pd.DataFrame(columns=("Year","State","County","Month","Commodity","Feature"))

for csvf in filtered_files:
    # only read part1, then match with part2
    if 'part2' in csvf:
        continue
    # print(csvf)
    crop = "UNKNOWN"

    suffix = csvf.split('/')[-1]
    state = suffix.split('_')[-4].upper()
    # print(state)
    if state != "MINNESOTA":
        continue
    county_name = suffix.split('_')[-3].upper()
    ym_str = csvf.split('_')[-2]

    year = int(suffix.split('-')[0][-4:])
    month = int(suffix.split('-')[1][:2])
    ym_obj = dt.datetime.strptime(ym_str, '%Y-%m')
    if ym_obj.year not in years:
        continue
    # else:
    #     print(ym_str)
        # pass

    df1 = pd.read_csv('s3://'+bucket_name+csvf)
    # df1.dropna(axis=1)
    csvf_part2 = csvf.replace('part1', 'part2')
    df2 = pd.read_csv('s3://'+bucket_name+csvf_part2)
    # df2.dropna(axis=1)


    df12 = pd.merge(df1, df2, on = 'datetime')
    
    df12 = df12.drop(columns=['sshf'])
    df12 = df12.drop(columns=['evavt'])
    
    df12['datetime'] = pd.to_datetime(df12['datetime'])
    # print("----------------------")
    # print(df12[df12['datetim-e'].dt.month >= 5])
    # df12 = df12[df12['datetime'].dt.month >= 5]
    # print(df12['datetime'].dt.month)
    df12 = df12[(df12['datetime'].dt.month >= 5) & (df12['datetime'].dt.month <= 11)]
    if df12.empty:
        print("No data available after filtering.")
        continue
      # drop datetime
    df12 = df12.drop(columns=['datetime'])
    
    # df12.drop(columns=['datetime'])
    # print(df12.head())
    # print("size:", len(df12))
    # print(df12.dtype)

    # print("-----------------------")
    # print(df12.shape)
    row = [year,state,county_name,month,crop]
    row.append(df12)
    # print(row[:4])

    # df_list.append(df12)
    dfLength = len(df_list)
    df_list.loc[dfLength] = row

# df_all = df_list[0]
# for df in df_list[1:]:
#     df_all = pd.concat([df_all, df], axis = 0)

print("Number of Features Per County Per Year:  >= ",len(df_list.iloc[1,4]))
# print(df_list["State"])
# df_list['Feature'] = df_list['Feature'].astype(object)

# df_list.to_csv('/content/drive/MyDrive/ai/era5/dataSat_cleaned_Iowa_2015-2020.csv', index=False)
# Out:
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 27
#      22     continue
#      23 # else:
#      24 #     print(ym_str)
#      25     # pass
# ---> 27 df1 = pd.read_csv('s3://'+bucket_name+csvf)
#      28 # df1.dropna(axis=1)
#      29 csvf_part2 = csvf.replace('part1', 'part2')
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pandas/io/common.py:713, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     710     codecs.lookup_error(errors)
#     712 # open URLs
# --> 713 ioargs = _get_filepath_or_buffer(
#     714     path_or_buf,
#     715     encoding=encoding,
#     716     compression=compression,
#     717     mode=mode,
#     718     storage_options=storage_options,
#     719 )
#     721 handle = ioargs.filepath_or_buffer
#     722 handles: list[BaseBuffer]
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/pandas/io/common.py:411, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     406     pass
#     408 try:
#     409     file_obj = fsspec.open(
#     410         filepath_or_buffer, mode=fsspec_mode, **(storage_options or {})
# --> 411     ).open()
#     412 # GH 34626 Reads from Public Buckets without Credentials needs anon=True
#     413 except tuple(err_types_to_retry_with_anon):
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/fsspec/core.py:147, in OpenFile.open(self)
#     140 def open(self):
#     141     """Materialise this as a real open file without context
#     142
#     143     The OpenFile object should be explicitly closed to avoid enclosed file
#     144     instances persisting. You must, therefore, keep a reference to the OpenFile
#     145     during the life of the file-like it generates.
#     146     """
# --> 147     return self.__enter__()
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/fsspec/core.py:105, in OpenFile.__enter__(self)
#     102 mode = self.mode.replace("t", "").replace("b", "") + "b"
#     104 try:
# --> 105     f = self.fs.open(self.path, mode=mode)
#     106 except FileNotFoundError as e:
#     107     if has_magic(self.path):
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/fsspec/spec.py:1303, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1301 else:
#    1302     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1303     f = self._open(
#    1304         path,
#    1305         mode=mode,
#    1306         block_size=block_size,
#    1307         autocommit=ac,
#    1308         cache_options=cache_options,
#    1309         **kwargs,
#    1310     )
#    1311     if compression is not None:
#    1312         from fsspec.compression import compr
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/s3fs/core.py:375, in S3FileSystem._open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     372 if cache_type is None:
#     373     cache_type = self.default_cache_type
# --> 375 return S3File(self, path, mode, block_size=block_size, acl=acl,
#     376               version_id=version_id, fill_cache=fill_cache,
#     377               s3_additional_kwargs=kw, cache_type=cache_type,
#     378               autocommit=autocommit, requester_pays=requester_pays)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/s3fs/core.py:1096, in S3File.__init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1094 self.s3_additional_kwargs = s3_additional_kwargs or {}
#    1095 self.req_kw = {'RequestPayer': 'requester'} if requester_pays else {}
# -> 1096 super().__init__(s3, path, mode, block_size, autocommit=autocommit,
#    1097                  cache_type=cache_type)
#    1098 self.s3 = self.fs  # compatibility
#    1099 if self.writable():
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/fsspec/spec.py:1698, in AbstractBufferedFile.__init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, size, **kwargs)
#    1696         self.size = size
#    1697     else:
# -> 1698         self.size = self.details["size"]
#    1699     self.cache = caches[cache_type](
#    1700         self.blocksize, self._fetch_range, self.size, **cache_options
#    1701     )
#    1702 else:
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/fsspec/spec.py:1711, in AbstractBufferedFile.details(self)
#    1708 @property
#    1709 def details(self):
#    1710     if self._details is None:
# -> 1711         self._details = self.fs.info(self.path)
#    1712     return self._details
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/s3fs/core.py:529, in S3FileSystem.info(self, path, version_id, refresh)
#     527 if self.version_aware or (key and self._ls_from_cache(path) is None) or refresh:
#     528     try:
# --> 529         out = self._call_s3(self.s3.head_object, kwargs, Bucket=bucket,
#     530                             Key=key, **version_id_kw(version_id), **self.req_kw)
#     531         return {
#     532             'ETag': out['ETag'],
#     533             'Key': '/'.join([bucket, key]),
#    (...)
#     540             'VersionId': out.get('VersionId')
#     541         }
#     542     except ClientError as e:
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/s3fs/core.py:200, in S3FileSystem._call_s3(self, method, *akwarglist, **kwargs)
#     197 logger.debug("CALL: %s - %s - %s" % (method.__name__, akwarglist, kw2))
#     198 additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist,
#     199                                                **kwargs)
# --> 200 return method(**additional_kwargs)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/client.py:967, in BaseClient._make_api_call(self, operation_name, api_params)
#     952 request_context = {
#     953     'client_region': self.meta.region_name,
#     954     'client_config': self.meta.config,
#     955     'has_streaming_input': operation_model.has_streaming_input,
#     956     'auth_type': operation_model.auth_type,
#     957 }
#     958 api_params = self._emit_api_params(
#     959     api_params=api_params,
#     960     operation_model=operation_model,
#     961     context=request_context,
#     962 )
#     963 (
#     964     endpoint_url,
#     965     additional_headers,
#     966     properties,
# --> 967 ) = self._resolve_endpoint_ruleset(
#     968     operation_model, api_params, request_context
#     969 )
#     970 if properties:
#     971     # Pass arbitrary endpoint info with the Request
#     972     # for use during construction.
#     973     request_context['endpoint_properties'] = properties
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/client.py:1118, in BaseClient._resolve_endpoint_ruleset(self, operation_model, params, request_context, ignore_signing_region)
#    1116     endpoint_properties = {}
#    1117 else:
# -> 1118     endpoint_info = self._ruleset_resolver.construct_endpoint(
#    1119         operation_model=operation_model,
#    1120         call_args=params,
#    1121         request_context=request_context,
#    1122     )
#    1123     endpoint_url = endpoint_info.url
#    1124     additional_headers = endpoint_info.headers
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/regions.py:495, in EndpointRulesetResolver.construct_endpoint(self, operation_model, call_args, request_context)
#     492 if request_context is None:
#     493     request_context = {}
# --> 495 provider_params = self._get_provider_params(
#     496     operation_model, call_args, request_context
#     497 )
#     498 LOG.debug(
#     499     'Calling endpoint provider with parameters: %s' % provider_params
#     500 )
#     501 try:
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/regions.py:556, in EndpointRulesetResolver._get_provider_params(self, operation_model, call_args, request_context)
#     550 param_val = self._resolve_param_from_context(
#     551     param_name=param_name,
#     552     operation_model=operation_model,
#     553     call_args=call_args,
#     554 )
#     555 if param_val is None and param_def.builtin is not None:
# --> 556     param_val = self._resolve_param_as_builtin(
#     557         builtin_name=param_def.builtin,
#     558         builtins=customized_builtins,
#     559     )
#     560 if param_val is not None:
#     561     provider_params[param_name] = param_val
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/botocore/regions.py:601, in EndpointRulesetResolver._resolve_param_as_builtin(self, builtin_name, builtins)
#     600 def _resolve_param_as_builtin(self, builtin_name, builtins):
# --> 601     if builtin_name not in EndpointResolverBuiltins.__members__.values():
#     602         raise UnknownEndpointResolutionBuiltInName(name=builtin_name)
#     603     return builtins.get(builtin_name)
#
# File ~/anaconda3/envs/tensorflow2_p310/lib/python3.10/enum.py:459, in EnumMeta.__members__(cls)
#     451 @property
#     452 def __members__(cls):
#     453     """
#     454     Returns a mapping of member name->value.
#     455
#     456     This mapping lists all enum members, including aliases. Note that this
#     457     is a read-only view of the internal mapping.
#     458     """
# --> 459     return MappingProxyType(cls._member_map_)
#
# KeyboardInterrupt:

# %%
df_list.shape

# %%
df_list.iloc[1][-1]

# %%
# sys.getsizeof(df_list) / 1024 / 1024  # Byte -> MB
print(df_list.shape)
grouped_data = df_list.groupby(['Year', 'State', 'County']).size().reset_index(name='Count')
print(grouped_data)

# %%
# read crop yield (cy) data
year_range = [2015, 2020]
years = [x for x in range(year_range[0], year_range[-1]+1)]

def is_convertible_to_int(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

# cy_file_list = glob('/content/drive/MyDrive/ai/crop_yield/*csv')
# print((cy_file_list))
bucket_name = 'pepper-dataset'
prefix = 'crop_data/crop_3/'

# List to store all object keys
cy_file_list = []

# Initial call to list_objects_v2
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

# Process the initial response
while True:
    # Collect keys from current response
    current_keys = [obj['Key'] for obj in response.get('Contents', [])]
    cy_file_list.extend(current_keys)

    # Check if there are more objects to retrieve
    if not response['IsTruncated']:
        break  # No more objects to retrieve

    # Get ContinuationToken for next paginated call
    continuation_token = response['NextContinuationToken']

    # Make subsequent call with ContinuationToken
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, ContinuationToken=continuation_token)
    
cy_file_list = ["/" + path if not path.startswith("/") else path for path in cy_file_list]

print(cy_file_list)
cy_df_list = []
for cy_file in cy_file_list:
    suffix = cy_file.split('/')[-1]
    temp = suffix.split('_')
    state = temp[0].upper()
    
    if state == "MINNESOTA":
        crop_type = temp[1]
        df = pd.read_csv('s3://'+bucket_name+cy_file)
        df = df[(df['Year'] >= 2015) & (df['Year'] <= 2020)]
        # Drop Rows that do not have "YIELD" in the "DATA ITEM" column
        dataYield = df.drop(df[~df["Data Item"].str.contains("YIELD")].index, inplace = False)
        # Drop Rows that have "IRRIGATED" in the "DATA ITEM" column
        dataYield = dataYield.drop(dataYield[dataYield["Data Item"].str.contains("IRRIGATED")].index, inplace = False)
        cy_df_list.append(dataYield)
        
        
# for cy_file in cy_file_list:
#     suffix = cy_file.split('/')[-1]
#     year = suffix.split('.')[0].split('_')[-1]
#     print(year)
#     if is_convertible_to_int(year) and int(year) not in years:
#       continue

#     crop_type = cy_file.split('_')[-2]
#     df = pd.read_csv('s3://'+bucket_name+cy_file)

#     # Drop Rows that do not have "YIELD" in the "DATA ITEM" column
#     dataYield = df.drop(df[~df["Data Item"].str.contains("YIELD")].index, inplace = False)
#     # Drop Rows that have "IRRIGATED" in the "DATA ITEM" column
#     dataYield = dataYield.drop(dataYield[dataYield["Data Item"].str.contains("IRRIGATED")].index, inplace = False)
#     cy_df_list.append(dataYield)

cy_df_all = cy_df_list[0]
for df in cy_df_list[1:]:
    cy_df_all = pd.concat([cy_df_all, df], axis = 0)
print(cy_df_all.shape)

print(cy_df_all.head())
# Out:
# ['/crop_data/crop_3/', '/crop_data/crop_3/Arkansas_corn_2000-2022.csv', '/crop_data/crop_3/Illinois_corn_2000-2022.csv', '/crop_data/crop_3/Iowa_corn_2000-2022.csv', '/crop_data/crop_3/Minnesota_corn_2000-2022.csv', '/crop_data/crop_3/NorthDakota_corn_2000-2022.csv', '/crop_data/crop_3/Ohio_corn_2000-2022.csv', '/crop_data/crop_3/Washington_corn_2000-2022.csv']
# (606, 21)
#     Program  Year Period  Week Ending Geo Level      State  State ANSI  \
# 848  SURVEY  2020   YEAR          NaN    COUNTY  MINNESOTA          27
# 851  SURVEY  2020   YEAR          NaN    COUNTY  MINNESOTA          27
# 855  SURVEY  2020   YEAR          NaN    COUNTY  MINNESOTA          27
# 858  SURVEY  2020   YEAR          NaN    COUNTY  MINNESOTA          27
# 862  SURVEY  2020   YEAR          NaN    COUNTY  MINNESOTA          27
#
#     Ag District  Ag District Code          County  County ANSI  Zip Code  \
# 848         NaN                99  OTHER COUNTIES          NaN       NaN
# 851         NaN                99  OTHER COUNTIES          NaN       NaN
# 855     CENTRAL                50          BENTON          9.0       NaN
# 858     CENTRAL                50          BENTON          9.0       NaN
# 862     CENTRAL                50          CARVER         19.0       NaN
#
#      Region  watershed_code  Watershed Commodity  \
# 848     NaN               0        NaN      CORN
# 851     NaN               0        NaN      CORN
# 855     NaN               0        NaN      CORN
# 858     NaN               0        NaN      CORN
# 862     NaN               0        NaN      CORN
#
#                                          Data Item Domain Domain Category  \
# 848     CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  TOTAL   NOT SPECIFIED
# 851  CORN, SILAGE - YIELD, MEASURED IN TONS / ACRE  TOTAL   NOT SPECIFIED
# 855     CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  TOTAL   NOT SPECIFIED
# 858  CORN, SILAGE - YIELD, MEASURED IN TONS / ACRE  TOTAL   NOT SPECIFIED
# 862     CORN, GRAIN - YIELD, MEASURED IN BU / ACRE  TOTAL   NOT SPECIFIED
#
#      Value  CV (%)
# 848  194.8     3.6
# 851     23     1.1
# 855  186.2     2.9
# 858   21.5     5.3
# 862  200.1     2.3

# %%
dataROI = cy_df_all[["Year","State","County","Commodity","Value"]]
name_year = dataROI["Year"].drop_duplicates()
name_states = dataROI["State"].drop_duplicates()
name_county = dataROI["County"].drop_duplicates()
name_crops = dataROI["Commodity"].drop_duplicates()

dfOut = pd.DataFrame(columns=("Year","State","County","Commodity","Yield"))

# For each year
idx = 0
for year in name_year:
  temp_year = dataROI.loc[dataROI["Year"]==year]
  # if debug and verbose: print(temp_year)
  # For each state
  for state in name_states:
    temp_state = temp_year.loc[temp_year["State"]==state]
    # if debug and verbose: print(temp_state)
    # For each county
    for county in name_county:
      temp_county = temp_state.loc[temp_state["County"]==county]
      # if debug and verbose: print(temp_county)
      # For each crop
      for crop in name_crops:
        temp_crops = temp_county.loc[temp_county["Commodity"]==crop]
        # if debug and verbose: print(temp_crops)
        crop_yield = temp_crops["Value"]
        crop_yield = crop_yield.replace(',','', regex=True)
        crop_yield = pd.to_numeric(crop_yield)
        crop_yield = crop_yield.sum()
        # if debug and verbose: print(crop_yield)

        # Add to Output Data Frame
        dfOut.loc[idx] = [year,state,county,crop,crop_yield]

        # Increment idx
        idx = idx + 1

print(dfOut.head())
# wheat_rows = dfOut[dfOut['Commodity'] == 'WHEAT']
# print("wheat_rows: ", len(wheat_rows))
dfOut
# Out:
#    Year      State          County Commodity  Yield
# 0  2020  MINNESOTA  OTHER COUNTIES      CORN  217.8
# 1  2020  MINNESOTA          BENTON      CORN  207.7
# 2  2020  MINNESOTA          CARVER      CORN  223.6
# 3  2020  MINNESOTA       KANDIYOHI      CORN  218.7
# 4  2020  MINNESOTA          MCLEOD      CORN  184.7
#      Year      State                     County Commodity  Yield
# 0    2020  MINNESOTA             OTHER COUNTIES      CORN  217.8
# 1    2020  MINNESOTA                     BENTON      CORN  207.7
# 2    2020  MINNESOTA                     CARVER      CORN  223.6
# 3    2020  MINNESOTA                  KANDIYOHI      CORN  218.7
# 4    2020  MINNESOTA                     MCLEOD      CORN  184.7
# ..    ...        ...                        ...       ...    ...
# 499  2015  MINNESOTA            YELLOW MEDICINE      CORN  187.3
# 500  2015  MINNESOTA  OTHER (COMBINED) COUNTIES      CORN  598.8
# 501  2015  MINNESOTA                   CHIPPEWA      CORN  193.5
# 502  2015  MINNESOTA                    KANABEC      CORN    0.0
# 503  2015  MINNESOTA                  ST. LOUIS      CORN  115.0
#
# [504 rows x 5 columns]

# %%
def runCorrelateFeatureLabel(dataLabel,dataFeature,crop="WHEAT",dropZeroYield=True,debug=False,verbose=False):
  """Takes 2 pandas DataFrames (Label & Feature) and pairs them together"""

  # Drop Rows without the Desired Crop
  # print("pre dataCrop:", dataLabel.head())
  dataCrop = dataLabel.drop(dataLabel[~dataLabel["Commodity"].str.contains("CORN")].index, inplace = False)
  print("pre2 dataCrop:", dataCrop.head())
  dataCrop = dataCrop.drop(columns=["Commodity"]) #TODO: Assume we are only using 1 commodity
  dataFeat = dataFeature.drop(columns=["Commodity"])
  print("dataCrop:", dataCrop.head())
  print("dataFeat:", dataFeat.head())
  # print("++++++++++++++++++")

  # Merge DataFrames
  # Ref: https://realpython.com/pandas-merge-join-and-concat/
  # dataCrop.index = dataCrop.index.astype('object')
  print("------1: ", dataCrop.dtypes)
  print("------2: ", dataFeat.dtypes)
  dataFeat['Year'] = dataFeat['Year'].astype('int64')
  dataMerge = dataCrop.merge(dataFeat,how='right',on=['Year','State','County'])
  print(dataMerge.head())

  # Drop Rows without yield information
  if dropZeroYield:
    dataOut = dataMerge.drop(dataMerge[dataMerge["Yield"]==0.0].index,inplace=False)
  else:
    dataOut = dataMerge

  # Drop Rows with NaN
  dataOut.dropna(subset=['Yield'],inplace=True)

  if debug: print(dataOut)

  return dataOut

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# print("row shape:", df_list.iloc[1][4].info())
print(dfOut.shape)
print(dfOut.head())
print(df_list.shape)
print(df_list.head())
print(df_list.iloc[1][5].shape)
print("---------------------+")
# print(df_list.iloc[1])
dataSet = runCorrelateFeatureLabel(dfOut,df_list,crop="CORN",dropZeroYield=True,debug=False)

print("------------------")
print(dataSet.shape)
print(dataSet.head())
# Out:
# (504, 5)
#    Year      State          County Commodity  Yield
# 0  2020  MINNESOTA  OTHER COUNTIES      CORN  217.8
# 1  2020  MINNESOTA          BENTON      CORN  207.7
# 2  2020  MINNESOTA          CARVER      CORN  223.6
# 3  2020  MINNESOTA       KANDIYOHI      CORN  218.7
# 4  2020  MINNESOTA          MCLEOD      CORN  184.7
# (1890, 6)
#    Year      State  County  Month Commodity  \
# 0  2015  MINNESOTA  BENTON      5   UNKNOWN
# 1  2015  MINNESOTA  BENTON      6   UNKNOWN
# 2  2015  MINNESOTA  BENTON      7   UNKNOWN
# 3  2015  MINNESOTA  BENTON      8   UNKNOWN
# 4  2015  MINNESOTA  BENTON      9   UNKNOWN
#
#                                              Feature
# 0                t2m           rsn      sde      ...
# 1                t2m           rsn      sde      ...
# 2                t2m           rsn      sde      ...
# 3                t2m           rsn      sde      ...
# 4                t2m           rsn      sde      ...
# (720, 17)
# ---------------------+
# pre2 dataCrop:    Year      State          County Commodity  Yield
# 0  2020  MINNESOTA  OTHER COUNTIES      CORN  217.8
# 1  2020  MINNESOTA          BENTON      CORN  207.7
# 2  2020  MINNESOTA          CARVER      CORN  223.6
# 3  2020  MINNESOTA       KANDIYOHI      CORN  218.7
# 4  2020  MINNESOTA          MCLEOD      CORN  184.7
# dataCrop:    Year      State          County  Yield
# 0  2020  MINNESOTA  OTHER COUNTIES  217.8
# 1  2020  MINNESOTA          BENTON  207.7
# 2  2020  MINNESOTA          CARVER  223.6
# 3  2020  MINNESOTA       KANDIYOHI  218.7
# 4  2020  MINNESOTA          MCLEOD  184.7
# dataFeat:    Year      State  County  Month  \
# 0  2015  MINNESOTA  BENTON      5
# 1  2015  MINNESOTA  BENTON      6
# 2  2015  MINNESOTA  BENTON      7
# 3  2015  MINNESOTA  BENTON      8
# 4  2015  MINNESOTA  BENTON      9
#
#                                              Feature
# 0                t2m           rsn      sde      ...
# 1                t2m           rsn      sde      ...
# 2                t2m           rsn      sde      ...
# 3                t2m           rsn      sde      ...
# 4                t2m           rsn      sde      ...
# ------1:  Year        int64
# State      object
# County     object
# Yield     float64
# dtype: object
# ------2:  Year        int64
# State      object
# County     object
# Month       int64
# Feature    object
# dtype: object
#    Year      State  County  Yield  Month  \
# 0  2015  MINNESOTA  BENTON  167.3      5
# 1  2015  MINNESOTA  BENTON  167.3      6
# 2  2015  MINNESOTA  BENTON  167.3      7
# 3  2015  MINNESOTA  BENTON  167.3      8
# 4  2015  MINNESOTA  BENTON  167.3      9
#
#                                              Feature
# 0                t2m           rsn      sde      ...
# 1                t2m           rsn      sde      ...
# 2                t2m           rsn      sde      ...
# 3                t2m           rsn      sde      ...
# 4                t2m           rsn      sde      ...
# ------------------
# (1890, 6)
#    Year      State  County  Yield  Month  \
# 0  2015  MINNESOTA  BENTON  167.3      5
# 1  2015  MINNESOTA  BENTON  167.3      6
# 2  2015  MINNESOTA  BENTON  167.3      7
# 3  2015  MINNESOTA  BENTON  167.3      8
# 4  2015  MINNESOTA  BENTON  167.3      9
#
#                                              Feature
# 0                t2m           rsn      sde      ...
# 1                t2m           rsn      sde      ...
# 2                t2m           rsn      sde      ...
# 3                t2m           rsn      sde      ...
# 4                t2m           rsn      sde      ...

# %%
dataSet.iloc[1][-1]
# Out:
#               t2m           rsn      sde          stl1          stl2  \
# 0    -6162.133333 -32766.000000 -32766.0 -15870.533333 -11645.800000
# 1    -7188.733333 -32766.000000 -32766.0 -16883.666667 -11590.400000
# 2    -8921.733333 -32766.000000 -32766.0 -18259.400000 -11685.866667
# 3   -10530.866667 -32766.000000 -32766.0 -19447.800000 -11899.400000
# 4   -12136.666667 -32766.000000 -32766.0 -20443.933333 -12198.733333
# 5   -13257.133333 -32766.000000 -32766.0 -21130.933333 -12543.133333
# 6   -13780.466667 -32766.000000 -32766.0 -21422.000000 -12885.066667
# 7   -14775.200000 -32766.000000 -32766.0 -21928.266667 -13248.400000
# 8   -15296.133333 -32766.000000 -32766.0 -22328.066667 -13620.133333
# 9   -15666.933333 -32766.000000 -32766.0 -22664.533333 -13992.266667
# 10  -15899.800000 -32766.000000 -32766.0 -22937.466667 -14358.133333
# 11  -15984.800000 -32766.000000 -32766.0 -23159.266667 -14713.533333
# 12  -14558.000000 -32766.000000 -32766.0 -22464.266667 -14961.466667
# 13  -12070.266667 -32766.000000 -32766.0 -20800.533333 -15009.533333
# 14   -9964.533333 -32766.000000 -32766.0 -19162.466667 -14879.266667
  label = data['Yield']
  print("label len: ", len(label))
  # print(label)
  month = data['Month']
  if debug: print(len(feature))

  feat_lst = []
  label_lst = []
  feat_new = []
  firstTimeLoop = True
  for idx in range(len(feature)):
    # if debug: print(idx)
    print("idx:", idx)
    if int(month.iloc[idx]) == 5:
      feat_new = []
    for f in feature.iloc[idx]:
      # print(f)
      # feat_new.append(feature.iloc[idx][f])
      for item in feature.iloc[idx][f]:
        feat_new.append(item)
    # feat_new = np.array(feat_new)

    # Drop Bad Datasets
    # if len(feat_new) != 20: #4320: for whole year, 2520 for Jan-Jul, 3240 for Nov-Jul
    #   if debug: print("skipping feature of length",len(feat_new))
    #   continue

    if int(month.iloc[idx]) != 11:
      continue

    if len(feat_new) != 87312:  # 检查 feat_new 列表的长度是否为 240
        print("Skipping feature at index", idx, "due to incorrect length:", len(feat_new))
        continue

    print("feat_new len:", len(feat_new))
    # print("feat_arr:", len(feat_arr))
    # Append Features
    feat_lst.append(feat_new)
    label_lst.append(label.iloc[idx])

  print(len(label_lst))
  # feat_arr = np.array(feat_lst)
  feat_arr = feat_lst
  # print(feat_arr[0])

  data_feature_expanded = pd.DataFrame(feat_arr)

  # 将 DataFrame 写入 CSV 文件
  print("start writing dataFrame to csv: ", 's3://'+bucket_name+'/MINNESOTA_data_feature_expanded_CORN.csv')
  data_feature_expanded.to_csv('s3://'+bucket_name+'/MINNESOTA_data_feature_expanded_CORN.csv', index=False)

  print("Data successfully written to 'MINNESOTA data_feature_expanded.csv'")

  # Get Ready to Save
  # feature = feat_arr.tolist()
  label = label_lst
  data_label_expanded = pd.DataFrame(label)
  data_label_expanded.to_csv('s3://'+bucket_name+'/MINNESOTA_data_label_expanded_CORN.csv', index=False)
  print("Data successfully written to 'MINNESOTA_data_label_expanded.csv'")

  # Save Path
  # saveFile = savePath + saveName
  # print("Saving to:",saveFile)
  # sio.savemat(saveFile, mdict={'feature': feat_arr, 'label': label})

  # df = pd.DataFrame(feat_arr)
  # df['label'] = label
  # filename = '/content/drive/MyDrive/ai/era5/yield_Iowa_corn_noIrr.csv'

  # 将 DataFrame 写入 CSV 文件
  # df.to_csv(filename, index=False, header=False)
  print("++++++++++++")
  # print("feat_arr shape: ", feat_arr.shape)
  # print(feat_arr.head())
  print(len(feat_arr))
  print(len(feat_arr[0]))
  print(label)


  return label, feat_arr


# print(dataSet.iloc[1][4].shape())

label, feat_arr = saveCorrelatedData(dataSet,"/content/drive/MyDrive/ai/era5/","yield_Iowa_corn_noIrr.mat",debug=True)
# Out:
# feature len:  1890
# label len:  1890
# 1890
# idx: 0
# idx: 1
# idx: 2
# idx: 3
# idx: 4
# idx: 5
# idx: 6
# feat_new len: 87312
# idx: 7
# idx: 8
# idx: 9
# idx: 10
# idx: 11
# idx: 12
# idx: 13
# feat_new len: 87312
# idx: 14
# idx: 15
# idx: 16
# idx: 17
# idx: 18
# idx: 19
# idx: 20
# feat_new len: 87312
# idx: 21
# idx: 22
# idx: 23
# idx: 24
# idx: 25
# idx: 26
# idx: 27
# feat_new len: 87312
# idx: 28
# idx: 29
# idx: 30
# idx: 31
# idx: 32
# idx: 33
# idx: 34
# feat_new len: 87312
# idx: 35
# idx: 36
# idx: 37
# idx: 38
# idx: 39
# idx: 40
# idx: 41
# feat_new len: 87312
# idx: 42
# idx: 43
# idx: 44
# idx: 45
# idx: 46
# idx: 47
# idx: 48
# feat_new len: 87312
# idx: 49
# idx: 50
# idx: 51
# idx: 52
# idx: 53
# idx: 54
# idx: 55
# feat_new len: 87312
# idx: 56
# idx: 57
# idx: 58
# idx: 59
# idx: 60
# idx: 61
# idx: 62
# feat_new len: 87312
# idx: 63
# idx: 64
# idx: 65
# idx: 66
# idx: 67
# idx: 68
# idx: 69
# feat_new len: 87312
# idx: 70
# idx: 71
# idx: 72
# idx: 73
# idx: 74
# idx: 75
# idx: 76
# feat_new len: 87312
# idx: 77
# idx: 78
# idx: 79
# idx: 80
# idx: 81
# idx: 82
# idx: 83
# feat_new len: 87312
# idx: 84
# idx: 85
# idx: 86
# idx: 87
# idx: 88
# idx: 89
# idx: 90
# feat_new len: 87312
# idx: 91
# idx: 92
# idx: 93
# idx: 94
# idx: 95
# idx: 96
# idx: 97
# feat_new len: 87312
# idx: 98
# idx: 99
# idx: 100
# idx: 101
# idx: 102
# idx: 103
# idx: 104
# feat_new len: 87312
# idx: 105
# idx: 106
# idx: 107
# idx: 108
# idx: 109
# idx: 110
# idx: 111
# feat_new len: 87312
# idx: 112
# idx: 113
# idx: 114
# idx: 115
# idx: 116
# idx: 117
# idx: 118
# feat_new len: 87312
# idx: 119
# idx: 120
# idx: 121
# idx: 122
# idx: 123
# idx: 124
# idx: 125
# feat_new len: 87312
# idx: 126
# idx: 127
# idx: 128
# idx: 129
# idx: 130
# idx: 131
# idx: 132
# feat_new len: 87312
# idx: 133
# idx: 134
# idx: 135
# idx: 136
# idx: 137
# idx: 138
# idx: 139
# feat_new len: 87312
# idx: 140
# idx: 141
# idx: 142
# idx: 143
# idx: 144
# idx: 145
# idx: 146
# feat_new len: 87312
# idx: 147
# idx: 148
# idx: 149
# idx: 150
# idx: 151
# idx: 152
# idx: 153
# feat_new len: 87312
# idx: 154
# idx: 155
# idx: 156
# idx: 157
# idx: 158
# idx: 159
# idx: 160
# feat_new len: 87312
# idx: 161
# idx: 162
# idx: 163
# idx: 164
# idx: 165
# idx: 166
# idx: 167
# feat_new len: 87312
# idx: 168
# idx: 169
# idx: 170
# idx: 171
# idx: 172
# idx: 173
# idx: 174
# feat_new len: 87312
# idx: 175
# idx: 176
# idx: 177
# idx: 178
# idx: 179
# idx: 180
# idx: 181
# feat_new len: 87312
# idx: 182
# idx: 183
# idx: 184
# idx: 185
# idx: 186
# idx: 187
# idx: 188
# feat_new len: 87312
# idx: 189
# idx: 190
# idx: 191
# idx: 192
# idx: 193
# idx: 194
# idx: 195
# feat_new len: 87312
# idx: 196
# idx: 197
# idx: 198
# idx: 199
# idx: 200
# idx: 201
# idx: 202
# feat_new len: 87312
# idx: 203
# idx: 204
# idx: 205
# idx: 206
# idx: 207
# idx: 208
# idx: 209
# feat_new len: 87312
# idx: 210
# idx: 211
# idx: 212
# idx: 213
# idx: 214
# idx: 215
# idx: 216
# feat_new len: 87312
# idx: 217
# idx: 398
# feat_new len: 87312
# idx: 399
# idx: 400
# idx: 401
# idx: 402
# idx: 403
# idx: 404
# idx: 405
# feat_new len: 87312
# idx: 406
# idx: 407
# idx: 408
# idx: 409
# idx: 410
# idx: 411
# idx: 412
# feat_new len: 87312
# idx: 413
# idx: 414
# idx: 415
# idx: 416
# idx: 417
# idx: 418
# idx: 419
# feat_new len: 87312
# idx: 420
# idx: 421
# idx: 422
# idx: 423
# idx: 424
# idx: 425
# idx: 426
# feat_new len: 87312
# idx: 427
# idx: 428
# idx: 429
# idx: 430
# idx: 431
# idx: 432
# idx: 433
# feat_new len: 87312
# idx: 434
# idx: 435
# idx: 436
# idx: 437
# idx: 438
# idx: 439
# idx: 440
# feat_new len: 87312
# idx: 441
# idx: 442
# idx: 443
# idx: 444
# idx: 445
# idx: 446
# idx: 447
# feat_new len: 87312
# idx: 448
# idx: 449
# idx: 450
# idx: 451
# idx: 452
# idx: 453
# idx: 454
# feat_new len: 87312
# idx: 455
# idx: 456
# idx: 457
# idx: 458
# idx: 459
# idx: 460
# idx: 461
# feat_new len: 87312
# idx: 462
# idx: 463
# idx: 464
# idx: 465
# idx: 466
# idx: 467
# idx: 468
# feat_new len: 87312
# idx: 469
# idx: 470
# idx: 471
# idx: 472
# idx: 473
# idx: 474
# idx: 475
# feat_new len: 87312
# idx: 476
# idx: 477
# idx: 478
# idx: 479
# idx: 480
# idx: 481
# idx: 482
# feat_new len: 87312
# idx: 483
# idx: 484
# idx: 485
# idx: 486
# idx: 487
# idx: 488
# idx: 489
# feat_new len: 87312
# idx: 490
# idx: 491
# idx: 492
# idx: 493
# idx: 494
# idx: 495
# idx: 496
# feat_new len: 87312
# idx: 497
# idx: 498
# idx: 499
# idx: 500
# idx: 501
# idx: 502
# idx: 503
# feat_new len: 87312
# idx: 504
# idx: 505
# idx: 506
# idx: 507
# idx: 508
# idx: 509
# idx: 510
# feat_new len: 87312
# idx: 511
# idx: 512
# idx: 513
# idx: 514
# idx: 515
# idx: 516
# idx: 517
# feat_new len: 87312
# idx: 518
# idx: 519
# idx: 520
# idx: 521
# idx: 522
# idx: 523
# idx: 524
# feat_new len: 87312
# idx: 525
# idx: 526
# idx: 527
# idx: 528
# idx: 529
# idx: 530
# idx: 531
# feat_new len: 87312
# idx: 532
# idx: 533
# idx: 534
# idx: 535
# idx: 536
# idx: 537
# idx: 538
# feat_new len: 87312
# idx: 539
# idx: 540
# idx: 541
# idx: 542
# idx: 543
# idx: 544
# idx: 545
# feat_new len: 87312
# idx: 546
# idx: 547
# idx: 548
# idx: 549
# idx: 550
# idx: 551
# idx: 552
# feat_new len: 87312
# idx: 553
# idx: 554
# idx: 555
# idx: 556
# idx: 557
# idx: 558
# idx: 559
# feat_new len: 87312
# idx: 560
# idx: 561
# idx: 562
# idx: 563
# idx: 564
# idx: 565
# idx: 566
# feat_new len: 87312
# idx: 567
# idx: 568
# idx: 569
# idx: 570
# idx: 571
# idx: 572
# idx: 573
# feat_new len: 87312
# idx: 574
# idx: 575
# idx: 576
# idx: 577
# idx: 578
# idx: 579
# idx: 580
# feat_new len: 87312
# idx: 581
# idx: 582
# idx: 583
# idx: 584
# idx: 585
# idx: 586
# idx: 587
# feat_new len: 87312
# idx: 588
# idx: 589
# idx: 590
# idx: 591
# idx: 592
# idx: 593
# idx: 594
# feat_new len: 87312
# idx: 595
# idx: 596
# idx: 597
# idx: 598
# idx: 599
# idx: 600
# idx: 601
# feat_new len: 87312
# idx: 602
# idx: 603
# idx: 604
# idx: 605
# idx: 606
# idx: 607
# idx: 608
# feat_new len: 87312
# idx: 609
# idx: 610
# idx: 611
# idx: 612
# idx: 613
# idx: 614
# idx: 615
# feat_new len: 87312
# idx: 616
# idx: 617
# idx: 618
# idx: 619
# idx: 620
# idx: 621
# idx: 622
# feat_new len: 87312
# idx: 623
# idx: 624
# idx: 625
# idx: 626
# idx: 627
# idx: 628
# idx: 629
# feat_new len: 87312
# idx: 630
# idx: 631
# idx: 632
# idx: 633
# idx: 634
# idx: 635
# idx: 636
# feat_new len: 87312
# idx: 637
# idx: 638
# idx: 639
# idx: 640
# idx: 641
# idx: 642
# idx: 643
# feat_new len: 87312
# idx: 644
# idx: 645
# idx: 646
# idx: 647
# idx: 648
# idx: 649
# idx: 650
# feat_new len: 87312
# idx: 651
# idx: 652
# idx: 653
# idx: 654
# idx: 655
# idx: 656
# idx: 657
# feat_new len: 87312
# idx: 658
# idx: 659
# idx: 660
# idx: 661
# idx: 662
# idx: 663
# idx: 664
# feat_new len: 87312
# idx: 665
# idx: 666
# idx: 667
# idx: 668
# idx: 669
# idx: 670
# idx: 671
# feat_new len: 87312
# idx: 672
# idx: 673
# idx: 674
# idx: 675
# idx: 676
# idx: 677
# idx: 678
# feat_new len: 87312
# idx: 679
# idx: 680
# idx: 681
# idx: 682
# idx: 683
# idx: 684
# idx: 685
# feat_new len: 87312
# idx: 686
# idx: 687
# idx: 688
# idx: 689
# idx: 690
# idx: 691
# idx: 692
# feat_new len: 87312
# idx: 693
# idx: 694
# idx: 695
# idx: 696
# idx: 697
# idx: 698
# idx: 699
# feat_new len: 87312
# idx: 700
# idx: 701
# idx: 702
# idx: 703
# idx: 704
# idx: 705
# idx: 706
# feat_new len: 87312
# idx: 707
# idx: 708
# idx: 709
# idx: 710
# idx: 711
# idx: 712
# idx: 713
# feat_new len: 87312
# idx: 714
# idx: 715
# idx: 716
# idx: 717
# idx: 718
# idx: 719
# idx: 720
# feat_new len: 87312
# idx: 721
# idx: 722
# idx: 723
# idx: 724
# idx: 725
# idx: 726
# idx: 727
# feat_new len: 87312
# idx: 728
# idx: 729
# idx: 730
# idx: 731
# idx: 732
# idx: 733
# idx: 734
# feat_new len: 87312
# idx: 735
# idx: 736
# idx: 737
# idx: 738
# idx: 739
# idx: 740
# idx: 741
# feat_new len: 87312
# idx: 742
# idx: 743
# idx: 744
# idx: 745
# idx: 746
# idx: 747
# idx: 748
# feat_new len: 87312
# idx: 749
# idx: 750
# idx: 751
# idx: 752
# idx: 753
# idx: 754
# idx: 755
# feat_new len: 87312
# idx: 756
# idx: 757
# idx: 758
# idx: 759
# idx: 760
# idx: 761
# idx: 762
# feat_new len: 87312
# idx: 763
# idx: 764
# idx: 765
# idx: 766
# idx: 767
# idx: 768
# idx: 769
# feat_new len: 87312
# idx: 770
# idx: 771
# idx: 772
# idx: 773
# idx: 774
# idx: 775
# idx: 776
# feat_new len: 87312
# idx: 777
# idx: 778
# idx: 779
# idx: 780
# idx: 781
# idx: 782
# idx: 783
# feat_new len: 87312
# idx: 784
# idx: 785
# idx: 786
# idx: 787
# idx: 788
# idx: 789
# idx: 790
# feat_new len: 87312
# idx: 791
# idx: 792
# idx: 793
# idx: 794
# idx: 795
# idx: 796
# idx: 797
# feat_new len: 87312
# idx: 798
# idx: 799
# idx: 800
# idx: 801
# idx: 802
# idx: 803
# idx: 804
# feat_new len: 87312
# idx: 805
# idx: 806
# idx: 807
# idx: 808
# idx: 809
# idx: 810
# idx: 811
# feat_new len: 87312
# idx: 812
# idx: 813
# idx: 814
# idx: 815
# idx: 816
# idx: 817
# idx: 818
# feat_new len: 87312
# idx: 819
# idx: 820
# idx: 821
# idx: 822
# idx: 823
# idx: 824
# idx: 825
# feat_new len: 87312
# idx: 826
# idx: 827
# idx: 828
# idx: 829
# idx: 830
# idx: 831
# idx: 832
# feat_new len: 87312
# idx: 833
# idx: 834
# idx: 835
# idx: 836
# idx: 837
# idx: 838
# idx: 839
# feat_new len: 87312
# idx: 840
# idx: 841
# idx: 842
# idx: 843
# idx: 844
# idx: 845
# idx: 846
# feat_new len: 87312
# idx: 847
# idx: 848
# idx: 849
# idx: 850
# idx: 851
# idx: 852
# idx: 853
# feat_new len: 87312
# idx: 854
# idx: 855
# idx: 856
# idx: 857
# idx: 858
# idx: 859
# idx: 860
# feat_new len: 87312
# idx: 861
# idx: 862
# idx: 863
# idx: 864
# idx: 865
# idx: 866
# idx: 867
# feat_new len: 87312
# idx: 868
# idx: 869
# idx: 870
# idx: 871
# idx: 872
# idx: 873
# idx: 874
# feat_new len: 87312
# idx: 875
# idx: 876
# idx: 877
# idx: 878
# idx: 879
# idx: 880
# idx: 881
# feat_new len: 87312
# idx: 882
# idx: 883
# idx: 884
# idx: 885
# idx: 886
# idx: 887
# idx: 888
# feat_new len: 87312
# idx: 889
# idx: 890
# idx: 891
# idx: 892
# idx: 893
# idx: 894
# idx: 895
# feat_new len: 87312
# idx: 896
# idx: 897
# idx: 898
# idx: 899
# idx: 900
# idx: 901
# idx: 902
# feat_new len: 87312
# idx: 903
# idx: 904
# idx: 905
# idx: 906
# idx: 907
# idx: 908
# idx: 909
# feat_new len: 87312
# idx: 910
# idx: 911
# idx: 912
# idx: 913
# idx: 914
# idx: 915
# idx: 916
# feat_new len: 87312
# idx: 917
# idx: 918
# idx: 919
# idx: 920
# idx: 921
# idx: 922
# idx: 923
# feat_new len: 87312
# idx: 924
# idx: 925
# idx: 926
# idx: 927
# idx: 928
# idx: 929
# idx: 930
# feat_new len: 87312
# idx: 931
# idx: 932
# idx: 933
# idx: 934
# idx: 935
# idx: 936
# idx: 937
# feat_new len: 87312
# idx: 938
# idx: 939
# idx: 940
# idx: 941
# idx: 942
# idx: 943
# idx: 944
# feat_new len: 87312
# idx: 945
# idx: 946
# idx: 947
# idx: 948
# idx: 949
# idx: 950
# idx: 951
# feat_new len: 87312
# idx: 952
# idx: 953
# idx: 954
# idx: 955
# idx: 956
# idx: 957
# idx: 958
# feat_new len: 87312
# idx: 959
# idx: 960
# idx: 961
# idx: 962
# idx: 963
# idx: 964
# idx: 965
# feat_new len: 87312
# idx: 966
# idx: 967
# idx: 968
# idx: 969
# idx: 970
# idx: 971
# idx: 972
# feat_new len: 87312
# idx: 973
# idx: 974
# idx: 975
# idx: 976
# idx: 977
# idx: 978
# idx: 979
# feat_new len: 87312
# idx: 980
# idx: 981
# idx: 982
# idx: 983
# idx: 984
# idx: 985
# idx: 986
# feat_new len: 87312
# idx: 987
# idx: 988
# idx: 989
# idx: 990
# idx: 991
# idx: 992
# idx: 993
# feat_new len: 87312
# idx: 994
# idx: 995
# idx: 996
# idx: 997
# idx: 998
# idx: 999
# idx: 1000
# feat_new len: 87312
# idx: 1001
# idx: 1002
# idx: 1003
# idx: 1004
# idx: 1005
# idx: 1006
# idx: 1007
# feat_new len: 87312
# idx: 1008
# idx: 1009
# idx: 1010
# idx: 1011
# idx: 1012
# idx: 1013
# idx: 1014
# feat_new len: 87312
# idx: 1015
# idx: 1016
# idx: 1017
# idx: 1018
# idx: 1019
# idx: 1020
# idx: 1021
# feat_new len: 87312
# idx: 1022
# idx: 1023
# idx: 1024
# idx: 1025
# idx: 1026
# idx: 1027
# idx: 1028
# feat_new len: 87312
# idx: 1029
# idx: 1030
# idx: 1031
# idx: 1032
# idx: 1033
# idx: 1034
# idx: 1035
# feat_new len: 87312
# idx: 1036
# idx: 1037
# idx: 1038
# idx: 1039
# idx: 1040
# idx: 1041
# idx: 1042
# feat_new len: 87312
# idx: 1043
# idx: 1044
# idx: 1045
# idx: 1046
# idx: 1047
# idx: 1048
# idx: 1049
# feat_new len: 87312
# idx: 1050
# idx: 1051
# idx: 1052
# idx: 1053
# idx: 1054
# idx: 1055
# idx: 1056
# feat_new len: 87312
# idx: 1057
# idx: 1058
# idx: 1059
# idx: 1060
# idx: 1061
# idx: 1062
# idx: 1063
# feat_new len: 87312
# idx: 1064
# idx: 1065
# idx: 1066
# idx: 1067
# idx: 1068
# idx: 1069
# idx: 1070
# feat_new len: 87312
# idx: 1071
# idx: 1072
# idx: 1073
# idx: 1074
# idx: 1075
# idx: 1076
# idx: 1077
# feat_new len: 87312
# idx: 1078
# idx: 1079
# idx: 1080
# idx: 1081
# idx: 1082
# idx: 1083
# idx: 1084
# feat_new len: 87312
# idx: 1085
# idx: 1086
# idx: 1087
# idx: 1088
# idx: 1089
# idx: 1090
# idx: 1091
# feat_new len: 87312
# idx: 1092
# idx: 1093
# idx: 1094
# idx: 1095
# idx: 1096
# idx: 1097
# idx: 1098
# feat_new len: 87312
# idx: 1099
# idx: 1100
# idx: 1101
# idx: 1102
# idx: 1103
# idx: 1104
# idx: 1105
# feat_new len: 87312
# idx: 1106
# idx: 1107
# idx: 1108
# idx: 1109
# idx: 1110
# idx: 1111
# idx: 1112
# feat_new len: 87312
# idx: 1113
# idx: 1114
# idx: 1115
# idx: 1116
# idx: 1117
# idx: 1118
# idx: 1119
# feat_new len: 87312
# idx: 1120
# idx: 1121
# idx: 1122
# idx: 1123
# idx: 1124
# idx: 1125
# idx: 1126
# feat_new len: 87312
# idx: 1127
# idx: 1128
# idx: 1129
# idx: 1130
# idx: 1131
# idx: 1132
# idx: 1133
# feat_new len: 87312
# idx: 1134
# idx: 1135
# idx: 1136
# idx: 1137
# idx: 1138
# idx: 1139
# idx: 1140
# feat_new len: 87312
# idx: 1141
# idx: 1142
# idx: 1143
# idx: 1144
# idx: 1145
# idx: 1146
# idx: 1147
# feat_new len: 87312
# idx: 1148
# idx: 1149
# idx: 1150
# idx: 1151
# idx: 1152
# idx: 1153
# idx: 1154
# feat_new len: 87312
# idx: 1155
# idx: 1156
# idx: 1157
# idx: 1158
# idx: 1159
# idx: 1160
# idx: 1161
# feat_new len: 87312
# idx: 1162
# idx: 1163
# idx: 1164
# idx: 1165
# idx: 1166
# idx: 1167
# idx: 1168
# feat_new len: 87312
# idx: 1169
# idx: 1170
# idx: 1171
# idx: 1172
# idx: 1173
# idx: 1174
# idx: 1175
# feat_new len: 87312
# idx: 1176
# idx: 1177
# idx: 1178
# idx: 1179
# idx: 1180
# idx: 1181
# idx: 1182
# feat_new len: 87312
# idx: 1183
# idx: 1184
# idx: 1185
# idx: 1186
# idx: 1187
# idx: 1188
# idx: 1189
# feat_new len: 87312
# idx: 1190
# idx: 1191
# idx: 1192
# idx: 1193
# idx: 1194
# idx: 1195
# idx: 1196
# feat_new len: 87312
# idx: 1197
# idx: 1198
# idx: 1199
# idx: 1200
# idx: 1201
# idx: 1202
# idx: 1203
# feat_new len: 87312
# idx: 1204
# idx: 1205
# idx: 1206
# idx: 1207
# idx: 1208
# idx: 1209
# idx: 1210
# feat_new len: 87312
# idx: 1211
# idx: 1212
# idx: 1213
# idx: 1214
# idx: 1215
# idx: 1216
# idx: 1217
# feat_new len: 87312
# idx: 1218
# idx: 1219
# idx: 1220
# idx: 1221
# idx: 1222
# idx: 1223
# idx: 1224
# feat_new len: 87312
# idx: 1225
# idx: 1226
# idx: 1227
# idx: 1228
# idx: 1229
# idx: 1230
# idx: 1231
# feat_new len: 87312
# idx: 1232
# idx: 1233
# idx: 1234
# idx: 1235
# idx: 1236
# idx: 1237
# idx: 1238
# feat_new len: 87312
# idx: 1239
# idx: 1240
# idx: 1241
# idx: 1242
# idx: 1243
# idx: 1244
# idx: 1245
# feat_new len: 87312
# idx: 1246
# idx: 1247
# idx: 1248
# idx: 1249
# idx: 1250
# idx: 1251
# idx: 1252
# feat_new len: 87312
# idx: 1253
# idx: 1254
# idx: 1255
# idx: 1256
# idx: 1257
# idx: 1258
# idx: 1259
# feat_new len: 87312
# idx: 1260
# idx: 1261
# idx: 1262
# idx: 1263
# idx: 1264
# idx: 1265
# idx: 1266
# feat_new len: 87312
# idx: 1267
# idx: 1268
# idx: 1269
# idx: 1270
# idx: 1271
# idx: 1272
# idx: 1273
# feat_new len: 87312
# idx: 1274
# idx: 1275
# idx: 1276
# idx: 1277
# idx: 1278
# idx: 1279
# idx: 1280
# feat_new len: 87312
# idx: 1281
# idx: 1282
# idx: 1283
# idx: 1284
# idx: 1285
# idx: 1286
# idx: 1287
# feat_new len: 87312
# idx: 1288
# idx: 1289
# idx: 1290
# idx: 1291
# idx: 1292
# idx: 1293
# idx: 1294
# feat_new len: 87312
# idx: 1295
# idx: 1296
# idx: 1297
# idx: 1298
# idx: 1299
# idx: 1300
# idx: 1301
# feat_new len: 87312
# idx: 1302
# idx: 1303
# idx: 1304
# idx: 1305
# idx: 1306
# idx: 1307
# idx: 1308
# feat_new len: 87312
# idx: 1309
# idx: 1310
# idx: 1311
# idx: 1312
# idx: 1313
# idx: 1314
# idx: 1315
# feat_new len: 87312
# idx: 1316
# idx: 1317
# idx: 1318
# idx: 1319
# idx: 1320
# idx: 1321
# idx: 1322
# feat_new len: 87312
# idx: 1323
# idx: 1324
# idx: 1325
# idx: 1326
# idx: 1327
# idx: 1328
# idx: 1329
# feat_new len: 87312
# idx: 1330
# idx: 1331
# idx: 1332
# idx: 1333
# idx: 1334
# idx: 1335
# idx: 1336
# feat_new len: 87312
# idx: 1337
# idx: 1338
# idx: 1339
# idx: 1340
# idx: 1341
# idx: 1342
# idx: 1343
# feat_new len: 87312
# idx: 1344
# idx: 1345
# idx: 1346
# idx: 1347
# idx: 1348
# idx: 1349
# idx: 1350
# feat_new len: 87312
# idx: 1351
# idx: 1352
# idx: 1353
# idx: 1354
# idx: 1355
# idx: 1356
# idx: 1357
# feat_new len: 87312
# idx: 1358
# idx: 1359
# idx: 1360
# idx: 1361
# idx: 1362
# idx: 1363
# idx: 1364
# feat_new len: 87312
# idx: 1365
# idx: 1366
# idx: 1367
# idx: 1368
# idx: 1369
# idx: 1370
# idx: 1371
# feat_new len: 87312
# idx: 1372
# idx: 1373
# idx: 1374
# idx: 1375
# idx: 1376
# idx: 1377
# idx: 1378
# feat_new len: 87312
# idx: 1379
# idx: 1380
# idx: 1381
# idx: 1382
# idx: 1383
# idx: 1384
# idx: 1385
# feat_new len: 87312
# idx: 1386
# idx: 1387
# idx: 1388
# idx: 1389
# idx: 1390
# idx: 1391
# idx: 1392
# feat_new len: 87312
# idx: 1393
# idx: 1394
# idx: 1395
# idx: 1396
# idx: 1397
# idx: 1398
# idx: 1399
# feat_new len: 87312
# idx: 1400
# idx: 1401
# idx: 1402
# idx: 1403
# idx: 1404
# idx: 1405
# idx: 1406
# feat_new len: 87312
# idx: 1407
# idx: 1408
# idx: 1409
# idx: 1410
# idx: 1411
# idx: 1412
# idx: 1413
# feat_new len: 87312
# idx: 1414
# idx: 1415
# idx: 1416
# idx: 1417
# idx: 1418
# idx: 1419
# idx: 1420
# feat_new len: 87312
# idx: 1421
# idx: 1422
# idx: 1423
# idx: 1424
# idx: 1425
# idx: 1426
# idx: 1427
# feat_new len: 87312
# idx: 1428
# idx: 1429
# idx: 1430
# idx: 1431
# idx: 1432
# idx: 1433
# idx: 1434
# feat_new len: 87312
# idx: 1435
# idx: 1436
# idx: 1437
# idx: 1438
# idx: 1439
# idx: 1440
# idx: 1441
# feat_new len: 87312
# idx: 1442
# idx: 1443
# idx: 1444
# idx: 1445
# idx: 1446
# idx: 1447
# idx: 1448
# feat_new len: 87312
# idx: 1449
# idx: 1450
# idx: 1451
# idx: 1452
# idx: 1453
# idx: 1454
# idx: 1455
# feat_new len: 87312
# idx: 1456
# idx: 1457
# idx: 1458
# idx: 1459
# idx: 1460
# idx: 1461
# idx: 1462
# feat_new len: 87312
# idx: 1463
# idx: 1464
# idx: 1465
# idx: 1466
# idx: 1467
# idx: 1468
# idx: 1469
# feat_new len: 87312
# idx: 1470
# idx: 1471
# idx: 1472
# idx: 1473
# idx: 1474
# idx: 1475
# idx: 1476
# feat_new len: 87312
# idx: 1477
# idx: 1478
# idx: 1479
# idx: 1480
# idx: 1481
# idx: 1482
# idx: 1483
# feat_new len: 87312
# idx: 1484
# idx: 1485
# idx: 1486
# idx: 1487
# idx: 1488
# idx: 1489
# idx: 1490
# feat_new len: 87312
# idx: 1491
# idx: 1492
# idx: 1493
# idx: 1494
# idx: 1495
# idx: 1496
# idx: 1497
# feat_new len: 87312
# idx: 1498
# idx: 1499
# idx: 1500
# idx: 1501
# idx: 1502
# idx: 1503
# idx: 1504
# feat_new len: 87312
# idx: 1505
# idx: 1506
# idx: 1507
# idx: 1508
# idx: 1509
# idx: 1510
# idx: 1511
# feat_new len: 87312
# idx: 1512
# idx: 1513
# idx: 1514
# idx: 1515
# idx: 1516
# idx: 1517
# idx: 1518
# feat_new len: 87312
# idx: 1519
# idx: 1520
# idx: 1521
# idx: 1522
# idx: 1523
# idx: 1524
# idx: 1525
# feat_new len: 87312
# idx: 1526
# idx: 1527
# idx: 1528
# idx: 1529
# idx: 1530
# idx: 1531
# idx: 1532
# feat_new len: 87312
# idx: 1533
# idx: 1534
# idx: 1535
# idx: 1536
# idx: 1537
# idx: 1538
# idx: 1539
# feat_new len: 87312
# idx: 1540
# idx: 1541
# idx: 1542
# idx: 1543
# idx: 1544
# idx: 1545
# idx: 1546
# feat_new len: 87312
# idx: 1547
# idx: 1548
# idx: 1549
# idx: 1550
# idx: 1551
# idx: 1552
# idx: 1553
# feat_new len: 87312
# idx: 1554
# idx: 1555
# idx: 1556
# idx: 1557
# idx: 1558
# idx: 1559
# idx: 1560
# feat_new len: 87312
# idx: 1561
# idx: 1562
# idx: 1563
# idx: 1564
# idx: 1565
# idx: 1566
# idx: 1567
# feat_new len: 87312
# idx: 1568
# idx: 1569
# idx: 1570
# idx: 1571
# idx: 1572
# idx: 1573
# idx: 1574
# feat_new len: 87312
# idx: 1575
# idx: 1576
# idx: 1577
# idx: 1578
# idx: 1579
# idx: 1580
# idx: 1581
# feat_new len: 87312
# idx: 1582
# idx: 1583
# idx: 1744
# idx: 1745
# idx: 1746
# idx: 1747
# idx: 1748
# idx: 1749
# feat_new len: 87312
# idx: 1750
# idx: 1751
# idx: 1752
# idx: 1753
# idx: 1754
# idx: 1755
# idx: 1756
# feat_new len: 87312
# idx: 1757
# idx: 1758
# idx: 1759
# idx: 1760
# idx: 1761
# idx: 1762
# idx: 1763
# feat_new len: 87312
# idx: 1764
# idx: 1765
# idx: 1766
# idx: 1767
# idx: 1768
# idx: 1769
# idx: 1770
# feat_new len: 87312
# idx: 1771
# idx: 1772
# idx: 1773
# idx: 1774
# idx: 1775
# idx: 1776
# idx: 1777
# feat_new len: 87312
# idx: 1778
# idx: 1779
# idx: 1780
# idx: 1781
# idx: 1782
# idx: 1783
# idx: 1784
# feat_new len: 87312
# idx: 1785
# idx: 1786
# idx: 1787
# idx: 1788
# idx: 1789
# idx: 1790
# idx: 1791
# feat_new len: 87312
# idx: 1792
# idx: 1793
# idx: 1794
# idx: 1795
# idx: 1796
# idx: 1797
# idx: 1798
# feat_new len: 87312
# idx: 1799
# idx: 1800
# idx: 1801
# idx: 1802
# idx: 1803
# idx: 1804
# idx: 1805
# feat_new len: 87312
# idx: 1806
# idx: 1807
# idx: 1808
# idx: 1809
# idx: 1810
# idx: 1811
# idx: 1812
# feat_new len: 87312
# idx: 1813
# idx: 1814
# idx: 1815
# idx: 1816
# idx: 1817
# idx: 1818
# idx: 1819
# feat_new len: 87312
# idx: 1820
# idx: 1821
# idx: 1822
# idx: 1823
# idx: 1824
# idx: 1825
# idx: 1826
# feat_new len: 87312
# idx: 1827
# idx: 1828
# idx: 1829
# idx: 1830
# idx: 1831
# idx: 1832
# idx: 1833
# feat_new len: 87312
# idx: 1834
# idx: 1835
# idx: 1836
# idx: 1837
# idx: 1838
# idx: 1839
# idx: 1840
# feat_new len: 87312
# idx: 1841
# idx: 1842
# idx: 1843
# idx: 1844
# idx: 1845
# idx: 1846
# idx: 1847
# feat_new len: 87312
# idx: 1848
# idx: 1849
# idx: 1850
# idx: 1851
# idx: 1852
# idx: 1853
# idx: 1854
# feat_new len: 87312
# idx: 1855
# idx: 1856
# idx: 1857
# idx: 1858
# idx: 1859
# idx: 1860
# idx: 1861
# feat_new len: 87312
# idx: 1862
# idx: 1863
# idx: 1864
# idx: 1865
# idx: 1866
# idx: 1867
# idx: 1868
# feat_new len: 87312
# idx: 1869
# idx: 1870
# idx: 1871
# idx: 1872
# idx: 1873
# idx: 1874
# idx: 1875
# feat_new len: 87312
# idx: 1876
# idx: 1877
# idx: 1878
# idx: 1879
# idx: 1880
# idx: 1881
# idx: 1882
# feat_new len: 87312
# idx: 1883
# idx: 1884
# idx: 1885
# idx: 1886
# idx: 1887
# idx: 1888
# idx: 1889
# feat_new len: 87312
# 270
# start writing dataFrame to csv:  s3://pepper-dataset/MINNESOTA_data_feature_expanded_CORN.csv
# Data successfully written to 'MINNESOTA data_feature_expanded.csv'
# Data successfully written to 'MINNESOTA_data_label_expanded.csv'
# ++++++++++++
# 270
# 87312
 87312)

# %%
print(data_feature.shape)
print(data_label.shape)
# Out:
# (633, 87312)
# (945, 1)

# %%
def dataReshape(dataIn,debug=True,runOnce=False):
  """Takes the 1D feature array and reshapes to 270x16"""
  print(dataIn.shape)

  dataOut = []
  for idx in range(len(dataIn)):
    dataTemp = dataIn[idx].reshape(5457, 16) #(216,15) 3240
    if debug: print(dataTemp.shape)
    dataOut.append(dataTemp)

    if runOnce: return -1

  return np.array(dataOut)

data_feature_rs = dataReshape(data_feature,debug=False,runOnce=False)
print(data_feature_rs.shape)

#Reshape test
X_test = dataReshape(X_test,debug=False,runOnce=False)
print(X_test.shape)
# Out:
# (633, 87312)
# (633, 5457, 16)
# (312, 87312)
# (312, 5457, 16)

# %%
# Network Parameters
BATCH_SIZE = 32
NUM_EPOCHS = 200
SHUFFLE_BUFFER_SIZE = 64

# Normalize Data
normalizer = Normalization(axis=-1)
normalizer.adapt(data_feature_rs)
data_feature_norm = normalizer(data_feature_rs)

# Normalize Test
normalizer = Normalization(axis=-1)
normalizer.adapt(X_test)
X_test_norm = normalizer(X_test)


# Split into train and test datasets
# Load the Data into a data loader
train_dataset = tf.data.Dataset.from_tensor_slices((data_feature_norm,y_train.T))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test_norm,y_test.T)) #TODO: REPLACE WITH TEST DATASET
DATASET_SIZE = len(data_feature_norm)

# Shuffle & Batch the Datasets
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
# Out:
# 2024-10-24 03:12:20.615535: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-10-24 03:12:20.896427: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 221073984 exceeds 10% of free system memory.
# 2024-10-24 03:12:28.763094: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 221073984 exceeds 10% of free system memory.
# 2024-10-24 03:12:28.947185: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 221073984 exceeds 10% of free system memory.
# 2024-10-24 03:12:29.233157: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 221073984 exceeds 10% of free system memory.

# %%
def step_decay(epoch):
   initial_lrate = 0.1
   drop = 0.5
   epochs_drop = 10.0
   lrate = initial_lrate * math.pow(drop,
           math.floor((1+epoch)/epochs_drop))
   return lrate

# %%
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, Add

def residual_block(input_tensor, filters, kernel_size=2):
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    
    # Add the input tensor back to the output
    x = Add()([x, input_tensor])
    x = Activation('relu')(x)
    return x

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, MaxPooling1D, concatenate
from tensorflow.keras.models import Model

# Input layer
visible = Input(shape=(5457, 16))

# First ResNet Pathway
cnn1 = Conv1D(filters=80, kernel_size=2, padding='same', activation='relu')(visible)
cnn1 = residual_block(cnn1, 80)
cnn1 = MaxPooling1D(pool_size=128)(cnn1)

# Second ResNet Pathway
cnn2 = Conv1D(filters=64, kernel_size=2, padding='same', activation='relu')(visible)
cnn2 = residual_block(cnn2, 64)
cnn2 = MaxPooling1D(pool_size=128)(cnn2)

# Third ResNet Pathway
cnn3 = Conv1D(filters=32, kernel_size=2, padding='same', activation='relu')(visible)
cnn3 = residual_block(cnn3, 32)
cnn3 = MaxPooling1D(pool_size=128)(cnn3)

# Fourth ResNet Pathway
cnn4 = Conv1D(filters=16, kernel_size=2, padding='same', activation='relu')(visible)
cnn4 = residual_block(cnn4, 16)
cnn4 = MaxPooling1D(pool_size=128)(cnn4)

# Concatenate the outputs from all paths
merged = concatenate([cnn1, cnn2, cnn3, cnn4], axis=2)

# Fully connected layer after concatenation
cnn = Dense(16)(merged)

# Flatten the output
cnn = Flatten()(cnn)

# Output layer
output1 = Dense(1, activation='linear')(cnn)

# Define the model
model = Model(inputs=visible, outputs=output1)

model.compile(optimizer='adam', loss='mse', metrics =['accuracy','mean_squared_error','mean_absolute_percentage_error',tf.keras.metrics.RootMeanSquaredError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5457, 16)]           0         []
#
#  conv1d (Conv1D)             (None, 5457, 80)             2640      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 5457, 64)             2112      ['input_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 5457, 32)             1056      ['input_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 5457, 16)             528       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 5457, 80)             12880     ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 5457, 64)             8256      ['conv1d_3[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5457, 32)             2080      ['conv1d_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 5457, 16)             528       ['conv1d_9[0][0]']
#
#  batch_normalization (Batch  (None, 5457, 80)             320       ['conv1d_1[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 5457, 64)             256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 5457, 32)             128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 5457, 16)             64        ['conv1d_10[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 5457, 80)             0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 5457, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 5457, 32)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 5457, 16)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 5457, 80)             12880     ['activation[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5457, 64)             8256      ['activation_2[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 5457, 32)             2080      ['activation_4[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 5457, 16)             528       ['activation_6[0][0]']
#
#  batch_normalization_1 (Bat  (None, 5457, 80)             320       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 5457, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 5457, 32)             128       ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 5457, 16)             64        ['conv1d_11[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 5457, 80)             0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv1d[0][0]']
#
#  add_1 (Add)                 (None, 5457, 64)             0         ['batch_normalization_3[0][0]'
#                                                                     , 'conv1d_3[0][0]']
#
#  add_2 (Add)                 (None, 5457, 32)             0         ['batch_normalization_5[0][0]'
#                                                                     , 'conv1d_6[0][0]']
#
#  add_3 (Add)                 (None, 5457, 16)             0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv1d_9[0][0]']
#
#  activation_1 (Activation)   (None, 5457, 80)             0         ['add[0][0]']
#
#  activation_3 (Activation)   (None, 5457, 64)             0         ['add_1[0][0]']
#
#  activation_5 (Activation)   (None, 5457, 32)             0         ['add_2[0][0]']
#
#  activation_7 (Activation)   (None, 5457, 16)             0         ['add_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 42, 80)               0         ['activation_1[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 42, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 42, 32)               0         ['activation_5[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 42, 16)               0         ['activation_7[0][0]']
#  g1D)
#
#  concatenate (Concatenate)   (None, 42, 192)              0         ['max_pooling1d[0][0]',
#                                                                      'max_pooling1d_1[0][0]',
#                                                                      'max_pooling1d_2[0][0]',
#                                                                      'max_pooling1d_3[0][0]']
#
#  dense (Dense)               (None, 42, 16)               3088      ['concatenate[0][0]']
#
#  flatten (Flatten)           (None, 672)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    673       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 59121 (230.94 KB)
# Trainable params: 58353 (227.94 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________

# %%
# FIT model with TRAINING DATA
history = model.fit(train_dataset, validation_data=test_dataset,epochs=NUM_EPOCHS,verbose=2)
model.summary()

# EVALUATE model with TESTING DATA
model.evaluate(test_dataset, verbose=0)

ynew = model.predict(test_dataset)
print(f'Test Loss: {ynew[0]}')
print(f'Test Mean Squared Error: {ynew[1]}')
print(f'Test Mean Absolute Percentage Error: {ynew[2]}')
print(f'Test Root Mean Squared Error: {ynew[3]}')

fig, ax = plt.subplots()
ax.set_title('Training and Validation \n Mean Absolute Percentage Error') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['mean_absolute_percentage_error'], color = 'blue', label = 'train')

# plt.title('Validation Mean Absolute Percentage Error (MAPE)') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['val_mean_absolute_percentage_error'], color = 'orange', label = 'val')
ax.legend()
# Out:
# 2024-10-24 03:12:30.792799: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 221073984 exceeds 10% of free system memory.
# Epoch 1/200
# 20/20 - 93s - loss: 9505.5625 - accuracy: 0.0000e+00 - mean_squared_error: 9505.5625 - mean_absolute_percentage_error: 48.3173 - root_mean_squared_error: 97.4965 - val_loss: 19536.5586 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 19536.5586 - val_mean_absolute_percentage_error: 77.0254 - val_root_mean_squared_error: 139.7732 - 93s/epoch - 5s/step
# Epoch 2/200
# 20/20 - 57s - loss: 1025.4413 - accuracy: 0.0000e+00 - mean_squared_error: 1025.4413 - mean_absolute_percentage_error: 20.9727 - root_mean_squared_error: 32.0225 - val_loss: 15754.0156 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 15754.0156 - val_mean_absolute_percentage_error: 70.0552 - val_root_mean_squared_error: 125.5150 - 57s/epoch - 3s/step
# Epoch 3/200
# 20/20 - 58s - loss: 1009.9720 - accuracy: 0.0000e+00 - mean_squared_error: 1009.9720 - mean_absolute_percentage_error: 20.9140 - root_mean_squared_error: 31.7801 - val_loss: 14856.7803 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 14856.7803 - val_mean_absolute_percentage_error: 68.2692 - val_root_mean_squared_error: 121.8884 - 58s/epoch - 3s/step
# Epoch 4/200
# 20/20 - 60s - loss: 973.9591 - accuracy: 0.0000e+00 - mean_squared_error: 973.9591 - mean_absolute_percentage_error: 20.4488 - root_mean_squared_error: 31.2083 - val_loss: 13349.9219 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 13349.9219 - val_mean_absolute_percentage_error: 65.1913 - val_root_mean_squared_error: 115.5419 - 60s/epoch - 3s/step
# Epoch 5/200
# 20/20 - 63s - loss: 906.6204 - accuracy: 0.0000e+00 - mean_squared_error: 906.6204 - mean_absolute_percentage_error: 19.8256 - root_mean_squared_error: 30.1101 - val_loss: 12497.3301 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 12497.3301 - val_mean_absolute_percentage_error: 63.3717 - val_root_mean_squared_error: 111.7915 - 63s/epoch - 3s/step
# Epoch 6/200
# 20/20 - 58s - loss: 884.8412 - accuracy: 0.0000e+00 - mean_squared_error: 884.8412 - mean_absolute_percentage_error: 19.4976 - root_mean_squared_error: 29.7463 - val_loss: 11917.3584 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 11917.3584 - val_mean_absolute_percentage_error: 62.0903 - val_root_mean_squared_error: 109.1667 - 58s/epoch - 3s/step
# Epoch 7/200
# 20/20 - 58s - loss: 868.2142 - accuracy: 0.0000e+00 - mean_squared_error: 868.2142 - mean_absolute_percentage_error: 19.3590 - root_mean_squared_error: 29.4655 - val_loss: 10874.1807 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 10874.1807 - val_mean_absolute_percentage_error: 59.7251 - val_root_mean_squared_error: 104.2793 - 58s/epoch - 3s/step
# Epoch 8/200
# 20/20 - 61s - loss: 819.4449 - accuracy: 0.0000e+00 - mean_squared_error: 819.4449 - mean_absolute_percentage_error: 18.8636 - root_mean_squared_error: 28.6259 - val_loss: 10103.8271 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 10103.8271 - val_mean_absolute_percentage_error: 57.9070 - val_root_mean_squared_error: 100.5178 - 61s/epoch - 3s/step
# Epoch 9/200
# 20/20 - 57s - loss: 822.3898 - accuracy: 0.0000e+00 - mean_squared_error: 822.3898 - mean_absolute_percentage_error: 18.9260 - root_mean_squared_error: 28.6773 - val_loss: 9098.8818 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 9098.8818 - val_mean_absolute_percentage_error: 55.4566 - val_root_mean_squared_error: 95.3881 - 57s/epoch - 3s/step
# Epoch 10/200
# 20/20 - 57s - loss: 822.0257 - accuracy: 0.0000e+00 - mean_squared_error: 822.0257 - mean_absolute_percentage_error: 18.6569 - root_mean_squared_error: 28.6710 - val_loss: 8205.8232 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 8205.8232 - val_mean_absolute_percentage_error: 53.1404 - val_root_mean_squared_error: 90.5860 - 57s/epoch - 3s/step
# Epoch 11/200
# 20/20 - 60s - loss: 775.6213 - accuracy: 0.0000e+00 - mean_squared_error: 775.6213 - mean_absolute_percentage_error: 18.3270 - root_mean_squared_error: 27.8500 - val_loss: 7399.3960 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 7399.3960 - val_mean_absolute_percentage_error: 50.9352 - val_root_mean_squared_error: 86.0197 - 60s/epoch - 3s/step
# Epoch 12/200
# 20/20 - 58s - loss: 871.6548 - accuracy: 0.0000e+00 - mean_squared_error: 871.6548 - mean_absolute_percentage_error: 19.2893 - root_mean_squared_error: 29.5238 - val_loss: 5660.8286 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 5660.8286 - val_mean_absolute_percentage_error: 45.6861 - val_root_mean_squared_error: 75.2385 - 58s/epoch - 3s/step
# Epoch 13/200
# 20/20 - 61s - loss: 881.8995 - accuracy: 0.0000e+00 - mean_squared_error: 881.8995 - mean_absolute_percentage_error: 19.3444 - root_mean_squared_error: 29.6968 - val_loss: 4672.2285 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 4672.2285 - val_mean_absolute_percentage_error: 42.3337 - val_root_mean_squared_error: 68.3537 - 61s/epoch - 3s/step
# Epoch 14/200
# 20/20 - 58s - loss: 800.4390 - accuracy: 0.0000e+00 - mean_squared_error: 800.4390 - mean_absolute_percentage_error: 18.4563 - root_mean_squared_error: 28.2920 - val_loss: 3776.3052 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 3776.3052 - val_mean_absolute_percentage_error: 39.0340 - val_root_mean_squared_error: 61.4516 - 58s/epoch - 3s/step
# Epoch 15/200
# 20/20 - 58s - loss: 729.1197 - accuracy: 0.0000e+00 - mean_squared_error: 729.1197 - mean_absolute_percentage_error: 17.6866 - root_mean_squared_error: 27.0022 - val_loss: 2875.9448 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2875.9448 - val_mean_absolute_percentage_error: 35.2731 - val_root_mean_squared_error: 53.6278 - 58s/epoch - 3s/step
# Epoch 16/200
# 20/20 - 60s - loss: 730.7039 - accuracy: 0.0000e+00 - mean_squared_error: 730.7039 - mean_absolute_percentage_error: 17.6045 - root_mean_squared_error: 27.0315 - val_loss: 3112.2314 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 3112.2314 - val_mean_absolute_percentage_error: 36.2756 - val_root_mean_squared_error: 55.7874 - 60s/epoch - 3s/step
# Epoch 17/200
# 20/20 - 58s - loss: 691.1740 - accuracy: 0.0000e+00 - mean_squared_error: 691.1740 - mean_absolute_percentage_error: 17.2480 - root_mean_squared_error: 26.2902 - val_loss: 2750.7932 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2750.7932 - val_mean_absolute_percentage_error: 34.6650 - val_root_mean_squared_error: 52.4480 - 58s/epoch - 3s/step
# Epoch 18/200
# 20/20 - 57s - loss: 676.2587 - accuracy: 0.0000e+00 - mean_squared_error: 676.2587 - mean_absolute_percentage_error: 17.0563 - root_mean_squared_error: 26.0050 - val_loss: 2564.5078 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2564.5078 - val_mean_absolute_percentage_error: 33.7757 - val_root_mean_squared_error: 50.6410 - 57s/epoch - 3s/step
# Epoch 19/200
# 20/20 - 62s - loss: 654.2468 - accuracy: 0.0000e+00 - mean_squared_error: 654.2468 - mean_absolute_percentage_error: 16.8270 - root_mean_squared_error: 25.5782 - val_loss: 2235.5520 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2235.5520 - val_mean_absolute_percentage_error: 32.1238 - val_root_mean_squared_error: 47.2816 - 62s/epoch - 3s/step
# Epoch 20/200
# 20/20 - 57s - loss: 620.4298 - accuracy: 0.0000e+00 - mean_squared_error: 620.4298 - mean_absolute_percentage_error: 16.3408 - root_mean_squared_error: 24.9084 - val_loss: 2031.2262 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2031.2262 - val_mean_absolute_percentage_error: 31.0351 - val_root_mean_squared_error: 45.0691 - 57s/epoch - 3s/step
# Epoch 21/200
# 20/20 - 57s - loss: 614.6151 - accuracy: 0.0000e+00 - mean_squared_error: 614.6151 - mean_absolute_percentage_error: 16.1307 - root_mean_squared_error: 24.7914 - val_loss: 1709.3113 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1709.3113 - val_mean_absolute_percentage_error: 29.1841 - val_root_mean_squared_error: 41.3438 - 57s/epoch - 3s/step
# Epoch 22/200
# 20/20 - 62s - loss: 726.6699 - accuracy: 0.0000e+00 - mean_squared_error: 726.6699 - mean_absolute_percentage_error: 17.6866 - root_mean_squared_error: 26.9568 - val_loss: 906.1815 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 906.1815 - val_mean_absolute_percentage_error: 23.6689 - val_root_mean_squared_error: 30.1028 - 62s/epoch - 3s/step
# Epoch 23/200
# 20/20 - 57s - loss: 670.4460 - accuracy: 0.0000e+00 - mean_squared_error: 670.4460 - mean_absolute_percentage_error: 17.0192 - root_mean_squared_error: 25.8930 - val_loss: 869.8698 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 869.8698 - val_mean_absolute_percentage_error: 23.2587 - val_root_mean_squared_error: 29.4936 - 57s/epoch - 3s/step
# Epoch 24/200
# 20/20 - 63s - loss: 597.8889 - accuracy: 0.0000e+00 - mean_squared_error: 597.8889 - mean_absolute_percentage_error: 15.9550 - root_mean_squared_error: 24.4518 - val_loss: 921.0130 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 921.0130 - val_mean_absolute_percentage_error: 23.5393 - val_root_mean_squared_error: 30.3482 - 63s/epoch - 3s/step
# Epoch 25/200
# 20/20 - 58s - loss: 636.8164 - accuracy: 0.0000e+00 - mean_squared_error: 636.8164 - mean_absolute_percentage_error: 16.4200 - root_mean_squared_error: 25.2352 - val_loss: 1050.0940 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1050.0940 - val_mean_absolute_percentage_error: 24.5465 - val_root_mean_squared_error: 32.4052 - 58s/epoch - 3s/step
# Epoch 26/200
# 20/20 - 58s - loss: 657.3603 - accuracy: 0.0000e+00 - mean_squared_error: 657.3603 - mean_absolute_percentage_error: 16.6263 - root_mean_squared_error: 25.6390 - val_loss: 836.9959 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 836.9959 - val_mean_absolute_percentage_error: 22.6917 - val_root_mean_squared_error: 28.9309 - 58s/epoch - 3s/step
# Epoch 27/200
# 20/20 - 62s - loss: 633.5864 - accuracy: 0.0000e+00 - mean_squared_error: 633.5864 - mean_absolute_percentage_error: 16.4637 - root_mean_squared_error: 25.1711 - val_loss: 798.4464 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 798.4464 - val_mean_absolute_percentage_error: 22.3602 - val_root_mean_squared_error: 28.2568 - 62s/epoch - 3s/step
# Epoch 28/200
# 20/20 - 58s - loss: 586.1954 - accuracy: 0.0000e+00 - mean_squared_error: 586.1954 - mean_absolute_percentage_error: 15.7649 - root_mean_squared_error: 24.2115 - val_loss: 806.6377 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 806.6377 - val_mean_absolute_percentage_error: 22.2877 - val_root_mean_squared_error: 28.4014 - 58s/epoch - 3s/step
# Epoch 29/200
# 20/20 - 60s - loss: 575.3785 - accuracy: 0.0000e+00 - mean_squared_error: 575.3785 - mean_absolute_percentage_error: 15.5692 - root_mean_squared_error: 23.9870 - val_loss: 809.0997 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 809.0997 - val_mean_absolute_percentage_error: 22.2764 - val_root_mean_squared_error: 28.4447 - 60s/epoch - 3s/step
# Epoch 30/200
# 20/20 - 56s - loss: 549.3758 - accuracy: 0.0000e+00 - mean_squared_error: 549.3758 - mean_absolute_percentage_error: 15.3322 - root_mean_squared_error: 23.4388 - val_loss: 851.5953 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 851.5953 - val_mean_absolute_percentage_error: 22.6686 - val_root_mean_squared_error: 29.1821 - 56s/epoch - 3s/step
# Epoch 31/200
# 20/20 - 58s - loss: 528.7947 - accuracy: 0.0000e+00 - mean_squared_error: 528.7947 - mean_absolute_percentage_error: 15.0744 - root_mean_squared_error: 22.9955 - val_loss: 855.6656 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 855.6656 - val_mean_absolute_percentage_error: 22.7225 - val_root_mean_squared_error: 29.2518 - 58s/epoch - 3s/step
# Epoch 32/200
# 20/20 - 60s - loss: 528.9080 - accuracy: 0.0000e+00 - mean_squared_error: 528.9080 - mean_absolute_percentage_error: 15.0240 - root_mean_squared_error: 22.9980 - val_loss: 934.5605 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 934.5605 - val_mean_absolute_percentage_error: 23.4685 - val_root_mean_squared_error: 30.5706 - 60s/epoch - 3s/step
# Epoch 33/200
# 20/20 - 58s - loss: 539.6761 - accuracy: 0.0000e+00 - mean_squared_error: 539.6761 - mean_absolute_percentage_error: 15.2042 - root_mean_squared_error: 23.2309 - val_loss: 729.2197 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 729.2197 - val_mean_absolute_percentage_error: 21.4287 - val_root_mean_squared_error: 27.0041 - 58s/epoch - 3s/step
# Epoch 34/200
# 20/20 - 57s - loss: 566.3286 - accuracy: 0.0000e+00 - mean_squared_error: 566.3286 - mean_absolute_percentage_error: 15.4798 - root_mean_squared_error: 23.7977 - val_loss: 681.7716 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 681.7716 - val_mean_absolute_percentage_error: 21.1568 - val_root_mean_squared_error: 26.1108 - 57s/epoch - 3s/step
# Epoch 35/200
# 20/20 - 56s - loss: 543.3770 - accuracy: 0.0000e+00 - mean_squared_error: 543.3770 - mean_absolute_percentage_error: 15.1889 - root_mean_squared_error: 23.3104 - val_loss: 660.6218 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 660.6218 - val_mean_absolute_percentage_error: 21.1662 - val_root_mean_squared_error: 25.7026 - 56s/epoch - 3s/step
# Epoch 36/200
# 20/20 - 57s - loss: 520.2465 - accuracy: 0.0000e+00 - mean_squared_error: 520.2465 - mean_absolute_percentage_error: 14.8237 - root_mean_squared_error: 22.8089 - val_loss: 695.8919 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 695.8919 - val_mean_absolute_percentage_error: 21.0353 - val_root_mean_squared_error: 26.3798 - 57s/epoch - 3s/step
# Epoch 37/200
# 20/20 - 60s - loss: 505.5977 - accuracy: 0.0000e+00 - mean_squared_error: 505.5977 - mean_absolute_percentage_error: 14.6809 - root_mean_squared_error: 22.4855 - val_loss: 706.3635 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 706.3635 - val_mean_absolute_percentage_error: 21.1416 - val_root_mean_squared_error: 26.5775 - 60s/epoch - 3s/step
# Epoch 38/200
# 20/20 - 57s - loss: 469.5443 - accuracy: 0.0000e+00 - mean_squared_error: 469.5443 - mean_absolute_percentage_error: 14.1975 - root_mean_squared_error: 21.6690 - val_loss: 689.8692 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 689.8692 - val_mean_absolute_percentage_error: 20.9575 - val_root_mean_squared_error: 26.2654 - 57s/epoch - 3s/step
# Epoch 39/200
# 20/20 - 58s - loss: 481.0644 - accuracy: 0.0000e+00 - mean_squared_error: 481.0644 - mean_absolute_percentage_error: 14.2348 - root_mean_squared_error: 21.9332 - val_loss: 674.4556 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 674.4556 - val_mean_absolute_percentage_error: 20.8320 - val_root_mean_squared_error: 25.9703 - 58s/epoch - 3s/step
# Epoch 40/200
# 20/20 - 57s - loss: 437.8673 - accuracy: 0.0000e+00 - mean_squared_error: 437.8673 - mean_absolute_percentage_error: 13.5989 - root_mean_squared_error: 20.9253 - val_loss: 696.9269 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 696.9269 - val_mean_absolute_percentage_error: 21.1053 - val_root_mean_squared_error: 26.3994 - 57s/epoch - 3s/step
# Epoch 41/200
# 20/20 - 58s - loss: 444.4733 - accuracy: 0.0000e+00 - mean_squared_error: 444.4733 - mean_absolute_percentage_error: 13.6577 - root_mean_squared_error: 21.0825 - val_loss: 676.2621 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 676.2621 - val_mean_absolute_percentage_error: 20.8788 - val_root_mean_squared_error: 26.0050 - 58s/epoch - 3s/step
# Epoch 42/200
# 20/20 - 63s - loss: 435.0996 - accuracy: 0.0000e+00 - mean_squared_error: 435.0996 - mean_absolute_percentage_error: 13.5704 - root_mean_squared_error: 20.8590 - val_loss: 672.1561 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 672.1561 - val_mean_absolute_percentage_error: 20.8607 - val_root_mean_squared_error: 25.9260 - 63s/epoch - 3s/step
# Epoch 43/200
# 20/20 - 58s - loss: 422.5598 - accuracy: 0.0000e+00 - mean_squared_error: 422.5598 - mean_absolute_percentage_error: 13.4274 - root_mean_squared_error: 20.5563 - val_loss: 809.8788 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 809.8788 - val_mean_absolute_percentage_error: 22.2932 - val_root_mean_squared_error: 28.4584 - 58s/epoch - 3s/step
# Epoch 44/200
# 20/20 - 58s - loss: 471.1487 - accuracy: 0.0000e+00 - mean_squared_error: 471.1487 - mean_absolute_percentage_error: 14.0743 - root_mean_squared_error: 21.7060 - val_loss: 619.8239 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 619.8239 - val_mean_absolute_percentage_error: 20.2853 - val_root_mean_squared_error: 24.8963 - 58s/epoch - 3s/step
# Epoch 45/200
# 20/20 - 60s - loss: 440.9521 - accuracy: 0.0000e+00 - mean_squared_error: 440.9521 - mean_absolute_percentage_error: 13.5788 - root_mean_squared_error: 20.9989 - val_loss: 611.4167 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 611.4167 - val_mean_absolute_percentage_error: 20.3213 - val_root_mean_squared_error: 24.7268 - 60s/epoch - 3s/step
# Epoch 46/200
# 20/20 - 57s - loss: 415.6507 - accuracy: 0.0000e+00 - mean_squared_error: 415.6507 - mean_absolute_percentage_error: 13.2812 - root_mean_squared_error: 20.3875 - val_loss: 603.3255 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 603.3255 - val_mean_absolute_percentage_error: 20.2409 - val_root_mean_squared_error: 24.5627 - 57s/epoch - 3s/step
# Epoch 47/200
# 20/20 - 58s - loss: 421.3385 - accuracy: 0.0000e+00 - mean_squared_error: 421.3385 - mean_absolute_percentage_error: 13.3876 - root_mean_squared_error: 20.5265 - val_loss: 604.6567 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 604.6567 - val_mean_absolute_percentage_error: 20.2160 - val_root_mean_squared_error: 24.5898 - 58s/epoch - 3s/step
# Epoch 48/200
# 20/20 - 57s - loss: 405.7282 - accuracy: 0.0000e+00 - mean_squared_error: 405.7282 - mean_absolute_percentage_error: 13.1127 - root_mean_squared_error: 20.1427 - val_loss: 630.0113 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 630.0113 - val_mean_absolute_percentage_error: 20.3495 - val_root_mean_squared_error: 25.1000 - 57s/epoch - 3s/step
# Epoch 49/200
# 20/20 - 56s - loss: 384.4310 - accuracy: 0.0000e+00 - mean_squared_error: 384.4310 - mean_absolute_percentage_error: 12.7039 - root_mean_squared_error: 19.6069 - val_loss: 621.8671 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 621.8671 - val_mean_absolute_percentage_error: 20.3155 - val_root_mean_squared_error: 24.9373 - 56s/epoch - 3s/step
# Epoch 50/200
# 20/20 - 60s - loss: 407.3896 - accuracy: 0.0000e+00 - mean_squared_error: 407.3896 - mean_absolute_percentage_error: 12.9627 - root_mean_squared_error: 20.1839 - val_loss: 595.1276 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 595.1276 - val_mean_absolute_percentage_error: 20.2052 - val_root_mean_squared_error: 24.3952 - 60s/epoch - 3s/step
# Epoch 51/200
# 20/20 - 58s - loss: 405.4655 - accuracy: 0.0000e+00 - mean_squared_error: 405.4655 - mean_absolute_percentage_error: 13.1736 - root_mean_squared_error: 20.1362 - val_loss: 624.9327 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 624.9327 - val_mean_absolute_percentage_error: 20.3445 - val_root_mean_squared_error: 24.9987 - 58s/epoch - 3s/step
# Epoch 52/200
# 20/20 - 60s - loss: 440.0560 - accuracy: 0.0000e+00 - mean_squared_error: 440.0560 - mean_absolute_percentage_error: 13.4899 - root_mean_squared_error: 20.9775 - val_loss: 585.6564 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 585.6564 - val_mean_absolute_percentage_error: 19.8543 - val_root_mean_squared_error: 24.2003 - 60s/epoch - 3s/step
# Epoch 53/200
# 20/20 - 58s - loss: 414.5914 - accuracy: 0.0000e+00 - mean_squared_error: 414.5914 - mean_absolute_percentage_error: 13.2409 - root_mean_squared_error: 20.3615 - val_loss: 628.6363 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 628.6363 - val_mean_absolute_percentage_error: 21.0715 - val_root_mean_squared_error: 25.0726 - 58s/epoch - 3s/step
# Epoch 54/200
# 20/20 - 58s - loss: 402.8623 - accuracy: 0.0000e+00 - mean_squared_error: 402.8623 - mean_absolute_percentage_error: 13.1139 - root_mean_squared_error: 20.0714 - val_loss: 586.9965 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 586.9965 - val_mean_absolute_percentage_error: 19.8769 - val_root_mean_squared_error: 24.2280 - 58s/epoch - 3s/step
# Epoch 55/200
# 20/20 - 61s - loss: 393.4687 - accuracy: 0.0000e+00 - mean_squared_error: 393.4687 - mean_absolute_percentage_error: 12.7947 - root_mean_squared_error: 19.8360 - val_loss: 593.8520 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 593.8520 - val_mean_absolute_percentage_error: 20.0321 - val_root_mean_squared_error: 24.3691 - 61s/epoch - 3s/step
# Epoch 56/200
# 20/20 - 60s - loss: 382.8482 - accuracy: 0.0000e+00 - mean_squared_error: 382.8482 - mean_absolute_percentage_error: 12.5642 - root_mean_squared_error: 19.5665 - val_loss: 581.0361 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 581.0361 - val_mean_absolute_percentage_error: 19.9049 - val_root_mean_squared_error: 24.1047 - 60s/epoch - 3s/step
# Epoch 57/200
# 20/20 - 61s - loss: 385.5287 - accuracy: 0.0000e+00 - mean_squared_error: 385.5287 - mean_absolute_percentage_error: 12.7149 - root_mean_squared_error: 19.6349 - val_loss: 576.3087 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 576.3087 - val_mean_absolute_percentage_error: 19.9169 - val_root_mean_squared_error: 24.0064 - 61s/epoch - 3s/step
# Epoch 58/200
# 20/20 - 58s - loss: 371.4595 - accuracy: 0.0000e+00 - mean_squared_error: 371.4595 - mean_absolute_percentage_error: 12.4556 - root_mean_squared_error: 19.2733 - val_loss: 595.2892 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 595.2892 - val_mean_absolute_percentage_error: 20.3617 - val_root_mean_squared_error: 24.3985 - 58s/epoch - 3s/step
# Epoch 59/200
# 20/20 - 61s - loss: 353.6916 - accuracy: 0.0000e+00 - mean_squared_error: 353.6916 - mean_absolute_percentage_error: 12.0458 - root_mean_squared_error: 18.8067 - val_loss: 582.5746 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 582.5746 - val_mean_absolute_percentage_error: 19.9661 - val_root_mean_squared_error: 24.1366 - 61s/epoch - 3s/step
# Epoch 60/200
# 20/20 - 57s - loss: 384.0179 - accuracy: 0.0000e+00 - mean_squared_error: 384.0179 - mean_absolute_percentage_error: 12.6458 - root_mean_squared_error: 19.5964 - val_loss: 598.7360 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 598.7360 - val_mean_absolute_percentage_error: 20.5672 - val_root_mean_squared_error: 24.4691 - 57s/epoch - 3s/step
# Epoch 61/200
# 20/20 - 58s - loss: 360.3370 - accuracy: 0.0000e+00 - mean_squared_error: 360.3370 - mean_absolute_percentage_error: 12.1915 - root_mean_squared_error: 18.9825 - val_loss: 581.2643 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 581.2643 - val_mean_absolute_percentage_error: 19.9277 - val_root_mean_squared_error: 24.1094 - 58s/epoch - 3s/step
# Epoch 62/200
# 20/20 - 65s - loss: 345.4100 - accuracy: 0.0000e+00 - mean_squared_error: 345.4100 - mean_absolute_percentage_error: 12.0482 - root_mean_squared_error: 18.5852 - val_loss: 621.5380 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 621.5380 - val_mean_absolute_percentage_error: 20.2192 - val_root_mean_squared_error: 24.9307 - 65s/epoch - 3s/step
# Epoch 63/200
# 20/20 - 58s - loss: 390.9786 - accuracy: 0.0000e+00 - mean_squared_error: 390.9786 - mean_absolute_percentage_error: 12.5863 - root_mean_squared_error: 19.7732 - val_loss: 596.6046 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 596.6046 - val_mean_absolute_percentage_error: 20.4728 - val_root_mean_squared_error: 24.4255 - 58s/epoch - 3s/step
# Epoch 64/200
# 20/20 - 60s - loss: 376.1657 - accuracy: 0.0000e+00 - mean_squared_error: 376.1657 - mean_absolute_percentage_error: 12.5688 - root_mean_squared_error: 19.3950 - val_loss: 569.5200 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 569.5200 - val_mean_absolute_percentage_error: 19.8199 - val_root_mean_squared_error: 23.8646 - 60s/epoch - 3s/step
# Epoch 65/200
# 20/20 - 56s - loss: 349.7831 - accuracy: 0.0000e+00 - mean_squared_error: 349.7831 - mean_absolute_percentage_error: 12.0141 - root_mean_squared_error: 18.7025 - val_loss: 571.5213 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 571.5213 - val_mean_absolute_percentage_error: 19.9164 - val_root_mean_squared_error: 23.9065 - 56s/epoch - 3s/step
# Epoch 66/200
# 20/20 - 61s - loss: 331.3920 - accuracy: 0.0000e+00 - mean_squared_error: 331.3920 - mean_absolute_percentage_error: 11.6904 - root_mean_squared_error: 18.2042 - val_loss: 590.7668 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 590.7668 - val_mean_absolute_percentage_error: 19.9438 - val_root_mean_squared_error: 24.3057 - 61s/epoch - 3s/step
# Epoch 67/200
# 20/20 - 57s - loss: 335.8171 - accuracy: 0.0000e+00 - mean_squared_error: 335.8171 - mean_absolute_percentage_error: 11.7385 - root_mean_squared_error: 18.3253 - val_loss: 575.4081 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 575.4081 - val_mean_absolute_percentage_error: 19.9818 - val_root_mean_squared_error: 23.9877 - 57s/epoch - 3s/step
# Epoch 68/200
# 20/20 - 57s - loss: 326.8178 - accuracy: 0.0000e+00 - mean_squared_error: 326.8178 - mean_absolute_percentage_error: 11.5734 - root_mean_squared_error: 18.0781 - val_loss: 575.7462 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 575.7462 - val_mean_absolute_percentage_error: 19.9683 - val_root_mean_squared_error: 23.9947 - 57s/epoch - 3s/step
# Epoch 69/200
# 20/20 - 60s - loss: 333.0964 - accuracy: 0.0000e+00 - mean_squared_error: 333.0964 - mean_absolute_percentage_error: 11.6280 - root_mean_squared_error: 18.2509 - val_loss: 566.3482 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 566.3482 - val_mean_absolute_percentage_error: 19.7516 - val_root_mean_squared_error: 23.7981 - 60s/epoch - 3s/step
# Epoch 70/200
# 20/20 - 56s - loss: 353.3652 - accuracy: 0.0000e+00 - mean_squared_error: 353.3652 - mean_absolute_percentage_error: 12.1492 - root_mean_squared_error: 18.7980 - val_loss: 571.1788 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 571.1788 - val_mean_absolute_percentage_error: 19.9267 - val_root_mean_squared_error: 23.8993 - 56s/epoch - 3s/step
# Epoch 71/200
# 20/20 - 57s - loss: 322.4292 - accuracy: 0.0000e+00 - mean_squared_error: 322.4292 - mean_absolute_percentage_error: 11.5526 - root_mean_squared_error: 17.9563 - val_loss: 598.7363 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 598.7363 - val_mean_absolute_percentage_error: 19.9911 - val_root_mean_squared_error: 24.4691 - 57s/epoch - 3s/step
# Epoch 72/200
# 20/20 - 56s - loss: 364.5563 - accuracy: 0.0000e+00 - mean_squared_error: 364.5563 - mean_absolute_percentage_error: 12.0676 - root_mean_squared_error: 19.0934 - val_loss: 621.6595 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 621.6595 - val_mean_absolute_percentage_error: 21.0148 - val_root_mean_squared_error: 24.9331 - 56s/epoch - 3s/step
# Epoch 73/200
# 20/20 - 56s - loss: 358.2480 - accuracy: 0.0000e+00 - mean_squared_error: 358.2480 - mean_absolute_percentage_error: 12.2262 - root_mean_squared_error: 18.9274 - val_loss: 595.2450 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 595.2450 - val_mean_absolute_percentage_error: 20.5525 - val_root_mean_squared_error: 24.3976 - 56s/epoch - 3s/step
# Epoch 74/200
# 20/20 - 60s - loss: 335.8922 - accuracy: 0.0000e+00 - mean_squared_error: 335.8922 - mean_absolute_percentage_error: 11.7889 - root_mean_squared_error: 18.3274 - val_loss: 632.2510 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 632.2510 - val_mean_absolute_percentage_error: 21.2324 - val_root_mean_squared_error: 25.1446 - 60s/epoch - 3s/step
# Epoch 75/200
# 20/20 - 58s - loss: 350.1793 - accuracy: 0.0000e+00 - mean_squared_error: 350.1793 - mean_absolute_percentage_error: 11.9600 - root_mean_squared_error: 18.7131 - val_loss: 573.0630 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 573.0630 - val_mean_absolute_percentage_error: 19.5653 - val_root_mean_squared_error: 23.9387 - 58s/epoch - 3s/step
# Epoch 76/200
# 20/20 - 56s - loss: 374.6136 - accuracy: 0.0000e+00 - mean_squared_error: 374.6136 - mean_absolute_percentage_error: 12.5098 - root_mean_squared_error: 19.3549 - val_loss: 667.6866 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 667.6866 - val_mean_absolute_percentage_error: 21.8706 - val_root_mean_squared_error: 25.8396 - 56s/epoch - 3s/step
# Epoch 77/200
# 20/20 - 56s - loss: 320.6566 - accuracy: 0.0000e+00 - mean_squared_error: 320.6566 - mean_absolute_percentage_error: 11.4679 - root_mean_squared_error: 17.9069 - val_loss: 627.8737 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 627.8737 - val_mean_absolute_percentage_error: 21.1952 - val_root_mean_squared_error: 25.0574 - 56s/epoch - 3s/step
# Epoch 78/200
# 20/20 - 57s - loss: 312.4756 - accuracy: 0.0000e+00 - mean_squared_error: 312.4756 - mean_absolute_percentage_error: 11.2761 - root_mean_squared_error: 17.6770 - val_loss: 570.8759 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 570.8759 - val_mean_absolute_percentage_error: 19.7144 - val_root_mean_squared_error: 23.8930 - 57s/epoch - 3s/step
# Epoch 79/200
# 20/20 - 59s - loss: 304.3896 - accuracy: 0.0000e+00 - mean_squared_error: 304.3896 - mean_absolute_percentage_error: 11.1651 - root_mean_squared_error: 17.4468 - val_loss: 577.6057 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 577.6057 - val_mean_absolute_percentage_error: 19.8086 - val_root_mean_squared_error: 24.0334 - 59s/epoch - 3s/step
# Epoch 80/200
# 20/20 - 57s - loss: 288.1747 - accuracy: 0.0000e+00 - mean_squared_error: 288.1747 - mean_absolute_percentage_error: 10.6972 - root_mean_squared_error: 16.9757 - val_loss: 564.0987 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 564.0987 - val_mean_absolute_percentage_error: 19.6762 - val_root_mean_squared_error: 23.7508 - 57s/epoch - 3s/step
# Epoch 81/200
# 20/20 - 57s - loss: 298.6660 - accuracy: 0.0000e+00 - mean_squared_error: 298.6660 - mean_absolute_percentage_error: 10.8934 - root_mean_squared_error: 17.2820 - val_loss: 588.2179 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 588.2179 - val_mean_absolute_percentage_error: 20.4025 - val_root_mean_squared_error: 24.2532 - 57s/epoch - 3s/step
# Epoch 82/200
# 20/20 - 62s - loss: 295.8957 - accuracy: 0.0000e+00 - mean_squared_error: 295.8957 - mean_absolute_percentage_error: 10.9234 - root_mean_squared_error: 17.2016 - val_loss: 563.6592 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 563.6592 - val_mean_absolute_percentage_error: 19.5747 - val_root_mean_squared_error: 23.7415 - 62s/epoch - 3s/step
# Epoch 83/200
# 20/20 - 58s - loss: 296.5800 - accuracy: 0.0000e+00 - mean_squared_error: 296.5800 - mean_absolute_percentage_error: 10.9107 - root_mean_squared_error: 17.2215 - val_loss: 573.4471 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 573.4471 - val_mean_absolute_percentage_error: 19.8891 - val_root_mean_squared_error: 23.9468 - 58s/epoch - 3s/step
# Epoch 84/200
# 20/20 - 56s - loss: 286.2199 - accuracy: 0.0000e+00 - mean_squared_error: 286.2199 - mean_absolute_percentage_error: 10.7293 - root_mean_squared_error: 16.9180 - val_loss: 562.2648 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 562.2648 - val_mean_absolute_percentage_error: 19.6147 - val_root_mean_squared_error: 23.7121 - 56s/epoch - 3s/step
# Epoch 85/200
# 20/20 - 57s - loss: 304.2540 - accuracy: 0.0000e+00 - mean_squared_error: 304.2540 - mean_absolute_percentage_error: 11.2171 - root_mean_squared_error: 17.4429 - val_loss: 597.1173 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 597.1173 - val_mean_absolute_percentage_error: 20.4976 - val_root_mean_squared_error: 24.4360 - 57s/epoch - 3s/step
# Epoch 86/200
# 20/20 - 56s - loss: 299.7243 - accuracy: 0.0000e+00 - mean_squared_error: 299.7243 - mean_absolute_percentage_error: 10.9266 - root_mean_squared_error: 17.3125 - val_loss: 620.0586 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 620.0586 - val_mean_absolute_percentage_error: 20.9308 - val_root_mean_squared_error: 24.9010 - 56s/epoch - 3s/step
# Epoch 87/200
# 20/20 - 59s - loss: 284.4549 - accuracy: 0.0000e+00 - mean_squared_error: 284.4549 - mean_absolute_percentage_error: 10.7154 - root_mean_squared_error: 16.8658 - val_loss: 595.1011 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 595.1011 - val_mean_absolute_percentage_error: 19.8983 - val_root_mean_squared_error: 24.3947 - 59s/epoch - 3s/step
# Epoch 88/200
# 20/20 - 58s - loss: 328.6067 - accuracy: 0.0000e+00 - mean_squared_error: 328.6067 - mean_absolute_percentage_error: 11.5303 - root_mean_squared_error: 18.1275 - val_loss: 588.2944 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 588.2944 - val_mean_absolute_percentage_error: 20.2953 - val_root_mean_squared_error: 24.2548 - 58s/epoch - 3s/step
# Epoch 89/200
# 20/20 - 57s - loss: 290.6484 - accuracy: 0.0000e+00 - mean_squared_error: 290.6484 - mean_absolute_percentage_error: 10.7170 - root_mean_squared_error: 17.0484 - val_loss: 566.3394 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 566.3394 - val_mean_absolute_percentage_error: 19.7967 - val_root_mean_squared_error: 23.7979 - 57s/epoch - 3s/step
# Epoch 90/200
# 20/20 - 60s - loss: 267.8321 - accuracy: 0.0000e+00 - mean_squared_error: 267.8321 - mean_absolute_percentage_error: 10.4144 - root_mean_squared_error: 16.3656 - val_loss: 571.5266 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 571.5266 - val_mean_absolute_percentage_error: 19.8102 - val_root_mean_squared_error: 23.9066 - 60s/epoch - 3s/step
# Epoch 91/200
# 20/20 - 56s - loss: 262.5077 - accuracy: 0.0000e+00 - mean_squared_error: 262.5077 - mean_absolute_percentage_error: 10.1472 - root_mean_squared_error: 16.2021 - val_loss: 561.9991 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 561.9991 - val_mean_absolute_percentage_error: 19.6327 - val_root_mean_squared_error: 23.7065 - 56s/epoch - 3s/step
# Epoch 92/200
# 20/20 - 60s - loss: 264.8636 - accuracy: 0.0000e+00 - mean_squared_error: 264.8636 - mean_absolute_percentage_error: 10.2065 - root_mean_squared_error: 16.2746 - val_loss: 570.7788 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 570.7788 - val_mean_absolute_percentage_error: 19.6212 - val_root_mean_squared_error: 23.8910 - 60s/epoch - 3s/step
# Epoch 93/200
# 20/20 - 57s - loss: 271.1466 - accuracy: 0.0000e+00 - mean_squared_error: 271.1466 - mean_absolute_percentage_error: 10.3529 - root_mean_squared_error: 16.4665 - val_loss: 563.5886 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 563.5886 - val_mean_absolute_percentage_error: 19.7183 - val_root_mean_squared_error: 23.7400 - 57s/epoch - 3s/step
# Epoch 94/200
# 20/20 - 57s - loss: 251.5900 - accuracy: 0.0000e+00 - mean_squared_error: 251.5900 - mean_absolute_percentage_error: 9.9580 - root_mean_squared_error: 15.8616 - val_loss: 572.2524 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 572.2524 - val_mean_absolute_percentage_error: 19.4451 - val_root_mean_squared_error: 23.9218 - 57s/epoch - 3s/step
# Epoch 95/200
# 20/20 - 61s - loss: 265.6926 - accuracy: 0.0000e+00 - mean_squared_error: 265.6926 - mean_absolute_percentage_error: 10.2856 - root_mean_squared_error: 16.3001 - val_loss: 607.3953 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 607.3953 - val_mean_absolute_percentage_error: 19.9066 - val_root_mean_squared_error: 24.6454 - 61s/epoch - 3s/step
# Epoch 96/200
# 20/20 - 57s - loss: 258.4313 - accuracy: 0.0000e+00 - mean_squared_error: 258.4313 - mean_absolute_percentage_error: 10.1069 - root_mean_squared_error: 16.0758 - val_loss: 569.2254 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 569.2254 - val_mean_absolute_percentage_error: 19.6125 - val_root_mean_squared_error: 23.8584 - 57s/epoch - 3s/step
# Epoch 97/200
# 20/20 - 57s - loss: 297.7319 - accuracy: 0.0000e+00 - mean_squared_error: 297.7319 - mean_absolute_percentage_error: 10.9088 - root_mean_squared_error: 17.2549 - val_loss: 669.6794 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 669.6794 - val_mean_absolute_percentage_error: 21.7553 - val_root_mean_squared_error: 25.8782 - 57s/epoch - 3s/step
# Epoch 98/200
# 20/20 - 59s - loss: 269.0975 - accuracy: 0.0000e+00 - mean_squared_error: 269.0975 - mean_absolute_percentage_error: 10.3471 - root_mean_squared_error: 16.4042 - val_loss: 583.8860 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 583.8860 - val_mean_absolute_percentage_error: 20.0398 - val_root_mean_squared_error: 24.1637 - 59s/epoch - 3s/step
# Epoch 99/200
# 20/20 - 58s - loss: 248.6188 - accuracy: 0.0000e+00 - mean_squared_error: 248.6188 - mean_absolute_percentage_error: 9.8345 - root_mean_squared_error: 15.7677 - val_loss: 563.1441 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 563.1441 - val_mean_absolute_percentage_error: 19.5606 - val_root_mean_squared_error: 23.7307 - 58s/epoch - 3s/step
# Epoch 100/200
# 20/20 - 57s - loss: 235.7896 - accuracy: 0.0000e+00 - mean_squared_error: 235.7896 - mean_absolute_percentage_error: 9.5310 - root_mean_squared_error: 15.3554 - val_loss: 573.9254 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 573.9254 - val_mean_absolute_percentage_error: 19.5513 - val_root_mean_squared_error: 23.9567 - 57s/epoch - 3s/step
# Epoch 101/200
# 20/20 - 60s - loss: 245.4352 - accuracy: 0.0000e+00 - mean_squared_error: 245.4352 - mean_absolute_percentage_error: 9.7799 - root_mean_squared_error: 15.6664 - val_loss: 573.5895 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 573.5895 - val_mean_absolute_percentage_error: 19.7542 - val_root_mean_squared_error: 23.9497 - 60s/epoch - 3s/step
# Epoch 102/200
# 20/20 - 57s - loss: 258.8391 - accuracy: 0.0000e+00 - mean_squared_error: 258.8391 - mean_absolute_percentage_error: 10.0943 - root_mean_squared_error: 16.0885 - val_loss: 578.7038 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 578.7038 - val_mean_absolute_percentage_error: 19.9869 - val_root_mean_squared_error: 24.0563 - 57s/epoch - 3s/step
# Epoch 103/200
# 20/20 - 60s - loss: 283.1574 - accuracy: 0.0000e+00 - mean_squared_error: 283.1574 - mean_absolute_percentage_error: 10.5670 - root_mean_squared_error: 16.8273 - val_loss: 726.4968 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 726.4968 - val_mean_absolute_percentage_error: 22.6910 - val_root_mean_squared_error: 26.9536 - 60s/epoch - 3s/step
# Epoch 104/200
# 20/20 - 58s - loss: 247.3984 - accuracy: 0.0000e+00 - mean_squared_error: 247.3984 - mean_absolute_percentage_error: 9.7485 - root_mean_squared_error: 15.7289 - val_loss: 547.6570 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 547.6570 - val_mean_absolute_percentage_error: 19.1480 - val_root_mean_squared_error: 23.4021 - 58s/epoch - 3s/step
# Epoch 105/200
# 20/20 - 57s - loss: 243.6904 - accuracy: 0.0000e+00 - mean_squared_error: 243.6904 - mean_absolute_percentage_error: 9.7298 - root_mean_squared_error: 15.6106 - val_loss: 563.1557 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 563.1557 - val_mean_absolute_percentage_error: 19.4666 - val_root_mean_squared_error: 23.7309 - 57s/epoch - 3s/step
# Epoch 106/200
# 20/20 - 61s - loss: 245.7532 - accuracy: 0.0000e+00 - mean_squared_error: 245.7532 - mean_absolute_percentage_error: 9.6351 - root_mean_squared_error: 15.6765 - val_loss: 578.8226 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 578.8226 - val_mean_absolute_percentage_error: 19.5526 - val_root_mean_squared_error: 24.0587 - 61s/epoch - 3s/step
# Epoch 107/200
# 20/20 - 59s - loss: 228.5723 - accuracy: 0.0000e+00 - mean_squared_error: 228.5723 - mean_absolute_percentage_error: 9.2510 - root_mean_squared_error: 15.1186 - val_loss: 569.9845 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 569.9845 - val_mean_absolute_percentage_error: 19.6744 - val_root_mean_squared_error: 23.8743 - 59s/epoch - 3s/step
# Epoch 108/200
# 20/20 - 57s - loss: 220.1161 - accuracy: 0.0000e+00 - mean_squared_error: 220.1161 - mean_absolute_percentage_error: 9.2134 - root_mean_squared_error: 14.8363 - val_loss: 586.3477 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 586.3477 - val_mean_absolute_percentage_error: 19.9075 - val_root_mean_squared_error: 24.2146 - 57s/epoch - 3s/step
# Epoch 109/200
# 20/20 - 57s - loss: 219.0620 - accuracy: 0.0000e+00 - mean_squared_error: 219.0620 - mean_absolute_percentage_error: 9.0515 - root_mean_squared_error: 14.8007 - val_loss: 582.2126 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 582.2126 - val_mean_absolute_percentage_error: 19.8245 - val_root_mean_squared_error: 24.1291 - 57s/epoch - 3s/step
# Epoch 110/200
# 20/20 - 57s - loss: 209.3071 - accuracy: 0.0000e+00 - mean_squared_error: 209.3071 - mean_absolute_percentage_error: 8.7984 - root_mean_squared_error: 14.4674 - val_loss: 567.3624 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 567.3624 - val_mean_absolute_percentage_error: 19.5678 - val_root_mean_squared_error: 23.8194 - 57s/epoch - 3s/step
# Epoch 111/200
# 20/20 - 61s - loss: 216.0756 - accuracy: 0.0000e+00 - mean_squared_error: 216.0756 - mean_absolute_percentage_error: 8.9612 - root_mean_squared_error: 14.6995 - val_loss: 593.8620 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 593.8620 - val_mean_absolute_percentage_error: 20.1744 - val_root_mean_squared_error: 24.3693 - 61s/epoch - 3s/step
# Epoch 112/200
# 20/20 - 60s - loss: 220.7015 - accuracy: 0.0000e+00 - mean_squared_error: 220.7015 - mean_absolute_percentage_error: 9.1553 - root_mean_squared_error: 14.8560 - val_loss: 553.7498 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 553.7498 - val_mean_absolute_percentage_error: 19.1178 - val_root_mean_squared_error: 23.5319 - 60s/epoch - 3s/step
# Epoch 113/200
# 20/20 - 61s - loss: 208.9100 - accuracy: 0.0000e+00 - mean_squared_error: 208.9100 - mean_absolute_percentage_error: 9.0429 - root_mean_squared_error: 14.4537 - val_loss: 579.7256 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 579.7256 - val_mean_absolute_percentage_error: 19.5401 - val_root_mean_squared_error: 24.0775 - 61s/epoch - 3s/step
# Epoch 114/200
# 20/20 - 57s - loss: 230.8963 - accuracy: 0.0000e+00 - mean_squared_error: 230.8963 - mean_absolute_percentage_error: 9.3308 - root_mean_squared_error: 15.1953 - val_loss: 711.9868 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 711.9868 - val_mean_absolute_percentage_error: 22.2049 - val_root_mean_squared_error: 26.6831 - 57s/epoch - 3s/step
# Epoch 115/200
# 20/20 - 61s - loss: 226.6651 - accuracy: 0.0000e+00 - mean_squared_error: 226.6651 - mean_absolute_percentage_error: 9.0608 - root_mean_squared_error: 15.0554 - val_loss: 704.7413 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 704.7413 - val_mean_absolute_percentage_error: 22.1626 - val_root_mean_squared_error: 26.5470 - 61s/epoch - 3s/step
# Epoch 116/200
# 20/20 - 58s - loss: 227.1021 - accuracy: 0.0000e+00 - mean_squared_error: 227.1021 - mean_absolute_percentage_error: 9.4820 - root_mean_squared_error: 15.0699 - val_loss: 552.9521 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 552.9521 - val_mean_absolute_percentage_error: 19.3071 - val_root_mean_squared_error: 23.5149 - 58s/epoch - 3s/step
# Epoch 117/200
# 20/20 - 65s - loss: 205.4923 - accuracy: 0.0000e+00 - mean_squared_error: 205.4923 - mean_absolute_percentage_error: 8.9212 - root_mean_squared_error: 14.3350 - val_loss: 601.0338 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 601.0338 - val_mean_absolute_percentage_error: 19.6423 - val_root_mean_squared_error: 24.5160 - 65s/epoch - 3s/step
# Epoch 118/200
# 20/20 - 58s - loss: 216.5407 - accuracy: 0.0000e+00 - mean_squared_error: 216.5407 - mean_absolute_percentage_error: 8.8779 - root_mean_squared_error: 14.7153 - val_loss: 572.9547 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 572.9547 - val_mean_absolute_percentage_error: 19.4908 - val_root_mean_squared_error: 23.9365 - 58s/epoch - 3s/step
# Epoch 119/200
# 20/20 - 59s - loss: 251.4867 - accuracy: 0.0000e+00 - mean_squared_error: 251.4867 - mean_absolute_percentage_error: 9.6922 - root_mean_squared_error: 15.8583 - val_loss: 616.8899 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 616.8899 - val_mean_absolute_percentage_error: 20.5001 - val_root_mean_squared_error: 24.8373 - 59s/epoch - 3s/step
# Epoch 120/200
# 20/20 - 58s - loss: 224.1696 - accuracy: 0.0000e+00 - mean_squared_error: 224.1696 - mean_absolute_percentage_error: 9.0557 - root_mean_squared_error: 14.9723 - val_loss: 666.7052 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 666.7052 - val_mean_absolute_percentage_error: 21.4522 - val_root_mean_squared_error: 25.8206 - 58s/epoch - 3s/step
# Epoch 121/200
# 20/20 - 57s - loss: 225.0702 - accuracy: 0.0000e+00 - mean_squared_error: 225.0702 - mean_absolute_percentage_error: 9.0832 - root_mean_squared_error: 15.0023 - val_loss: 562.0520 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 562.0520 - val_mean_absolute_percentage_error: 19.2090 - val_root_mean_squared_error: 23.7076 - 57s/epoch - 3s/step
# Epoch 122/200
# 20/20 - 61s - loss: 208.6433 - accuracy: 0.0000e+00 - mean_squared_error: 208.6433 - mean_absolute_percentage_error: 8.8044 - root_mean_squared_error: 14.4445 - val_loss: 621.3862 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 621.3862 - val_mean_absolute_percentage_error: 20.5435 - val_root_mean_squared_error: 24.9276 - 61s/epoch - 3s/step
# Epoch 123/200
# 20/20 - 58s - loss: 177.9428 - accuracy: 0.0000e+00 - mean_squared_error: 177.9428 - mean_absolute_percentage_error: 8.1360 - root_mean_squared_error: 13.3395 - val_loss: 587.9214 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 587.9214 - val_mean_absolute_percentage_error: 19.8534 - val_root_mean_squared_error: 24.2471 - 58s/epoch - 3s/step
# Epoch 124/200
# 20/20 - 57s - loss: 171.8009 - accuracy: 0.0000e+00 - mean_squared_error: 171.8009 - mean_absolute_percentage_error: 7.9147 - root_mean_squared_error: 13.1073 - val_loss: 567.2487 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 567.2487 - val_mean_absolute_percentage_error: 19.2534 - val_root_mean_squared_error: 23.8170 - 57s/epoch - 3s/step
# Epoch 125/200
# 20/20 - 61s - loss: 166.7120 - accuracy: 0.0000e+00 - mean_squared_error: 166.7120 - mean_absolute_percentage_error: 7.8027 - root_mean_squared_error: 12.9117 - val_loss: 590.6627 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 590.6627 - val_mean_absolute_percentage_error: 19.5596 - val_root_mean_squared_error: 24.3036 - 61s/epoch - 3s/step
# Epoch 126/200
# 20/20 - 58s - loss: 164.8008 - accuracy: 0.0000e+00 - mean_squared_error: 164.8008 - mean_absolute_percentage_error: 7.5851 - root_mean_squared_error: 12.8375 - val_loss: 582.4767 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 582.4767 - val_mean_absolute_percentage_error: 19.6346 - val_root_mean_squared_error: 24.1346 - 58s/epoch - 3s/step
# Epoch 127/200
# 20/20 - 60s - loss: 168.2618 - accuracy: 0.0000e+00 - mean_squared_error: 168.2618 - mean_absolute_percentage_error: 7.6574 - root_mean_squared_error: 12.9716 - val_loss: 574.2906 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 574.2906 - val_mean_absolute_percentage_error: 19.2324 - val_root_mean_squared_error: 23.9644 - 60s/epoch - 3s/step
# Epoch 128/200
# 20/20 - 57s - loss: 156.6326 - accuracy: 0.0000e+00 - mean_squared_error: 156.6326 - mean_absolute_percentage_error: 7.3846 - root_mean_squared_error: 12.5153 - val_loss: 628.4354 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 628.4354 - val_mean_absolute_percentage_error: 19.8962 - val_root_mean_squared_error: 25.0686 - 57s/epoch - 3s/step
# Epoch 129/200
# 20/20 - 60s - loss: 165.9377 - accuracy: 0.0000e+00 - mean_squared_error: 165.9377 - mean_absolute_percentage_error: 7.6987 - root_mean_squared_error: 12.8817 - val_loss: 587.6610 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 587.6610 - val_mean_absolute_percentage_error: 19.4899 - val_root_mean_squared_error: 24.2417 - 60s/epoch - 3s/step
# Epoch 130/200
# 20/20 - 57s - loss: 164.6524 - accuracy: 0.0000e+00 - mean_squared_error: 164.6524 - mean_absolute_percentage_error: 7.5271 - root_mean_squared_error: 12.8317 - val_loss: 584.0878 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 584.0878 - val_mean_absolute_percentage_error: 19.5420 - val_root_mean_squared_error: 24.1679 - 57s/epoch - 3s/step
# Epoch 131/200
# 20/20 - 58s - loss: 172.4888 - accuracy: 0.0000e+00 - mean_squared_error: 172.4888 - mean_absolute_percentage_error: 7.7499 - root_mean_squared_error: 13.1335 - val_loss: 621.6177 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 621.6177 - val_mean_absolute_percentage_error: 20.3156 - val_root_mean_squared_error: 24.9323 - 58s/epoch - 3s/step
# Epoch 132/200
# ...
# Epoch 188/200
# 20/20 - 57s - loss: 39.1713 - accuracy: 0.0000e+00 - mean_squared_error: 39.1713 - mean_absolute_percentage_error: 3.3226 - root_mean_squared_error: 6.2587 - val_loss: 635.8115 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 635.8115 - val_mean_absolute_percentage_error: 19.4216 - val_root_mean_squared_error: 25.2153 - 57s/epoch - 3s/step
# Epoch 189/200
# 20/20 - 60s - loss: 32.4005 - accuracy: 0.0000e+00 - mean_squared_error: 32.4005 - mean_absolute_percentage_error: 3.0156 - root_mean_squared_error: 5.6921 - val_loss: 621.6392 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 621.6392 - val_mean_absolute_percentage_error: 19.1238 - val_root_mean_squared_error: 24.9327 - 60s/epoch - 3s/step
# Epoch 190/200
# 20/20 - 59s - loss: 35.3153 - accuracy: 0.0000e+00 - mean_squared_error: 35.3153 - mean_absolute_percentage_error: 3.1083 - root_mean_squared_error: 5.9427 - val_loss: 625.7043 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 625.7043 - val_mean_absolute_percentage_error: 19.2655 - val_root_mean_squared_error: 25.0141 - 59s/epoch - 3s/step
# Epoch 191/200
# 20/20 - 62s - loss: 30.6079 - accuracy: 0.0000e+00 - mean_squared_error: 30.6079 - mean_absolute_percentage_error: 2.8523 - root_mean_squared_error: 5.5324 - val_loss: 654.6109 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 654.6109 - val_mean_absolute_percentage_error: 19.9816 - val_root_mean_squared_error: 25.5854 - 62s/epoch - 3s/step
# Epoch 192/200
# 20/20 - 58s - loss: 40.6129 - accuracy: 0.0000e+00 - mean_squared_error: 40.6129 - mean_absolute_percentage_error: 3.3382 - root_mean_squared_error: 6.3728 - val_loss: 614.9357 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 614.9357 - val_mean_absolute_percentage_error: 19.0919 - val_root_mean_squared_error: 24.7979 - 58s/epoch - 3s/step
# Epoch 193/200
# 20/20 - 58s - loss: 46.7322 - accuracy: 0.0000e+00 - mean_squared_error: 46.7322 - mean_absolute_percentage_error: 3.6587 - root_mean_squared_error: 6.8361 - val_loss: 629.7943 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 629.7943 - val_mean_absolute_percentage_error: 19.4587 - val_root_mean_squared_error: 25.0957 - 58s/epoch - 3s/step
# Epoch 194/200
# 20/20 - 60s - loss: 42.7703 - accuracy: 0.0000e+00 - mean_squared_error: 42.7703 - mean_absolute_percentage_error: 3.5924 - root_mean_squared_error: 6.5399 - val_loss: 648.6256 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 648.6256 - val_mean_absolute_percentage_error: 19.9510 - val_root_mean_squared_error: 25.4681 - 60s/epoch - 3s/step
# Epoch 195/200
# 20/20 - 57s - loss: 43.6554 - accuracy: 0.0000e+00 - mean_squared_error: 43.6554 - mean_absolute_percentage_error: 3.5938 - root_mean_squared_error: 6.6072 - val_loss: 646.3474 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 646.3474 - val_mean_absolute_percentage_error: 19.8913 - val_root_mean_squared_error: 25.4234 - 57s/epoch - 3s/step
# Epoch 196/200
# 20/20 - 57s - loss: 37.6240 - accuracy: 0.0000e+00 - mean_squared_error: 37.6240 - mean_absolute_percentage_error: 3.1984 - root_mean_squared_error: 6.1338 - val_loss: 645.4189 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 645.4189 - val_mean_absolute_percentage_error: 19.7636 - val_root_mean_squared_error: 25.4051 - 57s/epoch - 3s/step
# Epoch 197/200
# 20/20 - 60s - loss: 45.2283 - accuracy: 0.0000e+00 - mean_squared_error: 45.2283 - mean_absolute_percentage_error: 3.6903 - root_mean_squared_error: 6.7252 - val_loss: 631.9433 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 631.9433 - val_mean_absolute_percentage_error: 19.6759 - val_root_mean_squared_error: 25.1385 - 60s/epoch - 3s/step
# Epoch 198/200
# 20/20 - 58s - loss: 51.9394 - accuracy: 0.0000e+00 - mean_squared_error: 51.9394 - mean_absolute_percentage_error: 4.0655 - root_mean_squared_error: 7.2069 - val_loss: 650.9168 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 650.9168 - val_mean_absolute_percentage_error: 19.9251 - val_root_mean_squared_error: 25.5131 - 58s/epoch - 3s/step
# Epoch 199/200
# 20/20 - 60s - loss: 49.8363 - accuracy: 0.0000e+00 - mean_squared_error: 49.8363 - mean_absolute_percentage_error: 3.8733 - root_mean_squared_error: 7.0595 - val_loss: 673.4278 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 673.4278 - val_mean_absolute_percentage_error: 20.5405 - val_root_mean_squared_error: 25.9505 - 60s/epoch - 3s/step
# Epoch 200/200
# 20/20 - 59s - loss: 36.1557 - accuracy: 0.0000e+00 - mean_squared_error: 36.1557 - mean_absolute_percentage_error: 3.2297 - root_mean_squared_error: 6.0130 - val_loss: 627.1979 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 627.1979 - val_mean_absolute_percentage_error: 19.4530 - val_root_mean_squared_error: 25.0439 - 59s/epoch - 3s/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5457, 16)]           0         []
#
#  conv1d (Conv1D)             (None, 5457, 80)             2640      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 5457, 64)             2112      ['input_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 5457, 32)             1056      ['input_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 5457, 16)             528       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 5457, 80)             12880     ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 5457, 64)             8256      ['conv1d_3[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5457, 32)             2080      ['conv1d_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 5457, 16)             528       ['conv1d_9[0][0]']
#
#  batch_normalization (Batch  (None, 5457, 80)             320       ['conv1d_1[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 5457, 64)             256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 5457, 32)             128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 5457, 16)             64        ['conv1d_10[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 5457, 80)             0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 5457, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 5457, 32)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 5457, 16)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 5457, 80)             12880     ['activation[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5457, 64)             8256      ['activation_2[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 5457, 32)             2080      ['activation_4[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 5457, 16)             528       ['activation_6[0][0]']
#
#  batch_normalization_1 (Bat  (None, 5457, 80)             320       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 5457, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 5457, 32)             128       ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 5457, 16)             64        ['conv1d_11[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 5457, 80)             0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv1d[0][0]']
#
#  add_1 (Add)                 (None, 5457, 64)             0         ['batch_normalization_3[0][0]'
#                                                                     , 'conv1d_3[0][0]']
#
#  add_2 (Add)                 (None, 5457, 32)             0         ['batch_normalization_5[0][0]'
#                                                                     , 'conv1d_6[0][0]']
#
#  add_3 (Add)                 (None, 5457, 16)             0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv1d_9[0][0]']
#
#  activation_1 (Activation)   (None, 5457, 80)             0         ['add[0][0]']
#
#  activation_3 (Activation)   (None, 5457, 64)             0         ['add_1[0][0]']
#
#  activation_5 (Activation)   (None, 5457, 32)             0         ['add_2[0][0]']
#
#  activation_7 (Activation)   (None, 5457, 16)             0         ['add_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 42, 80)               0         ['activation_1[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 42, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 42, 32)               0         ['activation_5[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 42, 16)               0         ['activation_7[0][0]']
#  g1D)
#
#  concatenate (Concatenate)   (None, 42, 192)              0         ['max_pooling1d[0][0]',
#                                                                      'max_pooling1d_1[0][0]',
#                                                                      'max_pooling1d_2[0][0]',
#                                                                      'max_pooling1d_3[0][0]']
#
#  dense (Dense)               (None, 42, 16)               3088      ['concatenate[0][0]']
#
#  flatten (Flatten)           (None, 672)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    673       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 59121 (230.94 KB)
# Trainable params: 58353 (227.94 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________
# 10/10 [==============================] - 7s 489ms/step
# Test Loss: [173.38992]
# Test Mean Squared Error: [189.6575]
# Test Mean Absolute Percentage Error: [185.0041]
# Test Root Mean Squared Error: [146.38246]

# %%
results = model.evaluate(test_dataset, batch_size=64)
# Out:
# 10/10 [==============================] - 5s 460ms/step - loss: 627.1979 - accuracy: 0.0000e+00 - mean_squared_error: 627.1979 - mean_absolute_percentage_error: 19.4530 - root_mean_squared_error: 25.0439

# %%
import tensorflow as tf
import numpy as np

# 重置数据集
def create_test_dataset(X_test_norm, y_test):
    return tf.data.Dataset.from_tensor_slices((X_test_norm, y_test.T)).batch(64)

# 创建测试数据集
test_dataset = create_test_dataset(X_test_norm, y_test)

# EVALUATE model with TESTING DATA
results = model.evaluate(test_dataset, verbose=0)
print(f'Test Loss: {results[0]}')
print(f'Test Mean Squared Error: {results[1]}')
print(f'Test Mean Absolute Percentage Error: {results[2]}')
print(f'Test Root Mean Squared Error: {results[3]}')

# PREDICT with TESTING DATA
ynew = model.predict(test_dataset)

# 重置测试数据集
test_dataset = create_test_dataset(X_test_norm, y_test)

# EVALUATE model again with TESTING DATA
results = model.evaluate(test_dataset, batch_size=64)
print(f'loss: {results[0]} - accuracy: {results[1]} - mean_squared_error: {results[2]} - mean_absolute_percentage_error: {results[3]} - root_mean_squared_error: {results[4]}')
# Out:
# Test Loss: 627.1978149414062
# Test Mean Squared Error: 0.0
# Test Mean Absolute Percentage Error: 627.1978149414062
# Test Root Mean Squared Error: 19.45304298400879
# 5/5 [==============================] - 5s 975ms/step
# 5/5 [==============================] - 5s 1s/step - loss: 627.1978 - accuracy: 0.0000e+00 - mean_squared_error: 627.1978 - mean_absolute_percentage_error: 19.4530 - root_mean_squared_error: 25.0439
# loss: 627.1978149414062 - accuracy: 0.0 - mean_squared_error: 627.1978149414062 - mean_absolute_percentage_error: 19.45304298400879 - root_mean_squared_error: 25.04391860961914

# %%
# plt.figure()
# plt.title('Loss (Mean Squared Error)')
# plt.plot(history.history['loss'])
# plt.figure()
# plt.title('Accuracy')
# plt.plot(history.history['accuracy'])
# plt.figure()
# plt.title('Mean Squared Error')
# plt.plot(history.history['mean_squared_error'])
# plt.figure()
fig, ax = plt.subplots()
ax.set_title('Training and Validation \n Mean Squared Error') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['loss'], color = 'blue', label = 'train')
# plt.figure()
## Validation Plots
# plt.title('Validation Loss (MSE)') # loss = 100 * abs(y_true - y_pred) / y_true
# plt.plot(history.history['val_loss'])
# plt.figure()

# plt.title('Validation Mean Absolute Percentage Error (MAPE)') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['val_loss'], color = 'orange', label = 'val')
ax.semilogy((0,50))
ax.legend()
# plt.figure()
