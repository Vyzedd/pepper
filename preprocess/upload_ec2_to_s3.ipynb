# %% [markdown]
# ### This is temp used for uploading files from instance to s3 bucket.Files on the instance will be removed by running this script.

# %%
import boto3
import os

s3 = boto3.client('s3')

# %%
local_directory = '/home/ec2-user/SageMaker/pepper/county_env_NETCDF4'
bucket_name = 'pepper-dataset'
s3_prefix = 'Temp/county_env_NetCDF4/'

# %%
def upload_directory_to_s3_remove(local_directory, bucket_name, s3_prefix):
    total_files = 0
    for root, dirs, files in os.walk(local_directory):
        total_files += len(files)
    
    files_left = total_files
    files_uploaded = 0
    
    for root, dirs, files in os.walk(local_directory):
        for file in files:
            local_path = os.path.join(root, file)
            relative_path = os.path.relpath(local_path, local_directory)
            s3_path = os.path.join(s3_prefix, relative_path).replace("\\", "/")
            s3.upload_file(local_path, bucket_name, s3_path)
            files_uploaded += 1
            
            os.remove(local_path)
            files_left -= 1
            
            # Print progress
            print(f"Uploaded {files_uploaded} files. {files_left} files remaining.")

# %%
upload_directory_to_s3_remove(local_directory, bucket_name, s3_prefix)
# Out:
# Uploaded 1 files. 43991 files remaining.
# Uploaded 2 files. 43990 files remaining.
# Uploaded 3 files. 43989 files remaining.
# Uploaded 4 files. 43988 files remaining.
# Uploaded 5 files. 43987 files remaining.
# Uploaded 6 files. 43986 files remaining.
# Uploaded 7 files. 43985 files remaining.
# Uploaded 8 files. 43984 files remaining.
# Uploaded 9 files. 43983 files remaining.
# Uploaded 10 files. 43982 files remaining.
# Uploaded 11 files. 43981 files remaining.
# Uploaded 12 files. 43980 files remaining.
# Uploaded 13 files. 43979 files remaining.
# Uploaded 14 files. 43978 files remaining.
# Uploaded 15 files. 43977 files remaining.
# Uploaded 16 files. 43976 files remaining.
# Uploaded 17 files. 43975 files remaining.
# Uploaded 18 files. 43974 files remaining.
# Uploaded 19 files. 43973 files remaining.
# Uploaded 20 files. 43972 files remaining.
# Uploaded 21 files. 43971 files remaining.
# Uploaded 22 files. 43970 files remaining.
# Uploaded 23 files. 43969 files remaining.
# Uploaded 24 files. 43968 files remaining.
# Uploaded 25 files. 43967 files remaining.
# Uploaded 26 files. 43966 files remaining.
# Uploaded 27 files. 43965 files remaining.
# Uploaded 28 files. 43964 files remaining.
# Uploaded 29 files. 43963 files remaining.
# Uploaded 30 files. 43962 files remaining.
# Uploaded 31 files. 43961 files remaining.
# Uploaded 32 files. 43960 files remaining.
# Uploaded 33 files. 43959 files remaining.
# Uploaded 34 files. 43958 files remaining.
# Uploaded 35 files. 43957 files remaining.
# Uploaded 36 files. 43956 files remaining.
# Uploaded 37 files. 43955 files remaining.
# Uploaded 38 files. 43954 files remaining.
# Uploaded 39 files. 43953 files remaining.
# Uploaded 40 files. 43952 files remaining.
# Uploaded 41 files. 43951 files remaining.
# Uploaded 42 files. 43950 files remaining.
# Uploaded 43 files. 43949 files remaining.
# Uploaded 44 files. 43948 files remaining.
# Uploaded 45 files. 43947 files remaining.
# Uploaded 46 files. 43946 files remaining.
# Uploaded 47 files. 43945 files remaining.
# Uploaded 48 files. 43944 files remaining.
# Uploaded 49 files. 43943 files remaining.
# Uploaded 50 files. 43942 files remaining.
# Uploaded 51 files. 43941 files remaining.
# Uploaded 52 files. 43940 files remaining.
# Uploaded 53 files. 43939 files remaining.
# Uploaded 54 files. 43938 files remaining.
# Uploaded 55 files. 43937 files remaining.
# Uploaded 56 files. 43936 files remaining.
# Uploaded 57 files. 43935 files remaining.
# Uploaded 58 files. 43934 files remaining.
# Uploaded 59 files. 43933 files remaining.
# Uploaded 60 files. 43932 files remaining.
# Uploaded 61 files. 43931 files remaining.
# Uploaded 62 files. 43930 files remaining.
# Uploaded 63 files. 43929 files remaining.
# Uploaded 64 files. 43928 files remaining.
# Uploaded 65 files. 43927 files remaining.
# Uploaded 66 files. 43926 files remaining.
# Uploaded 67 files. 43925 files remaining.
# Uploaded 68 files. 43924 files remaining.
# Uploaded 69 files. 43923 files remaining.
# Uploaded 70 files. 43922 files remaining.
# Uploaded 71 files. 43921 files remaining.
# Uploaded 72 files. 43920 files remaining.
# Uploaded 73 files. 43919 files remaining.
# Uploaded 74 files. 43918 files remaining.
# Uploaded 75 files. 43917 files remaining.
# Uploaded 76 files. 43916 files remaining.
# Uploaded 77 files. 43915 files remaining.
# Uploaded 78 files. 43914 files remaining.
# Uploaded 79 files. 43913 files remaining.
# Uploaded 80 files. 43912 files remaining.
# Uploaded 81 files. 43911 files remaining.
# Uploaded 82 files. 43910 files remaining.
# Uploaded 83 files. 43909 files remaining.
# Uploaded 84 files. 43908 files remaining.
# Uploaded 85 files. 43907 files remaining.
# Uploaded 86 files. 43906 files remaining.
# Uploaded 87 files. 43905 files remaining.
# Uploaded 88 files. 43904 files remaining.
# Uploaded 89 files. 43903 files remaining.
# Uploaded 90 files. 43902 files remaining.
# Uploaded 91 files. 43901 files remaining.
# Uploaded 92 files. 43900 files remaining.
# Uploaded 93 files. 43899 files remaining.
# Uploaded 94 files. 43898 files remaining.
# Uploaded 95 files. 43897 files remaining.
# Uploaded 96 files. 43896 files remaining.
# Uploaded 97 files. 43895 files remaining.
# Uploaded 98 files. 43894 files remaining.
# Uploaded 99 files. 43893 files remaining.
# Uploaded 100 files. 43892 files remaining.
# Uploaded 101 files. 43891 files remaining.
# Uploaded 102 files. 43890 files remaining.
# Uploaded 103 files. 43889 files remaining.
# Uploaded 104 files. 43888 files remaining.
# Uploaded 105 files. 43887 files remaining.
# Uploaded 106 files. 43886 files remaining.
# Uploaded 107 files. 43885 files remaining.
# Uploaded 108 files. 43884 files remaining.
# Uploaded 109 files. 43883 files remaining.
# Uploaded 110 files. 43882 files remaining.
# Uploaded 111 files. 43881 files remaining.
# Uploaded 112 files. 43880 files remaining.
# Uploaded 113 files. 43879 files remaining.
# Uploaded 114 files. 43878 files remaining.
# Uploaded 115 files. 43877 files remaining.
# Uploaded 116 files. 43876 files remaining.
# Uploaded 117 files. 43875 files remaining.
# Uploaded 118 files. 43874 files remaining.
# Uploaded 119 files. 43873 files remaining.
# Uploaded 120 files. 43872 files remaining.
# Uploaded 121 files. 43871 files remaining.
# Uploaded 122 files. 43870 files remaining.
# Uploaded 123 files. 43869 files remaining.
# Uploaded 124 files. 43868 files remaining.
# Uploaded 125 files. 43867 files remaining.
# Uploaded 126 files. 43866 files remaining.
# Uploaded 127 files. 43865 files remaining.
# Uploaded 128 files. 43864 files remaining.
# Uploaded 129 files. 43863 files remaining.
# Uploaded 130 files. 43862 files remaining.
# Uploaded 131 files. 43861 files remaining.
# Uploaded 132 files. 43860 files remaining.
# Uploaded 133 files. 43859 files remaining.
# Uploaded 134 files. 43858 files remaining.
# Uploaded 135 files. 43857 files remaining.
# Uploaded 136 files. 43856 files remaining.
# Uploaded 137 files. 43855 files remaining.
# Uploaded 138 files. 43854 files remaining.
# Uploaded 139 files. 43853 files remaining.
# Uploaded 140 files. 43852 files remaining.
# Uploaded 141 files. 43851 files remaining.
# Uploaded 142 files. 43850 files remaining.
# Uploaded 143 files. 43849 files remaining.
# Uploaded 144 files. 43848 files remaining.
# Uploaded 145 files. 43847 files remaining.
# Uploaded 146 files. 43846 files remaining.
# Uploaded 147 files. 43845 files remaining.
# Uploaded 148 files. 43844 files remaining.
# Uploaded 149 files. 43843 files remaining.
# Uploaded 150 files. 43842 files remaining.
# Uploaded 151 files. 43841 files remaining.
# Uploaded 152 files. 43840 files remaining.
# Uploaded 153 files. 43839 files remaining.
# Uploaded 154 files. 43838 files remaining.
# Uploaded 155 files. 43837 files remaining.
# Uploaded 156 files. 43836 files remaining.
# Uploaded 157 files. 43835 files remaining.
# Uploaded 158 files. 43834 files remaining.
# Uploaded 159 files. 43833 files remaining.
# Uploaded 160 files. 43832 files remaining.
# Uploaded 161 files. 43831 files remaining.
# Uploaded 162 files. 43830 files remaining.
# Uploaded 163 files. 43829 files remaining.
# Uploaded 164 files. 43828 files remaining.
# Uploaded 165 files. 43827 files remaining.
# Uploaded 166 files. 43826 files remaining.
# Uploaded 167 files. 43825 files remaining.
# Uploaded 168 files. 43824 files remaining.
# Uploaded 169 files. 43823 files remaining.
# Uploaded 170 files. 43822 files remaining.
# Uploaded 171 files. 43821 files remaining.
# Uploaded 172 files. 43820 files remaining.
# Uploaded 173 files. 43819 files remaining.
# Uploaded 174 files. 43818 files remaining.
# Uploaded 175 files. 43817 files remaining.
# Uploaded 176 files. 43816 files remaining.
# Uploaded 177 files. 43815 files remaining.
# Uploaded 178 files. 43814 files remaining.
# Uploaded 179 files. 43813 files remaining.
# Uploaded 180 files. 43812 files remaining.
# Uploaded 181 files. 43811 files remaining.
# Uploaded 182 files. 43810 files remaining.
# Uploaded 183 files. 43809 files remaining.
# Uploaded 184 files. 43808 files remaining.
# Uploaded 185 files. 43807 files remaining.
# Uploaded 186 files. 43806 files remaining.
# Uploaded 187 files. 43805 files remaining.
# Uploaded 188 files. 43804 files remaining.
# Uploaded 189 files. 43803 files remaining.
# Uploaded 190 files. 43802 files remaining.
# Uploaded 191 files. 43801 files remaining.
# Uploaded 192 files. 43800 files remaining.
# Uploaded 193 files. 43799 files remaining.
# Uploaded 194 files. 43798 files remaining.
# Uploaded 195 files. 43797 files remaining.
# Uploaded 196 files. 43796 files remaining.
# Uploaded 197 files. 43795 files remaining.
# Uploaded 198 files. 43794 files remaining.
# Uploaded 199 files. 43793 files remaining.
# Uploaded 200 files. 43792 files remaining.
# Uploaded 201 files. 43791 files remaining.
# Uploaded 202 files. 43790 files remaining.
# Uploaded 203 files. 43789 files remaining.
# Uploaded 204 files. 43788 files remaining.
# Uploaded 205 files. 43787 files remaining.
# Uploaded 206 files. 43786 files remaining.
# Uploaded 207 files. 43785 files remaining.
# Uploaded 208 files. 43784 files remaining.
# Uploaded 209 files. 43783 files remaining.
# Uploaded 210 files. 43782 files remaining.
# Uploaded 211 files. 43781 files remaining.
# Uploaded 212 files. 43780 files remaining.
# Uploaded 213 files. 43779 files remaining.
# Uploaded 214 files. 43778 files remaining.
# Uploaded 215 files. 43777 files remaining.
# Uploaded 216 files. 43776 files remaining.
# Uploaded 217 files. 43775 files remaining.
# Uploaded 218 files. 43774 files remaining.
# Uploaded 219 files. 43773 files remaining.
# Uploaded 220 files. 43772 files remaining.
# Uploaded 221 files. 43771 files remaining.
# Uploaded 222 files. 43770 files remaining.
# Uploaded 223 files. 43769 files remaining.
# Uploaded 224 files. 43768 files remaining.
# Uploaded 225 files. 43767 files remaining.
# Uploaded 226 files. 43766 files remaining.
# Uploaded 227 files. 43765 files remaining.
# Uploaded 228 files. 43764 files remaining.
# Uploaded 229 files. 43763 files remaining.
# Uploaded 230 files. 43762 files remaining.
# Uploaded 231 files. 43761 files remaining.
# Uploaded 232 files. 43760 files remaining.
# Uploaded 233 files. 43759 files remaining.
# Uploaded 234 files. 43758 files remaining.
# Uploaded 235 files. 43757 files remaining.
# Uploaded 236 files. 43756 files remaining.
# Uploaded 237 files. 43755 files remaining.
# Uploaded 238 files. 43754 files remaining.
# Uploaded 239 files. 43753 files remaining.
# Uploaded 240 files. 43752 files remaining.
# Uploaded 241 files. 43751 files remaining.
# Uploaded 242 files. 43750 files remaining.
# Uploaded 243 files. 43749 files remaining.
# Uploaded 244 files. 43748 files remaining.
# Uploaded 245 files. 43747 files remaining.
# Uploaded 246 files. 43746 files remaining.
# Uploaded 247 files. 43745 files remaining.
# Uploaded 248 files. 43744 files remaining.
# Uploaded 249 files. 43743 files remaining.
# Uploaded 250 files. 43742 files remaining.
# Uploaded 251 files. 43741 files remaining.
# Uploaded 252 files. 43740 files remaining.
# Uploaded 253 files. 43739 files remaining.
# Uploaded 254 files. 43738 files remaining.
# Uploaded 255 files. 43737 files remaining.
# Uploaded 256 files. 43736 files remaining.
# Uploaded 257 files. 43735 files remaining.
# Uploaded 258 files. 43734 files remaining.
# Uploaded 259 files. 43733 files remaining.
# Uploaded 260 files. 43732 files remaining.
# Uploaded 261 files. 43731 files remaining.
# Uploaded 262 files. 43730 files remaining.
# Uploaded 263 files. 43729 files remaining.
# Uploaded 264 files. 43728 files remaining.
# Uploaded 265 files. 43727 files remaining.
# Uploaded 266 files. 43726 files remaining.
# Uploaded 267 files. 43725 files remaining.
# Uploaded 268 files. 43724 files remaining.
# Uploaded 269 files. 43723 files remaining.
# Uploaded 270 files. 43722 files remaining.
# Uploaded 271 files. 43721 files remaining.
# Uploaded 272 files. 43720 files remaining.
# Uploaded 273 files. 43719 files remaining.
# Uploaded 274 files. 43718 files remaining.
# Uploaded 275 files. 43717 files remaining.
# Uploaded 276 files. 43716 files remaining.
# Uploaded 277 files. 43715 files remaining.
# Uploaded 278 files. 43714 files remaining.
# Uploaded 279 files. 43713 files remaining.
# Uploaded 280 files. 43712 files remaining.
# Uploaded 281 files. 43711 files remaining.
# Uploaded 282 files. 43710 files remaining.
# Uploaded 283 files. 43709 files remaining.
# Uploaded 284 files. 43708 files remaining.
# Uploaded 285 files. 43707 files remaining.
# Uploaded 286 files. 43706 files remaining.
# Uploaded 287 files. 43705 files remaining.
# Uploaded 288 files. 43704 files remaining.
# Uploaded 289 files. 43703 files remaining.
# Uploaded 290 files. 43702 files remaining.
# Uploaded 291 files. 43701 files remaining.
# Uploaded 292 files. 43700 files remaining.
# Uploaded 293 files. 43699 files remaining.
# Uploaded 294 files. 43698 files remaining.
# Uploaded 295 files. 43697 files remaining.
# Uploaded 296 files. 43696 files remaining.
# Uploaded 297 files. 43695 files remaining.
# Uploaded 298 files. 43694 files remaining.
# Uploaded 299 files. 43693 files remaining.
# Uploaded 300 files. 43692 files remaining.
# Uploaded 301 files. 43691 files remaining.
# Uploaded 302 files. 43690 files remaining.
# Uploaded 303 files. 43689 files remaining.
# Uploaded 304 files. 43688 files remaining.
# Uploaded 305 files. 43687 files remaining.
# Uploaded 306 files. 43686 files remaining.
# Uploaded 307 files. 43685 files remaining.
# Uploaded 308 files. 43684 files remaining.
# Uploaded 309 files. 43683 files remaining.
# Uploaded 310 files. 43682 files remaining.
# Uploaded 311 files. 43681 files remaining.
# Uploaded 312 files. 43680 files remaining.
# Uploaded 313 files. 43679 files remaining.
# Uploaded 314 files. 43678 files remaining.
# Uploaded 315 files. 43677 files remaining.
# Uploaded 316 files. 43676 files remaining.
# Uploaded 317 files. 43675 files remaining.
# Uploaded 318 files. 43674 files remaining.
# Uploaded 319 files. 43673 files remaining.
# Uploaded 320 files. 43672 files remaining.
# Uploaded 321 files. 43671 files remaining.
# Uploaded 322 files. 43670 files remaining.
# Uploaded 323 files. 43669 files remaining.
# Uploaded 324 files. 43668 files remaining.
# Uploaded 325 files. 43667 files remaining.
# Uploaded 326 files. 43666 files remaining.
# Uploaded 327 files. 43665 files remaining.
# Uploaded 328 files. 43664 files remaining.
# Uploaded 329 files. 43663 files remaining.
# Uploaded 330 files. 43662 files remaining.
# Uploaded 331 files. 43661 files remaining.
# Uploaded 332 files. 43660 files remaining.
# Uploaded 333 files. 43659 files remaining.
# Uploaded 334 files. 43658 files remaining.
# Uploaded 335 files. 43657 files remaining.
# Uploaded 336 files. 43656 files remaining.
# Uploaded 337 files. 43655 files remaining.
# Uploaded 338 files. 43654 files remaining.
# Uploaded 339 files. 43653 files remaining.
# Uploaded 340 files. 43652 files remaining.
# Uploaded 341 files. 43651 files remaining.
# Uploaded 342 files. 43650 files remaining.
# Uploaded 343 files. 43649 files remaining.
# Uploaded 344 files. 43648 files remaining.
# Uploaded 345 files. 43647 files remaining.
# Uploaded 346 files. 43646 files remaining.
# Uploaded 347 files. 43645 files remaining.
# Uploaded 348 files. 43644 files remaining.
# Uploaded 349 files. 43643 files remaining.
# Uploaded 350 files. 43642 files remaining.
# Uploaded 351 files. 43641 files remaining.
# Uploaded 352 files. 43640 files remaining.
# Uploaded 353 files. 43639 files remaining.
# Uploaded 354 files. 43638 files remaining.
# Uploaded 355 files. 43637 files remaining.
# Uploaded 356 files. 43636 files remaining.
# Uploaded 357 files. 43635 files remaining.
# Uploaded 358 files. 43634 files remaining.
# Uploaded 359 files. 43633 files remaining.
# Uploaded 360 files. 43632 files remaining.
# Uploaded 361 files. 43631 files remaining.
# Uploaded 362 files. 43630 files remaining.
# Uploaded 363 files. 43629 files remaining.
# Uploaded 364 files. 43628 files remaining.
# Uploaded 365 files. 43627 files remaining.
# Uploaded 366 files. 43626 files remaining.
# Uploaded 367 files. 43625 files remaining.
# Uploaded 368 files. 43624 files remaining.
# Uploaded 369 files. 43623 files remaining.
# Uploaded 370 files. 43622 files remaining.
# Uploaded 371 files. 43621 files remaining.
# Uploaded 372 files. 43620 files remaining.
# Uploaded 373 files. 43619 files remaining.
# Uploaded 374 files. 43618 files remaining.
# Uploaded 375 files. 43617 files remaining.
# Uploaded 376 files. 43616 files remaining.
# Uploaded 377 files. 43615 files remaining.
# Uploaded 378 files. 43614 files remaining.
# Uploaded 379 files. 43613 files remaining.
# Uploaded 380 files. 43612 files remaining.
# Uploaded 381 files. 43611 files remaining.
# Uploaded 382 files. 43610 files remaining.
# Uploaded 383 files. 43609 files remaining.
# Uploaded 384 files. 43608 files remaining.
# Uploaded 385 files. 43607 files remaining.
# Uploaded 386 files. 43606 files remaining.
# Uploaded 387 files. 43605 files remaining.
# Uploaded 388 files. 43604 files remaining.
# Uploaded 389 files. 43603 files remaining.
# Uploaded 390 files. 43602 files remaining.
# Uploaded 391 files. 43601 files remaining.
# Uploaded 392 files. 43600 files remaining.
# Uploaded 393 files. 43599 files remaining.
# Uploaded 394 files. 43598 files remaining.
# Uploaded 395 files. 43597 files remaining.
# Uploaded 396 files. 43596 files remaining.
# Uploaded 397 files. 43595 files remaining.
# Uploaded 398 files. 43594 files remaining.
# Uploaded 399 files. 43593 files remaining.
# Uploaded 400 files. 43592 files remaining.
# Uploaded 401 files. 43591 files remaining.
# Uploaded 402 files. 43590 files remaining.
# Uploaded 403 files. 43589 files remaining.
# Uploaded 404 files. 43588 files remaining.
# Uploaded 405 files. 43587 files remaining.
# Uploaded 406 files. 43586 files remaining.
# Uploaded 407 files. 43585 files remaining.
# Uploaded 408 files. 43584 files remaining.
# Uploaded 409 files. 43583 files remaining.
# Uploaded 410 files. 43582 files remaining.
# Uploaded 411 files. 43581 files remaining.
# Uploaded 412 files. 43580 files remaining.
# Uploaded 413 files. 43579 files remaining.
# Uploaded 414 files. 43578 files remaining.
# Uploaded 415 files. 43577 files remaining.
# Uploaded 416 files. 43576 files remaining.
# Uploaded 417 files. 43575 files remaining.
# Uploaded 418 files. 43574 files remaining.
# Uploaded 419 files. 43573 files remaining.
# Uploaded 420 files. 43572 files remaining.
# Uploaded 421 files. 43571 files remaining.
# Uploaded 422 files. 43570 files remaining.
# Uploaded 423 files. 43569 files remaining.
# Uploaded 424 files. 43568 files remaining.
# Uploaded 425 files. 43567 files remaining.
# Uploaded 426 files. 43566 files remaining.
# Uploaded 427 files. 43565 files remaining.
# Uploaded 428 files. 43564 files remaining.
# Uploaded 429 files. 43563 files remaining.
# Uploaded 430 files. 43562 files remaining.
# Uploaded 431 files. 43561 files remaining.
# Uploaded 432 files. 43560 files remaining.
# Uploaded 433 files. 43559 files remaining.
# Uploaded 434 files. 43558 files remaining.
# Uploaded 435 files. 43557 files remaining.
# Uploaded 436 files. 43556 files remaining.
# Uploaded 437 files. 43555 files remaining.
# Uploaded 438 files. 43554 files remaining.
# Uploaded 439 files. 43553 files remaining.
# Uploaded 440 files. 43552 files remaining.
# Uploaded 441 files. 43551 files remaining.
# Uploaded 442 files. 43550 files remaining.
# Uploaded 443 files. 43549 files remaining.
# Uploaded 444 files. 43548 files remaining.
# Uploaded 445 files. 43547 files remaining.
# Uploaded 446 files. 43546 files remaining.
# Uploaded 447 files. 43545 files remaining.
# Uploaded 448 files. 43544 files remaining.
# Uploaded 449 files. 43543 files remaining.
# Uploaded 450 files. 43542 files remaining.
# Uploaded 451 files. 43541 files remaining.
# Uploaded 452 files. 43540 files remaining.
# Uploaded 453 files. 43539 files remaining.
# Uploaded 454 files. 43538 files remaining.
# Uploaded 455 files. 43537 files remaining.
# Uploaded 456 files. 43536 files remaining.
# Uploaded 457 files. 43535 files remaining.
# Uploaded 458 files. 43534 files remaining.
# Uploaded 459 files. 43533 files remaining.
# Uploaded 460 files. 43532 files remaining.
# Uploaded 461 files. 43531 files remaining.
# Uploaded 462 files. 43530 files remaining.
# Uploaded 463 files. 43529 files remaining.
# Uploaded 464 files. 43528 files remaining.
# Uploaded 465 files. 43527 files remaining.
# Uploaded 466 files. 43526 files remaining.
# Uploaded 467 files. 43525 files remaining.
# Uploaded 468 files. 43524 files remaining.
# Uploaded 469 files. 43523 files remaining.
# Uploaded 470 files. 43522 files remaining.
# Uploaded 471 files. 43521 files remaining.
# Uploaded 472 files. 43520 files remaining.
# Uploaded 473 files. 43519 files remaining.
# Uploaded 474 files. 43518 files remaining.
# Uploaded 475 files. 43517 files remaining.
# Uploaded 476 files. 43516 files remaining.
# Uploaded 477 files. 43515 files remaining.
# Uploaded 478 files. 43514 files remaining.
# Uploaded 479 files. 43513 files remaining.
# Uploaded 480 files. 43512 files remaining.
# Uploaded 481 files. 43511 files remaining.
# Uploaded 482 files. 43510 files remaining.
# Uploaded 483 files. 43509 files remaining.
# Uploaded 484 files. 43508 files remaining.
# Uploaded 485 files. 43507 files remaining.
# Uploaded 486 files. 43506 files remaining.
# Uploaded 487 files. 43505 files remaining.
# Uploaded 488 files. 43504 files remaining.
# Uploaded 489 files. 43503 files remaining.
# Uploaded 490 files. 43502 files remaining.
# Uploaded 491 files. 43501 files remaining.
# Uploaded 492 files. 43500 files remaining.
# Uploaded 493 files. 43499 files remaining.
# Uploaded 494 files. 43498 files remaining.
# Uploaded 495 files. 43497 files remaining.
# Uploaded 496 files. 43496 files remaining.
# Uploaded 497 files. 43495 files remaining.
# Uploaded 498 files. 43494 files remaining.
# Uploaded 499 files. 43493 files remaining.
# Uploaded 500 files. 43492 files remaining.
# Uploaded 501 files. 43491 files remaining.
# Uploaded 502 files. 43490 files remaining.
# Uploaded 503 files. 43489 files remaining.
# Uploaded 504 files. 43488 files remaining.
# Uploaded 505 files. 43487 files remaining.
# Uploaded 506 files. 43486 files remaining.
# Uploaded 507 files. 43485 files remaining.
# Uploaded 508 files. 43484 files remaining.
# Uploaded 509 files. 43483 files remaining.
# Uploaded 510 files. 43482 files remaining.
# Uploaded 511 files. 43481 files remaining.
# Uploaded 512 files. 43480 files remaining.
# Uploaded 513 files. 43479 files remaining.
# Uploaded 514 files. 43478 files remaining.
# Uploaded 515 files. 43477 files remaining.
# Uploaded 516 files. 43476 files remaining.
# Uploaded 517 files. 43475 files remaining.
# Uploaded 518 files. 43474 files remaining.
# Uploaded 519 files. 43473 files remaining.
# Uploaded 520 files. 43472 files remaining.
# Uploaded 521 files. 43471 files remaining.
# Uploaded 522 files. 43470 files remaining.
# Uploaded 523 files. 43469 files remaining.
# Uploaded 524 files. 43468 files remaining.
# Uploaded 525 files. 43467 files remaining.
# Uploaded 526 files. 43466 files remaining.
# Uploaded 527 files. 43465 files remaining.
# Uploaded 528 files. 43464 files remaining.
# Uploaded 529 files. 43463 files remaining.
# Uploaded 530 files. 43462 files remaining.
# Uploaded 531 files. 43461 files remaining.
# Uploaded 532 files. 43460 files remaining.
# Uploaded 533 files. 43459 files remaining.
# Uploaded 534 files. 43458 files remaining.
# Uploaded 535 files. 43457 files remaining.
# Uploaded 536 files. 43456 files remaining.
# Uploaded 537 files. 43455 files remaining.
# Uploaded 538 files. 43454 files remaining.
# Uploaded 539 files. 43453 files remaining.
# Uploaded 540 files. 43452 files remaining.
# Uploaded 541 files. 43451 files remaining.
# Uploaded 542 files. 43450 files remaining.
# Uploaded 543 files. 43449 files remaining.
# Uploaded 544 files. 43448 files remaining.
# Uploaded 545 files. 43447 files remaining.
# Uploaded 546 files. 43446 files remaining.
# Uploaded 547 files. 43445 files remaining.
# Uploaded 548 files. 43444 files remaining.
# Uploaded 549 files. 43443 files remaining.
# Uploaded 550 files. 43442 files remaining.
# Uploaded 551 files. 43441 files remaining.
# Uploaded 552 files. 43440 files remaining.
# Uploaded 553 files. 43439 files remaining.
# Uploaded 554 files. 43438 files remaining.
# Uploaded 555 files. 43437 files remaining.
# Uploaded 556 files. 43436 files remaining.
# Uploaded 557 files. 43435 files remaining.
# Uploaded 558 files. 43434 files remaining.
# Uploaded 559 files. 43433 files remaining.
# Uploaded 560 files. 43432 files remaining.
# Uploaded 561 files. 43431 files remaining.
# Uploaded 562 files. 43430 files remaining.
# Uploaded 563 files. 43429 files remaining.
# Uploaded 564 files. 43428 files remaining.
# Uploaded 565 files. 43427 files remaining.
# Uploaded 566 files. 43426 files remaining.
# Uploaded 567 files. 43425 files remaining.
# Uploaded 568 files. 43424 files remaining.
# Uploaded 569 files. 43423 files remaining.
# Uploaded 570 files. 43422 files remaining.
# Uploaded 571 files. 43421 files remaining.
# Uploaded 572 files. 43420 files remaining.
# Uploaded 573 files. 43419 files remaining.
# Uploaded 574 files. 43418 files remaining.
# Uploaded 575 files. 43417 files remaining.
# Uploaded 576 files. 43416 files remaining.
# Uploaded 577 files. 43415 files remaining.
# Uploaded 578 files. 43414 files remaining.
# Uploaded 579 files. 43413 files remaining.
# Uploaded 580 files. 43412 files remaining.
# Uploaded 581 files. 43411 files remaining.
# Uploaded 582 files. 43410 files remaining.
# Uploaded 583 files. 43409 files remaining.
# Uploaded 584 files. 43408 files remaining.
# Uploaded 585 files. 43407 files remaining.
# Uploaded 586 files. 43406 files remaining.
# Uploaded 587 files. 43405 files remaining.
# Uploaded 588 files. 43404 files remaining.
# Uploaded 589 files. 43403 files remaining.
# Uploaded 590 files. 43402 files remaining.
# Uploaded 591 files. 43401 files remaining.
# Uploaded 592 files. 43400 files remaining.
# Uploaded 593 files. 43399 files remaining.
# Uploaded 594 files. 43398 files remaining.
# Uploaded 595 files. 43397 files remaining.
# Uploaded 596 files. 43396 files remaining.
# Uploaded 597 files. 43395 files remaining.
# Uploaded 598 files. 43394 files remaining.
# Uploaded 599 files. 43393 files remaining.
# Uploaded 600 files. 43392 files remaining.
# Uploaded 601 files. 43391 files remaining.
# Uploaded 602 files. 43390 files remaining.
# Uploaded 603 files. 43389 files remaining.
# Uploaded 604 files. 43388 files remaining.
# Uploaded 605 files. 43387 files remaining.
# Uploaded 606 files. 43386 files remaining.
# Uploaded 607 files. 43385 files remaining.
# Uploaded 608 files. 43384 files remaining.
# Uploaded 609 files. 43383 files remaining.
# Uploaded 610 files. 43382 files remaining.
# Uploaded 611 files. 43381 files remaining.
# Uploaded 612 files. 43380 files remaining.
# Uploaded 613 files. 43379 files remaining.
# Uploaded 614 files. 43378 files remaining.
# Uploaded 615 files. 43377 files remaining.
# Uploaded 616 files. 43376 files remaining.
# Uploaded 617 files. 43375 files remaining.
# Uploaded 618 files. 43374 files remaining.
# Uploaded 619 files. 43373 files remaining.
# Uploaded 620 files. 43372 files remaining.
# Uploaded 621 files. 43371 files remaining.
# Uploaded 622 files. 43370 files remaining.
# Uploaded 623 files. 43369 files remaining.
# Uploaded 624 files. 43368 files remaining.
# Uploaded 625 files. 43367 files remaining.
# Uploaded 626 files. 43366 files remaining.
# Uploaded 627 files. 43365 files remaining.
# Uploaded 628 files. 43364 files remaining.
# Uploaded 629 files. 43363 files remaining.
# Uploaded 630 files. 43362 files remaining.
# Uploaded 631 files. 43361 files remaining.
# Uploaded 632 files. 43360 files remaining.
# Uploaded 633 files. 43359 files remaining.
# Uploaded 634 files. 43358 files remaining.
# Uploaded 635 files. 43357 files remaining.
# Uploaded 636 files. 43356 files remaining.
# Uploaded 637 files. 43355 files remaining.
# Uploaded 638 files. 43354 files remaining.
# Uploaded 639 files. 43353 files remaining.
# Uploaded 640 files. 43352 files remaining.
# Uploaded 641 files. 43351 files remaining.
# Uploaded 642 files. 43350 files remaining.
# Uploaded 643 files. 43349 files remaining.
# Uploaded 644 files. 43348 files remaining.
# Uploaded 645 files. 43347 files remaining.
# Uploaded 646 files. 43346 files remaining.
# Uploaded 647 files. 43345 files remaining.
# Uploaded 648 files. 43344 files remaining.
# Uploaded 649 files. 43343 files remaining.
# Uploaded 650 files. 43342 files remaining.
# Uploaded 651 files. 43341 files remaining.
# Uploaded 652 files. 43340 files remaining.
# Uploaded 653 files. 43339 files remaining.
# Uploaded 654 files. 43338 files remaining.
# Uploaded 655 files. 43337 files remaining.
# Uploaded 656 files. 43336 files remaining.
# Uploaded 657 files. 43335 files remaining.
# Uploaded 658 files. 43334 files remaining.
# Uploaded 659 files. 43333 files remaining.
# Uploaded 660 files. 43332 files remaining.
# Uploaded 661 files. 43331 files remaining.
# Uploaded 662 files. 43330 files remaining.
# Uploaded 663 files. 43329 files remaining.
# Uploaded 664 files. 43328 files remaining.
# Uploaded 665 files. 43327 files remaining.
# Uploaded 666 files. 43326 files remaining.
# Uploaded 667 files. 43325 files remaining.
# Uploaded 668 files. 43324 files remaining.
# Uploaded 669 files. 43323 files remaining.
# Uploaded 670 files. 43322 files remaining.
# Uploaded 671 files. 43321 files remaining.
# Uploaded 672 files. 43320 files remaining.
# Uploaded 673 files. 43319 files remaining.
# Uploaded 674 files. 43318 files remaining.
# Uploaded 675 files. 43317 files remaining.
# Uploaded 676 files. 43316 files remaining.
# Uploaded 677 files. 43315 files remaining.
# Uploaded 678 files. 43314 files remaining.
# Uploaded 679 files. 43313 files remaining.
