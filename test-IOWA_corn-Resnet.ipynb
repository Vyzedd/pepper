# %%
import os # Handle OS file systems and directory paths
import random # Random number
import numpy as np # Import NumPy for arrays and such
import matplotlib.pyplot as plt # Plotting Tools
import numpy.linalg as npl # Linear Algebra Library
import time # Time
# from google.colab import drive # Read files in from Google Drive
import pandas as pd # Import Pandas for data processing
import datetime as dt
import scipy.io as sio
import io
from decimal import Decimal # String to double conversion
from glob import glob  # 从 glob 模块中导入 glob 函数

# %%
import boto3
from botocore.exceptions import NoCredentialsError

# %%
# Optionally, you can specify the AWS region
s3 = boto3.client('s3', region_name='us-east-1')  # Replace 'us-west-2' with your AWS region

# %%
import pandas as pd
# s3_uri = 's3://pepper-dataset/crop_data/crop_IOWA/Iowa_corn_2019.csv'
# df = pd.read_csv(s3_uri)

# %%
# get county list
# county_path_list = glob('/content/drive/MyDrive/ai/era5/county_env/*')
# county_list = [os.path.basename(x) for x in county_path_list]
# print(county_list)

#Read files from s3
bucket_name = 'pepper-dataset'
prefix = 'county-env-data/county_env_IOWA/processed_with_all_features_ver_2/'

# List to store all object keys
county_files = []

# Initial call to list_objects_v2
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

# Process the initial response
while True:
    # Collect keys from current response
    current_keys = [obj['Key'] for obj in response.get('Contents', [])]
    county_files.extend(current_keys)

    # Check if there are more objects to retrieve
    if not response['IsTruncated']:
        break  # No more objects to retrieve

    # Get ContinuationToken for next paginated call
    continuation_token = response['NextContinuationToken']

    # Make subsequent call with ContinuationToken
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, ContinuationToken=continuation_token)
    
    
county_files = ["/" + path if not path.startswith("/") else path for path in county_files]

# %%
len(county_files)
# Out:
# 54648

# %%
county_files[:10]
# Out:
# ['/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-01_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-01_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-02_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-02_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-03_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-03_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-04_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-04_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-05_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-05_part2.csv']

# %%
# try 1 county
year_range = [2015, 2020]
years = [x for x in range(year_range[0], year_range[-1]+1)]

filtered_files = [file_path for file_path in county_files
                  if any(str(year) in file_path for year in years)]

# basedir = '/content/drive/MyDrive/ai/era5/county_env/'
# county_files = []

# for c in county_list:
#   county = os.path.join(basedir, c)
#   print(county)

#   county_f = glob(os.path.join(county, '*'))

#   for f in county_f:
#     ym_str = f.split('_')[-2]
#     ym_obj = dt.datetime.strptime(ym_str, '%Y-%m')
#     if ym_obj.year not in years:
#         continue
#     county_files.append(f)

print(len(filtered_files))

  # print(len(county_files))
  # print(county_files[:3])

# get year-month info for the county
# ym_list = [x.split('_')[-2] for x in county_files]
# ym_list = list(set(ym_list))
# ym_list.sort()
# print(ym_list)

filtered_files[:50]
# Out:
# 14256
# ['/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-01_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-01_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-02_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-02_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-03_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-03_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-04_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-04_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-05_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-05_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-06_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-06_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-07_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-07_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-08_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-08_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-09_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-09_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-10_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-10_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-11_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-11_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-12_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-12_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-01_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-01_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-02_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-02_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-03_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-03_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-04_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-04_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-05_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-05_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-06_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-06_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-07_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-07_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-08_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-08_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-09_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-09_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-10_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-10_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-11_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-11_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-12_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-12_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2017-01_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2017-01_part2.csv']

# %%
pd.read_csv('s3://'+bucket_name+filtered_files[0])
# Out:
#             t2m         rsn       sde        stl1        stl2        stl3  \
# 0    264.779109  157.898785  0.022211  270.594126  272.370047  276.240175
# 1    264.422925  157.904400  0.022114  270.453053  272.363595  276.224547
# 2    264.124610  157.912701  0.022114  270.239228  272.355498  276.208919
# 3    263.781137  157.918316  0.022017  269.972289  272.345787  276.193582
# 4    263.406891  157.925640  0.021871  269.575237  272.333674  276.177848
# ..          ...         ...       ...         ...         ...         ...
# 739  274.944472  168.355773  0.005863  273.101253  273.256931  273.429511
# 740  274.784137  168.371154  0.007812  273.148886  273.256569  273.430385
# 741  274.423772  167.692950  0.010891  273.174096  273.256043  273.431073
# 742  274.196871  165.558975  0.015332  273.193917  273.256372  273.432265
# 743  273.932061  163.638129  0.020557  273.202777  273.255812  273.433166
#
#            stl4         tsn     swvl1     swvl2     swvl3     swvl4  \
# 0    281.932781  262.736158  0.349909  0.351766  0.317072  0.309495
# 1    281.927790  262.692495  0.349842  0.351668  0.317102  0.309496
# 2    281.922726  262.665017  0.349778  0.351571  0.317130  0.309497
# 3    281.918383  262.487613  0.349710  0.351471  0.317161  0.309497
# 4    281.913200  262.197851  0.349647  0.351375  0.317189  0.309497
# ..          ...         ...       ...       ...       ...       ...
# 739  278.006532  273.160300  0.354087  0.337028  0.324468  0.310423
# 740  278.002548  273.160300  0.360544  0.337175  0.324473  0.310425
# 741  277.998637  273.160919  0.365072  0.337392  0.324479  0.310428
# 742  277.994725  273.160300  0.367889  0.337651  0.324486  0.310429
# 743  277.990598  273.159681  0.369467  0.337944  0.324491  0.310432
#
#                 datetime
# 0    2015-01-01 00:00:00
# 1    2015-01-01 01:00:00
# 2    2015-01-01 02:00:00
# 3    2015-01-01 03:00:00
# 4    2015-01-01 04:00:00
# ..                   ...
# 739  2015-01-31 19:00:00
# 740  2015-01-31 20:00:00
# 741  2015-01-31 21:00:00
# 742  2015-01-31 22:00:00
# 743  2015-01-31 23:00:00
#
# [744 rows x 13 columns]

# %%
df_list = pd.DataFrame(columns=("Year","State","County","Month","Commodity","Feature"))

for csvf in filtered_files:
    # only read part1, then match with part2
    if 'part2' in csvf:
        continue
    # print(csvf)
    crop = "UNKNOWN"

    suffix = csvf.split('/')[-1]
    state = suffix.split('_')[-4].upper()
    # print(state)
    if state != "IOWA":
        continue
    county_name = suffix.split('_')[-3].upper()
    ym_str = csvf.split('_')[-2]

    year = int(suffix.split('-')[0][-4:])
    month = int(suffix.split('-')[1][:2])
    ym_obj = dt.datetime.strptime(ym_str, '%Y-%m')
    if ym_obj.year not in years:
        continue
    # else:
    #     print(ym_str)
        # pass

    df1 = pd.read_csv('s3://'+bucket_name+csvf)
    # df1.dropna(axis=1)
    csvf_part2 = csvf.replace('part1', 'part2')
    df2 = pd.read_csv('s3://'+bucket_name+csvf_part2)
    # df2.dropna(axis=1)


    df12 = pd.merge(df1, df2, on = 'datetime')
    
    df12 = df12.drop(columns=['sshf'])
    df12 = df12.drop(columns=['evavt'])
    
    df12['datetime'] = pd.to_datetime(df12['datetime'])
    # print("----------------------")
    # print(df12[df12['datetim-e'].dt.month >= 5])
    # df12 = df12[df12['datetime'].dt.month >= 5]
    # print(df12['datetime'].dt.month)
    df12 = df12[(df12['datetime'].dt.month >= 5) & (df12['datetime'].dt.month <= 11)]
    if df12.empty:
        print("No data available after filtering.")
        continue
      # drop datetime
    df12 = df12.drop(columns=['datetime'])
    
    # df12.drop(columns=['datetime'])
    # print(df12.head())
    # print("size:", len(df12))
    # print(df12.dtype)

    # print("-----------------------")
    # print(df12.shape)
    row = [year,state,county_name,month,crop]
    row.append(df12)
    # print(row[:4])

    # df_list.append(df12)
    dfLength = len(df_list)
    df_list.loc[dfLength] = row

# df_all = df_list[0]
# for df in df_list[1:]:
#     df_all = pd.concat([df_all, df], axis = 0)

print("Number of Features Per County Per Year:  >= ",len(df_list.iloc[1,4]))
# print(df_list["State"])
# df_list['Feature'] = df_list['Feature'].astype(object)

# df_list.to_csv('/content/drive/MyDrive/ai/era5/dataSat_cleaned_Iowa_2015-2020.csv', index=False)
# Out:
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# ...
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.

# %%
df_list.shape

# %%
df_list.iloc[1][-1]

# %%
# sys.getsizeof(df_list) / 1024 / 1024  # Byte -> MB
print(df_list.shape)
grouped_data = df_list.groupby(['Year', 'State', 'County']).size().reset_index(name='Count')
print(grouped_data)

# %%
# read crop yield (cy) data
year_range = [2015, 2020]
years = [x for x in range(year_range[0], year_range[-1]+1)]

def is_convertible_to_int(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

# cy_file_list = glob('/content/drive/MyDrive/ai/crop_yield/*csv')
# print((cy_file_list))
bucket_name = 'pepper-dataset'
prefix = 'crop_data/crop_3/'

# List to store all object keys
cy_file_list = []

# Initial call to list_objects_v2
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

# Process the initial response
while True:
    # Collect keys from current response
    current_keys = [obj['Key'] for obj in response.get('Contents', [])]
    cy_file_list.extend(current_keys)

    # Check if there are more objects to retrieve
    if not response['IsTruncated']:
        break  # No more objects to retrieve

    # Get ContinuationToken for next paginated call
    continuation_token = response['NextContinuationToken']

    # Make subsequent call with ContinuationToken
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, ContinuationToken=continuation_token)
    
cy_file_list = ["/" + path if not path.startswith("/") else path for path in cy_file_list]

print(cy_file_list)
cy_df_list = []
for cy_file in cy_file_list:
    suffix = cy_file.split('/')[-1]
    temp = suffix.split('_')
    state = temp[0].upper()
    print(state)
    if state == "IOWA":
        crop_type = temp[1]
        df = pd.read_csv('s3://'+bucket_name+cy_file)
        df = df[(df['Year'] >= 2015) & (df['Year'] <= 2020)]
        # Drop Rows that do not have "YIELD" in the "DATA ITEM" column
        dataYield = df.drop(df[~df["Data Item"].str.contains("YIELD")].index, inplace = False)
        # Drop Rows that have "IRRIGATED" in the "DATA ITEM" column
        dataYield = dataYield.drop(dataYield[dataYield["Data Item"].str.contains("IRRIGATED")].index, inplace = False)
        cy_df_list.append(dataYield)
        
        
# for cy_file in cy_file_list:
#     suffix = cy_file.split('/')[-1]
#     year = suffix.split('.')[0].split('_')[-1]
#     print(year)
#     if is_convertible_to_int(year) and int(year) not in years:
#       continue

#     crop_type = cy_file.split('_')[-2]
#     df = pd.read_csv('s3://'+bucket_name+cy_file)

#     # Drop Rows that do not have "YIELD" in the "DATA ITEM" column
#     dataYield = df.drop(df[~df["Data Item"].str.contains("YIELD")].index, inplace = False)
#     # Drop Rows that have "IRRIGATED" in the "DATA ITEM" column
#     dataYield = dataYield.drop(dataYield[dataYield["Data Item"].str.contains("IRRIGATED")].index, inplace = False)
#     cy_df_list.append(dataYield)

cy_df_all = cy_df_list[0]
for df in cy_df_list[1:]:
    cy_df_all = pd.concat([cy_df_all, df], axis = 0)
print(cy_df_all.shape)

print(cy_df_all.head())

# %%
dataROI = cy_df_all[["Year","State","County","Commodity","Value"]]
name_year = dataROI["Year"].drop_duplicates()
name_states = dataROI["State"].drop_duplicates()
name_county = dataROI["County"].drop_duplicates()
name_crops = dataROI["Commodity"].drop_duplicates()

dfOut = pd.DataFrame(columns=("Year","State","County","Commodity","Yield"))

# For each year
idx = 0
for year in name_year:
  temp_year = dataROI.loc[dataROI["Year"]==year]
  # if debug and verbose: print(temp_year)
  # For each state
  for state in name_states:
    temp_state = temp_year.loc[temp_year["State"]==state]
    # if debug and verbose: print(temp_state)
    # For each county
    for county in name_county:
      temp_county = temp_state.loc[temp_state["County"]==county]
      # if debug and verbose: print(temp_county)
      # For each crop
      for crop in name_crops:
        temp_crops = temp_county.loc[temp_county["Commodity"]==crop]
        # if debug and verbose: print(temp_crops)
        crop_yield = temp_crops["Value"]
        crop_yield = crop_yield.replace(',','', regex=True)
        crop_yield = pd.to_numeric(crop_yield)
        crop_yield = crop_yield.sum()
        # if debug and verbose: print(crop_yield)

        # Add to Output Data Frame
        dfOut.loc[idx] = [year,state,county,crop,crop_yield]

        # Increment idx
        idx = idx + 1

print(dfOut.head())
# wheat_rows = dfOut[dfOut['Commodity'] == 'WHEAT']
# print("wheat_rows: ", len(wheat_rows))
dfOut

# %%
def runCorrelateFeatureLabel(dataLabel,dataFeature,crop="WHEAT",dropZeroYield=True,debug=False,verbose=False):
  """Takes 2 pandas DataFrames (Label & Feature) and pairs them together"""

  # Drop Rows without the Desired Crop
  # print("pre dataCrop:", dataLabel.head())
  dataCrop = dataLabel.drop(dataLabel[~dataLabel["Commodity"].str.contains("CORN")].index, inplace = False)
  print("pre2 dataCrop:", dataCrop.head())
  dataCrop = dataCrop.drop(columns=["Commodity"]) #TODO: Assume we are only using 1 commodity
  dataFeat = dataFeature.drop(columns=["Commodity"])
  print("dataCrop:", dataCrop.head())
  print("dataFeat:", dataFeat.head())
  # print("++++++++++++++++++")

  # Merge DataFrames
  # Ref: https://realpython.com/pandas-merge-join-and-concat/
  # dataCrop.index = dataCrop.index.astype('object')
  print("------1: ", dataCrop.dtypes)
  print("------2: ", dataFeat.dtypes)
  dataFeat['Year'] = dataFeat['Year'].astype('int64')
  dataMerge = dataCrop.merge(dataFeat,how='right',on=['Year','State','County'])
  print(dataMerge.head())

  # Drop Rows without yield information
  if dropZeroYield:
    dataOut = dataMerge.drop(dataMerge[dataMerge["Yield"]==0.0].index,inplace=False)
  else:
    dataOut = dataMerge

  # Drop Rows with NaN
  dataOut.dropna(subset=['Yield'],inplace=True)

  if debug: print(dataOut)

  return dataOut

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# print("row shape:", df_list.iloc[1][4].info())
print(dfOut.shape)
print(dfOut.head())
print(df_list.shape)
print(df_list.head())
print(df_list.iloc[1][5].shape)
print("---------------------+")
# print(df_list.iloc[1])
dataSet = runCorrelateFeatureLabel(dfOut,df_list,crop="CORN",dropZeroYield=True,debug=False)

print("------------------")
print(dataSet.shape)
print(dataSet.head())

# %%
dataSet.iloc[1][-1]

# %%
def saveCorrelatedData(data,savePath,saveName,debug=False):
  """Save the correlated data to a mat for easier processing"""

  # Extract from DataFrame as list
  feature = data['Feature']
  print("feature len: ", len(feature))
  label = data['Yield']
  print("label len: ", len(label))
  # print(label)
  month = data['Month']
  if debug: print(len(feature))

  feat_lst = []
  label_lst = []
  feat_new = []
  firstTimeLoop = True
  for idx in range(len(feature)):
    # if debug: print(idx)
    print("idx:", idx)
    if int(month.iloc[idx]) == 5:
      feat_new = []
    for f in feature.iloc[idx]:
      # print(f)
      # feat_new.append(feature.iloc[idx][f])
      for item in feature.iloc[idx][f]:
        feat_new.append(item)
    # feat_new = np.array(feat_new)

    # Drop Bad Datasets
    # if len(feat_new) != 20: #4320: for whole year, 2520 for Jan-Jul, 3240 for Nov-Jul
    #   if debug: print("skipping feature of length",len(feat_new))
    #   continue

    if int(month.iloc[idx]) != 11:
      continue

    if len(feat_new) != 87312:  # 检查 feat_new 列表的长度是否为 240
        print("Skipping feature at index", idx, "due to incorrect length:", len(feat_new))
        continue

    print("feat_new len:", len(feat_new))
    # print("feat_arr:", len(feat_arr))
    # Append Features
    feat_lst.append(feat_new)
    label_lst.append(label.iloc[idx])

  print(len(label_lst))
  # feat_arr = np.array(feat_lst)
  feat_arr = feat_lst
  # print(feat_arr[0])

  data_feature_expanded = pd.DataFrame(feat_arr)

  # 将 DataFrame 写入 CSV 文件
  print("start writing dataFrame to csv: ", 's3://'+bucket_name+'/IOWA_data_feature_expanded_CORN.csv')
  data_feature_expanded.to_csv('s3://'+bucket_name+'/IOWA_data_feature_expanded_CORN.csv', index=False)

  print("Data successfully written to 'IOWA data_feature_expanded.csv'")

  # Get Ready to Save
  # feature = feat_arr.tolist()
  label = label_lst
  data_label_expanded = pd.DataFrame(label)
  data_label_expanded.to_csv('s3://'+bucket_name+'/IOWA_data_label_expanded_CORN.csv', index=False)
  print("Data successfully written to 'IOWA_data_label_expanded.csv'")

  # Save Path
  # saveFile = savePath + saveName
  # print("Saving to:",saveFile)
  # sio.savemat(saveFile, mdict={'feature': feat_arr, 'label': label})

  # df = pd.DataFrame(feat_arr)
  # df['label'] = label
  # filename = '/content/drive/MyDrive/ai/era5/yield_Iowa_corn_noIrr.csv'

  # 将 DataFrame 写入 CSV 文件
  # df.to_csv(filename, index=False, header=False)
  print("++++++++++++")
  # print("feat_arr shape: ", feat_arr.shape)
  # print(feat_arr.head())
  print(len(feat_arr))
  print(len(feat_arr[0]))
  print(label)


  return label, feat_arr


# print(dataSet.iloc[1][4].shape())

label, feat_arr = saveCorrelatedData(dataSet,"/content/drive/MyDrive/ai/era5/","yield_Iowa_corn_noIrr.mat",debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 91
#      86   return label, feat_arr
#      89 # print(dataSet.iloc[1][4].shape())
# ---> 91 label, feat_arr = saveCorrelatedData(dataSet,"/content/drive/MyDrive/ai/era5/","yield_Iowa_corn_noIrr.mat",debug=True)
#
# NameError: name 'dataSet' is not defined

# %%
feat_arr[0]

# %%
# Helper Functions
def get_time_now_ms():
    """Returns the current time in milliseconds"""
    ts = time.time()
    ts = round(ts) * 1000
    return int(ts)

# %%
# !pip install keras

# %%
import tensorflow as tf
from keras.layers import Input, Dense, LSTM, MaxPooling1D, Conv1D
from keras.models import Model
import keras
from keras.layers import Dense, TimeDistributed
from keras.models import Sequential
# from keras.utils import to_categorical
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping
# from keras.utils import np_utils
import itertools

from keras.layers import LSTM, RepeatVector
# from keras.layers.convolutional import Conv1D,Conv2D
# from keras.layers.convolutional import MaxPooling1D,MaxPooling2D
from keras.layers import Dropout, Flatten
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from numpy import dstack,  hstack
import scipy.io as sio
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from sklearn.model_selection import train_test_split


# data_mat = "/content/drive/MyDrive/ai/era5/yield_Iowa_corn_noIrr.mat" #Name of File, may need to specify path
# data_dict = sio.loadmat(data_mat) #Load MAT as a python dictionary
# print(data_dict)
# Out:
# 2024-10-03 23:49:38.188514: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-03 23:49:38.215311: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-03 23:49:38.215353: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-03 23:49:38.231822: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-03 23:49:39.313389: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# data_feature = data_dict['feature'] #Extract Features
# data_feature = feat_arr
data_feature = pd.read_csv('s3://'+bucket_name+ '/IOWA_data_feature_expanded_CORN.csv')

# print('Data Feature Shape:',data_feature.shape) # Verify Shape
# print("feature len: ", len(data_feature[0][0]))
# data_label = data_dict['label'] #Extract Labels
# data_label = label
data_label = pd.read_csv('s3://'+bucket_name+ '/IOWA_data_label_expanded_CORN.csv')
# print('Data Label Shape:',data_label.shape) # Verify Shape

# print(data_label)
# c1 = ["dewpoint_temperature_2m", "temperature_2m", "soil_temperature_level_1","soil_temperature_level_2"
#       ,"soil_temperature_level_3","soil_temperature_level_4","snowfall","volumetric_soil_water_layer_1",
#       "volumetric_soil_water_layer_2","volumetric_soil_water_layer_3","volumetric_soil_water_layer_4",
#       "surface_net_solar_radiation","surface_net_solar_radiation1",
#       "total_evaporation","surface_pressure","total_precipitation"]

# c = ["dewpoint_temperature_2m", "temperature_2m", "soil_temperature_level_1","soil_temperature_level_2"
#                              ,"soil_temperature_level_3","soil_temperature_level_4","snowfall","volumetric_soil_water_layer_1",
#                               "volumetric_soil_water_layer_2","volumetric_soil_water_layer_3","volumetric_soil_water_layer_4",
#                               "surface_net_solar_radiation","surface_net_solar_radiation1",
#                               "total_evaporation","surface_pressure","total_precipitation"]*288



# 假设 data_feature 是一个 1*467 的 DataFrame，每个单元格是一个长度为 175200 的序列
# 构造一个示例 DataFrame（实际使用中应替换为你的 data_feature）
# data_feature = pd.DataFrame([[np.random.rand(175200) for _ in range(467)]])

# 将 DataFrame 转置
# data_feature_transposed = data_feature.T

# print("data_feature_transposed[0].tolist(): ", len(data_feature_transposed[0][0]))
# 展开每个单元格中的序列
# data_feature_expanded = pd.DataFrame(data_feature_transposed[0][0].tolist())

# 检查转换后的 DataFrame 形状
# print("Original shape:", data_feature.shape)
# print("Transformed shape:", data_feature_expanded.shape)


train_X = data_feature
train_y = data_label.T

train_X = np.nan_to_num(train_X)
train_y = np.nan_to_num(train_y)

print(train_X.shape)
print(train_y.shape)

x = np.asarray(train_X, dtype=np.float32)
y = np.asarray(train_y).flatten()

# Training/Validation split 67%, 33% split
data_feature, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
print(X_test.shape)
print(data_feature.shape)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/fsspec/registry.py:279: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# (562, 87312)
# (1, 562)
# (186, 87312)
# (376, 87312)

# %%
print(data_feature.shape)
print(data_label.shape)
# Out:
# (376, 87312)
# (562, 1)

# %%
def dataReshape(dataIn,debug=True,runOnce=False):
  """Takes the 1D feature array and reshapes to 270x16"""
  print(dataIn.shape)

  dataOut = []
  for idx in range(len(dataIn)):
    dataTemp = dataIn[idx].reshape(5457, 16) #(216,15) 3240
    if debug: print(dataTemp.shape)
    dataOut.append(dataTemp)

    if runOnce: return -1

  return np.array(dataOut)

data_feature_rs = dataReshape(data_feature,debug=False,runOnce=False)
print(data_feature_rs.shape)

#Reshape test
X_test = dataReshape(X_test,debug=False,runOnce=False)
print(X_test.shape)
# Out:
# (376, 87312)
# (376, 5457, 16)
# (186, 87312)
# (186, 5457, 16)

# %%
# Network Parameters
BATCH_SIZE = 32
NUM_EPOCHS = 200
SHUFFLE_BUFFER_SIZE = 64

# Normalize Data
normalizer = Normalization(axis=-1)
normalizer.adapt(data_feature_rs)
data_feature_norm = normalizer(data_feature_rs)

# Normalize Test
normalizer = Normalization(axis=-1)
normalizer.adapt(X_test)
X_test_norm = normalizer(X_test)


# Split into train and test datasets
# Load the Data into a data loader
train_dataset = tf.data.Dataset.from_tensor_slices((data_feature_norm,y_train.T))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test_norm,y_test.T)) #TODO: REPLACE WITH TEST DATASET
DATASET_SIZE = len(data_feature_norm)

# Shuffle & Batch the Datasets
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
# Out:
# 2024-10-03 23:52:13.025739: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-10-03 23:52:13.110419: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 131317248 exceeds 10% of free system memory.
# 2024-10-03 23:52:18.722351: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 131317248 exceeds 10% of free system memory.
# 2024-10-03 23:52:18.850771: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 131317248 exceeds 10% of free system memory.
# 2024-10-03 23:52:18.948867: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 131317248 exceeds 10% of free system memory.

# %%
def step_decay(epoch):
   initial_lrate = 0.1
   drop = 0.5
   epochs_drop = 10.0
   lrate = initial_lrate * math.pow(drop,
           math.floor((1+epoch)/epochs_drop))
   return lrate

# %%
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, Add

def residual_block(input_tensor, filters, kernel_size=2):
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    
    # Add the input tensor back to the output
    x = Add()([x, input_tensor])
    x = Activation('relu')(x)
    return x

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, MaxPooling1D, concatenate
from tensorflow.keras.models import Model

# Input layer
visible = Input(shape=(5457, 16))

# First ResNet Pathway
cnn1 = Conv1D(filters=80, kernel_size=2, padding='same', activation='relu')(visible)
cnn1 = residual_block(cnn1, 80)
cnn1 = MaxPooling1D(pool_size=128)(cnn1)

# Second ResNet Pathway
cnn2 = Conv1D(filters=64, kernel_size=2, padding='same', activation='relu')(visible)
cnn2 = residual_block(cnn2, 64)
cnn2 = MaxPooling1D(pool_size=128)(cnn2)

# Third ResNet Pathway
cnn3 = Conv1D(filters=32, kernel_size=2, padding='same', activation='relu')(visible)
cnn3 = residual_block(cnn3, 32)
cnn3 = MaxPooling1D(pool_size=128)(cnn3)

# Fourth ResNet Pathway
cnn4 = Conv1D(filters=16, kernel_size=2, padding='same', activation='relu')(visible)
cnn4 = residual_block(cnn4, 16)
cnn4 = MaxPooling1D(pool_size=128)(cnn4)

# Concatenate the outputs from all paths
merged = concatenate([cnn1, cnn2, cnn3, cnn4], axis=2)

# Fully connected layer after concatenation
cnn = Dense(16)(merged)

# Flatten the output
cnn = Flatten()(cnn)

# Output layer
output1 = Dense(1, activation='linear')(cnn)

# Define the model
model = Model(inputs=visible, outputs=output1)

model.compile(optimizer='adam', loss='mse', metrics =['accuracy','mean_squared_error','mean_absolute_percentage_error',tf.keras.metrics.RootMeanSquaredError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5457, 16)]           0         []
#
#  conv1d (Conv1D)             (None, 5457, 80)             2640      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 5457, 64)             2112      ['input_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 5457, 32)             1056      ['input_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 5457, 16)             528       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 5457, 80)             12880     ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 5457, 64)             8256      ['conv1d_3[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5457, 32)             2080      ['conv1d_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 5457, 16)             528       ['conv1d_9[0][0]']
#
#  batch_normalization (Batch  (None, 5457, 80)             320       ['conv1d_1[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 5457, 64)             256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 5457, 32)             128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 5457, 16)             64        ['conv1d_10[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 5457, 80)             0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 5457, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 5457, 32)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 5457, 16)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 5457, 80)             12880     ['activation[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5457, 64)             8256      ['activation_2[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 5457, 32)             2080      ['activation_4[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 5457, 16)             528       ['activation_6[0][0]']
#
#  batch_normalization_1 (Bat  (None, 5457, 80)             320       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 5457, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 5457, 32)             128       ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 5457, 16)             64        ['conv1d_11[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 5457, 80)             0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv1d[0][0]']
#
#  add_1 (Add)                 (None, 5457, 64)             0         ['batch_normalization_3[0][0]'
#                                                                     , 'conv1d_3[0][0]']
#
#  add_2 (Add)                 (None, 5457, 32)             0         ['batch_normalization_5[0][0]'
#                                                                     , 'conv1d_6[0][0]']
#
#  add_3 (Add)                 (None, 5457, 16)             0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv1d_9[0][0]']
#
#  activation_1 (Activation)   (None, 5457, 80)             0         ['add[0][0]']
#
#  activation_3 (Activation)   (None, 5457, 64)             0         ['add_1[0][0]']
#
#  activation_5 (Activation)   (None, 5457, 32)             0         ['add_2[0][0]']
#
#  activation_7 (Activation)   (None, 5457, 16)             0         ['add_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 42, 80)               0         ['activation_1[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 42, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 42, 32)               0         ['activation_5[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 42, 16)               0         ['activation_7[0][0]']
#  g1D)
#
#  concatenate (Concatenate)   (None, 42, 192)              0         ['max_pooling1d[0][0]',
#                                                                      'max_pooling1d_1[0][0]',
#                                                                      'max_pooling1d_2[0][0]',
#                                                                      'max_pooling1d_3[0][0]']
#
#  dense (Dense)               (None, 42, 16)               3088      ['concatenate[0][0]']
#
#  flatten (Flatten)           (None, 672)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    673       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 59121 (230.94 KB)
# Trainable params: 58353 (227.94 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________

# %%
# FIT model with TRAINING DATA
history = model.fit(train_dataset, validation_data=test_dataset,epochs=NUM_EPOCHS,verbose=2)
model.summary()

# EVALUATE model with TESTING DATA
model.evaluate(test_dataset, verbose=0)

ynew = model.predict(test_dataset)
print(f'Test Loss: {ynew[0]}')
print(f'Test Mean Squared Error: {ynew[1]}')
print(f'Test Mean Absolute Percentage Error: {ynew[2]}')
print(f'Test Root Mean Squared Error: {ynew[3]}')

fig, ax = plt.subplots()
ax.set_title('Training and Validation \n Mean Absolute Percentage Error') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['mean_absolute_percentage_error'], color = 'blue', label = 'train')

# plt.title('Validation Mean Absolute Percentage Error (MAPE)') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['val_mean_absolute_percentage_error'], color = 'orange', label = 'val')
ax.legend()
# Out:
# Epoch 1/200
# 2024-10-03 23:52:30.209370: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 131317248 exceeds 10% of free system memory.
# 12/12 - 62s - loss: 20280.6719 - accuracy: 0.0000e+00 - mean_squared_error: 20280.6719 - mean_absolute_percentage_error: 71.8275 - root_mean_squared_error: 142.4102 - val_loss: 26295.1562 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 26295.1562 - val_mean_absolute_percentage_error: 83.0474 - val_root_mean_squared_error: 162.1578 - 62s/epoch - 5s/step
# Epoch 2/200
# 12/12 - 38s - loss: 1328.7593 - accuracy: 0.0000e+00 - mean_squared_error: 1328.7593 - mean_absolute_percentage_error: 19.7141 - root_mean_squared_error: 36.4522 - val_loss: 16661.2031 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 16661.2031 - val_mean_absolute_percentage_error: 66.9643 - val_root_mean_squared_error: 129.0783 - 38s/epoch - 3s/step
# Epoch 3/200
# 12/12 - 35s - loss: 561.4827 - accuracy: 0.0000e+00 - mean_squared_error: 561.4827 - mean_absolute_percentage_error: 14.0334 - root_mean_squared_error: 23.6956 - val_loss: 12899.8105 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 12899.8105 - val_mean_absolute_percentage_error: 59.3857 - val_root_mean_squared_error: 113.5773 - 35s/epoch - 3s/step
# Epoch 4/200
# 12/12 - 36s - loss: 535.6154 - accuracy: 0.0000e+00 - mean_squared_error: 535.6154 - mean_absolute_percentage_error: 13.7451 - root_mean_squared_error: 23.1434 - val_loss: 11424.7881 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 11424.7881 - val_mean_absolute_percentage_error: 56.1026 - val_root_mean_squared_error: 106.8868 - 36s/epoch - 3s/step
# Epoch 5/200
# 12/12 - 36s - loss: 537.8684 - accuracy: 0.0000e+00 - mean_squared_error: 537.8684 - mean_absolute_percentage_error: 13.7990 - root_mean_squared_error: 23.1920 - val_loss: 10349.6416 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 10349.6416 - val_mean_absolute_percentage_error: 53.5675 - val_root_mean_squared_error: 101.7332 - 36s/epoch - 3s/step
# Epoch 6/200
# 12/12 - 36s - loss: 529.3036 - accuracy: 0.0000e+00 - mean_squared_error: 529.3036 - mean_absolute_percentage_error: 13.6404 - root_mean_squared_error: 23.0066 - val_loss: 9567.8760 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 9567.8760 - val_mean_absolute_percentage_error: 51.6365 - val_root_mean_squared_error: 97.8155 - 36s/epoch - 3s/step
# Epoch 7/200
# 12/12 - 38s - loss: 537.6363 - accuracy: 0.0000e+00 - mean_squared_error: 537.6363 - mean_absolute_percentage_error: 13.7419 - root_mean_squared_error: 23.1870 - val_loss: 8910.9902 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 8910.9902 - val_mean_absolute_percentage_error: 49.9489 - val_root_mean_squared_error: 94.3980 - 38s/epoch - 3s/step
# Epoch 8/200
# 12/12 - 34s - loss: 522.8203 - accuracy: 0.0000e+00 - mean_squared_error: 522.8203 - mean_absolute_percentage_error: 13.5478 - root_mean_squared_error: 22.8653 - val_loss: 8181.5352 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 8181.5352 - val_mean_absolute_percentage_error: 47.9941 - val_root_mean_squared_error: 90.4518 - 34s/epoch - 3s/step
# Epoch 9/200
# 12/12 - 35s - loss: 527.5692 - accuracy: 0.0000e+00 - mean_squared_error: 527.5692 - mean_absolute_percentage_error: 13.6145 - root_mean_squared_error: 22.9689 - val_loss: 7383.2178 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 7383.2178 - val_mean_absolute_percentage_error: 45.7885 - val_root_mean_squared_error: 85.9257 - 35s/epoch - 3s/step
# Epoch 10/200
# 12/12 - 34s - loss: 526.0624 - accuracy: 0.0000e+00 - mean_squared_error: 526.0624 - mean_absolute_percentage_error: 13.5732 - root_mean_squared_error: 22.9361 - val_loss: 6884.7559 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 6884.7559 - val_mean_absolute_percentage_error: 44.3470 - val_root_mean_squared_error: 82.9744 - 34s/epoch - 3s/step
# Epoch 11/200
# 12/12 - 34s - loss: 510.7862 - accuracy: 0.0000e+00 - mean_squared_error: 510.7862 - mean_absolute_percentage_error: 13.3790 - root_mean_squared_error: 22.6006 - val_loss: 6430.3096 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 6430.3096 - val_mean_absolute_percentage_error: 42.9846 - val_root_mean_squared_error: 80.1892 - 34s/epoch - 3s/step
# Epoch 12/200
# 12/12 - 37s - loss: 522.2227 - accuracy: 0.0000e+00 - mean_squared_error: 522.2227 - mean_absolute_percentage_error: 13.5195 - root_mean_squared_error: 22.8522 - val_loss: 5928.7363 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 5928.7363 - val_mean_absolute_percentage_error: 41.4195 - val_root_mean_squared_error: 76.9983 - 37s/epoch - 3s/step
# Epoch 13/200
# 12/12 - 34s - loss: 521.5086 - accuracy: 0.0000e+00 - mean_squared_error: 521.5086 - mean_absolute_percentage_error: 13.5187 - root_mean_squared_error: 22.8366 - val_loss: 5346.8638 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 5346.8638 - val_mean_absolute_percentage_error: 39.5101 - val_root_mean_squared_error: 73.1223 - 34s/epoch - 3s/step
# Epoch 14/200
# 12/12 - 35s - loss: 513.7493 - accuracy: 0.0000e+00 - mean_squared_error: 513.7493 - mean_absolute_percentage_error: 13.4017 - root_mean_squared_error: 22.6660 - val_loss: 4859.5620 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 4859.5620 - val_mean_absolute_percentage_error: 37.8213 - val_root_mean_squared_error: 69.7106 - 35s/epoch - 3s/step
# Epoch 15/200
# 12/12 - 36s - loss: 511.9612 - accuracy: 0.0000e+00 - mean_squared_error: 511.9612 - mean_absolute_percentage_error: 13.4021 - root_mean_squared_error: 22.6266 - val_loss: 4460.9170 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 4460.9170 - val_mean_absolute_percentage_error: 36.3680 - val_root_mean_squared_error: 66.7901 - 36s/epoch - 3s/step
# Epoch 16/200
# 12/12 - 36s - loss: 520.6603 - accuracy: 0.0000e+00 - mean_squared_error: 520.6603 - mean_absolute_percentage_error: 13.5110 - root_mean_squared_error: 22.8180 - val_loss: 3981.6982 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 3981.6982 - val_mean_absolute_percentage_error: 34.5190 - val_root_mean_squared_error: 63.1007 - 36s/epoch - 3s/step
# Epoch 17/200
# 12/12 - 36s - loss: 514.0546 - accuracy: 0.0000e+00 - mean_squared_error: 514.0546 - mean_absolute_percentage_error: 13.3861 - root_mean_squared_error: 22.6728 - val_loss: 3577.1243 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 3577.1243 - val_mean_absolute_percentage_error: 32.8585 - val_root_mean_squared_error: 59.8091 - 36s/epoch - 3s/step
# Epoch 18/200
# 12/12 - 37s - loss: 512.5477 - accuracy: 0.0000e+00 - mean_squared_error: 512.5477 - mean_absolute_percentage_error: 13.4098 - root_mean_squared_error: 22.6395 - val_loss: 3051.0024 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 3051.0024 - val_mean_absolute_percentage_error: 30.5254 - val_root_mean_squared_error: 55.2359 - 37s/epoch - 3s/step
# Epoch 19/200
# 12/12 - 35s - loss: 504.8605 - accuracy: 0.0000e+00 - mean_squared_error: 504.8605 - mean_absolute_percentage_error: 13.2693 - root_mean_squared_error: 22.4691 - val_loss: 2808.1123 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2808.1123 - val_mean_absolute_percentage_error: 29.3856 - val_root_mean_squared_error: 52.9916 - 35s/epoch - 3s/step
# Epoch 20/200
# 12/12 - 35s - loss: 500.5676 - accuracy: 0.0000e+00 - mean_squared_error: 500.5676 - mean_absolute_percentage_error: 13.2055 - root_mean_squared_error: 22.3734 - val_loss: 2528.8750 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2528.8750 - val_mean_absolute_percentage_error: 28.0186 - val_root_mean_squared_error: 50.2879 - 35s/epoch - 3s/step
# Epoch 21/200
# 12/12 - 38s - loss: 497.0728 - accuracy: 0.0000e+00 - mean_squared_error: 497.0728 - mean_absolute_percentage_error: 13.1607 - root_mean_squared_error: 22.2951 - val_loss: 2456.0605 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2456.0605 - val_mean_absolute_percentage_error: 27.6536 - val_root_mean_squared_error: 49.5587 - 38s/epoch - 3s/step
# Epoch 22/200
# 12/12 - 34s - loss: 507.5832 - accuracy: 0.0000e+00 - mean_squared_error: 507.5832 - mean_absolute_percentage_error: 13.3338 - root_mean_squared_error: 22.5296 - val_loss: 2129.8027 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2129.8027 - val_mean_absolute_percentage_error: 25.9546 - val_root_mean_squared_error: 46.1498 - 34s/epoch - 3s/step
# Epoch 23/200
# 12/12 - 34s - loss: 499.3377 - accuracy: 0.0000e+00 - mean_squared_error: 499.3377 - mean_absolute_percentage_error: 13.1988 - root_mean_squared_error: 22.3459 - val_loss: 1968.2920 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1968.2920 - val_mean_absolute_percentage_error: 25.0687 - val_root_mean_squared_error: 44.3654 - 34s/epoch - 3s/step
# Epoch 24/200
# 12/12 - 36s - loss: 501.1972 - accuracy: 0.0000e+00 - mean_squared_error: 501.1972 - mean_absolute_percentage_error: 13.2810 - root_mean_squared_error: 22.3874 - val_loss: 1733.7795 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1733.7795 - val_mean_absolute_percentage_error: 23.7452 - val_root_mean_squared_error: 41.6387 - 36s/epoch - 3s/step
# Epoch 25/200
# 12/12 - 37s - loss: 502.3142 - accuracy: 0.0000e+00 - mean_squared_error: 502.3142 - mean_absolute_percentage_error: 13.2165 - root_mean_squared_error: 22.4124 - val_loss: 1519.3224 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1519.3224 - val_mean_absolute_percentage_error: 22.4689 - val_root_mean_squared_error: 38.9785 - 37s/epoch - 3s/step
# Epoch 26/200
# 12/12 - 35s - loss: 500.5117 - accuracy: 0.0000e+00 - mean_squared_error: 500.5117 - mean_absolute_percentage_error: 13.2365 - root_mean_squared_error: 22.3721 - val_loss: 1334.6420 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1334.6420 - val_mean_absolute_percentage_error: 21.2857 - val_root_mean_squared_error: 36.5328 - 35s/epoch - 3s/step
# Epoch 27/200
# 12/12 - 34s - loss: 496.4501 - accuracy: 0.0000e+00 - mean_squared_error: 496.4501 - mean_absolute_percentage_error: 13.0979 - root_mean_squared_error: 22.2812 - val_loss: 1194.0081 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1194.0081 - val_mean_absolute_percentage_error: 20.3080 - val_root_mean_squared_error: 34.5544 - 34s/epoch - 3s/step
# Epoch 28/200
# 12/12 - 34s - loss: 490.1829 - accuracy: 0.0000e+00 - mean_squared_error: 490.1829 - mean_absolute_percentage_error: 13.0651 - root_mean_squared_error: 22.1401 - val_loss: 1234.7466 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1234.7466 - val_mean_absolute_percentage_error: 20.5921 - val_root_mean_squared_error: 35.1390 - 34s/epoch - 3s/step
# Epoch 29/200
# 12/12 - 34s - loss: 487.8791 - accuracy: 0.0000e+00 - mean_squared_error: 487.8791 - mean_absolute_percentage_error: 13.0112 - root_mean_squared_error: 22.0880 - val_loss: 1136.5731 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1136.5731 - val_mean_absolute_percentage_error: 19.8855 - val_root_mean_squared_error: 33.7131 - 34s/epoch - 3s/step
# Epoch 30/200
# 12/12 - 37s - loss: 482.1025 - accuracy: 0.0000e+00 - mean_squared_error: 482.1025 - mean_absolute_percentage_error: 12.9319 - root_mean_squared_error: 21.9568 - val_loss: 1065.5112 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1065.5112 - val_mean_absolute_percentage_error: 19.3643 - val_root_mean_squared_error: 32.6422 - 37s/epoch - 3s/step
# Epoch 31/200
# 12/12 - 35s - loss: 484.7111 - accuracy: 0.0000e+00 - mean_squared_error: 484.7111 - mean_absolute_percentage_error: 12.9499 - root_mean_squared_error: 22.0162 - val_loss: 980.0891 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 980.0891 - val_mean_absolute_percentage_error: 18.7082 - val_root_mean_squared_error: 31.3064 - 35s/epoch - 3s/step
# Epoch 32/200
# 12/12 - 36s - loss: 485.9957 - accuracy: 0.0000e+00 - mean_squared_error: 485.9957 - mean_absolute_percentage_error: 12.9443 - root_mean_squared_error: 22.0453 - val_loss: 1002.4875 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1002.4875 - val_mean_absolute_percentage_error: 18.8775 - val_root_mean_squared_error: 31.6621 - 36s/epoch - 3s/step
# Epoch 33/200
# 12/12 - 35s - loss: 485.5808 - accuracy: 0.0000e+00 - mean_squared_error: 485.5808 - mean_absolute_percentage_error: 13.0303 - root_mean_squared_error: 22.0359 - val_loss: 882.1172 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 882.1172 - val_mean_absolute_percentage_error: 17.8903 - val_root_mean_squared_error: 29.7005 - 35s/epoch - 3s/step
# Epoch 34/200
# 12/12 - 34s - loss: 478.9194 - accuracy: 0.0000e+00 - mean_squared_error: 478.9194 - mean_absolute_percentage_error: 12.9185 - root_mean_squared_error: 21.8842 - val_loss: 848.1791 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 848.1791 - val_mean_absolute_percentage_error: 17.5969 - val_root_mean_squared_error: 29.1235 - 34s/epoch - 3s/step
# Epoch 35/200
# 12/12 - 37s - loss: 479.4223 - accuracy: 0.0000e+00 - mean_squared_error: 479.4223 - mean_absolute_percentage_error: 12.9382 - root_mean_squared_error: 21.8957 - val_loss: 809.8625 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 809.8625 - val_mean_absolute_percentage_error: 17.2638 - val_root_mean_squared_error: 28.4581 - 37s/epoch - 3s/step
# Epoch 36/200
# 12/12 - 35s - loss: 472.1056 - accuracy: 0.0000e+00 - mean_squared_error: 472.1056 - mean_absolute_percentage_error: 12.7898 - root_mean_squared_error: 21.7280 - val_loss: 812.1357 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 812.1357 - val_mean_absolute_percentage_error: 17.2784 - val_root_mean_squared_error: 28.4980 - 35s/epoch - 3s/step
# Epoch 37/200
# 12/12 - 36s - loss: 468.7520 - accuracy: 0.0000e+00 - mean_squared_error: 468.7520 - mean_absolute_percentage_error: 12.7539 - root_mean_squared_error: 21.6507 - val_loss: 766.1544 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 766.1544 - val_mean_absolute_percentage_error: 16.8613 - val_root_mean_squared_error: 27.6795 - 36s/epoch - 3s/step
# Epoch 38/200
# 12/12 - 34s - loss: 466.9367 - accuracy: 0.0000e+00 - mean_squared_error: 466.9367 - mean_absolute_percentage_error: 12.7505 - root_mean_squared_error: 21.6087 - val_loss: 745.0605 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 745.0605 - val_mean_absolute_percentage_error: 16.6584 - val_root_mean_squared_error: 27.2958 - 34s/epoch - 3s/step
# Epoch 39/200
# 12/12 - 34s - loss: 465.8089 - accuracy: 0.0000e+00 - mean_squared_error: 465.8089 - mean_absolute_percentage_error: 12.7282 - root_mean_squared_error: 21.5826 - val_loss: 803.5219 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 803.5219 - val_mean_absolute_percentage_error: 17.1843 - val_root_mean_squared_error: 28.3465 - 34s/epoch - 3s/step
# Epoch 40/200
# 12/12 - 37s - loss: 464.2961 - accuracy: 0.0000e+00 - mean_squared_error: 464.2961 - mean_absolute_percentage_error: 12.7012 - root_mean_squared_error: 21.5475 - val_loss: 733.9205 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 733.9205 - val_mean_absolute_percentage_error: 16.5484 - val_root_mean_squared_error: 27.0910 - 37s/epoch - 3s/step
# Epoch 41/200
# 12/12 - 35s - loss: 474.1427 - accuracy: 0.0000e+00 - mean_squared_error: 474.1427 - mean_absolute_percentage_error: 12.8351 - root_mean_squared_error: 21.7748 - val_loss: 651.9479 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 651.9479 - val_mean_absolute_percentage_error: 15.7679 - val_root_mean_squared_error: 25.5333 - 35s/epoch - 3s/step
# Epoch 42/200
# 12/12 - 35s - loss: 467.5583 - accuracy: 0.0000e+00 - mean_squared_error: 467.5583 - mean_absolute_percentage_error: 12.7096 - root_mean_squared_error: 21.6231 - val_loss: 609.1602 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 609.1602 - val_mean_absolute_percentage_error: 15.3291 - val_root_mean_squared_error: 24.6812 - 35s/epoch - 3s/step
# Epoch 43/200
# 12/12 - 34s - loss: 481.6479 - accuracy: 0.0000e+00 - mean_squared_error: 481.6479 - mean_absolute_percentage_error: 13.0128 - root_mean_squared_error: 21.9465 - val_loss: 548.6146 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 548.6146 - val_mean_absolute_percentage_error: 14.6743 - val_root_mean_squared_error: 23.4225 - 34s/epoch - 3s/step
# Epoch 44/200
# 12/12 - 34s - loss: 471.3815 - accuracy: 0.0000e+00 - mean_squared_error: 471.3815 - mean_absolute_percentage_error: 12.8051 - root_mean_squared_error: 21.7113 - val_loss: 499.0167 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 499.0167 - val_mean_absolute_percentage_error: 14.0784 - val_root_mean_squared_error: 22.3387 - 34s/epoch - 3s/step
# Epoch 45/200
# 12/12 - 37s - loss: 470.7090 - accuracy: 0.0000e+00 - mean_squared_error: 470.7090 - mean_absolute_percentage_error: 12.8050 - root_mean_squared_error: 21.6958 - val_loss: 495.7966 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 495.7966 - val_mean_absolute_percentage_error: 14.0388 - val_root_mean_squared_error: 22.2665 - 37s/epoch - 3s/step
# Epoch 46/200
# 12/12 - 33s - loss: 464.5988 - accuracy: 0.0000e+00 - mean_squared_error: 464.5988 - mean_absolute_percentage_error: 12.7573 - root_mean_squared_error: 21.5546 - val_loss: 540.5956 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 540.5956 - val_mean_absolute_percentage_error: 14.5707 - val_root_mean_squared_error: 23.2507 - 33s/epoch - 3s/step
# Epoch 47/200
# 12/12 - 34s - loss: 455.4648 - accuracy: 0.0000e+00 - mean_squared_error: 455.4648 - mean_absolute_percentage_error: 12.5478 - root_mean_squared_error: 21.3416 - val_loss: 640.8489 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 640.8489 - val_mean_absolute_percentage_error: 15.6283 - val_root_mean_squared_error: 25.3150 - 34s/epoch - 3s/step
# Epoch 48/200
# 12/12 - 36s - loss: 472.5815 - accuracy: 0.0000e+00 - mean_squared_error: 472.5815 - mean_absolute_percentage_error: 12.7279 - root_mean_squared_error: 21.7389 - val_loss: 599.4825 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 599.4825 - val_mean_absolute_percentage_error: 15.2451 - val_root_mean_squared_error: 24.4843 - 36s/epoch - 3s/step
# Epoch 49/200
# 12/12 - 33s - loss: 504.8176 - accuracy: 0.0000e+00 - mean_squared_error: 504.8176 - mean_absolute_percentage_error: 13.1728 - root_mean_squared_error: 22.4681 - val_loss: 480.1677 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 480.1677 - val_mean_absolute_percentage_error: 13.8519 - val_root_mean_squared_error: 21.9127 - 33s/epoch - 3s/step
# Epoch 50/200
# 12/12 - 38s - loss: 487.5285 - accuracy: 0.0000e+00 - mean_squared_error: 487.5285 - mean_absolute_percentage_error: 12.9933 - root_mean_squared_error: 22.0800 - val_loss: 468.5500 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 468.5500 - val_mean_absolute_percentage_error: 13.6704 - val_root_mean_squared_error: 21.6460 - 38s/epoch - 3s/step
# Epoch 51/200
# 12/12 - 34s - loss: 464.6153 - accuracy: 0.0000e+00 - mean_squared_error: 464.6153 - mean_absolute_percentage_error: 12.7195 - root_mean_squared_error: 21.5549 - val_loss: 477.5696 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 477.5696 - val_mean_absolute_percentage_error: 13.8010 - val_root_mean_squared_error: 21.8534 - 34s/epoch - 3s/step
# Epoch 52/200
# 12/12 - 34s - loss: 459.1662 - accuracy: 0.0000e+00 - mean_squared_error: 459.1662 - mean_absolute_percentage_error: 12.6166 - root_mean_squared_error: 21.4282 - val_loss: 533.1458 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 533.1458 - val_mean_absolute_percentage_error: 14.4765 - val_root_mean_squared_error: 23.0899 - 34s/epoch - 3s/step
# Epoch 53/200
# 12/12 - 44s - loss: 447.3520 - accuracy: 0.0000e+00 - mean_squared_error: 447.3520 - mean_absolute_percentage_error: 12.4781 - root_mean_squared_error: 21.1507 - val_loss: 647.5259 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 647.5259 - val_mean_absolute_percentage_error: 15.6904 - val_root_mean_squared_error: 25.4465 - 44s/epoch - 4s/step
# Epoch 54/200
# 12/12 - 34s - loss: 466.6017 - accuracy: 0.0000e+00 - mean_squared_error: 466.6017 - mean_absolute_percentage_error: 12.6927 - root_mean_squared_error: 21.6010 - val_loss: 708.5156 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 708.5156 - val_mean_absolute_percentage_error: 16.2679 - val_root_mean_squared_error: 26.6180 - 34s/epoch - 3s/step
# Epoch 55/200
# 12/12 - 34s - loss: 454.7030 - accuracy: 0.0000e+00 - mean_squared_error: 454.7030 - mean_absolute_percentage_error: 12.5992 - root_mean_squared_error: 21.3238 - val_loss: 573.7205 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 573.7205 - val_mean_absolute_percentage_error: 14.9207 - val_root_mean_squared_error: 23.9525 - 34s/epoch - 3s/step
# Epoch 56/200
# 12/12 - 34s - loss: 445.9227 - accuracy: 0.0000e+00 - mean_squared_error: 445.9227 - mean_absolute_percentage_error: 12.3762 - root_mean_squared_error: 21.1169 - val_loss: 537.8995 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 537.8995 - val_mean_absolute_percentage_error: 14.5144 - val_root_mean_squared_error: 23.1927 - 34s/epoch - 3s/step
# Epoch 57/200
# 12/12 - 34s - loss: 450.1376 - accuracy: 0.0000e+00 - mean_squared_error: 450.1376 - mean_absolute_percentage_error: 12.4980 - root_mean_squared_error: 21.2164 - val_loss: 514.3540 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 514.3540 - val_mean_absolute_percentage_error: 14.2214 - val_root_mean_squared_error: 22.6794 - 34s/epoch - 3s/step
# Epoch 58/200
# 12/12 - 34s - loss: 431.0135 - accuracy: 0.0000e+00 - mean_squared_error: 431.0135 - mean_absolute_percentage_error: 12.2080 - root_mean_squared_error: 20.7609 - val_loss: 583.5928 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 583.5928 - val_mean_absolute_percentage_error: 15.0133 - val_root_mean_squared_error: 24.1577 - 34s/epoch - 3s/step
# Epoch 59/200
# 12/12 - 35s - loss: 433.2520 - accuracy: 0.0000e+00 - mean_squared_error: 433.2520 - mean_absolute_percentage_error: 12.2181 - root_mean_squared_error: 20.8147 - val_loss: 656.6832 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 656.6832 - val_mean_absolute_percentage_error: 15.7463 - val_root_mean_squared_error: 25.6258 - 35s/epoch - 3s/step
# Epoch 60/200
# 12/12 - 35s - loss: 433.8644 - accuracy: 0.0000e+00 - mean_squared_error: 433.8644 - mean_absolute_percentage_error: 12.1545 - root_mean_squared_error: 20.8294 - val_loss: 615.0084 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 615.0084 - val_mean_absolute_percentage_error: 15.3212 - val_root_mean_squared_error: 24.7994 - 35s/epoch - 3s/step
# Epoch 61/200
# 12/12 - 34s - loss: 425.4512 - accuracy: 0.0000e+00 - mean_squared_error: 425.4512 - mean_absolute_percentage_error: 12.1612 - root_mean_squared_error: 20.6265 - val_loss: 582.9592 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 582.9592 - val_mean_absolute_percentage_error: 14.9804 - val_root_mean_squared_error: 24.1445 - 34s/epoch - 3s/step
# Epoch 62/200
# 12/12 - 34s - loss: 421.8842 - accuracy: 0.0000e+00 - mean_squared_error: 421.8842 - mean_absolute_percentage_error: 12.0785 - root_mean_squared_error: 20.5398 - val_loss: 630.3582 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 630.3582 - val_mean_absolute_percentage_error: 15.4620 - val_root_mean_squared_error: 25.1069 - 34s/epoch - 3s/step
# Epoch 63/200
# 12/12 - 37s - loss: 421.0686 - accuracy: 0.0000e+00 - mean_squared_error: 421.0686 - mean_absolute_percentage_error: 11.9841 - root_mean_squared_error: 20.5200 - val_loss: 660.8071 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 660.8071 - val_mean_absolute_percentage_error: 15.7476 - val_root_mean_squared_error: 25.7062 - 37s/epoch - 3s/step
# Epoch 64/200
# 12/12 - 34s - loss: 413.2365 - accuracy: 0.0000e+00 - mean_squared_error: 413.2365 - mean_absolute_percentage_error: 11.9940 - root_mean_squared_error: 20.3282 - val_loss: 661.9042 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 661.9043 - val_mean_absolute_percentage_error: 15.7541 - val_root_mean_squared_error: 25.7275 - 34s/epoch - 3s/step
# Epoch 65/200
# 12/12 - 34s - loss: 412.0854 - accuracy: 0.0000e+00 - mean_squared_error: 412.0854 - mean_absolute_percentage_error: 11.8943 - root_mean_squared_error: 20.2999 - val_loss: 622.2403 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 622.2403 - val_mean_absolute_percentage_error: 15.3483 - val_root_mean_squared_error: 24.9447 - 34s/epoch - 3s/step
# Epoch 66/200
# 12/12 - 34s - loss: 409.4767 - accuracy: 0.0000e+00 - mean_squared_error: 409.4767 - mean_absolute_percentage_error: 11.8711 - root_mean_squared_error: 20.2355 - val_loss: 668.5591 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 668.5591 - val_mean_absolute_percentage_error: 15.8236 - val_root_mean_squared_error: 25.8565 - 34s/epoch - 3s/step
# Epoch 67/200
# 12/12 - 34s - loss: 396.1625 - accuracy: 0.0000e+00 - mean_squared_error: 396.1625 - mean_absolute_percentage_error: 11.6237 - root_mean_squared_error: 19.9038 - val_loss: 665.4905 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 665.4905 - val_mean_absolute_percentage_error: 15.7947 - val_root_mean_squared_error: 25.7971 - 34s/epoch - 3s/step
# Epoch 68/200
# 12/12 - 37s - loss: 385.6982 - accuracy: 0.0000e+00 - mean_squared_error: 385.6982 - mean_absolute_percentage_error: 11.5851 - root_mean_squared_error: 19.6392 - val_loss: 671.4810 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 671.4810 - val_mean_absolute_percentage_error: 15.8634 - val_root_mean_squared_error: 25.9130 - 37s/epoch - 3s/step
# Epoch 69/200
# 12/12 - 34s - loss: 391.2033 - accuracy: 0.0000e+00 - mean_squared_error: 391.2033 - mean_absolute_percentage_error: 11.5913 - root_mean_squared_error: 19.7789 - val_loss: 801.1435 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 801.1435 - val_mean_absolute_percentage_error: 17.0802 - val_root_mean_squared_error: 28.3045 - 34s/epoch - 3s/step
# Epoch 70/200
# 12/12 - 34s - loss: 405.6205 - accuracy: 0.0000e+00 - mean_squared_error: 405.6205 - mean_absolute_percentage_error: 11.8081 - root_mean_squared_error: 20.1400 - val_loss: 450.9255 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 450.9255 - val_mean_absolute_percentage_error: 13.3497 - val_root_mean_squared_error: 21.2350 - 34s/epoch - 3s/step
# Epoch 71/200
# 12/12 - 35s - loss: 399.1181 - accuracy: 0.0000e+00 - mean_squared_error: 399.1181 - mean_absolute_percentage_error: 11.6847 - root_mean_squared_error: 19.9779 - val_loss: 539.6774 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 539.6774 - val_mean_absolute_percentage_error: 14.3894 - val_root_mean_squared_error: 23.2310 - 35s/epoch - 3s/step
# Epoch 72/200
# 12/12 - 37s - loss: 430.4557 - accuracy: 0.0000e+00 - mean_squared_error: 430.4557 - mean_absolute_percentage_error: 12.1546 - root_mean_squared_error: 20.7474 - val_loss: 450.7748 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 450.7748 - val_mean_absolute_percentage_error: 13.3425 - val_root_mean_squared_error: 21.2315 - 37s/epoch - 3s/step
# Epoch 73/200
# 12/12 - 33s - loss: 398.3716 - accuracy: 0.0000e+00 - mean_squared_error: 398.3716 - mean_absolute_percentage_error: 11.6311 - root_mean_squared_error: 19.9592 - val_loss: 434.9678 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 434.9678 - val_mean_absolute_percentage_error: 13.0788 - val_root_mean_squared_error: 20.8559 - 33s/epoch - 3s/step
# Epoch 74/200
# 12/12 - 33s - loss: 383.3776 - accuracy: 0.0000e+00 - mean_squared_error: 383.3776 - mean_absolute_percentage_error: 11.4345 - root_mean_squared_error: 19.5800 - val_loss: 451.5635 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 451.5635 - val_mean_absolute_percentage_error: 13.3090 - val_root_mean_squared_error: 21.2500 - 33s/epoch - 3s/step
# Epoch 75/200
# 12/12 - 34s - loss: 397.3969 - accuracy: 0.0000e+00 - mean_squared_error: 397.3969 - mean_absolute_percentage_error: 11.8527 - root_mean_squared_error: 19.9348 - val_loss: 427.7560 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 427.7560 - val_mean_absolute_percentage_error: 12.9726 - val_root_mean_squared_error: 20.6823 - 34s/epoch - 3s/step
# Epoch 76/200
# 12/12 - 35s - loss: 393.5231 - accuracy: 0.0000e+00 - mean_squared_error: 393.5231 - mean_absolute_percentage_error: 11.6666 - root_mean_squared_error: 19.8374 - val_loss: 466.5996 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 466.5996 - val_mean_absolute_percentage_error: 13.4935 - val_root_mean_squared_error: 21.6009 - 35s/epoch - 3s/step
# Epoch 77/200
# 12/12 - 37s - loss: 397.0817 - accuracy: 0.0000e+00 - mean_squared_error: 397.0817 - mean_absolute_percentage_error: 11.5958 - root_mean_squared_error: 19.9269 - val_loss: 461.1547 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 461.1547 - val_mean_absolute_percentage_error: 13.3981 - val_root_mean_squared_error: 21.4745 - 37s/epoch - 3s/step
# Epoch 78/200
# 12/12 - 34s - loss: 420.1764 - accuracy: 0.0000e+00 - mean_squared_error: 420.1764 - mean_absolute_percentage_error: 12.1511 - root_mean_squared_error: 20.4982 - val_loss: 510.4724 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 510.4724 - val_mean_absolute_percentage_error: 13.9173 - val_root_mean_squared_error: 22.5936 - 34s/epoch - 3s/step
# Epoch 79/200
# 12/12 - 34s - loss: 431.5061 - accuracy: 0.0000e+00 - mean_squared_error: 431.5061 - mean_absolute_percentage_error: 12.2071 - root_mean_squared_error: 20.7727 - val_loss: 409.7292 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 409.7292 - val_mean_absolute_percentage_error: 12.7250 - val_root_mean_squared_error: 20.2418 - 34s/epoch - 3s/step
# Epoch 80/200
# 12/12 - 35s - loss: 422.4422 - accuracy: 0.0000e+00 - mean_squared_error: 422.4422 - mean_absolute_percentage_error: 12.1186 - root_mean_squared_error: 20.5534 - val_loss: 392.0150 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 392.0150 - val_mean_absolute_percentage_error: 12.3621 - val_root_mean_squared_error: 19.7994 - 35s/epoch - 3s/step
# Epoch 81/200
# 12/12 - 35s - loss: 395.5624 - accuracy: 0.0000e+00 - mean_squared_error: 395.5624 - mean_absolute_percentage_error: 11.7178 - root_mean_squared_error: 19.8888 - val_loss: 393.3567 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 393.3567 - val_mean_absolute_percentage_error: 12.4636 - val_root_mean_squared_error: 19.8332 - 35s/epoch - 3s/step
# Epoch 82/200
# 12/12 - 37s - loss: 384.3249 - accuracy: 0.0000e+00 - mean_squared_error: 384.3249 - mean_absolute_percentage_error: 11.5041 - root_mean_squared_error: 19.6042 - val_loss: 384.7458 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 384.7458 - val_mean_absolute_percentage_error: 12.2683 - val_root_mean_squared_error: 19.6149 - 37s/epoch - 3s/step
# Epoch 83/200
# 12/12 - 33s - loss: 370.3603 - accuracy: 0.0000e+00 - mean_squared_error: 370.3603 - mean_absolute_percentage_error: 11.1607 - root_mean_squared_error: 19.2447 - val_loss: 400.3283 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 400.3283 - val_mean_absolute_percentage_error: 12.5276 - val_root_mean_squared_error: 20.0082 - 33s/epoch - 3s/step
# Epoch 84/200
# 12/12 - 33s - loss: 349.1088 - accuracy: 0.0000e+00 - mean_squared_error: 349.1088 - mean_absolute_percentage_error: 10.9231 - root_mean_squared_error: 18.6845 - val_loss: 589.6724 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 589.6724 - val_mean_absolute_percentage_error: 14.9166 - val_root_mean_squared_error: 24.2832 - 33s/epoch - 3s/step
# Epoch 85/200
# 12/12 - 35s - loss: 356.2721 - accuracy: 0.0000e+00 - mean_squared_error: 356.2721 - mean_absolute_percentage_error: 11.1428 - root_mean_squared_error: 18.8752 - val_loss: 529.1514 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 529.1514 - val_mean_absolute_percentage_error: 14.1673 - val_root_mean_squared_error: 23.0033 - 35s/epoch - 3s/step
# Epoch 86/200
# 12/12 - 34s - loss: 339.3524 - accuracy: 0.0000e+00 - mean_squared_error: 339.3524 - mean_absolute_percentage_error: 10.7386 - root_mean_squared_error: 18.4215 - val_loss: 507.0744 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 507.0744 - val_mean_absolute_percentage_error: 13.9254 - val_root_mean_squared_error: 22.5183 - 34s/epoch - 3s/step
# Epoch 87/200
# 12/12 - 36s - loss: 330.3018 - accuracy: 0.0000e+00 - mean_squared_error: 330.3018 - mean_absolute_percentage_error: 10.7015 - root_mean_squared_error: 18.1742 - val_loss: 628.6652 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 628.6652 - val_mean_absolute_percentage_error: 15.3021 - val_root_mean_squared_error: 25.0732 - 36s/epoch - 3s/step
# Epoch 88/200
# 12/12 - 34s - loss: 375.8885 - accuracy: 0.0000e+00 - mean_squared_error: 375.8885 - mean_absolute_percentage_error: 11.2216 - root_mean_squared_error: 19.3878 - val_loss: 468.1065 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 468.1065 - val_mean_absolute_percentage_error: 13.4439 - val_root_mean_squared_error: 21.6358 - 34s/epoch - 3s/step
# Epoch 89/200
# 12/12 - 34s - loss: 343.5398 - accuracy: 0.0000e+00 - mean_squared_error: 343.5398 - mean_absolute_percentage_error: 10.8841 - root_mean_squared_error: 18.5348 - val_loss: 502.5529 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 502.5529 - val_mean_absolute_percentage_error: 13.8524 - val_root_mean_squared_error: 22.4177 - 34s/epoch - 3s/step
# Epoch 90/200
# 12/12 - 34s - loss: 332.4229 - accuracy: 0.0000e+00 - mean_squared_error: 332.4229 - mean_absolute_percentage_error: 10.7161 - root_mean_squared_error: 18.2325 - val_loss: 638.9351 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 638.9351 - val_mean_absolute_percentage_error: 15.4122 - val_root_mean_squared_error: 25.2772 - 34s/epoch - 3s/step
# Epoch 91/200
# 12/12 - 36s - loss: 348.6959 - accuracy: 0.0000e+00 - mean_squared_error: 348.6959 - mean_absolute_percentage_error: 10.9152 - root_mean_squared_error: 18.6734 - val_loss: 426.0266 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 426.0266 - val_mean_absolute_percentage_error: 12.7803 - val_root_mean_squared_error: 20.6404 - 36s/epoch - 3s/step
# Epoch 92/200
# 12/12 - 37s - loss: 329.2935 - accuracy: 0.0000e+00 - mean_squared_error: 329.2935 - mean_absolute_percentage_error: 10.6524 - root_mean_squared_error: 18.1464 - val_loss: 503.9435 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 503.9435 - val_mean_absolute_percentage_error: 13.8301 - val_root_mean_squared_error: 22.4487 - 37s/epoch - 3s/step
# Epoch 93/200
# 12/12 - 33s - loss: 316.9775 - accuracy: 0.0000e+00 - mean_squared_error: 316.9775 - mean_absolute_percentage_error: 10.5941 - root_mean_squared_error: 17.8039 - val_loss: 801.4487 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 801.4487 - val_mean_absolute_percentage_error: 17.0386 - val_root_mean_squared_error: 28.3099 - 33s/epoch - 3s/step
# Epoch 94/200
# 12/12 - 34s - loss: 325.7091 - accuracy: 0.0000e+00 - mean_squared_error: 325.7091 - mean_absolute_percentage_error: 10.5980 - root_mean_squared_error: 18.0474 - val_loss: 583.5212 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 583.5212 - val_mean_absolute_percentage_error: 14.7418 - val_root_mean_squared_error: 24.1562 - 34s/epoch - 3s/step
# Epoch 95/200
# 12/12 - 35s - loss: 307.9551 - accuracy: 0.0000e+00 - mean_squared_error: 307.9551 - mean_absolute_percentage_error: 10.3191 - root_mean_squared_error: 17.5486 - val_loss: 566.6140 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 566.6140 - val_mean_absolute_percentage_error: 14.6207 - val_root_mean_squared_error: 23.8037 - 35s/epoch - 3s/step
# Epoch 96/200
# 12/12 - 37s - loss: 303.6459 - accuracy: 0.0000e+00 - mean_squared_error: 303.6459 - mean_absolute_percentage_error: 10.1686 - root_mean_squared_error: 17.4254 - val_loss: 516.1940 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 516.1940 - val_mean_absolute_percentage_error: 13.9411 - val_root_mean_squared_error: 22.7199 - 37s/epoch - 3s/step
# Epoch 97/200
# 12/12 - 34s - loss: 307.5002 - accuracy: 0.0000e+00 - mean_squared_error: 307.5002 - mean_absolute_percentage_error: 10.3323 - root_mean_squared_error: 17.5357 - val_loss: 526.8661 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 526.8661 - val_mean_absolute_percentage_error: 14.1351 - val_root_mean_squared_error: 22.9536 - 34s/epoch - 3s/step
# Epoch 98/200
# 12/12 - 35s - loss: 345.0922 - accuracy: 0.0000e+00 - mean_squared_error: 345.0922 - mean_absolute_percentage_error: 10.8383 - root_mean_squared_error: 18.5767 - val_loss: 369.3518 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 369.3518 - val_mean_absolute_percentage_error: 11.9494 - val_root_mean_squared_error: 19.2185 - 35s/epoch - 3s/step
# Epoch 99/200
# 12/12 - 35s - loss: 308.0536 - accuracy: 0.0000e+00 - mean_squared_error: 308.0536 - mean_absolute_percentage_error: 10.3387 - root_mean_squared_error: 17.5515 - val_loss: 380.8438 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 380.8438 - val_mean_absolute_percentage_error: 12.0561 - val_root_mean_squared_error: 19.5152 - 35s/epoch - 3s/step
# Epoch 100/200
# 12/12 - 34s - loss: 299.0793 - accuracy: 0.0000e+00 - mean_squared_error: 299.0793 - mean_absolute_percentage_error: 10.1401 - root_mean_squared_error: 17.2939 - val_loss: 372.0584 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 372.0584 - val_mean_absolute_percentage_error: 12.0377 - val_root_mean_squared_error: 19.2888 - 34s/epoch - 3s/step
# Epoch 101/200
# 12/12 - 38s - loss: 292.0366 - accuracy: 0.0000e+00 - mean_squared_error: 292.0366 - mean_absolute_percentage_error: 9.9207 - root_mean_squared_error: 17.0891 - val_loss: 356.9745 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 356.9745 - val_mean_absolute_percentage_error: 11.8466 - val_root_mean_squared_error: 18.8938 - 38s/epoch - 3s/step
# Epoch 102/200
# 12/12 - 34s - loss: 296.0501 - accuracy: 0.0000e+00 - mean_squared_error: 296.0501 - mean_absolute_percentage_error: 10.1430 - root_mean_squared_error: 17.2061 - val_loss: 430.0623 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 430.0623 - val_mean_absolute_percentage_error: 12.8094 - val_root_mean_squared_error: 20.7379 - 34s/epoch - 3s/step
# Epoch 103/200
# 12/12 - 34s - loss: 304.9702 - accuracy: 0.0000e+00 - mean_squared_error: 304.9702 - mean_absolute_percentage_error: 10.3178 - root_mean_squared_error: 17.4634 - val_loss: 331.3543 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 331.3543 - val_mean_absolute_percentage_error: 11.4645 - val_root_mean_squared_error: 18.2031 - 34s/epoch - 3s/step
# Epoch 104/200
# 12/12 - 34s - loss: 302.7184 - accuracy: 0.0000e+00 - mean_squared_error: 302.7184 - mean_absolute_percentage_error: 10.2704 - root_mean_squared_error: 17.3988 - val_loss: 370.0294 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 370.0294 - val_mean_absolute_percentage_error: 11.9876 - val_root_mean_squared_error: 19.2361 - 34s/epoch - 3s/step
# Epoch 105/200
# 12/12 - 34s - loss: 280.9873 - accuracy: 0.0000e+00 - mean_squared_error: 280.9873 - mean_absolute_percentage_error: 9.8570 - root_mean_squared_error: 16.7627 - val_loss: 483.8222 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 483.8222 - val_mean_absolute_percentage_error: 13.5743 - val_root_mean_squared_error: 21.9960 - 34s/epoch - 3s/step
# Epoch 106/200
# 12/12 - 35s - loss: 285.5757 - accuracy: 0.0000e+00 - mean_squared_error: 285.5757 - mean_absolute_percentage_error: 9.8353 - root_mean_squared_error: 16.8990 - val_loss: 386.5214 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 386.5214 - val_mean_absolute_percentage_error: 12.2550 - val_root_mean_squared_error: 19.6601 - 35s/epoch - 3s/step
# Epoch 107/200
# 12/12 - 34s - loss: 273.8653 - accuracy: 0.0000e+00 - mean_squared_error: 273.8653 - mean_absolute_percentage_error: 9.7046 - root_mean_squared_error: 16.5489 - val_loss: 475.5988 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 475.5988 - val_mean_absolute_percentage_error: 13.4865 - val_root_mean_squared_error: 21.8082 - 34s/epoch - 3s/step
# Epoch 108/200
# 12/12 - 34s - loss: 285.8667 - accuracy: 0.0000e+00 - mean_squared_error: 285.8667 - mean_absolute_percentage_error: 9.9805 - root_mean_squared_error: 16.9076 - val_loss: 461.7682 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 461.7682 - val_mean_absolute_percentage_error: 13.2546 - val_root_mean_squared_error: 21.4888 - 34s/epoch - 3s/step
# Epoch 109/200
# 12/12 - 34s - loss: 293.5851 - accuracy: 0.0000e+00 - mean_squared_error: 293.5851 - mean_absolute_percentage_error: 10.1003 - root_mean_squared_error: 17.1343 - val_loss: 421.9838 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 421.9838 - val_mean_absolute_percentage_error: 12.8126 - val_root_mean_squared_error: 20.5422 - 34s/epoch - 3s/step
# Epoch 110/200
# 12/12 - 34s - loss: 286.4760 - accuracy: 0.0000e+00 - mean_squared_error: 286.4760 - mean_absolute_percentage_error: 9.8748 - root_mean_squared_error: 16.9256 - val_loss: 340.6102 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 340.6102 - val_mean_absolute_percentage_error: 11.4980 - val_root_mean_squared_error: 18.4556 - 34s/epoch - 3s/step
# Epoch 111/200
# 12/12 - 38s - loss: 267.8314 - accuracy: 0.0000e+00 - mean_squared_error: 267.8314 - mean_absolute_percentage_error: 9.6130 - root_mean_squared_error: 16.3656 - val_loss: 337.7365 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 337.7365 - val_mean_absolute_percentage_error: 11.4960 - val_root_mean_squared_error: 18.3776 - 38s/epoch - 3s/step
# Epoch 112/200
# 12/12 - 35s - loss: 262.5953 - accuracy: 0.0000e+00 - mean_squared_error: 262.5953 - mean_absolute_percentage_error: 9.5851 - root_mean_squared_error: 16.2048 - val_loss: 349.4595 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 349.4595 - val_mean_absolute_percentage_error: 11.6494 - val_root_mean_squared_error: 18.6938 - 35s/epoch - 3s/step
# Epoch 113/200
# 12/12 - 34s - loss: 272.2394 - accuracy: 0.0000e+00 - mean_squared_error: 272.2394 - mean_absolute_percentage_error: 9.8026 - root_mean_squared_error: 16.4997 - val_loss: 409.5799 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 409.5799 - val_mean_absolute_percentage_error: 12.7234 - val_root_mean_squared_error: 20.2381 - 34s/epoch - 3s/step
# Epoch 114/200
# 12/12 - 34s - loss: 282.2554 - accuracy: 0.0000e+00 - mean_squared_error: 282.2554 - mean_absolute_percentage_error: 9.9050 - root_mean_squared_error: 16.8005 - val_loss: 357.9203 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 357.9203 - val_mean_absolute_percentage_error: 11.7659 - val_root_mean_squared_error: 18.9188 - 34s/epoch - 3s/step
# Epoch 115/200
# 12/12 - 35s - loss: 280.6422 - accuracy: 0.0000e+00 - mean_squared_error: 280.6422 - mean_absolute_percentage_error: 9.6287 - root_mean_squared_error: 16.7524 - val_loss: 320.0082 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 320.0082 - val_mean_absolute_percentage_error: 11.3060 - val_root_mean_squared_error: 17.8888 - 35s/epoch - 3s/step
# Epoch 116/200
# 12/12 - 37s - loss: 256.5352 - accuracy: 0.0000e+00 - mean_squared_error: 256.5352 - mean_absolute_percentage_error: 9.3666 - root_mean_squared_error: 16.0167 - val_loss: 313.8957 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 313.8957 - val_mean_absolute_percentage_error: 11.1854 - val_root_mean_squared_error: 17.7171 - 37s/epoch - 3s/step
# Epoch 117/200
# 12/12 - 35s - loss: 251.6166 - accuracy: 0.0000e+00 - mean_squared_error: 251.6166 - mean_absolute_percentage_error: 9.3354 - root_mean_squared_error: 15.8624 - val_loss: 362.1790 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 362.1790 - val_mean_absolute_percentage_error: 11.9346 - val_root_mean_squared_error: 19.0310 - 35s/epoch - 3s/step
# Epoch 118/200
# 12/12 - 34s - loss: 254.9765 - accuracy: 0.0000e+00 - mean_squared_error: 254.9765 - mean_absolute_percentage_error: 9.3689 - root_mean_squared_error: 15.9680 - val_loss: 346.8389 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 346.8389 - val_mean_absolute_percentage_error: 11.6264 - val_root_mean_squared_error: 18.6236 - 34s/epoch - 3s/step
# Epoch 119/200
# 12/12 - 34s - loss: 259.7731 - accuracy: 0.0000e+00 - mean_squared_error: 259.7731 - mean_absolute_percentage_error: 9.6617 - root_mean_squared_error: 16.1175 - val_loss: 306.0602 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 306.0602 - val_mean_absolute_percentage_error: 10.9821 - val_root_mean_squared_error: 17.4946 - 34s/epoch - 3s/step
# Epoch 120/200
# 12/12 - 34s - loss: 248.8128 - accuracy: 0.0000e+00 - mean_squared_error: 248.8128 - mean_absolute_percentage_error: 9.2823 - root_mean_squared_error: 15.7738 - val_loss: 335.9014 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 335.9014 - val_mean_absolute_percentage_error: 11.5495 - val_root_mean_squared_error: 18.3276 - 34s/epoch - 3s/step
# Epoch 121/200
# 12/12 - 34s - loss: 246.2451 - accuracy: 0.0000e+00 - mean_squared_error: 246.2451 - mean_absolute_percentage_error: 9.1787 - root_mean_squared_error: 15.6922 - val_loss: 380.3015 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 380.3015 - val_mean_absolute_percentage_error: 12.1614 - val_root_mean_squared_error: 19.5013 - 34s/epoch - 3s/step
# Epoch 122/200
# 12/12 - 35s - loss: 263.1309 - accuracy: 0.0000e+00 - mean_squared_error: 263.1309 - mean_absolute_percentage_error: 9.5812 - root_mean_squared_error: 16.2213 - val_loss: 302.6209 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 302.6209 - val_mean_absolute_percentage_error: 10.9682 - val_root_mean_squared_error: 17.3960 - 35s/epoch - 3s/step
# Epoch 123/200
# 12/12 - 34s - loss: 255.1641 - accuracy: 0.0000e+00 - mean_squared_error: 255.1641 - mean_absolute_percentage_error: 9.4080 - root_mean_squared_error: 15.9739 - val_loss: 309.3386 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 309.3386 - val_mean_absolute_percentage_error: 11.0789 - val_root_mean_squared_error: 17.5880 - 34s/epoch - 3s/step
# Epoch 124/200
# 12/12 - 34s - loss: 251.8462 - accuracy: 0.0000e+00 - mean_squared_error: 251.8462 - mean_absolute_percentage_error: 9.3487 - root_mean_squared_error: 15.8697 - val_loss: 326.7027 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 326.7027 - val_mean_absolute_percentage_error: 11.3556 - val_root_mean_squared_error: 18.0749 - 34s/epoch - 3s/step
# Epoch 125/200
# 12/12 - 38s - loss: 241.4202 - accuracy: 0.0000e+00 - mean_squared_error: 241.4202 - mean_absolute_percentage_error: 9.1187 - root_mean_squared_error: 15.5377 - val_loss: 387.1145 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 387.1145 - val_mean_absolute_percentage_error: 12.2244 - val_root_mean_squared_error: 19.6752 - 38s/epoch - 3s/step
# Epoch 126/200
# 12/12 - 35s - loss: 257.1414 - accuracy: 0.0000e+00 - mean_squared_error: 257.1414 - mean_absolute_percentage_error: 9.4597 - root_mean_squared_error: 16.0356 - val_loss: 268.4291 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 268.4291 - val_mean_absolute_percentage_error: 10.4888 - val_root_mean_squared_error: 16.3838 - 35s/epoch - 3s/step
# Epoch 127/200
# 12/12 - 38s - loss: 253.8433 - accuracy: 0.0000e+00 - mean_squared_error: 253.8433 - mean_absolute_percentage_error: 9.4003 - root_mean_squared_error: 15.9325 - val_loss: 299.3436 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 299.3436 - val_mean_absolute_percentage_error: 11.0598 - val_root_mean_squared_error: 17.3015 - 38s/epoch - 3s/step
# Epoch 128/200
# 12/12 - 35s - loss: 241.6342 - accuracy: 0.0000e+00 - mean_squared_error: 241.6342 - mean_absolute_percentage_error: 9.1618 - root_mean_squared_error: 15.5446 - val_loss: 325.0050 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 325.0050 - val_mean_absolute_percentage_error: 11.3254 - val_root_mean_squared_error: 18.0279 - 35s/epoch - 3s/step
# Epoch 129/200
# 12/12 - 36s - loss: 247.9259 - accuracy: 0.0000e+00 - mean_squared_error: 247.9259 - mean_absolute_percentage_error: 9.2859 - root_mean_squared_error: 15.7457 - val_loss: 394.6337 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 394.6337 - val_mean_absolute_percentage_error: 12.3838 - val_root_mean_squared_error: 19.8654 - 36s/epoch - 3s/step
# Epoch 130/200
# 12/12 - 37s - loss: 237.3004 - accuracy: 0.0000e+00 - mean_squared_error: 237.3004 - mean_absolute_percentage_error: 9.0971 - root_mean_squared_error: 15.4046 - val_loss: 271.9988 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 271.9988 - val_mean_absolute_percentage_error: 10.5097 - val_root_mean_squared_error: 16.4924 - 37s/epoch - 3s/step
# Epoch 131/200
# 12/12 - 35s - loss: 257.1261 - accuracy: 0.0000e+00 - mean_squared_error: 257.1261 - mean_absolute_percentage_error: 9.3646 - root_mean_squared_error: 16.0352 - val_loss: 270.7298 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 270.7298 - val_mean_absolute_percentage_error: 10.4714 - val_root_mean_squared_error: 16.4539 - 35s/epoch - 3s/step
# Epoch 132/200
# ...
# Epoch 188/200
# 12/12 - 38s - loss: 178.0662 - accuracy: 0.0000e+00 - mean_squared_error: 178.0662 - mean_absolute_percentage_error: 7.8264 - root_mean_squared_error: 13.3441 - val_loss: 326.8326 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 326.8326 - val_mean_absolute_percentage_error: 11.3451 - val_root_mean_squared_error: 18.0785 - 38s/epoch - 3s/step
# Epoch 189/200
# 12/12 - 37s - loss: 205.5169 - accuracy: 0.0000e+00 - mean_squared_error: 205.5169 - mean_absolute_percentage_error: 8.3321 - root_mean_squared_error: 14.3359 - val_loss: 260.1418 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 260.1418 - val_mean_absolute_percentage_error: 10.1715 - val_root_mean_squared_error: 16.1289 - 37s/epoch - 3s/step
# Epoch 190/200
# 12/12 - 35s - loss: 177.5736 - accuracy: 0.0000e+00 - mean_squared_error: 177.5736 - mean_absolute_percentage_error: 7.7289 - root_mean_squared_error: 13.3257 - val_loss: 290.1425 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 290.1425 - val_mean_absolute_percentage_error: 10.6624 - val_root_mean_squared_error: 17.0336 - 35s/epoch - 3s/step
# Epoch 191/200
# 12/12 - 34s - loss: 197.5843 - accuracy: 0.0000e+00 - mean_squared_error: 197.5843 - mean_absolute_percentage_error: 8.2275 - root_mean_squared_error: 14.0565 - val_loss: 296.7044 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 296.7044 - val_mean_absolute_percentage_error: 10.8850 - val_root_mean_squared_error: 17.2251 - 34s/epoch - 3s/step
# Epoch 192/200
# 12/12 - 38s - loss: 212.9672 - accuracy: 0.0000e+00 - mean_squared_error: 212.9672 - mean_absolute_percentage_error: 8.5953 - root_mean_squared_error: 14.5934 - val_loss: 247.2635 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 247.2635 - val_mean_absolute_percentage_error: 9.9341 - val_root_mean_squared_error: 15.7246 - 38s/epoch - 3s/step
# Epoch 193/200
# 12/12 - 34s - loss: 181.8506 - accuracy: 0.0000e+00 - mean_squared_error: 181.8506 - mean_absolute_percentage_error: 7.8688 - root_mean_squared_error: 13.4852 - val_loss: 269.0694 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 269.0694 - val_mean_absolute_percentage_error: 10.4168 - val_root_mean_squared_error: 16.4033 - 34s/epoch - 3s/step
# Epoch 194/200
# 12/12 - 35s - loss: 177.4433 - accuracy: 0.0000e+00 - mean_squared_error: 177.4433 - mean_absolute_percentage_error: 7.9073 - root_mean_squared_error: 13.3208 - val_loss: 322.6594 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 322.6594 - val_mean_absolute_percentage_error: 11.2806 - val_root_mean_squared_error: 17.9627 - 35s/epoch - 3s/step
# Epoch 195/200
# 12/12 - 34s - loss: 182.6502 - accuracy: 0.0000e+00 - mean_squared_error: 182.6502 - mean_absolute_percentage_error: 7.8754 - root_mean_squared_error: 13.5148 - val_loss: 261.2527 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 261.2527 - val_mean_absolute_percentage_error: 10.2151 - val_root_mean_squared_error: 16.1633 - 34s/epoch - 3s/step
# Epoch 196/200
# 12/12 - 35s - loss: 163.1256 - accuracy: 0.0000e+00 - mean_squared_error: 163.1256 - mean_absolute_percentage_error: 7.4943 - root_mean_squared_error: 12.7721 - val_loss: 269.7393 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 269.7393 - val_mean_absolute_percentage_error: 10.3558 - val_root_mean_squared_error: 16.4237 - 35s/epoch - 3s/step
# Epoch 197/200
# 12/12 - 38s - loss: 177.5546 - accuracy: 0.0000e+00 - mean_squared_error: 177.5546 - mean_absolute_percentage_error: 7.8012 - root_mean_squared_error: 13.3250 - val_loss: 362.8080 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 362.8080 - val_mean_absolute_percentage_error: 11.9811 - val_root_mean_squared_error: 19.0475 - 38s/epoch - 3s/step
# Epoch 198/200
# 12/12 - 34s - loss: 187.6190 - accuracy: 0.0000e+00 - mean_squared_error: 187.6190 - mean_absolute_percentage_error: 7.9247 - root_mean_squared_error: 13.6974 - val_loss: 247.7006 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 247.7006 - val_mean_absolute_percentage_error: 9.8734 - val_root_mean_squared_error: 15.7385 - 34s/epoch - 3s/step
# Epoch 199/200
# 12/12 - 34s - loss: 174.6698 - accuracy: 0.0000e+00 - mean_squared_error: 174.6698 - mean_absolute_percentage_error: 7.7279 - root_mean_squared_error: 13.2163 - val_loss: 293.0003 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 293.0003 - val_mean_absolute_percentage_error: 10.9081 - val_root_mean_squared_error: 17.1173 - 34s/epoch - 3s/step
# Epoch 200/200
# 12/12 - 35s - loss: 172.7725 - accuracy: 0.0000e+00 - mean_squared_error: 172.7725 - mean_absolute_percentage_error: 7.7209 - root_mean_squared_error: 13.1443 - val_loss: 284.6545 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 284.6545 - val_mean_absolute_percentage_error: 10.5813 - val_root_mean_squared_error: 16.8717 - 35s/epoch - 3s/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5457, 16)]           0         []
#
#  conv1d (Conv1D)             (None, 5457, 80)             2640      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 5457, 64)             2112      ['input_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 5457, 32)             1056      ['input_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 5457, 16)             528       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 5457, 80)             12880     ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 5457, 64)             8256      ['conv1d_3[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5457, 32)             2080      ['conv1d_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 5457, 16)             528       ['conv1d_9[0][0]']
#
#  batch_normalization (Batch  (None, 5457, 80)             320       ['conv1d_1[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 5457, 64)             256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 5457, 32)             128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 5457, 16)             64        ['conv1d_10[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 5457, 80)             0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 5457, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 5457, 32)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 5457, 16)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 5457, 80)             12880     ['activation[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5457, 64)             8256      ['activation_2[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 5457, 32)             2080      ['activation_4[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 5457, 16)             528       ['activation_6[0][0]']
#
#  batch_normalization_1 (Bat  (None, 5457, 80)             320       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 5457, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 5457, 32)             128       ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 5457, 16)             64        ['conv1d_11[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 5457, 80)             0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv1d[0][0]']
#
#  add_1 (Add)                 (None, 5457, 64)             0         ['batch_normalization_3[0][0]'
#                                                                     , 'conv1d_3[0][0]']
#
#  add_2 (Add)                 (None, 5457, 32)             0         ['batch_normalization_5[0][0]'
#                                                                     , 'conv1d_6[0][0]']
#
#  add_3 (Add)                 (None, 5457, 16)             0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv1d_9[0][0]']
#
#  activation_1 (Activation)   (None, 5457, 80)             0         ['add[0][0]']
#
#  activation_3 (Activation)   (None, 5457, 64)             0         ['add_1[0][0]']
#
#  activation_5 (Activation)   (None, 5457, 32)             0         ['add_2[0][0]']
#
#  activation_7 (Activation)   (None, 5457, 16)             0         ['add_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 42, 80)               0         ['activation_1[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 42, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 42, 32)               0         ['activation_5[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 42, 16)               0         ['activation_7[0][0]']
#  g1D)
#
#  concatenate (Concatenate)   (None, 42, 192)              0         ['max_pooling1d[0][0]',
#                                                                      'max_pooling1d_1[0][0]',
#                                                                      'max_pooling1d_2[0][0]',
#                                                                      'max_pooling1d_3[0][0]']
#
#  dense (Dense)               (None, 42, 16)               3088      ['concatenate[0][0]']
#
#  flatten (Flatten)           (None, 672)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    673       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 59121 (230.94 KB)
# Trainable params: 58353 (227.94 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________
# 6/6 [==============================] - 4s 462ms/step
# Test Loss: [128.14677]
# Test Mean Squared Error: [212.01073]
# Test Mean Absolute Percentage Error: [174.08937]
# Test Root Mean Squared Error: [193.65424]

# %%
results = model.evaluate(test_dataset, batch_size=64)
# Out:
# 6/6 [==============================] - 3s 448ms/step - loss: 284.6545 - accuracy: 0.0000e+00 - mean_squared_error: 284.6545 - mean_absolute_percentage_error: 10.5813 - root_mean_squared_error: 16.8717

# %%
import tensorflow as tf
import numpy as np

# 重置数据集
def create_test_dataset(X_test_norm, y_test):
    return tf.data.Dataset.from_tensor_slices((X_test_norm, y_test.T)).batch(64)

# 创建测试数据集
test_dataset = create_test_dataset(X_test_norm, y_test)

# EVALUATE model with TESTING DATA
results = model.evaluate(test_dataset, verbose=0)
print(f'Test Loss: {results[0]}')
print(f'Test Mean Squared Error: {results[1]}')
print(f'Test Mean Absolute Percentage Error: {results[2]}')
print(f'Test Root Mean Squared Error: {results[3]}')

# PREDICT with TESTING DATA
ynew = model.predict(test_dataset)

# 重置测试数据集
test_dataset = create_test_dataset(X_test_norm, y_test)

# EVALUATE model again with TESTING DATA
results = model.evaluate(test_dataset, batch_size=64)
print(f'loss: {results[0]} - accuracy: {results[1]} - mean_squared_error: {results[2]} - mean_absolute_percentage_error: {results[3]} - root_mean_squared_error: {results[4]}')
# Out:
# Test Loss: 284.654541015625
# Test Mean Squared Error: 0.0
# Test Mean Absolute Percentage Error: 284.654541015625
# Test Root Mean Squared Error: 10.581343650817871
# 3/3 [==============================] - 4s 1s/step
# 3/3 [==============================] - 4s 1s/step - loss: 284.6545 - accuracy: 0.0000e+00 - mean_squared_error: 284.6545 - mean_absolute_percentage_error: 10.5813 - root_mean_squared_error: 16.8717
# loss: 284.654541015625 - accuracy: 0.0 - mean_squared_error: 284.654541015625 - mean_absolute_percentage_error: 10.581343650817871 - root_mean_squared_error: 16.871707916259766

# %%
# plt.figure()
# plt.title('Loss (Mean Squared Error)')
# plt.plot(history.history['loss'])
# plt.figure()
# plt.title('Accuracy')
# plt.plot(history.history['accuracy'])
# plt.figure()
# plt.title('Mean Squared Error')
# plt.plot(history.history['mean_squared_error'])
# plt.figure()
fig, ax = plt.subplots()
ax.set_title('Training and Validation \n Mean Squared Error') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['loss'], color = 'blue', label = 'train')
# plt.figure()
## Validation Plots
# plt.title('Validation Loss (MSE)') # loss = 100 * abs(y_true - y_pred) / y_true
# plt.plot(history.history['val_loss'])
# plt.figure()

# plt.title('Validation Mean Absolute Percentage Error (MAPE)') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['val_loss'], color = 'orange', label = 'val')
ax.semilogy((0,50))
ax.legend()
# plt.figure()
