# %%
import os # Handle OS file systems and directory paths
import random # Random number
import numpy as np # Import NumPy for arrays and such
import matplotlib.pyplot as plt # Plotting Tools
import numpy.linalg as npl # Linear Algebra Library
import time # Time
# from google.colab import drive # Read files in from Google Drive
import pandas as pd # Import Pandas for data processing
import datetime as dt
import scipy.io as sio
import io
from decimal import Decimal # String to double conversion
from glob import glob  # 从 glob 模块中导入 glob 函数

# %%
import boto3
from botocore.exceptions import NoCredentialsError

# %%
# Optionally, you can specify the AWS region
s3 = boto3.client('s3', region_name='us-east-1')  # Replace 'us-west-2' with your AWS region

# %%
import pandas as pd
# s3_uri = 's3://pepper-dataset/crop_data/crop_IOWA/Iowa_corn_2019.csv'
# df = pd.read_csv(s3_uri)

#Read files from s3
bucket_name = 'pepper-dataset'
prefix = 'county-env-data/county_env_IOWA/processed_with_all_features_ver_2/'

# %%
# get county list
# county_path_list = glob('/content/drive/MyDrive/ai/era5/county_env/*')
# county_list = [os.path.basename(x) for x in county_path_list]
# print(county_list)

#Read files from s3
bucket_name = 'pepper-dataset'
prefix = 'county-env-data/county_env_IOWA/processed_with_all_features_ver_2/'

# List to store all object keys
county_files = []

# Initial call to list_objects_v2
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

# Process the initial response
while True:
    # Collect keys from current response
    current_keys = [obj['Key'] for obj in response.get('Contents', [])]
    county_files.extend(current_keys)

    # Check if there are more objects to retrieve
    if not response['IsTruncated']:
        break  # No more objects to retrieve

    # Get ContinuationToken for next paginated call
    continuation_token = response['NextContinuationToken']

    # Make subsequent call with ContinuationToken
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, ContinuationToken=continuation_token)
    
    
county_files = ["/" + path if not path.startswith("/") else path for path in county_files]

# %%
len(county_files)
# Out:
# 54648

# %%
county_files[:10]
# Out:
# ['/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-01_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-01_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-02_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-02_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-03_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-03_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-04_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-04_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-05_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2000-05_part2.csv']

# %%
# try 1 county
year_range = [2015, 2020]
years = [x for x in range(year_range[0], year_range[-1]+1)]

filtered_files = [file_path for file_path in county_files
                  if any(str(year) in file_path for year in years)]

# basedir = '/content/drive/MyDrive/ai/era5/county_env/'
# county_files = []

# for c in county_list:
#   county = os.path.join(basedir, c)
#   print(county)

#   county_f = glob(os.path.join(county, '*'))

#   for f in county_f:
#     ym_str = f.split('_')[-2]
#     ym_obj = dt.datetime.strptime(ym_str, '%Y-%m')
#     if ym_obj.year not in years:
#         continue
#     county_files.append(f)

print(len(filtered_files))

  # print(len(county_files))
  # print(county_files[:3])

# get year-month info for the county
# ym_list = [x.split('_')[-2] for x in county_files]
# ym_list = list(set(ym_list))
# ym_list.sort()
# print(ym_list)

filtered_files[:50]
# Out:
# 14256
# ['/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-01_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-01_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-02_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-02_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-03_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-03_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-04_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-04_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-05_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-05_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-06_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-06_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-07_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-07_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-08_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-08_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-09_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-09_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-10_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-10_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-11_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-11_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-12_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2015-12_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-01_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-01_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-02_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-02_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-03_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-03_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-04_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-04_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-05_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-05_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-06_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-06_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-07_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-07_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-08_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-08_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-09_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-09_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-10_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-10_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-11_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-11_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-12_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2016-12_part2.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2017-01_part1.csv',
#  '/county-env-data/county_env_IOWA/processed_with_all_features_ver_2/Iowa_Adair/Iowa_Adair_2017-01_part2.csv']

# %%
pd.read_csv('s3://'+bucket_name+filtered_files[0])
# Out:
#             t2m         rsn       sde        stl1        stl2        stl3  \
# 0    264.779109  157.898785  0.022211  270.594126  272.370047  276.240175
# 1    264.422925  157.904400  0.022114  270.453053  272.363595  276.224547
# 2    264.124610  157.912701  0.022114  270.239228  272.355498  276.208919
# 3    263.781137  157.918316  0.022017  269.972289  272.345787  276.193582
# 4    263.406891  157.925640  0.021871  269.575237  272.333674  276.177848
# ..          ...         ...       ...         ...         ...         ...
# 739  274.944472  168.355773  0.005863  273.101253  273.256931  273.429511
# 740  274.784137  168.371154  0.007812  273.148886  273.256569  273.430385
# 741  274.423772  167.692950  0.010891  273.174096  273.256043  273.431073
# 742  274.196871  165.558975  0.015332  273.193917  273.256372  273.432265
# 743  273.932061  163.638129  0.020557  273.202777  273.255812  273.433166
#
#            stl4         tsn     swvl1     swvl2     swvl3     swvl4  \
# 0    281.932781  262.736158  0.349909  0.351766  0.317072  0.309495
# 1    281.927790  262.692495  0.349842  0.351668  0.317102  0.309496
# 2    281.922726  262.665017  0.349778  0.351571  0.317130  0.309497
# 3    281.918383  262.487613  0.349710  0.351471  0.317161  0.309497
# 4    281.913200  262.197851  0.349647  0.351375  0.317189  0.309497
# ..          ...         ...       ...       ...       ...       ...
# 739  278.006532  273.160300  0.354087  0.337028  0.324468  0.310423
# 740  278.002548  273.160300  0.360544  0.337175  0.324473  0.310425
# 741  277.998637  273.160919  0.365072  0.337392  0.324479  0.310428
# 742  277.994725  273.160300  0.367889  0.337651  0.324486  0.310429
# 743  277.990598  273.159681  0.369467  0.337944  0.324491  0.310432
#
#                 datetime
# 0    2015-01-01 00:00:00
# 1    2015-01-01 01:00:00
# 2    2015-01-01 02:00:00
# 3    2015-01-01 03:00:00
# 4    2015-01-01 04:00:00
# ..                   ...
# 739  2015-01-31 19:00:00
# 740  2015-01-31 20:00:00
# 741  2015-01-31 21:00:00
# 742  2015-01-31 22:00:00
# 743  2015-01-31 23:00:00
#
# [744 rows x 13 columns]

# %%
df_list = pd.DataFrame(columns=("Year","State","County","Month","Commodity","Feature"))

for csvf in filtered_files:
    # only read part1, then match with part2
    if 'part2' in csvf:
        continue
    # print(csvf)
    crop = "UNKNOWN"

    suffix = csvf.split('/')[-1]
    state = suffix.split('_')[-4].upper()
    # print(state)
    if state != "IOWA":
        continue
    county_name = suffix.split('_')[-3].upper()
    ym_str = csvf.split('_')[-2]

    year = int(suffix.split('-')[0][-4:])
    month = int(suffix.split('-')[1][:2])
    ym_obj = dt.datetime.strptime(ym_str, '%Y-%m')
    if ym_obj.year not in years:
        continue
    # else:
    #     print(ym_str)
        # pass

    df1 = pd.read_csv('s3://'+bucket_name+csvf)
    # df1.dropna(axis=1)
    csvf_part2 = csvf.replace('part1', 'part2')
    df2 = pd.read_csv('s3://'+bucket_name+csvf_part2)
    # df2.dropna(axis=1)


    df12 = pd.merge(df1, df2, on = 'datetime')
    
    df12 = df12.drop(columns=['sshf'])
    df12 = df12.drop(columns=['evavt'])
    
    df12['datetime'] = pd.to_datetime(df12['datetime'])
    # print("----------------------")
    # print(df12[df12['datetim-e'].dt.month >= 5])
    # df12 = df12[df12['datetime'].dt.month >= 5]
    # print(df12['datetime'].dt.month)
    df12 = df12[(df12['datetime'].dt.month >= 5) & (df12['datetime'].dt.month <= 11)]
    if df12.empty:
        print("No data available after filtering.")
        continue
      # drop datetime
    df12 = df12.drop(columns=['datetime'])
    
    # df12.drop(columns=['datetime'])
    # print(df12.head())
    # print("size:", len(df12))
    # print(df12.dtype)

    # print("-----------------------")
    # print(df12.shape)
    row = [year,state,county_name,month,crop]
    row.append(df12)
    # print(row[:4])

    # df_list.append(df12)
    dfLength = len(df_list)
    df_list.loc[dfLength] = row

# df_all = df_list[0]
# for df in df_list[1:]:
#     df_all = pd.concat([df_all, df], axis = 0)

print("Number of Features Per County Per Year:  >= ",len(df_list.iloc[1,4]))
# print(df_list["State"])
# df_list['Feature'] = df_list['Feature'].astype(object)

# df_list.to_csv('/content/drive/MyDrive/ai/era5/dataSat_cleaned_Iowa_2015-2020.csv', index=False)
# Out:
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# ...
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.
# No data available after filtering.

# %%
df_list.shape

# %%
df_list.iloc[1][-1]

# %%
# sys.getsizeof(df_list) / 1024 / 1024  # Byte -> MB
print(df_list.shape)
grouped_data = df_list.groupby(['Year', 'State', 'County']).size().reset_index(name='Count')
print(grouped_data)

# %%
# read crop yield (cy) data
year_range = [2015, 2020]
years = [x for x in range(year_range[0], year_range[-1]+1)]

def is_convertible_to_int(s):
    try:
        int(s)
        return True
    except ValueError:
        return False

# cy_file_list = glob('/content/drive/MyDrive/ai/crop_yield/*csv')
# print((cy_file_list))
bucket_name = 'pepper-dataset'
prefix = 'crop_data/crop_3/'

# List to store all object keys
cy_file_list = []

# Initial call to list_objects_v2
response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix)

# Process the initial response
while True:
    # Collect keys from current response
    current_keys = [obj['Key'] for obj in response.get('Contents', [])]
    cy_file_list.extend(current_keys)

    # Check if there are more objects to retrieve
    if not response['IsTruncated']:
        break  # No more objects to retrieve

    # Get ContinuationToken for next paginated call
    continuation_token = response['NextContinuationToken']

    # Make subsequent call with ContinuationToken
    response = s3.list_objects_v2(Bucket=bucket_name, Prefix=prefix, ContinuationToken=continuation_token)
    
cy_file_list = ["/" + path if not path.startswith("/") else path for path in cy_file_list]

print(cy_file_list)
cy_df_list = []
for cy_file in cy_file_list:
    suffix = cy_file.split('/')[-1]
    temp = suffix.split('_')
    state = temp[0].upper()
    print(state)
    if state == "IOWA":
        crop_type = temp[1]
        df = pd.read_csv('s3://'+bucket_name+cy_file)
        df = df[(df['Year'] >= 2015) & (df['Year'] <= 2020)]
        # Drop Rows that do not have "YIELD" in the "DATA ITEM" column
        dataYield = df.drop(df[~df["Data Item"].str.contains("YIELD")].index, inplace = False)
        # Drop Rows that have "IRRIGATED" in the "DATA ITEM" column
        dataYield = dataYield.drop(dataYield[dataYield["Data Item"].str.contains("IRRIGATED")].index, inplace = False)
        cy_df_list.append(dataYield)
        
        
# for cy_file in cy_file_list:
#     suffix = cy_file.split('/')[-1]
#     year = suffix.split('.')[0].split('_')[-1]
#     print(year)
#     if is_convertible_to_int(year) and int(year) not in years:
#       continue

#     crop_type = cy_file.split('_')[-2]
#     df = pd.read_csv('s3://'+bucket_name+cy_file)

#     # Drop Rows that do not have "YIELD" in the "DATA ITEM" column
#     dataYield = df.drop(df[~df["Data Item"].str.contains("YIELD")].index, inplace = False)
#     # Drop Rows that have "IRRIGATED" in the "DATA ITEM" column
#     dataYield = dataYield.drop(dataYield[dataYield["Data Item"].str.contains("IRRIGATED")].index, inplace = False)
#     cy_df_list.append(dataYield)

cy_df_all = cy_df_list[0]
for df in cy_df_list[1:]:
    cy_df_all = pd.concat([cy_df_all, df], axis = 0)
print(cy_df_all.shape)

print(cy_df_all.head())

# %%
dataROI = cy_df_all[["Year","State","County","Commodity","Value"]]
name_year = dataROI["Year"].drop_duplicates()
name_states = dataROI["State"].drop_duplicates()
name_county = dataROI["County"].drop_duplicates()
name_crops = dataROI["Commodity"].drop_duplicates()

dfOut = pd.DataFrame(columns=("Year","State","County","Commodity","Yield"))

# For each year
idx = 0
for year in name_year:
  temp_year = dataROI.loc[dataROI["Year"]==year]
  # if debug and verbose: print(temp_year)
  # For each state
  for state in name_states:
    temp_state = temp_year.loc[temp_year["State"]==state]
    # if debug and verbose: print(temp_state)
    # For each county
    for county in name_county:
      temp_county = temp_state.loc[temp_state["County"]==county]
      # if debug and verbose: print(temp_county)
      # For each crop
      for crop in name_crops:
        temp_crops = temp_county.loc[temp_county["Commodity"]==crop]
        # if debug and verbose: print(temp_crops)
        crop_yield = temp_crops["Value"]
        crop_yield = crop_yield.replace(',','', regex=True)
        crop_yield = pd.to_numeric(crop_yield)
        crop_yield = crop_yield.sum()
        # if debug and verbose: print(crop_yield)

        # Add to Output Data Frame
        dfOut.loc[idx] = [year,state,county,crop,crop_yield]

        # Increment idx
        idx = idx + 1

print(dfOut.head())
# wheat_rows = dfOut[dfOut['Commodity'] == 'WHEAT']
# print("wheat_rows: ", len(wheat_rows))
dfOut

# %%
def runCorrelateFeatureLabel(dataLabel,dataFeature,crop="WHEAT",dropZeroYield=True,debug=False,verbose=False):
  """Takes 2 pandas DataFrames (Label & Feature) and pairs them together"""

  # Drop Rows without the Desired Crop
  # print("pre dataCrop:", dataLabel.head())
  dataCrop = dataLabel.drop(dataLabel[~dataLabel["Commodity"].str.contains("CORN")].index, inplace = False)
  print("pre2 dataCrop:", dataCrop.head())
  dataCrop = dataCrop.drop(columns=["Commodity"]) #TODO: Assume we are only using 1 commodity
  dataFeat = dataFeature.drop(columns=["Commodity"])
  print("dataCrop:", dataCrop.head())
  print("dataFeat:", dataFeat.head())
  # print("++++++++++++++++++")

  # Merge DataFrames
  # Ref: https://realpython.com/pandas-merge-join-and-concat/
  # dataCrop.index = dataCrop.index.astype('object')
  print("------1: ", dataCrop.dtypes)
  print("------2: ", dataFeat.dtypes)
  dataFeat['Year'] = dataFeat['Year'].astype('int64')
  dataMerge = dataCrop.merge(dataFeat,how='right',on=['Year','State','County'])
  print(dataMerge.head())

  # Drop Rows without yield information
  if dropZeroYield:
    dataOut = dataMerge.drop(dataMerge[dataMerge["Yield"]==0.0].index,inplace=False)
  else:
    dataOut = dataMerge

  # Drop Rows with NaN
  dataOut.dropna(subset=['Yield'],inplace=True)

  if debug: print(dataOut)

  return dataOut

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# print("row shape:", df_list.iloc[1][4].info())
print(dfOut.shape)
print(dfOut.head())
print(df_list.shape)
print(df_list.head())
print(df_list.iloc[1][5].shape)
print("---------------------+")
# print(df_list.iloc[1])
dataSet = runCorrelateFeatureLabel(dfOut,df_list,crop="CORN",dropZeroYield=True,debug=False)

print("------------------")
print(dataSet.shape)
print(dataSet.head())

# %%
dataSet.iloc[1][-1]

# %%
def saveCorrelatedData(data,savePath,saveName,debug=False):
  """Save the correlated data to a mat for easier processing"""

  # Extract from DataFrame as list
  feature = data['Feature']
  print("feature len: ", len(feature))
  label = data['Yield']
  print("label len: ", len(label))
  # print(label)
  month = data['Month']
  if debug: print(len(feature))

  feat_lst = []
  label_lst = []
  feat_new = []
  firstTimeLoop = True
  for idx in range(len(feature)):
    # if debug: print(idx)
    print("idx:", idx)
    if int(month.iloc[idx]) == 5:
      feat_new = []
    for f in feature.iloc[idx]:
      # print(f)
      # feat_new.append(feature.iloc[idx][f])
      for item in feature.iloc[idx][f]:
        feat_new.append(item)
    # feat_new = np.array(feat_new)

    # Drop Bad Datasets
    # if len(feat_new) != 20: #4320: for whole year, 2520 for Jan-Jul, 3240 for Nov-Jul
    #   if debug: print("skipping feature of length",len(feat_new))
    #   continue

    if int(month.iloc[idx]) != 11:
      continue

    if len(feat_new) != 87312:  # 检查 feat_new 列表的长度是否为 240
        print("Skipping feature at index", idx, "due to incorrect length:", len(feat_new))
        continue

    print("feat_new len:", len(feat_new))
    # print("feat_arr:", len(feat_arr))
    # Append Features
    feat_lst.append(feat_new)
    label_lst.append(label.iloc[idx])

  print(len(label_lst))
  # feat_arr = np.array(feat_lst)
  feat_arr = feat_lst
  # print(feat_arr[0])

  data_feature_expanded = pd.DataFrame(feat_arr)

  # 将 DataFrame 写入 CSV 文件
  print("start writing dataFrame to csv: ", 's3://'+bucket_name+'/IOWA_data_feature_expanded_CORN.csv')
  data_feature_expanded.to_csv('s3://'+bucket_name+'/IOWA_data_feature_expanded_CORN.csv', index=False)

  print("Data successfully written to 'IOWA data_feature_expanded.csv'")

  # Get Ready to Save
  # feature = feat_arr.tolist()
  label = label_lst
  data_label_expanded = pd.DataFrame(label)
  data_label_expanded.to_csv('s3://'+bucket_name+'/IOWA_data_label_expanded_CORN.csv', index=False)
  print("Data successfully written to 'IOWA_data_label_expanded.csv'")

  # Save Path
  # saveFile = savePath + saveName
  # print("Saving to:",saveFile)
  # sio.savemat(saveFile, mdict={'feature': feat_arr, 'label': label})

  # df = pd.DataFrame(feat_arr)
  # df['label'] = label
  # filename = '/content/drive/MyDrive/ai/era5/yield_Iowa_corn_noIrr.csv'

  # 将 DataFrame 写入 CSV 文件
  # df.to_csv(filename, index=False, header=False)
  print("++++++++++++")
  # print("feat_arr shape: ", feat_arr.shape)
  # print(feat_arr.head())
  print(len(feat_arr))
  print(len(feat_arr[0]))
  print(label)


  return label, feat_arr


# print(dataSet.iloc[1][4].shape())

label, feat_arr = saveCorrelatedData(dataSet,"/content/drive/MyDrive/ai/era5/","yield_Iowa_corn_noIrr.mat",debug=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 91
#      86   return label, feat_arr
#      89 # print(dataSet.iloc[1][4].shape())
# ---> 91 label, feat_arr = saveCorrelatedData(dataSet,"/content/drive/MyDrive/ai/era5/","yield_Iowa_corn_noIrr.mat",debug=True)
#
# NameError: name 'dataSet' is not defined

# %%
feat_arr[0]

# %%
# Helper Functions
def get_time_now_ms():
    """Returns the current time in milliseconds"""
    ts = time.time()
    ts = round(ts) * 1000
    return int(ts)

# %%
# !pip install keras

# %%
import tensorflow as tf
from keras.layers import Input, Dense, LSTM, MaxPooling1D, Conv1D
from keras.models import Model
import keras
from keras.layers import Dense, TimeDistributed
from keras.models import Sequential
# from keras.utils import to_categorical
from keras.optimizers import SGD, Adam
from keras.callbacks import EarlyStopping
# from keras.utils import np_utils
import itertools

from keras.layers import LSTM, RepeatVector
# from keras.layers.convolutional import Conv1D,Conv2D
# from keras.layers.convolutional import MaxPooling1D,MaxPooling2D
from keras.layers import Dropout, Flatten
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler # for normalization
from sklearn.preprocessing import MinMaxScaler
from numpy import dstack,  hstack
import scipy.io as sio
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from sklearn.model_selection import train_test_split


# data_mat = "/content/drive/MyDrive/ai/era5/yield_Iowa_corn_noIrr.mat" #Name of File, may need to specify path
# data_dict = sio.loadmat(data_mat) #Load MAT as a python dictionary
# print(data_dict)
# Out:
# 2024-11-03 16:36:57.677534: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-03 16:36:57.703355: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-03 16:36:57.703397: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-03 16:36:57.718627: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-03 16:36:58.805534: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# data_feature = data_dict['feature'] #Extract Features
# data_feature = feat_arr
data_feature = pd.read_csv('s3://'+bucket_name+ '/IOWA_data_feature_expanded_CORN.csv')

# print('Data Feature Shape:',data_feature.shape) # Verify Shape
# print("feature len: ", len(data_feature[0][0]))
# data_label = data_dict['label'] #Extract Labels
# data_label = label
data_label = pd.read_csv('s3://'+bucket_name+ '/IOWA_data_label_expanded_CORN.csv')
# print('Data Label Shape:',data_label.shape) # Verify Shape

# print(data_label)
# c1 = ["dewpoint_temperature_2m", "temperature_2m", "soil_temperature_level_1","soil_temperature_level_2"
#       ,"soil_temperature_level_3","soil_temperature_level_4","snowfall","volumetric_soil_water_layer_1",
#       "volumetric_soil_water_layer_2","volumetric_soil_water_layer_3","volumetric_soil_water_layer_4",
#       "surface_net_solar_radiation","surface_net_solar_radiation1",
#       "total_evaporation","surface_pressure","total_precipitation"]

# c = ["dewpoint_temperature_2m", "temperature_2m", "soil_temperature_level_1","soil_temperature_level_2"
#                              ,"soil_temperature_level_3","soil_temperature_level_4","snowfall","volumetric_soil_water_layer_1",
#                               "volumetric_soil_water_layer_2","volumetric_soil_water_layer_3","volumetric_soil_water_layer_4",
#                               "surface_net_solar_radiation","surface_net_solar_radiation1",
#                               "total_evaporation","surface_pressure","total_precipitation"]*288



# 假设 data_feature 是一个 1*467 的 DataFrame，每个单元格是一个长度为 175200 的序列
# 构造一个示例 DataFrame（实际使用中应替换为你的 data_feature）
# data_feature = pd.DataFrame([[np.random.rand(175200) for _ in range(467)]])

# 将 DataFrame 转置
# data_feature_transposed = data_feature.T

# print("data_feature_transposed[0].tolist(): ", len(data_feature_transposed[0][0]))
# 展开每个单元格中的序列
# data_feature_expanded = pd.DataFrame(data_feature_transposed[0][0].tolist())

# 检查转换后的 DataFrame 形状
# print("Original shape:", data_feature.shape)
# print("Transformed shape:", data_feature_expanded.shape)


train_X = data_feature
train_y = data_label.T

train_X = np.nan_to_num(train_X)
train_y = np.nan_to_num(train_y)

print(train_X.shape)
print(train_y.shape)

x = np.asarray(train_X, dtype=np.float32)
y = np.asarray(train_y).flatten()

# Training/Validation split 67%, 33% split
data_feature, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
print(X_test.shape)
print(data_feature.shape)
# Out:
# /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages/fsspec/registry.py:279: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
# (2017, 87312)
# (1, 2017)
# (666, 87312)
# (1351, 87312)

# %%
print(data_feature.shape)
print(data_label.shape)
# Out:
# (1351, 87312)
# (2017, 1)

# %%
def dataReshape(dataIn,debug=True,runOnce=False):
  """Takes the 1D feature array and reshapes to 270x16"""
  print(dataIn.shape)

  dataOut = []
  for idx in range(len(dataIn)):
    dataTemp = dataIn[idx].reshape(5457, 16) #(216,15) 3240
    if debug: print(dataTemp.shape)
    dataOut.append(dataTemp)

    if runOnce: return -1

  return np.array(dataOut)

data_feature_rs = dataReshape(data_feature,debug=False,runOnce=False)
print(data_feature_rs.shape)

#Reshape test
X_test = dataReshape(X_test,debug=False,runOnce=False)
print(X_test.shape)
# Out:
# (1351, 87312)
# (1351, 5457, 16)
# (666, 87312)
# (666, 5457, 16)

# %%
# Network Parameters
BATCH_SIZE = 32
NUM_EPOCHS = 200
SHUFFLE_BUFFER_SIZE = 64

# Normalize Data
normalizer = Normalization(axis=-1)
normalizer.adapt(data_feature_rs)
data_feature_norm = normalizer(data_feature_rs)

# Normalize Test
normalizer = Normalization(axis=-1)
normalizer.adapt(X_test)
X_test_norm = normalizer(X_test)


# Split into train and test datasets
# Load the Data into a data loader
train_dataset = tf.data.Dataset.from_tensor_slices((data_feature_norm,y_train.T))
test_dataset = tf.data.Dataset.from_tensor_slices((X_test_norm,y_test.T)) #TODO: REPLACE WITH TEST DATASET
DATASET_SIZE = len(data_feature_norm)

# Shuffle & Batch the Datasets
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)
# Out:
# 2024-11-03 16:50:38.856932: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-11-03 16:50:39.081692: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 471834048 exceeds 10% of free system memory.
# 2024-11-03 16:50:44.474042: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 471834048 exceeds 10% of free system memory.
# 2024-11-03 16:50:44.934581: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 471834048 exceeds 10% of free system memory.
# 2024-11-03 16:50:45.212600: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 471834048 exceeds 10% of free system memory.
# 2024-11-03 16:50:45.642869: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 232599168 exceeds 10% of free system memory.

# %%
def step_decay(epoch):
   initial_lrate = 0.1
   drop = 0.5
   epochs_drop = 10.0
   lrate = initial_lrate * math.pow(drop,
           math.floor((1+epoch)/epochs_drop))
   return lrate

# %%
from tensorflow.keras.layers import Conv1D, BatchNormalization, Activation, Add

def residual_block(input_tensor, filters, kernel_size=2):
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    x = Conv1D(filters=filters, kernel_size=kernel_size, padding='same')(x)
    x = BatchNormalization()(x)
    
    # Add the input tensor back to the output
    x = Add()([x, input_tensor])
    x = Activation('relu')(x)
    return x

# %%
from tensorflow.keras.layers import Input, Dense, Flatten, MaxPooling1D, concatenate
from tensorflow.keras.models import Model

# Input layer
visible = Input(shape=(5457, 16))

# First ResNet Pathway
cnn1 = Conv1D(filters=80, kernel_size=2, padding='same', activation='relu')(visible)
cnn1 = residual_block(cnn1, 80)
cnn1 = MaxPooling1D(pool_size=128)(cnn1)

# Second ResNet Pathway
cnn2 = Conv1D(filters=64, kernel_size=2, padding='same', activation='relu')(visible)
cnn2 = residual_block(cnn2, 64)
cnn2 = MaxPooling1D(pool_size=128)(cnn2)

# Third ResNet Pathway
cnn3 = Conv1D(filters=32, kernel_size=2, padding='same', activation='relu')(visible)
cnn3 = residual_block(cnn3, 32)
cnn3 = MaxPooling1D(pool_size=128)(cnn3)

# Fourth ResNet Pathway
cnn4 = Conv1D(filters=16, kernel_size=2, padding='same', activation='relu')(visible)
cnn4 = residual_block(cnn4, 16)
cnn4 = MaxPooling1D(pool_size=128)(cnn4)

# Concatenate the outputs from all paths
merged = concatenate([cnn1, cnn2, cnn3, cnn4], axis=2)

# Fully connected layer after concatenation
cnn = Dense(16)(merged)

# Flatten the output
cnn = Flatten()(cnn)

# Output layer
output1 = Dense(1, activation='linear')(cnn)

# Define the model
model = Model(inputs=visible, outputs=output1)

model.compile(optimizer='adam', loss='mse', metrics =['accuracy','mean_squared_error','mean_absolute_percentage_error',tf.keras.metrics.RootMeanSquaredError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5457, 16)]           0         []
#
#  conv1d (Conv1D)             (None, 5457, 80)             2640      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 5457, 64)             2112      ['input_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 5457, 32)             1056      ['input_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 5457, 16)             528       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 5457, 80)             12880     ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 5457, 64)             8256      ['conv1d_3[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5457, 32)             2080      ['conv1d_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 5457, 16)             528       ['conv1d_9[0][0]']
#
#  batch_normalization (Batch  (None, 5457, 80)             320       ['conv1d_1[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 5457, 64)             256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 5457, 32)             128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 5457, 16)             64        ['conv1d_10[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 5457, 80)             0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 5457, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 5457, 32)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 5457, 16)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 5457, 80)             12880     ['activation[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5457, 64)             8256      ['activation_2[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 5457, 32)             2080      ['activation_4[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 5457, 16)             528       ['activation_6[0][0]']
#
#  batch_normalization_1 (Bat  (None, 5457, 80)             320       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 5457, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 5457, 32)             128       ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 5457, 16)             64        ['conv1d_11[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 5457, 80)             0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv1d[0][0]']
#
#  add_1 (Add)                 (None, 5457, 64)             0         ['batch_normalization_3[0][0]'
#                                                                     , 'conv1d_3[0][0]']
#
#  add_2 (Add)                 (None, 5457, 32)             0         ['batch_normalization_5[0][0]'
#                                                                     , 'conv1d_6[0][0]']
#
#  add_3 (Add)                 (None, 5457, 16)             0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv1d_9[0][0]']
#
#  activation_1 (Activation)   (None, 5457, 80)             0         ['add[0][0]']
#
#  activation_3 (Activation)   (None, 5457, 64)             0         ['add_1[0][0]']
#
#  activation_5 (Activation)   (None, 5457, 32)             0         ['add_2[0][0]']
#
#  activation_7 (Activation)   (None, 5457, 16)             0         ['add_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 42, 80)               0         ['activation_1[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 42, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 42, 32)               0         ['activation_5[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 42, 16)               0         ['activation_7[0][0]']
#  g1D)
#
#  concatenate (Concatenate)   (None, 42, 192)              0         ['max_pooling1d[0][0]',
#                                                                      'max_pooling1d_1[0][0]',
#                                                                      'max_pooling1d_2[0][0]',
#                                                                      'max_pooling1d_3[0][0]']
#
#  dense (Dense)               (None, 42, 16)               3088      ['concatenate[0][0]']
#
#  flatten (Flatten)           (None, 672)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    673       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 59121 (230.94 KB)
# Trainable params: 58353 (227.94 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________

# %%
# FIT model with TRAINING DATA
history = model.fit(train_dataset, validation_data=test_dataset,epochs=NUM_EPOCHS,verbose=2)
model.summary()

# EVALUATE model with TESTING DATA
model.evaluate(test_dataset, verbose=0)

ynew = model.predict(test_dataset)
print(f'Test Loss: {ynew[0]}')
print(f'Test Mean Squared Error: {ynew[1]}')
print(f'Test Mean Absolute Percentage Error: {ynew[2]}')
print(f'Test Root Mean Squared Error: {ynew[3]}')

fig, ax = plt.subplots()
ax.set_title('Training and Validation \n Mean Absolute Percentage Error') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['mean_absolute_percentage_error'], color = 'blue', label = 'train')

# plt.title('Validation Mean Absolute Percentage Error (MAPE)') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['val_mean_absolute_percentage_error'], color = 'orange', label = 'val')
ax.legend()
# Out:
# Epoch 1/200
# 43/43 - 95s - loss: 5056.6689 - accuracy: 0.0000e+00 - mean_squared_error: 5056.6689 - mean_absolute_percentage_error: 29.2253 - root_mean_squared_error: 71.1103 - val_loss: 9317.8623 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 9317.8623 - val_mean_absolute_percentage_error: 50.2479 - val_root_mean_squared_error: 96.5291 - 95s/epoch - 2s/step
# Epoch 2/200
# 43/43 - 67s - loss: 803.4577 - accuracy: 0.0000e+00 - mean_squared_error: 803.4577 - mean_absolute_percentage_error: 16.2774 - root_mean_squared_error: 28.3453 - val_loss: 6493.4761 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 6493.4761 - val_mean_absolute_percentage_error: 41.1709 - val_root_mean_squared_error: 80.5821 - 67s/epoch - 2s/step
# Epoch 3/200
# 43/43 - 68s - loss: 781.7095 - accuracy: 0.0000e+00 - mean_squared_error: 781.7095 - mean_absolute_percentage_error: 16.0334 - root_mean_squared_error: 27.9591 - val_loss: 4888.8984 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 4888.8984 - val_mean_absolute_percentage_error: 35.2331 - val_root_mean_squared_error: 69.9207 - 68s/epoch - 2s/step
# Epoch 4/200
# 43/43 - 65s - loss: 775.1426 - accuracy: 0.0000e+00 - mean_squared_error: 775.1426 - mean_absolute_percentage_error: 15.9928 - root_mean_squared_error: 27.8414 - val_loss: 3691.6040 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 3691.6040 - val_mean_absolute_percentage_error: 30.3036 - val_root_mean_squared_error: 60.7586 - 65s/epoch - 2s/step
# Epoch 5/200
# 43/43 - 66s - loss: 736.1543 - accuracy: 0.0000e+00 - mean_squared_error: 736.1543 - mean_absolute_percentage_error: 15.6094 - root_mean_squared_error: 27.1322 - val_loss: 2845.5703 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 2845.5703 - val_mean_absolute_percentage_error: 26.3609 - val_root_mean_squared_error: 53.3439 - 66s/epoch - 2s/step
# Epoch 6/200
# 43/43 - 65s - loss: 737.6167 - accuracy: 0.0000e+00 - mean_squared_error: 737.6167 - mean_absolute_percentage_error: 15.5556 - root_mean_squared_error: 27.1591 - val_loss: 1838.2252 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1838.2252 - val_mean_absolute_percentage_error: 21.0200 - val_root_mean_squared_error: 42.8745 - 65s/epoch - 2s/step
# Epoch 7/200
# 43/43 - 66s - loss: 718.5725 - accuracy: 0.0000e+00 - mean_squared_error: 718.5725 - mean_absolute_percentage_error: 15.4213 - root_mean_squared_error: 26.8062 - val_loss: 1599.1840 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1599.1840 - val_mean_absolute_percentage_error: 19.5610 - val_root_mean_squared_error: 39.9898 - 66s/epoch - 2s/step
# Epoch 8/200
# 43/43 - 67s - loss: 689.3999 - accuracy: 0.0000e+00 - mean_squared_error: 689.3999 - mean_absolute_percentage_error: 15.0781 - root_mean_squared_error: 26.2564 - val_loss: 1120.7549 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1120.7549 - val_mean_absolute_percentage_error: 16.3297 - val_root_mean_squared_error: 33.4777 - 67s/epoch - 2s/step
# Epoch 9/200
# 43/43 - 66s - loss: 670.9318 - accuracy: 0.0000e+00 - mean_squared_error: 670.9318 - mean_absolute_percentage_error: 14.8597 - root_mean_squared_error: 25.9024 - val_loss: 1069.1852 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 1069.1852 - val_mean_absolute_percentage_error: 15.9323 - val_root_mean_squared_error: 32.6984 - 66s/epoch - 2s/step
# Epoch 10/200
# 43/43 - 66s - loss: 643.8882 - accuracy: 0.0000e+00 - mean_squared_error: 643.8882 - mean_absolute_percentage_error: 14.5990 - root_mean_squared_error: 25.3750 - val_loss: 998.2687 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 998.2687 - val_mean_absolute_percentage_error: 15.3558 - val_root_mean_squared_error: 31.5954 - 66s/epoch - 2s/step
# Epoch 11/200
# 43/43 - 65s - loss: 620.8211 - accuracy: 0.0000e+00 - mean_squared_error: 620.8211 - mean_absolute_percentage_error: 14.2856 - root_mean_squared_error: 24.9163 - val_loss: 914.3859 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 914.3859 - val_mean_absolute_percentage_error: 14.6590 - val_root_mean_squared_error: 30.2388 - 65s/epoch - 2s/step
# Epoch 12/200
# 43/43 - 65s - loss: 597.7469 - accuracy: 0.0000e+00 - mean_squared_error: 597.7469 - mean_absolute_percentage_error: 13.9984 - root_mean_squared_error: 24.4489 - val_loss: 689.2061 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 689.2061 - val_mean_absolute_percentage_error: 12.7543 - val_root_mean_squared_error: 26.2527 - 65s/epoch - 2s/step
# Epoch 13/200
# 43/43 - 68s - loss: 584.1921 - accuracy: 0.0000e+00 - mean_squared_error: 584.1921 - mean_absolute_percentage_error: 13.8969 - root_mean_squared_error: 24.1701 - val_loss: 657.5530 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 657.5530 - val_mean_absolute_percentage_error: 12.4653 - val_root_mean_squared_error: 25.6428 - 68s/epoch - 2s/step
# Epoch 14/200
# 43/43 - 66s - loss: 575.9534 - accuracy: 0.0000e+00 - mean_squared_error: 575.9534 - mean_absolute_percentage_error: 13.7791 - root_mean_squared_error: 23.9990 - val_loss: 561.5101 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 561.5101 - val_mean_absolute_percentage_error: 11.5647 - val_root_mean_squared_error: 23.6962 - 66s/epoch - 2s/step
# Epoch 15/200
# 43/43 - 65s - loss: 558.7258 - accuracy: 0.0000e+00 - mean_squared_error: 558.7258 - mean_absolute_percentage_error: 13.6029 - root_mean_squared_error: 23.6374 - val_loss: 563.0166 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 563.0166 - val_mean_absolute_percentage_error: 11.5278 - val_root_mean_squared_error: 23.7280 - 65s/epoch - 2s/step
# Epoch 16/200
# 43/43 - 68s - loss: 526.0083 - accuracy: 0.0000e+00 - mean_squared_error: 526.0083 - mean_absolute_percentage_error: 13.2107 - root_mean_squared_error: 22.9349 - val_loss: 635.9189 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 635.9189 - val_mean_absolute_percentage_error: 12.1530 - val_root_mean_squared_error: 25.2174 - 68s/epoch - 2s/step
# Epoch 17/200
# 43/43 - 66s - loss: 510.3614 - accuracy: 0.0000e+00 - mean_squared_error: 510.3614 - mean_absolute_percentage_error: 13.0594 - root_mean_squared_error: 22.5912 - val_loss: 491.6546 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 491.6546 - val_mean_absolute_percentage_error: 10.8028 - val_root_mean_squared_error: 22.1733 - 66s/epoch - 2s/step
# Epoch 18/200
# 43/43 - 66s - loss: 478.9884 - accuracy: 0.0000e+00 - mean_squared_error: 478.9884 - mean_absolute_percentage_error: 12.6835 - root_mean_squared_error: 21.8858 - val_loss: 463.0491 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 463.0491 - val_mean_absolute_percentage_error: 10.4644 - val_root_mean_squared_error: 21.5186 - 66s/epoch - 2s/step
# Epoch 19/200
# 43/43 - 67s - loss: 480.4011 - accuracy: 0.0000e+00 - mean_squared_error: 480.4011 - mean_absolute_percentage_error: 12.7502 - root_mean_squared_error: 21.9181 - val_loss: 505.7265 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 505.7265 - val_mean_absolute_percentage_error: 10.8531 - val_root_mean_squared_error: 22.4884 - 67s/epoch - 2s/step
# Epoch 20/200
# 43/43 - 65s - loss: 545.4877 - accuracy: 0.0000e+00 - mean_squared_error: 545.4877 - mean_absolute_percentage_error: 13.5710 - root_mean_squared_error: 23.3557 - val_loss: 545.2751 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 545.2751 - val_mean_absolute_percentage_error: 11.4547 - val_root_mean_squared_error: 23.3511 - 65s/epoch - 2s/step
# Epoch 21/200
# 43/43 - 67s - loss: 509.1836 - accuracy: 0.0000e+00 - mean_squared_error: 509.1836 - mean_absolute_percentage_error: 13.0497 - root_mean_squared_error: 22.5651 - val_loss: 429.5512 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 429.5512 - val_mean_absolute_percentage_error: 10.0916 - val_root_mean_squared_error: 20.7256 - 67s/epoch - 2s/step
# Epoch 22/200
# 43/43 - 65s - loss: 474.3283 - accuracy: 0.0000e+00 - mean_squared_error: 474.3283 - mean_absolute_percentage_error: 12.6408 - root_mean_squared_error: 21.7791 - val_loss: 420.2492 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 420.2492 - val_mean_absolute_percentage_error: 9.9346 - val_root_mean_squared_error: 20.5000 - 65s/epoch - 2s/step
# Epoch 23/200
# 43/43 - 65s - loss: 466.2339 - accuracy: 0.0000e+00 - mean_squared_error: 466.2339 - mean_absolute_percentage_error: 12.5562 - root_mean_squared_error: 21.5925 - val_loss: 414.4913 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 414.4913 - val_mean_absolute_percentage_error: 9.8350 - val_root_mean_squared_error: 20.3591 - 65s/epoch - 2s/step
# Epoch 24/200
# 43/43 - 65s - loss: 434.4415 - accuracy: 0.0000e+00 - mean_squared_error: 434.4415 - mean_absolute_percentage_error: 12.1397 - root_mean_squared_error: 20.8433 - val_loss: 432.6453 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 432.6453 - val_mean_absolute_percentage_error: 10.0675 - val_root_mean_squared_error: 20.8001 - 65s/epoch - 2s/step
# Epoch 25/200
# 43/43 - 67s - loss: 432.6683 - accuracy: 0.0000e+00 - mean_squared_error: 432.6683 - mean_absolute_percentage_error: 12.1112 - root_mean_squared_error: 20.8007 - val_loss: 388.6148 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 388.6148 - val_mean_absolute_percentage_error: 9.5327 - val_root_mean_squared_error: 19.7133 - 67s/epoch - 2s/step
# Epoch 26/200
# 43/43 - 67s - loss: 436.6961 - accuracy: 0.0000e+00 - mean_squared_error: 436.6961 - mean_absolute_percentage_error: 12.2001 - root_mean_squared_error: 20.8973 - val_loss: 370.5592 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 370.5592 - val_mean_absolute_percentage_error: 9.3552 - val_root_mean_squared_error: 19.2499 - 67s/epoch - 2s/step
# Epoch 27/200
# 43/43 - 68s - loss: 411.5042 - accuracy: 0.0000e+00 - mean_squared_error: 411.5042 - mean_absolute_percentage_error: 11.8314 - root_mean_squared_error: 20.2856 - val_loss: 369.4011 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 369.4011 - val_mean_absolute_percentage_error: 9.3247 - val_root_mean_squared_error: 19.2198 - 68s/epoch - 2s/step
# Epoch 28/200
# 43/43 - 66s - loss: 391.4200 - accuracy: 0.0000e+00 - mean_squared_error: 391.4200 - mean_absolute_percentage_error: 11.6048 - root_mean_squared_error: 19.7843 - val_loss: 413.4880 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 413.4880 - val_mean_absolute_percentage_error: 9.7598 - val_root_mean_squared_error: 20.3344 - 66s/epoch - 2s/step
# Epoch 29/200
# 43/43 - 67s - loss: 385.4071 - accuracy: 0.0000e+00 - mean_squared_error: 385.4071 - mean_absolute_percentage_error: 11.4913 - root_mean_squared_error: 19.6318 - val_loss: 550.9794 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 550.9794 - val_mean_absolute_percentage_error: 11.1740 - val_root_mean_squared_error: 23.4730 - 67s/epoch - 2s/step
# Epoch 30/200
# 43/43 - 67s - loss: 431.1954 - accuracy: 0.0000e+00 - mean_squared_error: 431.1954 - mean_absolute_percentage_error: 12.0496 - root_mean_squared_error: 20.7652 - val_loss: 327.0058 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 327.0058 - val_mean_absolute_percentage_error: 8.7097 - val_root_mean_squared_error: 18.0833 - 67s/epoch - 2s/step
# Epoch 31/200
# 43/43 - 65s - loss: 390.7029 - accuracy: 0.0000e+00 - mean_squared_error: 390.7029 - mean_absolute_percentage_error: 11.5848 - root_mean_squared_error: 19.7662 - val_loss: 321.8949 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 321.8949 - val_mean_absolute_percentage_error: 8.6150 - val_root_mean_squared_error: 17.9414 - 65s/epoch - 2s/step
# Epoch 32/200
# 43/43 - 67s - loss: 358.6727 - accuracy: 0.0000e+00 - mean_squared_error: 358.6727 - mean_absolute_percentage_error: 11.0953 - root_mean_squared_error: 18.9387 - val_loss: 322.1262 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 322.1262 - val_mean_absolute_percentage_error: 8.6726 - val_root_mean_squared_error: 17.9479 - 67s/epoch - 2s/step
# Epoch 33/200
# 43/43 - 65s - loss: 355.4201 - accuracy: 0.0000e+00 - mean_squared_error: 355.4201 - mean_absolute_percentage_error: 11.0604 - root_mean_squared_error: 18.8526 - val_loss: 299.6588 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 299.6588 - val_mean_absolute_percentage_error: 8.2626 - val_root_mean_squared_error: 17.3107 - 65s/epoch - 2s/step
# Epoch 34/200
# 43/43 - 65s - loss: 354.8114 - accuracy: 0.0000e+00 - mean_squared_error: 354.8114 - mean_absolute_percentage_error: 10.9925 - root_mean_squared_error: 18.8364 - val_loss: 297.7205 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 297.7205 - val_mean_absolute_percentage_error: 8.2779 - val_root_mean_squared_error: 17.2546 - 65s/epoch - 2s/step
# Epoch 35/200
# 43/43 - 66s - loss: 337.0686 - accuracy: 0.0000e+00 - mean_squared_error: 337.0686 - mean_absolute_percentage_error: 10.7620 - root_mean_squared_error: 18.3594 - val_loss: 311.5523 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 311.5523 - val_mean_absolute_percentage_error: 8.4382 - val_root_mean_squared_error: 17.6508 - 66s/epoch - 2s/step
# Epoch 36/200
# 43/43 - 66s - loss: 341.3907 - accuracy: 0.0000e+00 - mean_squared_error: 341.3907 - mean_absolute_percentage_error: 10.8164 - root_mean_squared_error: 18.4768 - val_loss: 284.8119 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 284.8119 - val_mean_absolute_percentage_error: 8.1612 - val_root_mean_squared_error: 16.8764 - 66s/epoch - 2s/step
# Epoch 37/200
# 43/43 - 66s - loss: 352.8129 - accuracy: 0.0000e+00 - mean_squared_error: 352.8129 - mean_absolute_percentage_error: 10.9874 - root_mean_squared_error: 18.7833 - val_loss: 278.2983 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 278.2983 - val_mean_absolute_percentage_error: 7.9843 - val_root_mean_squared_error: 16.6823 - 66s/epoch - 2s/step
# Epoch 38/200
# 43/43 - 69s - loss: 327.4652 - accuracy: 0.0000e+00 - mean_squared_error: 327.4652 - mean_absolute_percentage_error: 10.5970 - root_mean_squared_error: 18.0960 - val_loss: 269.7573 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 269.7573 - val_mean_absolute_percentage_error: 7.9954 - val_root_mean_squared_error: 16.4243 - 69s/epoch - 2s/step
# Epoch 39/200
# 43/43 - 66s - loss: 326.6140 - accuracy: 0.0000e+00 - mean_squared_error: 326.6140 - mean_absolute_percentage_error: 10.5915 - root_mean_squared_error: 18.0725 - val_loss: 280.5127 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 280.5127 - val_mean_absolute_percentage_error: 7.9493 - val_root_mean_squared_error: 16.7485 - 66s/epoch - 2s/step
# Epoch 40/200
# 43/43 - 67s - loss: 325.1595 - accuracy: 0.0000e+00 - mean_squared_error: 325.1595 - mean_absolute_percentage_error: 10.5234 - root_mean_squared_error: 18.0322 - val_loss: 265.1281 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 265.1281 - val_mean_absolute_percentage_error: 7.8757 - val_root_mean_squared_error: 16.2828 - 67s/epoch - 2s/step
# Epoch 41/200
# 43/43 - 66s - loss: 317.0787 - accuracy: 0.0000e+00 - mean_squared_error: 317.0787 - mean_absolute_percentage_error: 10.4519 - root_mean_squared_error: 17.8067 - val_loss: 257.2546 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 257.2546 - val_mean_absolute_percentage_error: 7.5806 - val_root_mean_squared_error: 16.0392 - 66s/epoch - 2s/step
# Epoch 42/200
# 43/43 - 65s - loss: 294.1614 - accuracy: 0.0000e+00 - mean_squared_error: 294.1614 - mean_absolute_percentage_error: 10.0792 - root_mean_squared_error: 17.1511 - val_loss: 298.9157 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 298.9157 - val_mean_absolute_percentage_error: 8.1112 - val_root_mean_squared_error: 17.2892 - 65s/epoch - 2s/step
# Epoch 43/200
# 43/43 - 66s - loss: 308.3171 - accuracy: 0.0000e+00 - mean_squared_error: 308.3171 - mean_absolute_percentage_error: 10.1641 - root_mean_squared_error: 17.5590 - val_loss: 259.8372 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 259.8372 - val_mean_absolute_percentage_error: 7.9080 - val_root_mean_squared_error: 16.1195 - 66s/epoch - 2s/step
# Epoch 44/200
# 43/43 - 65s - loss: 299.2771 - accuracy: 0.0000e+00 - mean_squared_error: 299.2771 - mean_absolute_percentage_error: 10.1261 - root_mean_squared_error: 17.2996 - val_loss: 246.0430 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 246.0430 - val_mean_absolute_percentage_error: 7.4554 - val_root_mean_squared_error: 15.6858 - 65s/epoch - 2s/step
# Epoch 45/200
# 43/43 - 65s - loss: 292.8351 - accuracy: 0.0000e+00 - mean_squared_error: 292.8351 - mean_absolute_percentage_error: 10.0185 - root_mean_squared_error: 17.1124 - val_loss: 250.5396 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 250.5396 - val_mean_absolute_percentage_error: 7.7528 - val_root_mean_squared_error: 15.8284 - 65s/epoch - 2s/step
# Epoch 46/200
# 43/43 - 67s - loss: 293.1115 - accuracy: 0.0000e+00 - mean_squared_error: 293.1115 - mean_absolute_percentage_error: 9.9597 - root_mean_squared_error: 17.1205 - val_loss: 231.3736 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 231.3736 - val_mean_absolute_percentage_error: 7.3170 - val_root_mean_squared_error: 15.2110 - 67s/epoch - 2s/step
# Epoch 47/200
# 43/43 - 67s - loss: 293.4851 - accuracy: 0.0000e+00 - mean_squared_error: 293.4851 - mean_absolute_percentage_error: 9.9886 - root_mean_squared_error: 17.1314 - val_loss: 237.5106 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 237.5106 - val_mean_absolute_percentage_error: 7.3543 - val_root_mean_squared_error: 15.4114 - 67s/epoch - 2s/step
# Epoch 48/200
# 43/43 - 66s - loss: 286.6877 - accuracy: 0.0000e+00 - mean_squared_error: 286.6877 - mean_absolute_percentage_error: 9.9326 - root_mean_squared_error: 16.9319 - val_loss: 234.9093 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 234.9093 - val_mean_absolute_percentage_error: 7.4541 - val_root_mean_squared_error: 15.3268 - 66s/epoch - 2s/step
# Epoch 49/200
# 43/43 - 66s - loss: 261.2406 - accuracy: 0.0000e+00 - mean_squared_error: 261.2406 - mean_absolute_percentage_error: 9.4522 - root_mean_squared_error: 16.1629 - val_loss: 258.3094 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 258.3094 - val_mean_absolute_percentage_error: 7.5183 - val_root_mean_squared_error: 16.0720 - 66s/epoch - 2s/step
# Epoch 50/200
# 43/43 - 63s - loss: 263.1796 - accuracy: 0.0000e+00 - mean_squared_error: 263.1796 - mean_absolute_percentage_error: 9.4534 - root_mean_squared_error: 16.2228 - val_loss: 225.5148 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 225.5148 - val_mean_absolute_percentage_error: 7.2342 - val_root_mean_squared_error: 15.0171 - 63s/epoch - 1s/step
# Epoch 51/200
# 43/43 - 67s - loss: 294.3325 - accuracy: 0.0000e+00 - mean_squared_error: 294.3325 - mean_absolute_percentage_error: 10.0194 - root_mean_squared_error: 17.1561 - val_loss: 352.7691 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 352.7691 - val_mean_absolute_percentage_error: 9.5323 - val_root_mean_squared_error: 18.7821 - 67s/epoch - 2s/step
# Epoch 52/200
# 43/43 - 66s - loss: 275.1414 - accuracy: 0.0000e+00 - mean_squared_error: 275.1414 - mean_absolute_percentage_error: 9.6687 - root_mean_squared_error: 16.5874 - val_loss: 222.3179 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 222.3179 - val_mean_absolute_percentage_error: 7.0975 - val_root_mean_squared_error: 14.9103 - 66s/epoch - 2s/step
# Epoch 53/200
# 43/43 - 64s - loss: 256.1924 - accuracy: 0.0000e+00 - mean_squared_error: 256.1924 - mean_absolute_percentage_error: 9.3096 - root_mean_squared_error: 16.0060 - val_loss: 226.7065 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 226.7065 - val_mean_absolute_percentage_error: 7.3294 - val_root_mean_squared_error: 15.0568 - 64s/epoch - 1s/step
# Epoch 54/200
# 43/43 - 66s - loss: 271.9127 - accuracy: 0.0000e+00 - mean_squared_error: 271.9127 - mean_absolute_percentage_error: 9.6286 - root_mean_squared_error: 16.4898 - val_loss: 233.7894 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 233.7894 - val_mean_absolute_percentage_error: 7.1671 - val_root_mean_squared_error: 15.2902 - 66s/epoch - 2s/step
# Epoch 55/200
# 43/43 - 66s - loss: 289.4343 - accuracy: 0.0000e+00 - mean_squared_error: 289.4343 - mean_absolute_percentage_error: 9.9380 - root_mean_squared_error: 17.0128 - val_loss: 252.2242 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 252.2242 - val_mean_absolute_percentage_error: 7.8893 - val_root_mean_squared_error: 15.8816 - 66s/epoch - 2s/step
# Epoch 56/200
# 43/43 - 66s - loss: 256.0941 - accuracy: 0.0000e+00 - mean_squared_error: 256.0941 - mean_absolute_percentage_error: 9.3234 - root_mean_squared_error: 16.0029 - val_loss: 216.5287 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 216.5287 - val_mean_absolute_percentage_error: 7.0565 - val_root_mean_squared_error: 14.7149 - 66s/epoch - 2s/step
# Epoch 57/200
# 43/43 - 68s - loss: 239.8579 - accuracy: 0.0000e+00 - mean_squared_error: 239.8579 - mean_absolute_percentage_error: 8.9958 - root_mean_squared_error: 15.4873 - val_loss: 247.6507 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 247.6507 - val_mean_absolute_percentage_error: 7.3492 - val_root_mean_squared_error: 15.7369 - 68s/epoch - 2s/step
# Epoch 58/200
# 43/43 - 66s - loss: 235.6491 - accuracy: 0.0000e+00 - mean_squared_error: 235.6491 - mean_absolute_percentage_error: 8.9142 - root_mean_squared_error: 15.3509 - val_loss: 220.8226 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 220.8226 - val_mean_absolute_percentage_error: 7.0432 - val_root_mean_squared_error: 14.8601 - 66s/epoch - 2s/step
# Epoch 59/200
# 43/43 - 66s - loss: 234.5730 - accuracy: 0.0000e+00 - mean_squared_error: 234.5730 - mean_absolute_percentage_error: 8.8836 - root_mean_squared_error: 15.3158 - val_loss: 221.5057 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 221.5057 - val_mean_absolute_percentage_error: 7.0518 - val_root_mean_squared_error: 14.8831 - 66s/epoch - 2s/step
# Epoch 60/200
# 43/43 - 66s - loss: 234.9014 - accuracy: 0.0000e+00 - mean_squared_error: 234.9014 - mean_absolute_percentage_error: 8.8984 - root_mean_squared_error: 15.3265 - val_loss: 206.0432 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 206.0432 - val_mean_absolute_percentage_error: 6.9824 - val_root_mean_squared_error: 14.3542 - 66s/epoch - 2s/step
# Epoch 61/200
# 43/43 - 65s - loss: 251.7846 - accuracy: 0.0000e+00 - mean_squared_error: 251.7846 - mean_absolute_percentage_error: 9.2191 - root_mean_squared_error: 15.8677 - val_loss: 198.8800 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 198.8800 - val_mean_absolute_percentage_error: 6.7481 - val_root_mean_squared_error: 14.1025 - 65s/epoch - 2s/step
# Epoch 62/200
# 43/43 - 66s - loss: 234.5199 - accuracy: 0.0000e+00 - mean_squared_error: 234.5199 - mean_absolute_percentage_error: 8.9057 - root_mean_squared_error: 15.3140 - val_loss: 197.3440 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 197.3440 - val_mean_absolute_percentage_error: 6.7721 - val_root_mean_squared_error: 14.0479 - 66s/epoch - 2s/step
# Epoch 63/200
# 43/43 - 65s - loss: 221.1234 - accuracy: 0.0000e+00 - mean_squared_error: 221.1234 - mean_absolute_percentage_error: 8.6233 - root_mean_squared_error: 14.8702 - val_loss: 228.9580 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 228.9580 - val_mean_absolute_percentage_error: 7.5156 - val_root_mean_squared_error: 15.1314 - 65s/epoch - 2s/step
# Epoch 64/200
# 43/43 - 65s - loss: 234.7366 - accuracy: 0.0000e+00 - mean_squared_error: 234.7366 - mean_absolute_percentage_error: 8.8416 - root_mean_squared_error: 15.3211 - val_loss: 193.6518 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 193.6518 - val_mean_absolute_percentage_error: 6.7430 - val_root_mean_squared_error: 13.9159 - 65s/epoch - 2s/step
# Epoch 65/200
# 43/43 - 67s - loss: 224.0276 - accuracy: 0.0000e+00 - mean_squared_error: 224.0276 - mean_absolute_percentage_error: 8.6800 - root_mean_squared_error: 14.9676 - val_loss: 207.4458 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 207.4458 - val_mean_absolute_percentage_error: 7.0265 - val_root_mean_squared_error: 14.4030 - 67s/epoch - 2s/step
# Epoch 66/200
# 43/43 - 65s - loss: 239.9025 - accuracy: 0.0000e+00 - mean_squared_error: 239.9025 - mean_absolute_percentage_error: 8.9345 - root_mean_squared_error: 15.4888 - val_loss: 196.2322 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 196.2322 - val_mean_absolute_percentage_error: 6.7803 - val_root_mean_squared_error: 14.0083 - 65s/epoch - 2s/step
# Epoch 67/200
# 43/43 - 65s - loss: 225.5776 - accuracy: 0.0000e+00 - mean_squared_error: 225.5776 - mean_absolute_percentage_error: 8.7292 - root_mean_squared_error: 15.0192 - val_loss: 215.9339 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 215.9339 - val_mean_absolute_percentage_error: 7.1791 - val_root_mean_squared_error: 14.6947 - 65s/epoch - 2s/step
# Epoch 68/200
# 43/43 - 67s - loss: 218.5590 - accuracy: 0.0000e+00 - mean_squared_error: 218.5590 - mean_absolute_percentage_error: 8.5320 - root_mean_squared_error: 14.7837 - val_loss: 197.1900 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 197.1900 - val_mean_absolute_percentage_error: 6.8546 - val_root_mean_squared_error: 14.0424 - 67s/epoch - 2s/step
# Epoch 69/200
# 43/43 - 65s - loss: 222.6584 - accuracy: 0.0000e+00 - mean_squared_error: 222.6584 - mean_absolute_percentage_error: 8.6494 - root_mean_squared_error: 14.9217 - val_loss: 199.3698 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 199.3698 - val_mean_absolute_percentage_error: 6.8836 - val_root_mean_squared_error: 14.1198 - 65s/epoch - 2s/step
# Epoch 70/200
# 43/43 - 65s - loss: 236.8779 - accuracy: 0.0000e+00 - mean_squared_error: 236.8779 - mean_absolute_percentage_error: 8.9326 - root_mean_squared_error: 15.3908 - val_loss: 187.3829 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 187.3829 - val_mean_absolute_percentage_error: 6.5474 - val_root_mean_squared_error: 13.6888 - 65s/epoch - 2s/step
# Epoch 71/200
# 43/43 - 65s - loss: 209.6209 - accuracy: 0.0000e+00 - mean_squared_error: 209.6209 - mean_absolute_percentage_error: 8.3937 - root_mean_squared_error: 14.4783 - val_loss: 191.9457 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 191.9457 - val_mean_absolute_percentage_error: 6.7254 - val_root_mean_squared_error: 13.8544 - 65s/epoch - 2s/step
# Epoch 72/200
# 43/43 - 67s - loss: 211.4050 - accuracy: 0.0000e+00 - mean_squared_error: 211.4050 - mean_absolute_percentage_error: 8.3878 - root_mean_squared_error: 14.5398 - val_loss: 189.6606 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 189.6606 - val_mean_absolute_percentage_error: 6.6212 - val_root_mean_squared_error: 13.7717 - 67s/epoch - 2s/step
# Epoch 73/200
# 43/43 - 67s - loss: 214.1699 - accuracy: 0.0000e+00 - mean_squared_error: 214.1699 - mean_absolute_percentage_error: 8.4175 - root_mean_squared_error: 14.6345 - val_loss: 199.0429 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 199.0429 - val_mean_absolute_percentage_error: 6.6932 - val_root_mean_squared_error: 14.1083 - 67s/epoch - 2s/step
# Epoch 74/200
# 43/43 - 67s - loss: 235.5322 - accuracy: 0.0000e+00 - mean_squared_error: 235.5322 - mean_absolute_percentage_error: 8.9044 - root_mean_squared_error: 15.3471 - val_loss: 203.6490 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 203.6490 - val_mean_absolute_percentage_error: 6.9460 - val_root_mean_squared_error: 14.2706 - 67s/epoch - 2s/step
# Epoch 75/200
# 43/43 - 66s - loss: 208.0951 - accuracy: 0.0000e+00 - mean_squared_error: 208.0951 - mean_absolute_percentage_error: 8.3132 - root_mean_squared_error: 14.4255 - val_loss: 188.9513 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 188.9513 - val_mean_absolute_percentage_error: 6.6393 - val_root_mean_squared_error: 13.7460 - 66s/epoch - 2s/step
# Epoch 76/200
# 43/43 - 69s - loss: 214.4126 - accuracy: 0.0000e+00 - mean_squared_error: 214.4126 - mean_absolute_percentage_error: 8.4462 - root_mean_squared_error: 14.6428 - val_loss: 194.7911 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 194.7911 - val_mean_absolute_percentage_error: 6.7820 - val_root_mean_squared_error: 13.9568 - 69s/epoch - 2s/step
# Epoch 77/200
# 43/43 - 66s - loss: 209.6970 - accuracy: 0.0000e+00 - mean_squared_error: 209.6970 - mean_absolute_percentage_error: 8.4179 - root_mean_squared_error: 14.4809 - val_loss: 207.8648 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 207.8648 - val_mean_absolute_percentage_error: 6.8221 - val_root_mean_squared_error: 14.4175 - 66s/epoch - 2s/step
# Epoch 78/200
# 43/43 - 66s - loss: 193.0008 - accuracy: 0.0000e+00 - mean_squared_error: 193.0008 - mean_absolute_percentage_error: 8.0494 - root_mean_squared_error: 13.8925 - val_loss: 182.0841 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 182.0841 - val_mean_absolute_percentage_error: 6.4562 - val_root_mean_squared_error: 13.4939 - 66s/epoch - 2s/step
# Epoch 79/200
# 43/43 - 66s - loss: 188.0950 - accuracy: 0.0000e+00 - mean_squared_error: 188.0950 - mean_absolute_percentage_error: 7.9519 - root_mean_squared_error: 13.7148 - val_loss: 183.7598 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 183.7598 - val_mean_absolute_percentage_error: 6.5769 - val_root_mean_squared_error: 13.5558 - 66s/epoch - 2s/step
# Epoch 80/200
# 43/43 - 66s - loss: 192.4053 - accuracy: 0.0000e+00 - mean_squared_error: 192.4053 - mean_absolute_percentage_error: 7.9320 - root_mean_squared_error: 13.8710 - val_loss: 188.5921 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 188.5921 - val_mean_absolute_percentage_error: 6.5401 - val_root_mean_squared_error: 13.7329 - 66s/epoch - 2s/step
# Epoch 81/200
# 43/43 - 67s - loss: 188.4986 - accuracy: 0.0000e+00 - mean_squared_error: 188.4986 - mean_absolute_percentage_error: 7.9134 - root_mean_squared_error: 13.7295 - val_loss: 189.7461 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 189.7461 - val_mean_absolute_percentage_error: 6.6271 - val_root_mean_squared_error: 13.7748 - 67s/epoch - 2s/step
# Epoch 82/200
# 43/43 - 66s - loss: 185.1984 - accuracy: 0.0000e+00 - mean_squared_error: 185.1984 - mean_absolute_percentage_error: 7.7689 - root_mean_squared_error: 13.6088 - val_loss: 187.4483 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 187.4483 - val_mean_absolute_percentage_error: 6.5249 - val_root_mean_squared_error: 13.6912 - 66s/epoch - 2s/step
# Epoch 83/200
# 43/43 - 66s - loss: 181.7611 - accuracy: 0.0000e+00 - mean_squared_error: 181.7611 - mean_absolute_percentage_error: 7.7408 - root_mean_squared_error: 13.4819 - val_loss: 184.4658 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 184.4658 - val_mean_absolute_percentage_error: 6.5518 - val_root_mean_squared_error: 13.5818 - 66s/epoch - 2s/step
# Epoch 84/200
# 43/43 - 68s - loss: 199.1972 - accuracy: 0.0000e+00 - mean_squared_error: 199.1972 - mean_absolute_percentage_error: 8.0321 - root_mean_squared_error: 14.1137 - val_loss: 218.3678 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 218.3678 - val_mean_absolute_percentage_error: 7.2189 - val_root_mean_squared_error: 14.7773 - 68s/epoch - 2s/step
# Epoch 85/200
# 43/43 - 66s - loss: 200.6882 - accuracy: 0.0000e+00 - mean_squared_error: 200.6882 - mean_absolute_percentage_error: 8.1245 - root_mean_squared_error: 14.1664 - val_loss: 187.8766 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 187.8766 - val_mean_absolute_percentage_error: 6.5594 - val_root_mean_squared_error: 13.7068 - 66s/epoch - 2s/step
# Epoch 86/200
# 43/43 - 68s - loss: 190.8320 - accuracy: 0.0000e+00 - mean_squared_error: 190.8320 - mean_absolute_percentage_error: 7.9506 - root_mean_squared_error: 13.8142 - val_loss: 228.8825 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 228.8825 - val_mean_absolute_percentage_error: 7.4156 - val_root_mean_squared_error: 15.1289 - 68s/epoch - 2s/step
# Epoch 87/200
# 43/43 - 66s - loss: 183.2495 - accuracy: 0.0000e+00 - mean_squared_error: 183.2495 - mean_absolute_percentage_error: 7.8007 - root_mean_squared_error: 13.5370 - val_loss: 185.8244 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 185.8244 - val_mean_absolute_percentage_error: 6.6211 - val_root_mean_squared_error: 13.6317 - 66s/epoch - 2s/step
# Epoch 88/200
# 43/43 - 66s - loss: 175.0818 - accuracy: 0.0000e+00 - mean_squared_error: 175.0818 - mean_absolute_percentage_error: 7.5964 - root_mean_squared_error: 13.2318 - val_loss: 185.4343 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 185.4343 - val_mean_absolute_percentage_error: 6.6047 - val_root_mean_squared_error: 13.6174 - 66s/epoch - 2s/step
# Epoch 89/200
# 43/43 - 67s - loss: 183.2082 - accuracy: 0.0000e+00 - mean_squared_error: 183.2082 - mean_absolute_percentage_error: 7.8290 - root_mean_squared_error: 13.5354 - val_loss: 183.3027 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 183.3027 - val_mean_absolute_percentage_error: 6.5249 - val_root_mean_squared_error: 13.5389 - 67s/epoch - 2s/step
# Epoch 90/200
# 43/43 - 66s - loss: 177.5949 - accuracy: 0.0000e+00 - mean_squared_error: 177.5949 - mean_absolute_percentage_error: 7.7199 - root_mean_squared_error: 13.3265 - val_loss: 184.5280 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 184.5280 - val_mean_absolute_percentage_error: 6.5905 - val_root_mean_squared_error: 13.5841 - 66s/epoch - 2s/step
# Epoch 91/200
# 43/43 - 66s - loss: 178.9261 - accuracy: 0.0000e+00 - mean_squared_error: 178.9261 - mean_absolute_percentage_error: 7.7098 - root_mean_squared_error: 13.3763 - val_loss: 184.1584 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 184.1584 - val_mean_absolute_percentage_error: 6.6027 - val_root_mean_squared_error: 13.5705 - 66s/epoch - 2s/step
# Epoch 92/200
# 43/43 - 66s - loss: 178.2538 - accuracy: 0.0000e+00 - mean_squared_error: 178.2538 - mean_absolute_percentage_error: 7.7013 - root_mean_squared_error: 13.3512 - val_loss: 199.6382 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 199.6382 - val_mean_absolute_percentage_error: 6.9086 - val_root_mean_squared_error: 14.1293 - 66s/epoch - 2s/step
# Epoch 93/200
# 43/43 - 65s - loss: 184.2578 - accuracy: 0.0000e+00 - mean_squared_error: 184.2578 - mean_absolute_percentage_error: 7.7780 - root_mean_squared_error: 13.5742 - val_loss: 204.0930 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 204.0930 - val_mean_absolute_percentage_error: 7.0117 - val_root_mean_squared_error: 14.2861 - 65s/epoch - 2s/step
# Epoch 94/200
# 43/43 - 68s - loss: 169.3225 - accuracy: 0.0000e+00 - mean_squared_error: 169.3225 - mean_absolute_percentage_error: 7.4752 - root_mean_squared_error: 13.0124 - val_loss: 178.5074 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 178.5074 - val_mean_absolute_percentage_error: 6.4337 - val_root_mean_squared_error: 13.3607 - 68s/epoch - 2s/step
# Epoch 95/200
# 43/43 - 66s - loss: 176.9642 - accuracy: 0.0000e+00 - mean_squared_error: 176.9642 - mean_absolute_percentage_error: 7.6069 - root_mean_squared_error: 13.3028 - val_loss: 177.4952 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 177.4952 - val_mean_absolute_percentage_error: 6.4581 - val_root_mean_squared_error: 13.3227 - 66s/epoch - 2s/step
# Epoch 96/200
# 43/43 - 66s - loss: 177.5241 - accuracy: 0.0000e+00 - mean_squared_error: 177.5241 - mean_absolute_percentage_error: 7.6296 - root_mean_squared_error: 13.3238 - val_loss: 182.5142 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 182.5142 - val_mean_absolute_percentage_error: 6.5653 - val_root_mean_squared_error: 13.5098 - 66s/epoch - 2s/step
# Epoch 97/200
# 43/43 - 66s - loss: 172.7476 - accuracy: 0.0000e+00 - mean_squared_error: 172.7476 - mean_absolute_percentage_error: 7.5482 - root_mean_squared_error: 13.1433 - val_loss: 203.4064 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 203.4064 - val_mean_absolute_percentage_error: 6.6601 - val_root_mean_squared_error: 14.2621 - 66s/epoch - 2s/step
# Epoch 98/200
# 43/43 - 66s - loss: 194.4598 - accuracy: 0.0000e+00 - mean_squared_error: 194.4598 - mean_absolute_percentage_error: 8.0088 - root_mean_squared_error: 13.9449 - val_loss: 176.3640 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 176.3640 - val_mean_absolute_percentage_error: 6.3602 - val_root_mean_squared_error: 13.2802 - 66s/epoch - 2s/step
# Epoch 99/200
# 43/43 - 67s - loss: 168.4585 - accuracy: 0.0000e+00 - mean_squared_error: 168.4585 - mean_absolute_percentage_error: 7.4510 - root_mean_squared_error: 12.9792 - val_loss: 194.7516 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 194.7516 - val_mean_absolute_percentage_error: 6.8173 - val_root_mean_squared_error: 13.9553 - 67s/epoch - 2s/step
# Epoch 100/200
# 43/43 - 67s - loss: 167.3748 - accuracy: 0.0000e+00 - mean_squared_error: 167.3748 - mean_absolute_percentage_error: 7.3838 - root_mean_squared_error: 12.9373 - val_loss: 198.2603 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 198.2603 - val_mean_absolute_percentage_error: 6.6257 - val_root_mean_squared_error: 14.0805 - 67s/epoch - 2s/step
# Epoch 101/200
# 43/43 - 66s - loss: 169.3702 - accuracy: 0.0000e+00 - mean_squared_error: 169.3702 - mean_absolute_percentage_error: 7.4988 - root_mean_squared_error: 13.0142 - val_loss: 189.6676 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 189.6676 - val_mean_absolute_percentage_error: 6.5484 - val_root_mean_squared_error: 13.7720 - 66s/epoch - 2s/step
# Epoch 102/200
# 43/43 - 65s - loss: 180.4504 - accuracy: 0.0000e+00 - mean_squared_error: 180.4504 - mean_absolute_percentage_error: 7.7086 - root_mean_squared_error: 13.4332 - val_loss: 199.9289 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 199.9289 - val_mean_absolute_percentage_error: 6.9155 - val_root_mean_squared_error: 14.1396 - 65s/epoch - 2s/step
# Epoch 103/200
# 43/43 - 67s - loss: 164.2581 - accuracy: 0.0000e+00 - mean_squared_error: 164.2581 - mean_absolute_percentage_error: 7.3329 - root_mean_squared_error: 12.8163 - val_loss: 183.5465 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 183.5465 - val_mean_absolute_percentage_error: 6.4894 - val_root_mean_squared_error: 13.5479 - 67s/epoch - 2s/step
# Epoch 104/200
# 43/43 - 66s - loss: 172.2008 - accuracy: 0.0000e+00 - mean_squared_error: 172.2008 - mean_absolute_percentage_error: 7.5083 - root_mean_squared_error: 13.1225 - val_loss: 188.9635 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 188.9635 - val_mean_absolute_percentage_error: 6.5359 - val_root_mean_squared_error: 13.7464 - 66s/epoch - 2s/step
# Epoch 105/200
# 43/43 - 67s - loss: 157.9427 - accuracy: 0.0000e+00 - mean_squared_error: 157.9427 - mean_absolute_percentage_error: 7.1646 - root_mean_squared_error: 12.5675 - val_loss: 179.0236 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 179.0236 - val_mean_absolute_percentage_error: 6.3682 - val_root_mean_squared_error: 13.3800 - 67s/epoch - 2s/step
# Epoch 106/200
# 43/43 - 65s - loss: 166.3273 - accuracy: 0.0000e+00 - mean_squared_error: 166.3273 - mean_absolute_percentage_error: 7.3372 - root_mean_squared_error: 12.8968 - val_loss: 185.6167 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 185.6167 - val_mean_absolute_percentage_error: 6.5966 - val_root_mean_squared_error: 13.6241 - 65s/epoch - 2s/step
# Epoch 107/200
# 43/43 - 67s - loss: 151.7870 - accuracy: 0.0000e+00 - mean_squared_error: 151.7870 - mean_absolute_percentage_error: 7.0395 - root_mean_squared_error: 12.3202 - val_loss: 183.7420 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 183.7420 - val_mean_absolute_percentage_error: 6.6157 - val_root_mean_squared_error: 13.5551 - 67s/epoch - 2s/step
# Epoch 108/200
# 43/43 - 68s - loss: 160.5285 - accuracy: 0.0000e+00 - mean_squared_error: 160.5285 - mean_absolute_percentage_error: 7.2399 - root_mean_squared_error: 12.6700 - val_loss: 189.5098 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 189.5098 - val_mean_absolute_percentage_error: 6.4428 - val_root_mean_squared_error: 13.7663 - 68s/epoch - 2s/step
# Epoch 109/200
# 43/43 - 66s - loss: 160.6712 - accuracy: 0.0000e+00 - mean_squared_error: 160.6712 - mean_absolute_percentage_error: 7.2085 - root_mean_squared_error: 12.6756 - val_loss: 188.3321 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 188.3321 - val_mean_absolute_percentage_error: 6.6322 - val_root_mean_squared_error: 13.7234 - 66s/epoch - 2s/step
# Epoch 110/200
# 43/43 - 68s - loss: 179.7803 - accuracy: 0.0000e+00 - mean_squared_error: 179.7803 - mean_absolute_percentage_error: 7.6478 - root_mean_squared_error: 13.4082 - val_loss: 175.9141 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 175.9141 - val_mean_absolute_percentage_error: 6.4234 - val_root_mean_squared_error: 13.2633 - 68s/epoch - 2s/step
# Epoch 111/200
# 43/43 - 69s - loss: 155.8041 - accuracy: 0.0000e+00 - mean_squared_error: 155.8041 - mean_absolute_percentage_error: 7.2078 - root_mean_squared_error: 12.4822 - val_loss: 186.3081 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 186.3081 - val_mean_absolute_percentage_error: 6.4474 - val_root_mean_squared_error: 13.6495 - 69s/epoch - 2s/step
# Epoch 112/200
# 43/43 - 68s - loss: 190.4220 - accuracy: 0.0000e+00 - mean_squared_error: 190.4220 - mean_absolute_percentage_error: 7.9308 - root_mean_squared_error: 13.7993 - val_loss: 180.6017 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 180.6017 - val_mean_absolute_percentage_error: 6.4886 - val_root_mean_squared_error: 13.4388 - 68s/epoch - 2s/step
# Epoch 113/200
# 43/43 - 67s - loss: 161.7353 - accuracy: 0.0000e+00 - mean_squared_error: 161.7353 - mean_absolute_percentage_error: 7.3976 - root_mean_squared_error: 12.7175 - val_loss: 178.1162 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 178.1162 - val_mean_absolute_percentage_error: 6.4451 - val_root_mean_squared_error: 13.3460 - 67s/epoch - 2s/step
# Epoch 114/200
# 43/43 - 65s - loss: 165.2677 - accuracy: 0.0000e+00 - mean_squared_error: 165.2677 - mean_absolute_percentage_error: 7.3676 - root_mean_squared_error: 12.8556 - val_loss: 176.9547 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 176.9547 - val_mean_absolute_percentage_error: 6.3812 - val_root_mean_squared_error: 13.3024 - 65s/epoch - 2s/step
# Epoch 115/200
# 43/43 - 66s - loss: 153.7240 - accuracy: 0.0000e+00 - mean_squared_error: 153.7240 - mean_absolute_percentage_error: 7.0875 - root_mean_squared_error: 12.3985 - val_loss: 173.5186 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 173.5186 - val_mean_absolute_percentage_error: 6.3122 - val_root_mean_squared_error: 13.1726 - 66s/epoch - 2s/step
# Epoch 116/200
# 43/43 - 67s - loss: 161.6752 - accuracy: 0.0000e+00 - mean_squared_error: 161.6752 - mean_absolute_percentage_error: 7.2181 - root_mean_squared_error: 12.7152 - val_loss: 180.0564 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 180.0564 - val_mean_absolute_percentage_error: 6.4445 - val_root_mean_squared_error: 13.4185 - 67s/epoch - 2s/step
# Epoch 117/200
# 43/43 - 66s - loss: 145.9212 - accuracy: 0.0000e+00 - mean_squared_error: 145.9212 - mean_absolute_percentage_error: 6.9164 - root_mean_squared_error: 12.0798 - val_loss: 177.3057 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 177.3057 - val_mean_absolute_percentage_error: 6.3707 - val_root_mean_squared_error: 13.3156 - 66s/epoch - 2s/step
# Epoch 118/200
# 43/43 - 66s - loss: 146.2079 - accuracy: 0.0000e+00 - mean_squared_error: 146.2079 - mean_absolute_percentage_error: 6.9074 - root_mean_squared_error: 12.0916 - val_loss: 202.7300 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 202.7300 - val_mean_absolute_percentage_error: 6.7058 - val_root_mean_squared_error: 14.2383 - 66s/epoch - 2s/step
# Epoch 119/200
# 43/43 - 68s - loss: 163.7063 - accuracy: 0.0000e+00 - mean_squared_error: 163.7063 - mean_absolute_percentage_error: 7.2776 - root_mean_squared_error: 12.7948 - val_loss: 181.9621 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 181.9621 - val_mean_absolute_percentage_error: 6.4906 - val_root_mean_squared_error: 13.4893 - 68s/epoch - 2s/step
# Epoch 120/200
# 43/43 - 66s - loss: 144.9709 - accuracy: 0.0000e+00 - mean_squared_error: 144.9709 - mean_absolute_percentage_error: 6.8686 - root_mean_squared_error: 12.0404 - val_loss: 195.2855 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 195.2855 - val_mean_absolute_percentage_error: 6.5662 - val_root_mean_squared_error: 13.9745 - 66s/epoch - 2s/step
# Epoch 121/200
# 43/43 - 65s - loss: 155.9540 - accuracy: 0.0000e+00 - mean_squared_error: 155.9540 - mean_absolute_percentage_error: 7.1249 - root_mean_squared_error: 12.4882 - val_loss: 182.7761 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 182.7761 - val_mean_absolute_percentage_error: 6.5672 - val_root_mean_squared_error: 13.5195 - 65s/epoch - 2s/step
# Epoch 122/200
# 43/43 - 66s - loss: 144.0876 - accuracy: 0.0000e+00 - mean_squared_error: 144.0876 - mean_absolute_percentage_error: 6.8667 - root_mean_squared_error: 12.0036 - val_loss: 227.9815 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 227.9815 - val_mean_absolute_percentage_error: 7.0465 - val_root_mean_squared_error: 15.0991 - 66s/epoch - 2s/step
# Epoch 123/200
# 43/43 - 65s - loss: 148.5097 - accuracy: 0.0000e+00 - mean_squared_error: 148.5097 - mean_absolute_percentage_error: 6.9600 - root_mean_squared_error: 12.1865 - val_loss: 185.7796 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 185.7796 - val_mean_absolute_percentage_error: 6.5765 - val_root_mean_squared_error: 13.6301 - 65s/epoch - 2s/step
# Epoch 124/200
# 43/43 - 65s - loss: 158.5766 - accuracy: 0.0000e+00 - mean_squared_error: 158.5766 - mean_absolute_percentage_error: 7.1763 - root_mean_squared_error: 12.5927 - val_loss: 194.5561 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 194.5561 - val_mean_absolute_percentage_error: 6.5624 - val_root_mean_squared_error: 13.9483 - 65s/epoch - 2s/step
# Epoch 125/200
# 43/43 - 66s - loss: 141.2902 - accuracy: 0.0000e+00 - mean_squared_error: 141.2902 - mean_absolute_percentage_error: 6.7011 - root_mean_squared_error: 11.8866 - val_loss: 181.9382 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 181.9382 - val_mean_absolute_percentage_error: 6.4578 - val_root_mean_squared_error: 13.4884 - 66s/epoch - 2s/step
# Epoch 126/200
# 43/43 - 65s - loss: 150.6322 - accuracy: 0.0000e+00 - mean_squared_error: 150.6322 - mean_absolute_percentage_error: 7.0161 - root_mean_squared_error: 12.2732 - val_loss: 183.0271 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 183.0271 - val_mean_absolute_percentage_error: 6.4539 - val_root_mean_squared_error: 13.5288 - 65s/epoch - 2s/step
# Epoch 127/200
# 43/43 - 66s - loss: 142.2967 - accuracy: 0.0000e+00 - mean_squared_error: 142.2967 - mean_absolute_percentage_error: 6.8437 - root_mean_squared_error: 11.9288 - val_loss: 178.2871 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 178.2871 - val_mean_absolute_percentage_error: 6.4428 - val_root_mean_squared_error: 13.3524 - 66s/epoch - 2s/step
# Epoch 128/200
# 43/43 - 65s - loss: 140.2908 - accuracy: 0.0000e+00 - mean_squared_error: 140.2908 - mean_absolute_percentage_error: 6.7326 - root_mean_squared_error: 11.8444 - val_loss: 188.1399 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 188.1399 - val_mean_absolute_percentage_error: 6.6296 - val_root_mean_squared_error: 13.7164 - 65s/epoch - 2s/step
# Epoch 129/200
# 43/43 - 66s - loss: 160.3963 - accuracy: 0.0000e+00 - mean_squared_error: 160.3963 - mean_absolute_percentage_error: 7.3031 - root_mean_squared_error: 12.6648 - val_loss: 184.7349 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 184.7349 - val_mean_absolute_percentage_error: 6.5769 - val_root_mean_squared_error: 13.5917 - 66s/epoch - 2s/step
# Epoch 130/200
# 43/43 - 66s - loss: 146.9067 - accuracy: 0.0000e+00 - mean_squared_error: 146.9067 - mean_absolute_percentage_error: 6.9334 - root_mean_squared_error: 12.1205 - val_loss: 185.0032 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 185.0032 - val_mean_absolute_percentage_error: 6.4514 - val_root_mean_squared_error: 13.6016 - 66s/epoch - 2s/step
# Epoch 131/200
# 43/43 - 66s - loss: 145.9103 - accuracy: 0.0000e+00 - mean_squared_error: 145.9103 - mean_absolute_percentage_error: 6.8260 - root_mean_squared_error: 12.0793 - val_loss: 191.0648 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 191.0648 - val_mean_absolute_percentage_error: 6.6927 - val_root_mean_squared_error: 13.8226 - 66s/epoch - 2s/step
# Epoch 132/200
# 43/43 - 66s - loss: 139.2327 - accuracy: 0.0000e+00 - mean_squared_error: 139.2327 - mean_absolute_percentage_error: 6.6970 - root_mean_squared_error: 11.7997 - val_loss: 210.3187 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 210.3187 - val_mean_absolute_percentage_error: 6.7378 - val_root_mean_squared_error: 14.5024 - 66s/epoch - 2s/step
# Epoch 133/200
# ...
# Epoch 188/200
# 43/43 - 68s - loss: 118.9688 - accuracy: 0.0000e+00 - mean_squared_error: 118.9688 - mean_absolute_percentage_error: 6.1326 - root_mean_squared_error: 10.9073 - val_loss: 203.9803 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 203.9803 - val_mean_absolute_percentage_error: 6.5614 - val_root_mean_squared_error: 14.2822 - 68s/epoch - 2s/step
# Epoch 189/200
# 43/43 - 68s - loss: 108.3583 - accuracy: 0.0000e+00 - mean_squared_error: 108.3583 - mean_absolute_percentage_error: 5.8215 - root_mean_squared_error: 10.4095 - val_loss: 228.8465 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 228.8465 - val_mean_absolute_percentage_error: 6.8881 - val_root_mean_squared_error: 15.1277 - 68s/epoch - 2s/step
# Epoch 190/200
# 43/43 - 67s - loss: 117.9456 - accuracy: 0.0000e+00 - mean_squared_error: 117.9456 - mean_absolute_percentage_error: 6.0997 - root_mean_squared_error: 10.8603 - val_loss: 182.4993 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 182.4993 - val_mean_absolute_percentage_error: 6.2750 - val_root_mean_squared_error: 13.5092 - 67s/epoch - 2s/step
# Epoch 191/200
# 43/43 - 65s - loss: 113.0899 - accuracy: 0.0000e+00 - mean_squared_error: 113.0899 - mean_absolute_percentage_error: 6.0444 - root_mean_squared_error: 10.6344 - val_loss: 226.1847 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 226.1847 - val_mean_absolute_percentage_error: 6.8470 - val_root_mean_squared_error: 15.0394 - 65s/epoch - 2s/step
# Epoch 192/200
# 43/43 - 68s - loss: 111.0651 - accuracy: 0.0000e+00 - mean_squared_error: 111.0651 - mean_absolute_percentage_error: 5.8583 - root_mean_squared_error: 10.5387 - val_loss: 198.3289 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 198.3289 - val_mean_absolute_percentage_error: 6.4133 - val_root_mean_squared_error: 14.0829 - 68s/epoch - 2s/step
# Epoch 193/200
# 43/43 - 66s - loss: 104.0578 - accuracy: 0.0000e+00 - mean_squared_error: 104.0578 - mean_absolute_percentage_error: 5.6828 - root_mean_squared_error: 10.2009 - val_loss: 232.9113 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 232.9113 - val_mean_absolute_percentage_error: 6.8839 - val_root_mean_squared_error: 15.2614 - 66s/epoch - 2s/step
# Epoch 194/200
# 43/43 - 67s - loss: 113.7170 - accuracy: 0.0000e+00 - mean_squared_error: 113.7170 - mean_absolute_percentage_error: 6.0429 - root_mean_squared_error: 10.6638 - val_loss: 189.7520 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 189.7520 - val_mean_absolute_percentage_error: 6.4164 - val_root_mean_squared_error: 13.7751 - 67s/epoch - 2s/step
# Epoch 195/200
# 43/43 - 66s - loss: 103.6880 - accuracy: 0.0000e+00 - mean_squared_error: 103.6880 - mean_absolute_percentage_error: 5.7258 - root_mean_squared_error: 10.1827 - val_loss: 210.5622 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 210.5622 - val_mean_absolute_percentage_error: 6.6369 - val_root_mean_squared_error: 14.5108 - 66s/epoch - 2s/step
# Epoch 196/200
# 43/43 - 66s - loss: 123.8876 - accuracy: 0.0000e+00 - mean_squared_error: 123.8876 - mean_absolute_percentage_error: 6.2968 - root_mean_squared_error: 11.1305 - val_loss: 191.9339 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 191.9339 - val_mean_absolute_percentage_error: 6.5536 - val_root_mean_squared_error: 13.8540 - 66s/epoch - 2s/step
# Epoch 197/200
# 43/43 - 68s - loss: 111.3966 - accuracy: 0.0000e+00 - mean_squared_error: 111.3966 - mean_absolute_percentage_error: 5.9557 - root_mean_squared_error: 10.5545 - val_loss: 204.3881 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 204.3881 - val_mean_absolute_percentage_error: 6.5753 - val_root_mean_squared_error: 14.2964 - 68s/epoch - 2s/step
# Epoch 198/200
# 43/43 - 66s - loss: 120.7147 - accuracy: 0.0000e+00 - mean_squared_error: 120.7147 - mean_absolute_percentage_error: 6.1573 - root_mean_squared_error: 10.9870 - val_loss: 212.9915 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 212.9915 - val_mean_absolute_percentage_error: 6.5928 - val_root_mean_squared_error: 14.5942 - 66s/epoch - 2s/step
# Epoch 199/200
# 43/43 - 65s - loss: 112.9250 - accuracy: 0.0000e+00 - mean_squared_error: 112.9250 - mean_absolute_percentage_error: 6.0231 - root_mean_squared_error: 10.6266 - val_loss: 184.1621 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 184.1621 - val_mean_absolute_percentage_error: 6.3059 - val_root_mean_squared_error: 13.5706 - 65s/epoch - 2s/step
# Epoch 200/200
# 43/43 - 67s - loss: 116.3215 - accuracy: 0.0000e+00 - mean_squared_error: 116.3215 - mean_absolute_percentage_error: 6.0888 - root_mean_squared_error: 10.7852 - val_loss: 194.0914 - val_accuracy: 0.0000e+00 - val_mean_squared_error: 194.0914 - val_mean_absolute_percentage_error: 6.3936 - val_root_mean_squared_error: 13.9317 - 67s/epoch - 2s/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 5457, 16)]           0         []
#
#  conv1d (Conv1D)             (None, 5457, 80)             2640      ['input_1[0][0]']
#
#  conv1d_3 (Conv1D)           (None, 5457, 64)             2112      ['input_1[0][0]']
#
#  conv1d_6 (Conv1D)           (None, 5457, 32)             1056      ['input_1[0][0]']
#
#  conv1d_9 (Conv1D)           (None, 5457, 16)             528       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 5457, 80)             12880     ['conv1d[0][0]']
#
#  conv1d_4 (Conv1D)           (None, 5457, 64)             8256      ['conv1d_3[0][0]']
#
#  conv1d_7 (Conv1D)           (None, 5457, 32)             2080      ['conv1d_6[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 5457, 16)             528       ['conv1d_9[0][0]']
#
#  batch_normalization (Batch  (None, 5457, 80)             320       ['conv1d_1[0][0]']
#  Normalization)
#
#  batch_normalization_2 (Bat  (None, 5457, 64)             256       ['conv1d_4[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 5457, 32)             128       ['conv1d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 5457, 16)             64        ['conv1d_10[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 5457, 80)             0         ['batch_normalization[0][0]']
#
#  activation_2 (Activation)   (None, 5457, 64)             0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  activation_4 (Activation)   (None, 5457, 32)             0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  activation_6 (Activation)   (None, 5457, 16)             0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_2 (Conv1D)           (None, 5457, 80)             12880     ['activation[0][0]']
#
#  conv1d_5 (Conv1D)           (None, 5457, 64)             8256      ['activation_2[0][0]']
#
#  conv1d_8 (Conv1D)           (None, 5457, 32)             2080      ['activation_4[0][0]']
#
#  conv1d_11 (Conv1D)          (None, 5457, 16)             528       ['activation_6[0][0]']
#
#  batch_normalization_1 (Bat  (None, 5457, 80)             320       ['conv1d_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 5457, 64)             256       ['conv1d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 5457, 32)             128       ['conv1d_8[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 5457, 16)             64        ['conv1d_11[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 5457, 80)             0         ['batch_normalization_1[0][0]'
#                                                                     , 'conv1d[0][0]']
#
#  add_1 (Add)                 (None, 5457, 64)             0         ['batch_normalization_3[0][0]'
#                                                                     , 'conv1d_3[0][0]']
#
#  add_2 (Add)                 (None, 5457, 32)             0         ['batch_normalization_5[0][0]'
#                                                                     , 'conv1d_6[0][0]']
#
#  add_3 (Add)                 (None, 5457, 16)             0         ['batch_normalization_7[0][0]'
#                                                                     , 'conv1d_9[0][0]']
#
#  activation_1 (Activation)   (None, 5457, 80)             0         ['add[0][0]']
#
#  activation_3 (Activation)   (None, 5457, 64)             0         ['add_1[0][0]']
#
#  activation_5 (Activation)   (None, 5457, 32)             0         ['add_2[0][0]']
#
#  activation_7 (Activation)   (None, 5457, 16)             0         ['add_3[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 42, 80)               0         ['activation_1[0][0]']
#  D)
#
#  max_pooling1d_1 (MaxPoolin  (None, 42, 64)               0         ['activation_3[0][0]']
#  g1D)
#
#  max_pooling1d_2 (MaxPoolin  (None, 42, 32)               0         ['activation_5[0][0]']
#  g1D)
#
#  max_pooling1d_3 (MaxPoolin  (None, 42, 16)               0         ['activation_7[0][0]']
#  g1D)
#
#  concatenate (Concatenate)   (None, 42, 192)              0         ['max_pooling1d[0][0]',
#                                                                      'max_pooling1d_1[0][0]',
#                                                                      'max_pooling1d_2[0][0]',
#                                                                      'max_pooling1d_3[0][0]']
#
#  dense (Dense)               (None, 42, 16)               3088      ['concatenate[0][0]']
#
#  flatten (Flatten)           (None, 672)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    673       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 59121 (230.94 KB)
# Trainable params: 58353 (227.94 KB)
# Non-trainable params: 768 (3.00 KB)
# __________________________________________________________________________________________________
# 21/21 [==============================] - 7s 261ms/step
# Test Loss: [177.6806]
# Test Mean Squared Error: [91.00498]
# Test Mean Absolute Percentage Error: [150.87584]
# Test Root Mean Squared Error: [190.52249]

# %%
results = model.evaluate(test_dataset, batch_size=64)
# Out:
# 21/21 [==============================] - 6s 268ms/step - loss: 194.0914 - accuracy: 0.0000e+00 - mean_squared_error: 194.0914 - mean_absolute_percentage_error: 6.3936 - root_mean_squared_error: 13.9317

# %%
import tensorflow as tf
import numpy as np

# 重置数据集
def create_test_dataset(X_test_norm, y_test):
    return tf.data.Dataset.from_tensor_slices((X_test_norm, y_test.T)).batch(64)

# 创建测试数据集
test_dataset = create_test_dataset(X_test_norm, y_test)

# EVALUATE model with TESTING DATA
results = model.evaluate(test_dataset, verbose=0)
print(f'Test Loss: {results[0]}')
print(f'Test Mean Squared Error: {results[1]}')
print(f'Test Mean Absolute Percentage Error: {results[2]}')
print(f'Test Root Mean Squared Error: {results[3]}')

# PREDICT with TESTING DATA
ynew = model.predict(test_dataset)

# 重置测试数据集
test_dataset = create_test_dataset(X_test_norm, y_test)

# EVALUATE model again with TESTING DATA
results = model.evaluate(test_dataset, batch_size=64)
print(f'loss: {results[0]} - accuracy: {results[1]} - mean_squared_error: {results[2]} - mean_absolute_percentage_error: {results[3]} - root_mean_squared_error: {results[4]}')
# Out:
# Test Loss: 194.09136962890625
# Test Mean Squared Error: 0.0
# Test Mean Absolute Percentage Error: 194.09136962890625
# Test Root Mean Squared Error: 6.393553256988525
# 11/11 [==============================] - 6s 551ms/step
# 11/11 [==============================] - 6s 540ms/step - loss: 194.0914 - accuracy: 0.0000e+00 - mean_squared_error: 194.0914 - mean_absolute_percentage_error: 6.3936 - root_mean_squared_error: 13.9317
# loss: 194.09136962890625 - accuracy: 0.0 - mean_squared_error: 194.09136962890625 - mean_absolute_percentage_error: 6.393553256988525 - root_mean_squared_error: 13.931668281555176

# %%
# plt.figure()
# plt.title('Loss (Mean Squared Error)')
# plt.plot(history.history['loss'])
# plt.figure()
# plt.title('Accuracy')
# plt.plot(history.history['accuracy'])
# plt.figure()
# plt.title('Mean Squared Error')
# plt.plot(history.history['mean_squared_error'])
# plt.figure()
fig, ax = plt.subplots()
ax.set_title('Training and Validation \n Mean Squared Error') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['loss'], color = 'blue', label = 'train')
# plt.figure()
## Validation Plots
# plt.title('Validation Loss (MSE)') # loss = 100 * abs(y_true - y_pred) / y_true
# plt.plot(history.history['val_loss'])
# plt.figure()

# plt.title('Validation Mean Absolute Percentage Error (MAPE)') # loss = 100 * abs(y_true - y_pred) / y_true
ax.plot(history.history['val_loss'], color = 'orange', label = 'val')
ax.semilogy((0,50))
ax.legend()
# plt.figure()
